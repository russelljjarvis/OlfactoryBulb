# %%
import os; os.chdir("..");
import multiprocessing
from prev_ob_models.Birgiolas2020.fitting import *
# Out:
# /home/justas/anaconda2/envs/p27/lib/python2.7/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Could not load NEURONBackend

# %%
import sys
cell_id = sys.argv[1] if len(sys.argv) > 1 and sys.argv[1].isdigit() else 5
print(cell_id)
# Out:
# 5

# %%
fitter = CellFitter(cell_type="gc", fitting_model_class="prev_ob_models.Birgiolas2020.isolated_cells.GC"+str(cell_id))
# Out:
# ('Starting gc FITTER for model:', 'prev_ob_models.Birgiolas2020.isolated_cells.GC5')

# %%
fitter.clear_cache()
#fitter.top = [[0.518568993696911, 22.331096575385537, 3.9991551066170175, 44.54836939907614, -55.16528090080958, -89.29463560245307, 0.00018368809366833735, 2.922232364299777, 0.07465156310126753, 0.19498287109045842, 0.03935002363776688, -49.39660394446575, 2.548528534052994e-06, 0.006660630409332343]]
fitter.fit(25, 200)
raise
# Out:
# ('STARTED GEN', 'ZERO', 'size', 25)
# ('DONE with', 1, 'of', 25, 'of GEN', 'ZERO', 'with Fitness', '48.64')
# ('DONE with', 2, 'of', 25, 'of GEN', 'ZERO', 'with Fitness', '15.01')
# ('DONE with', 3, 'of', 25, 'of GEN', 'ZERO', 'with Fitness', '1034.68')
# ('DONE with', 4, 'of', 25, 'of GEN', 'ZERO', 'with Fitness', '15.60')
# ('DONE with', 5, 'of', 25, 'of GEN', 'ZERO', 'with Fitness', '35.74')
# ('DONE with', 6, 'of', 25, 'of GEN', 'ZERO', 'with Fitness', '14.29')
# ('DONE with', 7, 'of', 25, 'of GEN', 'ZERO', 'with Fitness', '14.40')
# ('DONE with', 8, 'of', 25, 'of GEN', 'ZERO', 'with Fitness', '41.25')
# ('DONE with', 9, 'of', 25, 'of GEN', 'ZERO', 'with Fitness', '24.36')
# ('DONE with', 10, 'of', 25, 'of GEN', 'ZERO', 'with Fitness', '16.02')
# ('DONE with', 11, 'of', 25, 'of GEN', 'ZERO', 'with Fitness', '43.29')
# ('DONE with', 12, 'of', 25, 'of GEN', 'ZERO', 'with Fitness', '17.52')
# ('DONE with', 13, 'of', 25, 'of GEN', 'ZERO', 'with Fitness', '39.09')
# ('DONE with', 14, 'of', 25, 'of GEN', 'ZERO', 'with Fitness', '20.39')
# ('DONE with', 15, 'of', 25, 'of GEN', 'ZERO', 'with Fitness', '31.80')
# ('DONE with', 16, 'of', 25, 'of GEN', 'ZERO', 'with Fitness', '7.40')
# ('DONE with', 17, 'of', 25, 'of GEN', 'ZERO', 'with Fitness', '21.48')
# ('DONE with', 18, 'of', 25, 'of GEN', 'ZERO', 'with Fitness', '31.74')
# ('DONE with', 19, 'of', 25, 'of GEN', 'ZERO', 'with Fitness', '31.52')
# ('DONE with', 20, 'of', 25, 'of GEN', 'ZERO', 'with Fitness', '7.17')
# ('DONE with', 21, 'of', 25, 'of GEN', 'ZERO', 'with Fitness', '12.50')
# ('DONE with', 22, 'of', 25, 'of GEN', 'ZERO', 'with Fitness', '208.74')
# ('DONE with', 23, 'of', 25, 'of GEN', 'ZERO', 'with Fitness', '11.21')
# ('DONE with', 24, 'of', 25, 'of GEN', 'ZERO', 'with Fitness', '16.99')
# ('DONE with', 25, 'of', 25, 'of GEN', 'ZERO', 'with Fitness', '18.58')
# ('GEN', 1, 'Parents', 5, 'Elite', 13, 'DIV', 6, 'RND', 6, 'TOT NEW', 25)
# ('STARTED GEN', '1', 'size', 25)
# ('DONE with', 1, 'of', 25, 'of GEN', '1', 'with Fitness', '20.27')
# ('DONE with', 2, 'of', 25, 'of GEN', '1', 'with Fitness', '69.21')
# ('DONE with', 3, 'of', 25, 'of GEN', '1', 'with Fitness', '14.97')
# ('DONE with', 4, 'of', 25, 'of GEN', '1', 'with Fitness', '15.26')
# ('DONE with', 5, 'of', 25, 'of GEN', '1', 'with Fitness', '117.69')
# ('DONE with', 6, 'of', 25, 'of GEN', '1', 'with Fitness', '50.11')
# ('DONE with', 7, 'of', 25, 'of GEN', '1', 'with Fitness', '19.49')
# ('DONE with', 8, 'of', 25, 'of GEN', '1', 'with Fitness', '17.31')
# ('DONE with', 9, 'of', 25, 'of GEN', '1', 'with Fitness', '19.14')
# ('DONE with', 10, 'of', 25, 'of GEN', '1', 'with Fitness', '10.51')
# ('DONE with', 11, 'of', 25, 'of GEN', '1', 'with Fitness', '17.02')
# ('DONE with', 12, 'of', 25, 'of GEN', '1', 'with Fitness', '151.33')
# ('DONE with', 13, 'of', 25, 'of GEN', '1', 'with Fitness', '8.48')
# ('DONE with', 14, 'of', 25, 'of GEN', '1', 'with Fitness', '57.85')
# ('DONE with', 15, 'of', 25, 'of GEN', '1', 'with Fitness', '42.05')
# ('DONE with', 16, 'of', 25, 'of GEN', '1', 'with Fitness', '15.28')
# ('DONE with', 17, 'of', 25, 'of GEN', '1', 'with Fitness', '13.74')
# ('DONE with', 18, 'of', 25, 'of GEN', '1', 'with Fitness', '28.96')
# ('DONE with', 19, 'of', 25, 'of GEN', '1', 'with Fitness', '16.16')
# ('DONE with', 20, 'of', 25, 'of GEN', '1', 'with Fitness', '16.87')
# ('DONE with', 21, 'of', 25, 'of GEN', '1', 'with Fitness', '19.50')
# ('DONE with', 22, 'of', 25, 'of GEN', '1', 'with Fitness', '6.96')
# ('DONE with', 23, 'of', 25, 'of GEN', '1', 'with Fitness', '35.61')
# ('DONE with', 24, 'of', 25, 'of GEN', '1', 'with Fitness', '42.99')
# ('DONE with', 25, 'of', 25, 'of GEN', '1', 'with Fitness', '7.14')
# ('Generation', 1, 'out of', 200, 'COMPLETE')
# ('Best fitness:', 6.960385744242177)
# ('Best individual', [0.945630435639413, 111.10755772310617, 3.553334302331439, 32.31565349228474, -49.50647388390325, -78.74188810848844, 0.0002748438736330845, 7.394243997915121, 0.05948243010641981, 0.14387331212161794, 0.0868440283641541, -54.78869053050586, 3.475632058708355e-05, 0.024391455262029356])
# 29.16% of range. Val: 0.945630435639 Low: 0.1 High: 3.0 ATTR: diam in ['apical']
# 92.27% of range. Val: 111.107557723 Low: 5.0 High: 120.0 ATTR: Ra in ['all']
# 34.88% of range. Val: 3.55333430233 Low: 0.1 High: 10.0 ATTR: cm in ['all']
# 55.79% of range. Val: 32.3156534923 Low: 10.0 High: 50.0 ATTR: ena in ['all']
# 72.13% of range. Val: -49.5064738839 Low: -100.0 High: -30.0 ATTR: ek in ['all']
# 42.52% of range. Val: -78.7418881085 Low: -100.0 High: -50.0 ATTR: e_pas in ['all']
# 13.74% of range. Val: 0.000274843873633 Low: 0 High: 0.002 ATTR: g_pas in ['all']
# 73.94% of range. Val: 7.39424399792 Low: 0 High: 10 ATTR: sh_Na in ['all']
# 59.48% of range. Val: 0.0594824301064 Low: 0 High: 0.1 ATTR: gbar_Na in ['all']
# 35.97% of range. Val: 0.143873312122 Low: 0 High: 0.4 ATTR: gbar_Kd in ['all']
# 21.71% of range. Val: 0.0868440283642 Low: 0 High: 0.4 ATTR: gbar_KA in ['somatic']
# 10.42% of range. Val: -54.7886905305 Low: -60.0 High: -10.0 ATTR: eh in ['somatic']
# 34.76% of range. Val: 3.47563205871e-05 Low: 0 High: 0.0001 ATTR: gbar_Ih in ['somatic']
# 18.76% of range. Val: 0.024391455262 Low: 0 High: 0.13 ATTR: gbar_KM in ['somatic']
# ('GEN', 2, 'Parents', 5, 'Elite', 13, 'DIV', 6, 'RND', 6, 'TOT NEW', 25)
# ('STARTED GEN', '2', 'size', 25)
# ('DONE with', 1, 'of', 25, 'of GEN', '2', 'with Fitness', '37.45')
# ('DONE with', 2, 'of', 25, 'of GEN', '2', 'with Fitness', '30.26')
# ('DONE with', 3, 'of', 25, 'of GEN', '2', 'with Fitness', '11.68')
# ('DONE with', 4, 'of', 25, 'of GEN', '2', 'with Fitness', '29.58')
# ('DONE with', 5, 'of', 25, 'of GEN', '2', 'with Fitness', '58.03')
# ('DONE with', 6, 'of', 25, 'of GEN', '2', 'with Fitness', '7.96')
# ('DONE with', 7, 'of', 25, 'of GEN', '2', 'with Fitness', '28.93')
# ('DONE with', 8, 'of', 25, 'of GEN', '2', 'with Fitness', '12.76')
# ('DONE with', 9, 'of', 25, 'of GEN', '2', 'with Fitness', '8.50')
# ('DONE with', 10, 'of', 25, 'of GEN', '2', 'with Fitness', '16.77')
# ('DONE with', 11, 'of', 25, 'of GEN', '2', 'with Fitness', '13.08')
# ('DONE with', 12, 'of', 25, 'of GEN', '2', 'with Fitness', '28.30')
# ('DONE with', 13, 'of', 25, 'of GEN', '2', 'with Fitness', '17.28')
# ('DONE with', 14, 'of', 25, 'of GEN', '2', 'with Fitness', '20.25')
# ('DONE with', 15, 'of', 25, 'of GEN', '2', 'with Fitness', '16.49')
# ('DONE with', 16, 'of', 25, 'of GEN', '2', 'with Fitness', '19.77')
# ('DONE with', 17, 'of', 25, 'of GEN', '2', 'with Fitness', '14.54')
# ('DONE with', 18, 'of', 25, 'of GEN', '2', 'with Fitness', '7.40')
# ('DONE with', 19, 'of', 25, 'of GEN', '2', 'with Fitness', '12.97')
# ('DONE with', 20, 'of', 25, 'of GEN', '2', 'with Fitness', '18.95')
# ('DONE with', 21, 'of', 25, 'of GEN', '2', 'with Fitness', '14.97')
# ('DONE with', 22, 'of', 25, 'of GEN', '2', 'with Fitness', '12.97')
# ('DONE with', 23, 'of', 25, 'of GEN', '2', 'with Fitness', '8.11')
# ('DONE with', 2, 'of', 25, 'of GEN', '2', 'with Fitness', '30.26')
# ('DONE with', 24, 'of', 25, 'of GEN', '2', 'with Fitness', '61.75')
# ('DONE with', 25, 'of', 25, 'of GEN', '2', 'with Fitness', '10.51')
# ('Generation', 2, 'out of', 200, 'COMPLETE')
# ('Best fitness:', 6.960385744242177)
# ('Best individual', [0.945630435639413, 111.10755772310617, 3.553334302331439, 32.31565349228474, -49.50647388390325, -78.74188810848844, 0.0002748438736330845, 7.394243997915121, 0.05948243010641981, 0.14387331212161794, 0.0868440283641541, -54.78869053050586, 3.475632058708355e-05, 0.024391455262029356])
# 29.16% of range. Val: 0.945630435639 Low: 0.1 High: 3.0 ATTR: diam in ['apical']
# 92.27% of range. Val: 111.107557723 Low: 5.0 High: 120.0 ATTR: Ra in ['all']
# 34.88% of range. Val: 3.55333430233 Low: 0.1 High: 10.0 ATTR: cm in ['all']
# 55.79% of range. Val: 32.3156534923 Low: 10.0 High: 50.0 ATTR: ena in ['all']
# 72.13% of range. Val: -49.5064738839 Low: -100.0 High: -30.0 ATTR: ek in ['all']
# 42.52% of range. Val: -78.7418881085 Low: -100.0 High: -50.0 ATTR: e_pas in ['all']
# 13.74% of range. Val: 0.000274843873633 Low: 0 High: 0.002 ATTR: g_pas in ['all']
# 73.94% of range. Val: 7.39424399792 Low: 0 High: 10 ATTR: sh_Na in ['all']
# 59.48% of range. Val: 0.0594824301064 Low: 0 High: 0.1 ATTR: gbar_Na in ['all']
# 35.97% of range. Val: 0.143873312122 Low: 0 High: 0.4 ATTR: gbar_Kd in ['all']
# 21.71% of range. Val: 0.0868440283642 Low: 0 High: 0.4 ATTR: gbar_KA in ['somatic']
# 10.42% of range. Val: -54.7886905305 Low: -60.0 High: -10.0 ATTR: eh in ['somatic']
# 34.76% of range. Val: 3.47563205871e-05 Low: 0 High: 0.0001 ATTR: gbar_Ih in ['somatic']
# 18.76% of range. Val: 0.024391455262 Low: 0 High: 0.13 ATTR: gbar_KM in ['somatic']
# ('GEN', 3, 'Parents', 5, 'Elite', 13, 'DIV', 6, 'RND', 6, 'TOT NEW', 25)
# ('STARTED GEN', '3', 'size', 25)
# ('DONE with', 1, 'of', 25, 'of GEN', '3', 'with Fitness', '46.87')
# ('DONE with', 2, 'of', 25, 'of GEN', '3', 'with Fitness', '7.69')
# ('DONE with', 3, 'of', 25, 'of GEN', '3', 'with Fitness', '11.66')
# ('DONE with', 4, 'of', 25, 'of GEN', '3', 'with Fitness', '23.42')
# ('DONE with', 5, 'of', 25, 'of GEN', '3', 'with Fitness', '17.06')
# ('DONE with', 6, 'of', 25, 'of GEN', '3', 'with Fitness', '33.31')
# ('DONE with', 7, 'of', 25, 'of GEN', '3', 'with Fitness', '26.78')
# ('DONE with', 8, 'of', 25, 'of GEN', '3', 'with Fitness', '61.69')
# ('DONE with', 9, 'of', 25, 'of GEN', '3', 'with Fitness', '13.43')
# ('DONE with', 10, 'of', 25, 'of GEN', '3', 'with Fitness', '19.81')
# ('DONE with', 11, 'of', 25, 'of GEN', '3', 'with Fitness', '15.21')
# ('DONE with', 12, 'of', 25, 'of GEN', '3', 'with Fitness', '21.52')
# ('DONE with', 13, 'of', 25, 'of GEN', '3', 'with Fitness', '30.17')
# ('DONE with', 14, 'of', 25, 'of GEN', '3', 'with Fitness', '15.20')
# ('DONE with', 15, 'of', 25, 'of GEN', '3', 'with Fitness', '7.40')
# ('DONE with', 16, 'of', 25, 'of GEN', '3', 'with Fitness', '13.11')
# ('DONE with', 17, 'of', 25, 'of GEN', '3', 'with Fitness', '14.93')
# ('DONE with', 18, 'of', 25, 'of GEN', '3', 'with Fitness', '15.68')
# ('DONE with', 19, 'of', 25, 'of GEN', '3', 'with Fitness', '10.34')
# ('DONE with', 20, 'of', 25, 'of GEN', '3', 'with Fitness', '15.03')
# ('DONE with', 21, 'of', 25, 'of GEN', '3', 'with Fitness', '8.34')
# ('DONE with', 22, 'of', 25, 'of GEN', '3', 'with Fitness', '49.16')
# ('DONE with', 23, 'of', 25, 'of GEN', '3', 'with Fitness', '7.14')
# ('DONE with', 24, 'of', 25, 'of GEN', '3', 'with Fitness', '15.00')
# ('DONE with', 25, 'of', 25, 'of GEN', '3', 'with Fitness', '6.96')
# ('Generation', 3, 'out of', 200, 'COMPLETE')
# ('Best fitness:', 6.960385744242177)
# ('Best individual', [0.945630435639413, 111.10755772310617, 3.553334302331439, 32.31565349228474, -49.50647388390325, -78.74188810848844, 0.0002748438736330845, 7.394243997915121, 0.05948243010641981, 0.14387331212161794, 0.0868440283641541, -54.78869053050586, 3.475632058708355e-05, 0.024391455262029356])
# 29.16% of range. Val: 0.945630435639 Low: 0.1 High: 3.0 ATTR: diam in ['apical']
# 92.27% of range. Val: 111.107557723 Low: 5.0 High: 120.0 ATTR: Ra in ['all']
# 34.88% of range. Val: 3.55333430233 Low: 0.1 High: 10.0 ATTR: cm in ['all']
# 55.79% of range. Val: 32.3156534923 Low: 10.0 High: 50.0 ATTR: ena in ['all']
# 72.13% of range. Val: -49.5064738839 Low: -100.0 High: -30.0 ATTR: ek in ['all']
# 42.52% of range. Val: -78.7418881085 Low: -100.0 High: -50.0 ATTR: e_pas in ['all']
# 13.74% of range. Val: 0.000274843873633 Low: 0 High: 0.002 ATTR: g_pas in ['all']
# 73.94% of range. Val: 7.39424399792 Low: 0 High: 10 ATTR: sh_Na in ['all']
# 59.48% of range. Val: 0.0594824301064 Low: 0 High: 0.1 ATTR: gbar_Na in ['all']
# 35.97% of range. Val: 0.143873312122 Low: 0 High: 0.4 ATTR: gbar_Kd in ['all']
# 21.71% of range. Val: 0.0868440283642 Low: 0 High: 0.4 ATTR: gbar_KA in ['somatic']
# 10.42% of range. Val: -54.7886905305 Low: -60.0 High: -10.0 ATTR: eh in ['somatic']
# 34.76% of range. Val: 3.47563205871e-05 Low: 0 High: 0.0001 ATTR: gbar_Ih in ['somatic']
# 18.76% of range. Val: 0.024391455262 Low: 0 High: 0.13 ATTR: gbar_KM in ['somatic']
# ('GEN', 4, 'Parents', 5, 'Elite', 13, 'DIV', 6, 'RND', 6, 'TOT NEW', 25)
# ('STARTED GEN', '4', 'size', 25)
# ('DONE with', 1, 'of', 25, 'of GEN', '4', 'with Fitness', '34.83')
# ('DONE with', 2, 'of', 25, 'of GEN', '4', 'with Fitness', '106.20')
# ('DONE with', 3, 'of', 25, 'of GEN', '4', 'with Fitness', '38.99')
# ('DONE with', 4, 'of', 25, 'of GEN', '4', 'with Fitness', '37.28')
# ('DONE with', 5, 'of', 25, 'of GEN', '4', 'with Fitness', '74.97')
# ('DONE with', 6, 'of', 25, 'of GEN', '4', 'with Fitness', '166.28')
# ('DONE with', 7, 'of', 25, 'of GEN', '4', 'with Fitness', '16.14')
# ('DONE with', 1, 'of', 25, 'of GEN', '4', 'with Fitness', '34.83')
# ('DONE with', 2, 'of', 25, 'of GEN', '4', 'with Fitness', '106.20')
# ('DONE with', 3, 'of', 25, 'of GEN', '4', 'with Fitness', '38.99')
# ('DONE with', 4, 'of', 25, 'of GEN', '4', 'with Fitness', '37.28')
# ('DONE with', 5, 'of', 25, 'of GEN', '4', 'with Fitness', '74.97')
# ('DONE with', 6, 'of', 25, 'of GEN', '4', 'with Fitness', '166.28')
# ('DONE with', 8, 'of', 25, 'of GEN', '4', 'with Fitness', '5.64')
# ('DONE with', 9, 'of', 25, 'of GEN', '4', 'with Fitness', '13.12')
# ('DONE with', 10, 'of', 25, 'of GEN', '4', 'with Fitness', '16.23')
# ('DONE with', 11, 'of', 25, 'of GEN', '4', 'with Fitness', '21.54')
# ('DONE with', 12, 'of', 25, 'of GEN', '4', 'with Fitness', '29.13')
# ('DONE with', 13, 'of', 25, 'of GEN', '4', 'with Fitness', '7.15')
# ('DONE with', 14, 'of', 25, 'of GEN', '4', 'with Fitness', '6.96')
# ('DONE with', 15, 'of', 25, 'of GEN', '4', 'with Fitness', '7.03')
# ('DONE with', 16, 'of', 25, 'of GEN', '4', 'with Fitness', '14.95')
# ('DONE with', 17, 'of', 25, 'of GEN', '4', 'with Fitness', '15.08')
# ('DONE with', 18, 'of', 25, 'of GEN', '4', 'with Fitness', '13.28')
# ('DONE with', 19, 'of', 25, 'of GEN', '4', 'with Fitness', '7.14')
# ('DONE with', 20, 'of', 25, 'of GEN', '4', 'with Fitness', '7.14')
# ('DONE with', 21, 'of', 25, 'of GEN', '4', 'with Fitness', '9.44')
# ('DONE with', 22, 'of', 25, 'of GEN', '4', 'with Fitness', '15.00')
# ('DONE with', 23, 'of', 25, 'of GEN', '4', 'with Fitness', '10.23')
# ('DONE with', 24, 'of', 25, 'of GEN', '4', 'with Fitness', '6.94')
# ('DONE with', 25, 'of', 25, 'of GEN', '4', 'with Fitness', '7.14')
# ('Generation', 4, 'out of', 200, 'COMPLETE')
# ('Best fitness:', 5.637756035582147)
# ('Best individual', [0.7563200529638154, 92.09606569098322, 5.512629167837416, 49.01437227637376, -51.66992761855848, -78.74188810848844, 0.000280091359574945, 7.394243997915121, 0.08138934971943226, 0.1723498842857927, 0.08975084878394496, -54.78869053050586, 3.475632058708355e-05, 0.024391455262029356])
# 22.63% of range. Val: 0.756320052964 Low: 0.1 High: 3.0 ATTR: diam in ['apical']
# 75.74% of range. Val: 92.096065691 Low: 5.0 High: 120.0 ATTR: Ra in ['all']
# 54.67% of range. Val: 5.51262916784 Low: 0.1 High: 10.0 ATTR: cm in ['all']
# 97.54% of range. Val: 49.0143722764 Low: 10.0 High: 50.0 ATTR: ena in ['all']
# 69.04% of range. Val: -51.6699276186 Low: -100.0 High: -30.0 ATTR: ek in ['all']
# 42.52% of range. Val: -78.7418881085 Low: -100.0 High: -50.0 ATTR: e_pas in ['all']
# 14.00% of range. Val: 0.000280091359575 Low: 0 High: 0.002 ATTR: g_pas in ['all']
# 73.94% of range. Val: 7.39424399792 Low: 0 High: 10 ATTR: sh_Na in ['all']
# 81.39% of range. Val: 0.0813893497194 Low: 0 High: 0.1 ATTR: gbar_Na in ['all']
# 43.09% of range. Val: 0.172349884286 Low: 0 High: 0.4 ATTR: gbar_Kd in ['all']
# 22.44% of range. Val: 0.0897508487839 Low: 0 High: 0.4 ATTR: gbar_KA in ['somatic']
# 10.42% of range. Val: -54.7886905305 Low: -60.0 High: -10.0 ATTR: eh in ['somatic']
# 34.76% of range. Val: 3.47563205871e-05 Low: 0 High: 0.0001 ATTR: gbar_Ih in ['somatic']
# 18.76% of range. Val: 0.024391455262 Low: 0 High: 0.13 ATTR: gbar_KM in ['somatic']
# ('GEN', 5, 'Parents', 5, 'Elite', 13, 'DIV', 6, 'RND', 6, 'TOT NEW', 25)
# ('STARTED GEN', '5', 'size', 25)
# ('DONE with', 1, 'of', 25, 'of GEN', '5', 'with Fitness', '60.81')
# ('DONE with', 2, 'of', 25, 'of GEN', '5', 'with Fitness', '38.77')
# ('DONE with', 3, 'of', 25, 'of GEN', '5', 'with Fitness', '32.10')
# ('DONE with', 4, 'of', 25, 'of GEN', '5', 'with Fitness', '25.59')
# ('DONE with', 5, 'of', 25, 'of GEN', '5', 'with Fitness', '34.68')
# ('DONE with', 6, 'of', 25, 'of GEN', '5', 'with Fitness', '35.59')
# ('DONE with', 7, 'of', 25, 'of GEN', '5', 'with Fitness', '7.07')
# ('DONE with', 8, 'of', 25, 'of GEN', '5', 'with Fitness', '7.03')
# ('DONE with', 9, 'of', 25, 'of GEN', '5', 'with Fitness', '6.93')
# ('DONE with', 10, 'of', 25, 'of GEN', '5', 'with Fitness', '7.18')
# ('DONE with', 11, 'of', 25, 'of GEN', '5', 'with Fitness', '6.35')
# ('DONE with', 12, 'of', 25, 'of GEN', '5', 'with Fitness', '14.36')
# ('DONE with', 13, 'of', 25, 'of GEN', '5', 'with Fitness', '5.64')
# ('DONE with', 14, 'of', 25, 'of GEN', '5', 'with Fitness', '11.17')
# ('DONE with', 15, 'of', 25, 'of GEN', '5', 'with Fitness', '6.96')
# ('DONE with', 16, 'of', 25, 'of GEN', '5', 'with Fitness', '14.17')
# ('DONE with', 17, 'of', 25, 'of GEN', '5', 'with Fitness', '8.63')
# ('DONE with', 18, 'of', 25, 'of GEN', '5', 'with Fitness', '6.77')
# ('DONE with', 19, 'of', 25, 'of GEN', '5', 'with Fitness', '6.66')
# ('DONE with', 20, 'of', 25, 'of GEN', '5', 'with Fitness', '8.70')
# ('DONE with', 21, 'of', 25, 'of GEN', '5', 'with Fitness', '8.86')
# ('DONE with', 22, 'of', 25, 'of GEN', '5', 'with Fitness', '69.79')
# ('DONE with', 23, 'of', 25, 'of GEN', '5', 'with Fitness', '6.45')
# ('DONE with', 24, 'of', 25, 'of GEN', '5', 'with Fitness', '7.70')
# ('DONE with', 25, 'of', 25, 'of GEN', '5', 'with Fitness', '7.10')
# ('Generation', 5, 'out of', 200, 'COMPLETE')
# ('Best fitness:', 5.637756035582147)
# ('Best individual', [0.7563200529638154, 92.09606569098322, 5.512629167837416, 49.01437227637376, -51.66992761855848, -78.74188810848844, 0.000280091359574945, 7.394243997915121, 0.08138934971943226, 0.1723498842857927, 0.08975084878394496, -54.78869053050586, 3.475632058708355e-05, 0.024391455262029356])
# 22.63% of range. Val: 0.756320052964 Low: 0.1 High: 3.0 ATTR: diam in ['apical']
# 75.74% of range. Val: 92.096065691 Low: 5.0 High: 120.0 ATTR: Ra in ['all']
# 54.67% of range. Val: 5.51262916784 Low: 0.1 High: 10.0 ATTR: cm in ['all']
# 97.54% of range. Val: 49.0143722764 Low: 10.0 High: 50.0 ATTR: ena in ['all']
# 69.04% of range. Val: -51.6699276186 Low: -100.0 High: -30.0 ATTR: ek in ['all']
# 42.52% of range. Val: -78.7418881085 Low: -100.0 High: -50.0 ATTR: e_pas in ['all']
# 14.00% of range. Val: 0.000280091359575 Low: 0 High: 0.002 ATTR: g_pas in ['all']
# 73.94% of range. Val: 7.39424399792 Low: 0 High: 10 ATTR: sh_Na in ['all']
# 81.39% of range. Val: 0.0813893497194 Low: 0 High: 0.1 ATTR: gbar_Na in ['all']
# 43.09% of range. Val: 0.172349884286 Low: 0 High: 0.4 ATTR: gbar_Kd in ['all']
# 22.44% of range. Val: 0.0897508487839 Low: 0 High: 0.4 ATTR: gbar_KA in ['somatic']
# 10.42% of range. Val: -54.7886905305 Low: -60.0 High: -10.0 ATTR: eh in ['somatic']
# 34.76% of range. Val: 3.47563205871e-05 Low: 0 High: 0.0001 ATTR: gbar_Ih in ['somatic']
# 18.76% of range. Val: 0.024391455262 Low: 0 High: 0.13 ATTR: gbar_KM in ['somatic']
# ('GEN', 6, 'Parents', 5, 'Elite', 13, 'DIV', 6, 'RND', 6, 'TOT NEW', 25)
# ('STARTED GEN', '6', 'size', 25)
# ('DONE with', 1, 'of', 25, 'of GEN', '6', 'with Fitness', '77.74')
# ('DONE with', 2, 'of', 25, 'of GEN', '6', 'with Fitness', '37.91')
# ('DONE with', 3, 'of', 25, 'of GEN', '6', 'with Fitness', '100.86')
# ('DONE with', 4, 'of', 25, 'of GEN', '6', 'with Fitness', '16.02')
# ('DONE with', 5, 'of', 25, 'of GEN', '6', 'with Fitness', '140.09')
# ('DONE with', 6, 'of', 25, 'of GEN', '6', 'with Fitness', '161.02')
# ('DONE with', 7, 'of', 25, 'of GEN', '6', 'with Fitness', '7.01')
# ('DONE with', 8, 'of', 25, 'of GEN', '6', 'with Fitness', '13.68')
# ('DONE with', 9, 'of', 25, 'of GEN', '6', 'with Fitness', '9.86')
# ('DONE with', 10, 'of', 25, 'of GEN', '6', 'with Fitness', '8.04')
# ('DONE with', 11, 'of', 25, 'of GEN', '6', 'with Fitness', '20.47')
# ('DONE with', 12, 'of', 25, 'of GEN', '6', 'with Fitness', '16.17')
# ('DONE with', 13, 'of', 25, 'of GEN', '6', 'with Fitness', '20.56')
# ('DONE with', 14, 'of', 25, 'of GEN', '6', 'with Fitness', '6.52')
# ('DONE with', 15, 'of', 25, 'of GEN', '6', 'with Fitness', '6.71')
# ('DONE with', 16, 'of', 25, 'of GEN', '6', 'with Fitness', '20.05')
# ('DONE with', 17, 'of', 25, 'of GEN', '6', 'with Fitness', '6.16')
# ('DONE with', 18, 'of', 25, 'of GEN', '6', 'with Fitness', '6.87')
# ('DONE with', 19, 'of', 25, 'of GEN', '6', 'with Fitness', '14.87')
# ('DONE with', 20, 'of', 25, 'of GEN', '6', 'with Fitness', '77.85')
# ('DONE with', 21, 'of', 25, 'of GEN', '6', 'with Fitness', '11.30')
# ('DONE with', 22, 'of', 25, 'of GEN', '6', 'with Fitness', '9.31')
# ('DONE with', 23, 'of', 25, 'of GEN', '6', 'with Fitness', '8.20')
# ('DONE with', 24, 'of', 25, 'of GEN', '6', 'with Fitness', '5.71')
# ('DONE with', 25, 'of', 25, 'of GEN', '6', 'with Fitness', '6.45')
# ('Generation', 6, 'out of', 200, 'COMPLETE')
# ('Best fitness:', 5.637756035582147)
# ('Best individual', [0.7563200529638154, 92.09606569098322, 5.512629167837416, 49.01437227637376, -51.66992761855848, -78.74188810848844, 0.000280091359574945, 7.394243997915121, 0.08138934971943226, 0.1723498842857927, 0.08975084878394496, -54.78869053050586, 3.475632058708355e-05, 0.024391455262029356])
# 22.63% of range. Val: 0.756320052964 Low: 0.1 High: 3.0 ATTR: diam in ['apical']
# 75.74% of range. Val: 92.096065691 Low: 5.0 High: 120.0 ATTR: Ra in ['all']
# 54.67% of range. Val: 5.51262916784 Low: 0.1 High: 10.0 ATTR: cm in ['all']
# 97.54% of range. Val: 49.0143722764 Low: 10.0 High: 50.0 ATTR: ena in ['all']
# 69.04% of range. Val: -51.6699276186 Low: -100.0 High: -30.0 ATTR: ek in ['all']
# 42.52% of range. Val: -78.7418881085 Low: -100.0 High: -50.0 ATTR: e_pas in ['all']
# 14.00% of range. Val: 0.000280091359575 Low: 0 High: 0.002 ATTR: g_pas in ['all']
# 73.94% of range. Val: 7.39424399792 Low: 0 High: 10 ATTR: sh_Na in ['all']
# 81.39% of range. Val: 0.0813893497194 Low: 0 High: 0.1 ATTR: gbar_Na in ['all']
# 43.09% of range. Val: 0.172349884286 Low: 0 High: 0.4 ATTR: gbar_Kd in ['all']
# 22.44% of range. Val: 0.0897508487839 Low: 0 High: 0.4 ATTR: gbar_KA in ['somatic']
# 10.42% of range. Val: -54.7886905305 Low: -60.0 High: -10.0 ATTR: eh in ['somatic']
# 34.76% of range. Val: 3.47563205871e-05 Low: 0 High: 0.0001 ATTR: gbar_Ih in ['somatic']
# 18.76% of range. Val: 0.024391455262 Low: 0 High: 0.13 ATTR: gbar_KM in ['somatic']
# ('GEN', 7, 'Parents', 5, 'Elite', 13, 'DIV', 6, 'RND', 6, 'TOT NEW', 25)
# ('STARTED GEN', '7', 'size', 25)
# ('DONE with', 1, 'of', 25, 'of GEN', '7', 'with Fitness', '37.80')
# ('DONE with', 2, 'of', 25, 'of GEN', '7', 'with Fitness', '113.19')
# ('DONE with', 3, 'of', 25, 'of GEN', '7', 'with Fitness', '113.46')
# ('DONE with', 4, 'of', 25, 'of GEN', '7', 'with Fitness', '15.87')
# ('DONE with', 5, 'of', 25, 'of GEN', '7', 'with Fitness', '33.84')
# ('DONE with', 6, 'of', 25, 'of GEN', '7', 'with Fitness', '65.34')
# ('DONE with', 7, 'of', 25, 'of GEN', '7', 'with Fitness', '53.31')
# ('DONE with', 8, 'of', 25, 'of GEN', '7', 'with Fitness', '20.68')
# ('DONE with', 9, 'of', 25, 'of GEN', '7', 'with Fitness', '12.80')
# ('DONE with', 10, 'of', 25, 'of GEN', '7', 'with Fitness', '13.16')
# ('DONE with', 11, 'of', 25, 'of GEN', '7', 'with Fitness', '7.90')
# ('DONE with', 12, 'of', 25, 'of GEN', '7', 'with Fitness', '8.04')
# ('DONE with', 13, 'of', 25, 'of GEN', '7', 'with Fitness', '5.64')
# ('DONE with', 14, 'of', 25, 'of GEN', '7', 'with Fitness', '21.04')
# ('DONE with', 15, 'of', 25, 'of GEN', '7', 'with Fitness', '10.51')
# ('DONE with', 16, 'of', 25, 'of GEN', '7', 'with Fitness', '8.28')
# ('DONE with', 17, 'of', 25, 'of GEN', '7', 'with Fitness', '18.39')
# ('DONE with', 18, 'of', 25, 'of GEN', '7', 'with Fitness', '5.71')
# ('DONE with', 19, 'of', 25, 'of GEN', '7', 'with Fitness', '5.72')
# ('DONE with', 20, 'of', 25, 'of GEN', '7', 'with Fitness', '177.38')
# ('DONE with', 21, 'of', 25, 'of GEN', '7', 'with Fitness', '6.83')
# ('DONE with', 22, 'of', 25, 'of GEN', '7', 'with Fitness', '6.16')
# ('DONE with', 23, 'of', 25, 'of GEN', '7', 'with Fitness', '19.57')
# ('DONE with', 24, 'of', 25, 'of GEN', '7', 'with Fitness', '10.50')
# ('DONE with', 25, 'of', 25, 'of GEN', '7', 'with Fitness', '6.16')
# ('Generation', 7, 'out of', 200, 'COMPLETE')
# ('Best fitness:', 5.637756035582147)
# ('Best individual', [0.7563200529638154, 92.09606569098322, 5.512629167837416, 49.01437227637376, -51.66992761855848, -78.74188810848844, 0.000280091359574945, 7.394243997915121, 0.08138934971943226, 0.1723498842857927, 0.08975084878394496, -54.78869053050586, 3.475632058708355e-05, 0.024391455262029356])
# 22.63% of range. Val: 0.756320052964 Low: 0.1 High: 3.0 ATTR: diam in ['apical']
# 75.74% of range. Val: 92.096065691 Low: 5.0 High: 120.0 ATTR: Ra in ['all']
# 54.67% of range. Val: 5.51262916784 Low: 0.1 High: 10.0 ATTR: cm in ['all']
# 97.54% of range. Val: 49.0143722764 Low: 10.0 High: 50.0 ATTR: ena in ['all']
# 69.04% of range. Val: -51.6699276186 Low: -100.0 High: -30.0 ATTR: ek in ['all']
# 42.52% of range. Val: -78.7418881085 Low: -100.0 High: -50.0 ATTR: e_pas in ['all']
# 14.00% of range. Val: 0.000280091359575 Low: 0 High: 0.002 ATTR: g_pas in ['all']
# 73.94% of range. Val: 7.39424399792 Low: 0 High: 10 ATTR: sh_Na in ['all']
# 81.39% of range. Val: 0.0813893497194 Low: 0 High: 0.1 ATTR: gbar_Na in ['all']
# 43.09% of range. Val: 0.172349884286 Low: 0 High: 0.4 ATTR: gbar_Kd in ['all']
# 22.44% of range. Val: 0.0897508487839 Low: 0 High: 0.4 ATTR: gbar_KA in ['somatic']
# 10.42% of range. Val: -54.7886905305 Low: -60.0 High: -10.0 ATTR: eh in ['somatic']
# 34.76% of range. Val: 3.47563205871e-05 Low: 0 High: 0.0001 ATTR: gbar_Ih in ['somatic']
# 18.76% of range. Val: 0.024391455262 Low: 0 High: 0.13 ATTR: gbar_KM in ['somatic']
# ('GEN', 8, 'Parents', 5, 'Elite', 13, 'DIV', 6, 'RND', 6, 'TOT NEW', 25)
# ('STARTED GEN', '8', 'size', 25)
# ('DONE with', 1, 'of', 25, 'of GEN', '8', 'with Fitness', '14.47')
# ('DONE with', 2, 'of', 25, 'of GEN', '8', 'with Fitness', '72.66')
# ('DONE with', 3, 'of', 25, 'of GEN', '8', 'with Fitness', '15.29')
# ('DONE with', 4, 'of', 25, 'of GEN', '8', 'with Fitness', '67.17')
# ('DONE with', 5, 'of', 25, 'of GEN', '8', 'with Fitness', '31.06')
# ('DONE with', 6, 'of', 25, 'of GEN', '8', 'with Fitness', '21.72')
# ('DONE with', 7, 'of', 25, 'of GEN', '8', 'with Fitness', '8.89')
# ('DONE with', 8, 'of', 25, 'of GEN', '8', 'with Fitness', '15.06')
# ('DONE with', 9, 'of', 25, 'of GEN', '8', 'with Fitness', '11.01')
# ('DONE with', 10, 'of', 25, 'of GEN', '8', 'with Fitness', '10.20')
# ('DONE with', 11, 'of', 25, 'of GEN', '8', 'with Fitness', '14.49')
# ('DONE with', 12, 'of', 25, 'of GEN', '8', 'with Fitness', '18.55')
# ('DONE with', 13, 'of', 25, 'of GEN', '8', 'with Fitness', '6.84')
# ('DONE with', 14, 'of', 25, 'of GEN', '8', 'with Fitness', '9.20')
# ('DONE with', 15, 'of', 25, 'of GEN', '8', 'with Fitness', '5.98')
# ('DONE with', 16, 'of', 25, 'of GEN', '8', 'with Fitness', '5.51')
# ('DONE with', 17, 'of', 25, 'of GEN', '8', 'with Fitness', '5.71')
# ('DONE with', 18, 'of', 25, 'of GEN', '8', 'with Fitness', '5.56')
# ('DONE with', 19, 'of', 25, 'of GEN', '8', 'with Fitness', '5.71')
# ('DONE with', 20, 'of', 25, 'of GEN', '8', 'with Fitness', '8.12')
# ('DONE with', 21, 'of', 25, 'of GEN', '8', 'with Fitness', '15.86')
# ('DONE with', 22, 'of', 25, 'of GEN', '8', 'with Fitness', '12.14')
# ('DONE with', 23, 'of', 25, 'of GEN', '8', 'with Fitness', '5.71')
# ('DONE with', 24, 'of', 25, 'of GEN', '8', 'with Fitness', '8.23')
# ('DONE with', 25, 'of', 25, 'of GEN', '8', 'with Fitness', '9.98')
# ('Generation', 8, 'out of', 200, 'COMPLETE')
# ('Best fitness:', 5.507226258596779)
# ('Best individual', [0.7563200529638154, 103.38714765249036, 3.2167223798052635, 49.01437227637376, -50.04027041406785, -78.74188810848844, 0.000280091359574945, 7.394243997915121, 0.07191239439446442, 0.15223317998272465, 0.08975084878394496, -54.78869053050586, 3.731260082986325e-06, 0.024391455262029356])
# 22.63% of range. Val: 0.756320052964 Low: 0.1 High: 3.0 ATTR: diam in ['apical']
# 85.55% of range. Val: 103.387147652 Low: 5.0 High: 120.0 ATTR: Ra in ['all']
# 31.48% of range. Val: 3.21672237981 Low: 0.1 High: 10.0 ATTR: cm in ['all']
# 97.54% of range. Val: 49.0143722764 Low: 10.0 High: 50.0 ATTR: ena in ['all']
# 71.37% of range. Val: -50.0402704141 Low: -100.0 High: -30.0 ATTR: ek in ['all']
# 42.52% of range. Val: -78.7418881085 Low: -100.0 High: -50.0 ATTR: e_pas in ['all']
# 14.00% of range. Val: 0.000280091359575 Low: 0 High: 0.002 ATTR: g_pas in ['all']
# 73.94% of range. Val: 7.39424399792 Low: 0 High: 10 ATTR: sh_Na in ['all']
# 71.91% of range. Val: 0.0719123943945 Low: 0 High: 0.1 ATTR: gbar_Na in ['all']
# 38.06% of range. Val: 0.152233179983 Low: 0 High: 0.4 ATTR: gbar_Kd in ['all']
# 22.44% of range. Val: 0.0897508487839 Low: 0 High: 0.4 ATTR: gbar_KA in ['somatic']
# 10.42% of range. Val: -54.7886905305 Low: -60.0 High: -10.0 ATTR: eh in ['somatic']
# 3.73% of range. Val: 3.73126008299e-06 Low: 0 High: 0.0001 ATTR: gbar_Ih in ['somatic']
# 18.76% of range. Val: 0.024391455262 Low: 0 High: 0.13 ATTR: gbar_KM in ['somatic']
# ('GEN', 9, 'Parents', 5, 'Elite', 13, 'DIV', 6, 'RND', 6, 'TOT NEW', 25)
# ('STARTED GEN', '9', 'size', 25)
# ('DONE with', 1, 'of', 25, 'of GEN', '9', 'with Fitness', '52.55')
# ('DONE with', 2, 'of', 25, 'of GEN', '9', 'with Fitness', '40.76')
# ('DONE with', 3, 'of', 25, 'of GEN', '9', 'with Fitness', '22.80')
# ('DONE with', 4, 'of', 25, 'of GEN', '9', 'with Fitness', '15.18')
# ('DONE with', 5, 'of', 25, 'of GEN', '9', 'with Fitness', '53.42')
# ('DONE with', 6, 'of', 25, 'of GEN', '9', 'with Fitness', '28.57')
# ('DONE with', 7, 'of', 25, 'of GEN', '9', 'with Fitness', '7.63')
# ('DONE with', 8, 'of', 25, 'of GEN', '9', 'with Fitness', '9.38')
# ('DONE with', 9, 'of', 25, 'of GEN', '9', 'with Fitness', '16.09')
# ('DONE with', 10, 'of', 25, 'of GEN', '9', 'with Fitness', '22.66')
# ('DONE with', 11, 'of', 25, 'of GEN', '9', 'with Fitness', '12.39')
# ('DONE with', 12, 'of', 25, 'of GEN', '9', 'with Fitness', '20.92')
# ('DONE with', 13, 'of', 25, 'of GEN', '9', 'with Fitness', '26.47')
# ('DONE with', 14, 'of', 25, 'of GEN', '9', 'with Fitness', '19.58')
# ('DONE with', 15, 'of', 25, 'of GEN', '9', 'with Fitness', '15.96')
# ('DONE with', 16, 'of', 25, 'of GEN', '9', 'with Fitness', '5.72')
# ('DONE with', 17, 'of', 25, 'of GEN', '9', 'with Fitness', '6.44')
# ('DONE with', 18, 'of', 25, 'of GEN', '9', 'with Fitness', '4.94')
# ('DONE with', 19, 'of', 25, 'of GEN', '9', 'with Fitness', '5.37')
# ('DONE with', 20, 'of', 25, 'of GEN', '9', 'with Fitness', '6.01')
# ('DONE with', 21, 'of', 25, 'of GEN', '9', 'with Fitness', '12.89')
# ('DONE with', 22, 'of', 25, 'of GEN', '9', 'with Fitness', '9.80')
# ('DONE with', 23, 'of', 25, 'of GEN', '9', 'with Fitness', '5.51')
# ('DONE with', 24, 'of', 25, 'of GEN', '9', 'with Fitness', '5.59')
# ('DONE with', 25, 'of', 25, 'of GEN', '9', 'with Fitness', '6.65')
# ('Generation', 9, 'out of', 200, 'COMPLETE')
# ('Best fitness:', 4.943101259056401)
# ('Best individual', [0.7586418910492941, 86.65272860596073, 4.6432063321644, 40.64960659425323, -49.50647388390325, -78.74188810848844, 0.0001265901589034576, 7.394243997915121, 0.08123297335282005, 0.15596432654668943, 0.0855663662874783, -54.78869053050586, 1.1169643797820546e-05, 0.024391455262029356])
# 22.71% of range. Val: 0.758641891049 Low: 0.1 High: 3.0 ATTR: diam in ['apical']
# 71.00% of range. Val: 86.652728606 Low: 5.0 High: 120.0 ATTR: Ra in ['all']
# 45.89% of range. Val: 4.64320633216 Low: 0.1 High: 10.0 ATTR: cm in ['all']
# 76.62% of range. Val: 40.6496065943 Low: 10.0 High: 50.0 ATTR: ena in ['all']
# 72.13% of range. Val: -49.5064738839 Low: -100.0 High: -30.0 ATTR: ek in ['all']
# 42.52% of range. Val: -78.7418881085 Low: -100.0 High: -50.0 ATTR: e_pas in ['all']
# 6.33% of range. Val: 0.000126590158903 Low: 0 High: 0.002 ATTR: g_pas in ['all']
# 73.94% of range. Val: 7.39424399792 Low: 0 High: 10 ATTR: sh_Na in ['all']
# 81.23% of range. Val: 0.0812329733528 Low: 0 High: 0.1 ATTR: gbar_Na in ['all']
# 38.99% of range. Val: 0.155964326547 Low: 0 High: 0.4 ATTR: gbar_Kd in ['all']
# 21.39% of range. Val: 0.0855663662875 Low: 0 High: 0.4 ATTR: gbar_KA in ['somatic']
# 10.42% of range. Val: -54.7886905305 Low: -60.0 High: -10.0 ATTR: eh in ['somatic']
# 11.17% of range. Val: 1.11696437978e-05 Low: 0 High: 0.0001 ATTR: gbar_Ih in ['somatic']
# 18.76% of range. Val: 0.024391455262 Low: 0 High: 0.13 ATTR: gbar_KM in ['somatic']
# ('GEN', 10, 'Parents', 5, 'Elite', 13, 'DIV', 6, 'RND', 6, 'TOT NEW', 25)
# ('STARTED GEN', '10', 'size', 25)
# ('DONE with', 1, 'of', 25, 'of GEN', '10', 'with Fitness', '23.99')
# ('DONE with', 2, 'of', 25, 'of GEN', '10', 'with Fitness', '46.38')
# ('DONE with', 3, 'of', 25, 'of GEN', '10', 'with Fitness', '22.86')
# ('DONE with', 4, 'of', 25, 'of GEN', '10', 'with Fitness', '50.34')
# ('DONE with', 5, 'of', 25, 'of GEN', '10', 'with Fitness', '51.94')
# ('DONE with', 6, 'of', 25, 'of GEN', '10', 'with Fitness', '105.39')
# ('DONE with', 7, 'of', 25, 'of GEN', '10', 'with Fitness', '110.45')
# ('DONE with', 8, 'of', 25, 'of GEN', '10', 'with Fitness', '13.31')
# ('DONE with', 9, 'of', 25, 'of GEN', '10', 'with Fitness', '10.59')
# ('DONE with', 10, 'of', 25, 'of GEN', '10', 'with Fitness', '11.99')
# ('DONE with', 11, 'of', 25, 'of GEN', '10', 'with Fitness', '27.34')
# ('DONE with', 12, 'of', 25, 'of GEN', '10', 'with Fitness', '91.67')
# ('DONE with', 13, 'of', 25, 'of GEN', '10', 'with Fitness', '5.44')
# ('DONE with', 14, 'of', 25, 'of GEN', '10', 'with Fitness', '5.45')
# ('DONE with', 15, 'of', 25, 'of GEN', '10', 'with Fitness', '14.33')
# ('DONE with', 16, 'of', 25, 'of GEN', '10', 'with Fitness', '15.44')
# ('DONE with', 17, 'of', 25, 'of GEN', '10', 'with Fitness', '5.56')
# ('DONE with', 18, 'of', 25, 'of GEN', '10', 'with Fitness', '5.87')
# ('DONE with', 19, 'of', 25, 'of GEN', '10', 'with Fitness', '6.21')
# ('DONE with', 20, 'of', 25, 'of GEN', '10', 'with Fitness', '5.56')
# ('DONE with', 21, 'of', 25, 'of GEN', '10', 'with Fitness', '7.52')
# ('DONE with', 22, 'of', 25, 'of GEN', '10', 'with Fitness', '8.02')
# ('DONE with', 23, 'of', 25, 'of GEN', '10', 'with Fitness', '16.43')
# ('DONE with', 24, 'of', 25, 'of GEN', '10', 'with Fitness', '5.59')
# ('DONE with', 25, 'of', 25, 'of GEN', '10', 'with Fitness', '4.97')
# ('Generation', 10, 'out of', 200, 'COMPLETE')
# ('Best fitness:', 4.943101259056401)
# ('Best individual', [0.7586418910492941, 86.65272860596073, 4.6432063321644, 40.64960659425323, -49.50647388390325, -78.74188810848844, 0.0001265901589034576, 7.394243997915121, 0.08123297335282005, 0.15596432654668943, 0.0855663662874783, -54.78869053050586, 1.1169643797820546e-05, 0.024391455262029356])
# 22.71% of range. Val: 0.758641891049 Low: 0.1 High: 3.0 ATTR: diam in ['apical']
# 71.00% of range. Val: 86.652728606 Low: 5.0 High: 120.0 ATTR: Ra in ['all']
# 45.89% of range. Val: 4.64320633216 Low: 0.1 High: 10.0 ATTR: cm in ['all']
# 76.62% of range. Val: 40.6496065943 Low: 10.0 High: 50.0 ATTR: ena in ['all']
# 72.13% of range. Val: -49.5064738839 Low: -100.0 High: -30.0 ATTR: ek in ['all']
# 42.52% of range. Val: -78.7418881085 Low: -100.0 High: -50.0 ATTR: e_pas in ['all']
# 6.33% of range. Val: 0.000126590158903 Low: 0 High: 0.002 ATTR: g_pas in ['all']
# 73.94% of range. Val: 7.39424399792 Low: 0 High: 10 ATTR: sh_Na in ['all']
# 81.23% of range. Val: 0.0812329733528 Low: 0 High: 0.1 ATTR: gbar_Na in ['all']
# 38.99% of range. Val: 0.155964326547 Low: 0 High: 0.4 ATTR: gbar_Kd in ['all']
# 21.39% of range. Val: 0.0855663662875 Low: 0 High: 0.4 ATTR: gbar_KA in ['somatic']
# 10.42% of range. Val: -54.7886905305 Low: -60.0 High: -10.0 ATTR: eh in ['somatic']
# 11.17% of range. Val: 1.11696437978e-05 Low: 0 High: 0.0001 ATTR: gbar_Ih in ['somatic']
# 18.76% of range. Val: 0.024391455262 Low: 0 High: 0.13 ATTR: gbar_KM in ['somatic']
# ('GEN', 11, 'Parents', 5, 'Elite', 13, 'DIV', 6, 'RND', 6, 'TOT NEW', 25)
# ('STARTED GEN', '11', 'size', 25)
# ('DONE with', 1, 'of', 25, 'of GEN', '11', 'with Fitness', '70.24')
# ('DONE with', 2, 'of', 25, 'of GEN', '11', 'with Fitness', '18.96')
# ('DONE with', 3, 'of', 25, 'of GEN', '11', 'with Fitness', '14.42')
# ('DONE with', 4, 'of', 25, 'of GEN', '11', 'with Fitness', '31.08')
# ('DONE with', 5, 'of', 25, 'of GEN', '11', 'with Fitness', '31.32')
# ('DONE with', 6, 'of', 25, 'of GEN', '11', 'with Fitness', '14.80')
# ('DONE with', 7, 'of', 25, 'of GEN', '11', 'with Fitness', '33.63')
# ('DONE with', 8, 'of', 25, 'of GEN', '11', 'with Fitness', '8.13')
# ('DONE with', 9, 'of', 25, 'of GEN', '11', 'with Fitness', '12.40')
# ('DONE with', 10, 'of', 25, 'of GEN', '11', 'with Fitness', '8.04')
# ('DONE with', 11, 'of', 25, 'of GEN', '11', 'with Fitness', '5.65')
# ('DONE with', 12, 'of', 25, 'of GEN', '11', 'with Fitness', '5.53')
# ('DONE with', 13, 'of', 25, 'of GEN', '11', 'with Fitness', '59.15')
# ('DONE with', 14, 'of', 25, 'of GEN', '11', 'with Fitness', '26.81')
# ('DONE with', 15, 'of', 25, 'of GEN', '11', 'with Fitness', '5.44')
# ('DONE with', 16, 'of', 25, 'of GEN', '11', 'with Fitness', '13.72')
# ('DONE with', 17, 'of', 25, 'of GEN', '11', 'with Fitness', '5.37')
# ('DONE with', 18, 'of', 25, 'of GEN', '11', 'with Fitness', '5.37')
# ('DONE with', 19, 'of', 25, 'of GEN', '11', 'with Fitness', '5.45')
# ('DONE with', 20, 'of', 25, 'of GEN', '11', 'with Fitness', '14.42')
# ('DONE with', 21, 'of', 25, 'of GEN', '11', 'with Fitness', '5.91')
# ('DONE with', 22, 'of', 25, 'of GEN', '11', 'with Fitness', '4.95')
# ('DONE with', 23, 'of', 25, 'of GEN', '11', 'with Fitness', '5.08')
# ('DONE with', 24, 'of', 25, 'of GEN', '11', 'with Fitness', '16.15')
# ('DONE with', 25, 'of', 25, 'of GEN', '11', 'with Fitness', '5.37')
# ('Generation', 11, 'out of', 200, 'COMPLETE')
# ('Best fitness:', 4.943101259056401)
# ('Best individual', [0.7586418910492941, 86.65272860596073, 4.6432063321644, 40.64960659425323, -49.50647388390325, -78.74188810848844, 0.0001265901589034576, 7.394243997915121, 0.08123297335282005, 0.15596432654668943, 0.0855663662874783, -54.78869053050586, 1.1169643797820546e-05, 0.024391455262029356])
# 22.71% of range. Val: 0.758641891049 Low: 0.1 High: 3.0 ATTR: diam in ['apical']
# 71.00% of range. Val: 86.652728606 Low: 5.0 High: 120.0 ATTR: Ra in ['all']
# 45.89% of range. Val: 4.64320633216 Low: 0.1 High: 10.0 ATTR: cm in ['all']
# 76.62% of range. Val: 40.6496065943 Low: 10.0 High: 50.0 ATTR: ena in ['all']
# 72.13% of range. Val: -49.5064738839 Low: -100.0 High: -30.0 ATTR: ek in ['all']
# 42.52% of range. Val: -78.7418881085 Low: -100.0 High: -50.0 ATTR: e_pas in ['all']
# 6.33% of range. Val: 0.000126590158903 Low: 0 High: 0.002 ATTR: g_pas in ['all']
# 73.94% of range. Val: 7.39424399792 Low: 0 High: 10 ATTR: sh_Na in ['all']
# 81.23% of range. Val: 0.0812329733528 Low: 0 High: 0.1 ATTR: gbar_Na in ['all']
# 38.99% of range. Val: 0.155964326547 Low: 0 High: 0.4 ATTR: gbar_Kd in ['all']
# 21.39% of range. Val: 0.0855663662875 Low: 0 High: 0.4 ATTR: gbar_KA in ['somatic']
# 10.42% of range. Val: -54.7886905305 Low: -60.0 High: -10.0 ATTR: eh in ['somatic']
# 11.17% of range. Val: 1.11696437978e-05 Low: 0 High: 0.0001 ATTR: gbar_Ih in ['somatic']
# 18.76% of range. Val: 0.024391455262 Low: 0 High: 0.13 ATTR: gbar_KM in ['somatic']
# ('GEN', 12, 'Parents', 5, 'Elite', 13, 'DIV', 6, 'RND', 6, 'TOT NEW', 25)
# ('STARTED GEN', '12', 'size', 25)
# ('DONE with', 1, 'of', 25, 'of GEN', '12', 'with Fitness', '28.94')
# ('DONE with', 2, 'of', 25, 'of GEN', '12', 'with Fitness', '19.15')
# ('DONE with', 3, 'of', 25, 'of GEN', '12', 'with Fitness', '10.15')
# ('DONE with', 4, 'of', 25, 'of GEN', '12', 'with Fitness', '43.71')
# ('DONE with', 5, 'of', 25, 'of GEN', '12', 'with Fitness', '16.01')
# ('DONE with', 6, 'of', 25, 'of GEN', '12', 'with Fitness', '32.25')
# ('DONE with', 7, 'of', 25, 'of GEN', '12', 'with Fitness', '10.49')
# ('DONE with', 8, 'of', 25, 'of GEN', '12', 'with Fitness', '15.67')
# ('DONE with', 9, 'of', 25, 'of GEN', '12', 'with Fitness', '23.30')
# ('DONE with', 10, 'of', 25, 'of GEN', '12', 'with Fitness', '53.61')
# ('DONE with', 11, 'of', 25, 'of GEN', '12', 'with Fitness', '13.79')
# ('DONE with', 12, 'of', 25, 'of GEN', '12', 'with Fitness', '12.92')
# ('DONE with', 13, 'of', 25, 'of GEN', '12', 'with Fitness', '10.56')
# ('DONE with', 14, 'of', 25, 'of GEN', '12', 'with Fitness', '5.32')
# ('DONE with', 15, 'of', 25, 'of GEN', '12', 'with Fitness', '5.39')
# ('DONE with', 16, 'of', 25, 'of GEN', '12', 'with Fitness', '4.83')
# ('DONE with', 17, 'of', 25, 'of GEN', '12', 'with Fitness', '5.20')
# ('DONE with', 18, 'of', 25, 'of GEN', '12', 'with Fitness', '5.14')
# ('DONE with', 19, 'of', 25, 'of GEN', '12', 'with Fitness', '4.95')
# ('DONE with', 20, 'of', 25, 'of GEN', '12', 'with Fitness', '4.96')
# ('DONE with', 21, 'of', 25, 'of GEN', '12', 'with Fitness', '5.70')
# ('DONE with', 22, 'of', 25, 'of GEN', '12', 'with Fitness', '29.32')
# ('DONE with', 23, 'of', 25, 'of GEN', '12', 'with Fitness', '6.59')
# ('DONE with', 24, 'of', 25, 'of GEN', '12', 'with Fitness', '28.23')
# ('DONE with', 25, 'of', 25, 'of GEN', '12', 'with Fitness', '9.03')
# ('Generation', 12, 'out of', 200, 'COMPLETE')
# ('Best fitness:', 4.83293428012575)
# ('Best individual', [0.6894850848661034, 49.42555773176772, 4.294271364708687, 43.468528504340696, -49.50647388390325, -78.74188810848844, 0.0002166927307766324, 7.394243997915121, 0.08076622273658252, 0.17085107911360292, 0.06919210965366841, -54.78869053050586, 7.33381739214372e-05, 0.024391455262029356])
# 20.33% of range. Val: 0.689485084866 Low: 0.1 High: 3.0 ATTR: diam in ['apical']
# 38.63% of range. Val: 49.4255577318 Low: 5.0 High: 120.0 ATTR: Ra in ['all']
# 42.37% of range. Val: 4.29427136471 Low: 0.1 High: 10.0 ATTR: cm in ['all']
# 83.67% of range. Val: 43.4685285043 Low: 10.0 High: 50.0 ATTR: ena in ['all']
# 72.13% of range. Val: -49.5064738839 Low: -100.0 High: -30.0 ATTR: ek in ['all']
# 42.52% of range. Val: -78.7418881085 Low: -100.0 High: -50.0 ATTR: e_pas in ['all']
# 10.83% of range. Val: 0.000216692730777 Low: 0 High: 0.002 ATTR: g_pas in ['all']
# 73.94% of range. Val: 7.39424399792 Low: 0 High: 10 ATTR: sh_Na in ['all']
# 80.77% of range. Val: 0.0807662227366 Low: 0 High: 0.1 ATTR: gbar_Na in ['all']
# 42.71% of range. Val: 0.170851079114 Low: 0 High: 0.4 ATTR: gbar_Kd in ['all']
# 17.30% of range. Val: 0.0691921096537 Low: 0 High: 0.4 ATTR: gbar_KA in ['somatic']
# 10.42% of range. Val: -54.7886905305 Low: -60.0 High: -10.0 ATTR: eh in ['somatic']
# 73.34% of range. Val: 7.33381739214e-05 Low: 0 High: 0.0001 ATTR: gbar_Ih in ['somatic']
# 18.76% of range. Val: 0.024391455262 Low: 0 High: 0.13 ATTR: gbar_KM in ['somatic']
# ('GEN', 13, 'Parents', 5, 'Elite', 13, 'DIV', 6, 'RND', 6, 'TOT NEW', 25)
# ('STARTED GEN', '13', 'size', 25)
# ('DONE with', 1, 'of', 25, 'of GEN', '13', 'with Fitness', '14.55')
# ('DONE with', 2, 'of', 25, 'of GEN', '13', 'with Fitness', '18.00')
# ('DONE with', 3, 'of', 25, 'of GEN', '13', 'with Fitness', '32.89')
# ('DONE with', 4, 'of', 25, 'of GEN', '13', 'with Fitness', '20.00')
# ('DONE with', 5, 'of', 25, 'of GEN', '13', 'with Fitness', '39.25')
# ('DONE with', 6, 'of', 25, 'of GEN', '13', 'with Fitness', '35.64')
# ('DONE with', 7, 'of', 25, 'of GEN', '13', 'with Fitness', '5.62')
# ('DONE with', 8, 'of', 25, 'of GEN', '13', 'with Fitness', '38.09')
# ('DONE with', 9, 'of', 25, 'of GEN', '13', 'with Fitness', '10.75')
# ('DONE with', 10, 'of', 25, 'of GEN', '13', 'with Fitness', '63.70')
# ('DONE with', 11, 'of', 25, 'of GEN', '13', 'with Fitness', '16.39')
# ('DONE with', 12, 'of', 25, 'of GEN', '13', 'with Fitness', '9.28')
# ('DONE with', 13, 'of', 25, 'of GEN', '13', 'with Fitness', '13.51')
# ('DONE with', 14, 'of', 25, 'of GEN', '13', 'with Fitness', '15.56')
# ('DONE with', 15, 'of', 25, 'of GEN', '13', 'with Fitness', '18.04')
# ('DONE with', 16, 'of', 25, 'of GEN', '13', 'with Fitness', '43.89')
# ('DONE with', 17, 'of', 25, 'of GEN', '13', 'with Fitness', '5.04')
# ('DONE with', 18, 'of', 25, 'of GEN', '13', 'with Fitness', '4.90')
# ('DONE with', 19, 'of', 25, 'of GEN', '13', 'with Fitness', '13.55')
# ('DONE with', 20, 'of', 25, 'of GEN', '13', 'with Fitness', '4.83')
# ('DONE with', 21, 'of', 25, 'of GEN', '13', 'with Fitness', '26.45')
# ('DONE with', 22, 'of', 25, 'of GEN', '13', 'with Fitness', '25.50')
# ('DONE with', 23, 'of', 25, 'of GEN', '13', 'with Fitness', '16.55')
# ('DONE with', 24, 'of', 25, 'of GEN', '13', 'with Fitness', '13.21')
# ('DONE with', 25, 'of', 25, 'of GEN', '13', 'with Fitness', '9.16')
# ('Generation', 13, 'out of', 200, 'COMPLETE')
# ('Best fitness:', 4.825599776461392)
# ('Best individual', [0.6894850848661034, 53.09794714664069, 4.031498550915225, 40.64960659425323, -49.50647388390325, -78.74188810848844, 0.0001836591235844589, 7.394243997915121, 0.07777881675524445, 0.16553452115974043, 0.06923319785840239, -54.78869053050586, 3.512561182566447e-05, 0.024391455262029356])
# 20.33% of range. Val: 0.689485084866 Low: 0.1 High: 3.0 ATTR: diam in ['apical']
# 41.82% of range. Val: 53.0979471466 Low: 5.0 High: 120.0 ATTR: Ra in ['all']
# 39.71% of range. Val: 4.03149855092 Low: 0.1 High: 10.0 ATTR: cm in ['all']
# 76.62% of range. Val: 40.6496065943 Low: 10.0 High: 50.0 ATTR: ena in ['all']
# 72.13% of range. Val: -49.5064738839 Low: -100.0 High: -30.0 ATTR: ek in ['all']
# 42.52% of range. Val: -78.7418881085 Low: -100.0 High: -50.0 ATTR: e_pas in ['all']
# 9.18% of range. Val: 0.000183659123584 Low: 0 High: 0.002 ATTR: g_pas in ['all']
# 73.94% of range. Val: 7.39424399792 Low: 0 High: 10 ATTR: sh_Na in ['all']
# 77.78% of range. Val: 0.0777788167552 Low: 0 High: 0.1 ATTR: gbar_Na in ['all']
# 41.38% of range. Val: 0.16553452116 Low: 0 High: 0.4 ATTR: gbar_Kd in ['all']
# 17.31% of range. Val: 0.0692331978584 Low: 0 High: 0.4 ATTR: gbar_KA in ['somatic']
# 10.42% of range. Val: -54.7886905305 Low: -60.0 High: -10.0 ATTR: eh in ['somatic']
# 35.13% of range. Val: 3.51256118257e-05 Low: 0 High: 0.0001 ATTR: gbar_Ih in ['somatic']
# 18.76% of range. Val: 0.024391455262 Low: 0 High: 0.13 ATTR: gbar_KM in ['somatic']
# ('GEN', 14, 'Parents', 5, 'Elite', 13, 'DIV', 6, 'RND', 6, 'TOT NEW', 25)
# ('STARTED GEN', '14', 'size', 25)
# ('DONE with', 1, 'of', 25, 'of GEN', '14', 'with Fitness', '45.85')
# ('DONE with', 2, 'of', 25, 'of GEN', '14', 'with Fitness', '98.35')
# ('DONE with', 3, 'of', 25, 'of GEN', '14', 'with Fitness', '26.95')
# ('DONE with', 4, 'of', 25, 'of GEN', '14', 'with Fitness', '86.65')
# ('DONE with', 5, 'of', 25, 'of GEN', '14', 'with Fitness', '56.63')
# ('DONE with', 6, 'of', 25, 'of GEN', '14', 'with Fitness', '42.94')
# ('DONE with', 7, 'of', 25, 'of GEN', '14', 'with Fitness', '96.02')
# ('DONE with', 8, 'of', 25, 'of GEN', '14', 'with Fitness', '21.30')
# ('DONE with', 9, 'of', 25, 'of GEN', '14', 'with Fitness', '28.04')
# ('DONE with', 10, 'of', 25, 'of GEN', '14', 'with Fitness', '4.84')
# ('DONE with', 11, 'of', 25, 'of GEN', '14', 'with Fitness', '12.07')
# ('DONE with', 12, 'of', 25, 'of GEN', '14', 'with Fitness', '10.69')
# ('DONE with', 13, 'of', 25, 'of GEN', '14', 'with Fitness', '7.81')
# ('DONE with', 14, 'of', 25, 'of GEN', '14', 'with Fitness', '6.02')
# ('DONE with', 15, 'of', 25, 'of GEN', '14', 'with Fitness', '5.81')
# ('DONE with', 16, 'of', 25, 'of GEN', '14', 'with Fitness', '36.70')
# ('DONE with', 17, 'of', 25, 'of GEN', '14', 'with Fitness', '6.06')
# ('DONE with', 18, 'of', 25, 'of GEN', '14', 'with Fitness', '11.24')
# ('DONE with', 19, 'of', 25, 'of GEN', '14', 'with Fitness', '5.48')
# ('DONE with', 20, 'of', 25, 'of GEN', '14', 'with Fitness', '18.62')
# ('DONE with', 21, 'of', 25, 'of GEN', '14', 'with Fitness', '4.95')
# ('DONE with', 22, 'of', 25, 'of GEN', '14', 'with Fitness', '5.09')
# ('DONE with', 23, 'of', 25, 'of GEN', '14', 'with Fitness', '14.18')
# ('DONE with', 24, 'of', 25, 'of GEN', '14', 'with Fitness', '4.94')
# ('DONE with', 25, 'of', 25, 'of GEN', '14', 'with Fitness', '4.79')
# ('Generation', 14, 'out of', 200, 'COMPLETE')
# ('Best fitness:', 4.794407758771733)
# ('Best individual', [0.6894850848661034, 54.95315608419278, 3.553334302331439, 43.156484896757014, -49.50647388390325, -78.74188810848844, 0.00018330473895951567, 7.394243997915121, 0.06871747357199524, 0.14722737230872723, 0.06923319785840239, -54.78869053050586, 1.105418599575017e-05, 0.024391455262029356])
# 20.33% of range. Val: 0.689485084866 Low: 0.1 High: 3.0 ATTR: diam in ['apical']
# 43.44% of range. Val: 54.9531560842 Low: 5.0 High: 120.0 ATTR: Ra in ['all']
# 34.88% of range. Val: 3.55333430233 Low: 0.1 High: 10.0 ATTR: cm in ['all']
# 82.89% of range. Val: 43.1564848968 Low: 10.0 High: 50.0 ATTR: ena in ['all']
# ...
# ('DONE with', 21, 'of', 25, 'of GEN', '196', 'with Fitness', '7.44')
# ('DONE with', 22, 'of', 25, 'of GEN', '196', 'with Fitness', '3.60')
# ('DONE with', 23, 'of', 25, 'of GEN', '196', 'with Fitness', '5.46')
# ('DONE with', 24, 'of', 25, 'of GEN', '196', 'with Fitness', '7.01')
# ('DONE with', 25, 'of', 25, 'of GEN', '196', 'with Fitness', '19.86')
# ('Generation', 196, 'out of', 200, 'COMPLETE')
# ('Best fitness:', 3.599211212583726)
# ('Best individual', [0.6612176297384526, 58.094003958059446, 3.3943923884236686, 37.26904050043951, -49.50647388390325, -86.25711959382369, 9.692038669317667e-05, 8.307611212489611, 0.09335591754413584, 0.14722737230872723, 0.04182067505119284, -57.7385836483234, 6.56570790637639e-07, 0.001077740080191274])
# 19.35% of range. Val: 0.661217629738 Low: 0.1 High: 3.0 ATTR: diam in ['apical']
# 46.17% of range. Val: 58.0940039581 Low: 5.0 High: 120.0 ATTR: Ra in ['all']
# 33.28% of range. Val: 3.39439238842 Low: 0.1 High: 10.0 ATTR: cm in ['all']
# 68.17% of range. Val: 37.2690405004 Low: 10.0 High: 50.0 ATTR: ena in ['all']
# 72.13% of range. Val: -49.5064738839 Low: -100.0 High: -30.0 ATTR: ek in ['all']
# 27.49% of range. Val: -86.2571195938 Low: -100.0 High: -50.0 ATTR: e_pas in ['all']
# 4.85% of range. Val: 9.69203866932e-05 Low: 0 High: 0.002 ATTR: g_pas in ['all']
# 83.08% of range. Val: 8.30761121249 Low: 0 High: 10 ATTR: sh_Na in ['all']
# 93.36% of range. Val: 0.0933559175441 Low: 0 High: 0.1 ATTR: gbar_Na in ['all']
# 36.81% of range. Val: 0.147227372309 Low: 0 High: 0.4 ATTR: gbar_Kd in ['all']
# 10.46% of range. Val: 0.0418206750512 Low: 0 High: 0.4 ATTR: gbar_KA in ['somatic']
# 4.52% of range. Val: -57.7385836483 Low: -60.0 High: -10.0 ATTR: eh in ['somatic']
# 0.66% of range. Val: 6.56570790638e-07 Low: 0 High: 0.0001 ATTR: gbar_Ih in ['somatic']
# 0.83% of range. Val: 0.00107774008019 Low: 0 High: 0.13 ATTR: gbar_KM in ['somatic']
# ('GEN', 197, 'Parents', 5, 'Elite', 13, 'DIV', 6, 'RND', 6, 'TOT NEW', 25)
# ('STARTED GEN', '197', 'size', 25)
# ('DONE with', 1, 'of', 25, 'of GEN', '197', 'with Fitness', '25.31')
# ('DONE with', 2, 'of', 25, 'of GEN', '197', 'with Fitness', '151.00')
# ('DONE with', 3, 'of', 25, 'of GEN', '197', 'with Fitness', '87.00')
# ('DONE with', 4, 'of', 25, 'of GEN', '197', 'with Fitness', '118.00')
# ('DONE with', 5, 'of', 25, 'of GEN', '197', 'with Fitness', '203.68')
# ('DONE with', 6, 'of', 25, 'of GEN', '197', 'with Fitness', '74.02')
# ('DONE with', 7, 'of', 25, 'of GEN', '197', 'with Fitness', '10.61')
# ('DONE with', 8, 'of', 25, 'of GEN', '197', 'with Fitness', '12.49')
# ('DONE with', 9, 'of', 25, 'of GEN', '197', 'with Fitness', '8.31')
# ('DONE with', 10, 'of', 25, 'of GEN', '197', 'with Fitness', '18.72')
# ('DONE with', 11, 'of', 25, 'of GEN', '197', 'with Fitness', '18.57')
# ('DONE with', 12, 'of', 25, 'of GEN', '197', 'with Fitness', '7.62')
# ('DONE with', 13, 'of', 25, 'of GEN', '197', 'with Fitness', '3.60')
# ('DONE with', 14, 'of', 25, 'of GEN', '197', 'with Fitness', '3.60')
# ('DONE with', 15, 'of', 25, 'of GEN', '197', 'with Fitness', '7.08')
# ('DONE with', 16, 'of', 25, 'of GEN', '197', 'with Fitness', '3.60')
# ('DONE with', 17, 'of', 25, 'of GEN', '197', 'with Fitness', '11.55')
# ('DONE with', 18, 'of', 25, 'of GEN', '197', 'with Fitness', '3.60')
# ('DONE with', 19, 'of', 25, 'of GEN', '197', 'with Fitness', '3.60')
# ('DONE with', 20, 'of', 25, 'of GEN', '197', 'with Fitness', '12.37')
# ('DONE with', 21, 'of', 25, 'of GEN', '197', 'with Fitness', '16.03')
# ('DONE with', 22, 'of', 25, 'of GEN', '197', 'with Fitness', '24.16')
# ('DONE with', 23, 'of', 25, 'of GEN', '197', 'with Fitness', '45.45')
# ('DONE with', 24, 'of', 25, 'of GEN', '197', 'with Fitness', '10.51')
# ('DONE with', 25, 'of', 25, 'of GEN', '197', 'with Fitness', '4.03')
# ('Generation', 197, 'out of', 200, 'COMPLETE')
# ('Best fitness:', 3.599211212583726)
# ('Best individual', [0.6612176297384526, 58.094003958059446, 3.3943923884236686, 37.26904050043951, -49.50647388390325, -86.25711959382369, 9.692038669317667e-05, 8.307611212489611, 0.09335591754413584, 0.14722737230872723, 0.04182067505119284, -57.7385836483234, 6.56570790637639e-07, 0.001077740080191274])
# 19.35% of range. Val: 0.661217629738 Low: 0.1 High: 3.0 ATTR: diam in ['apical']
# 46.17% of range. Val: 58.0940039581 Low: 5.0 High: 120.0 ATTR: Ra in ['all']
# 33.28% of range. Val: 3.39439238842 Low: 0.1 High: 10.0 ATTR: cm in ['all']
# 68.17% of range. Val: 37.2690405004 Low: 10.0 High: 50.0 ATTR: ena in ['all']
# 72.13% of range. Val: -49.5064738839 Low: -100.0 High: -30.0 ATTR: ek in ['all']
# 27.49% of range. Val: -86.2571195938 Low: -100.0 High: -50.0 ATTR: e_pas in ['all']
# 4.85% of range. Val: 9.69203866932e-05 Low: 0 High: 0.002 ATTR: g_pas in ['all']
# 83.08% of range. Val: 8.30761121249 Low: 0 High: 10 ATTR: sh_Na in ['all']
# 93.36% of range. Val: 0.0933559175441 Low: 0 High: 0.1 ATTR: gbar_Na in ['all']
# 36.81% of range. Val: 0.147227372309 Low: 0 High: 0.4 ATTR: gbar_Kd in ['all']
# 10.46% of range. Val: 0.0418206750512 Low: 0 High: 0.4 ATTR: gbar_KA in ['somatic']
# 4.52% of range. Val: -57.7385836483 Low: -60.0 High: -10.0 ATTR: eh in ['somatic']
# 0.66% of range. Val: 6.56570790638e-07 Low: 0 High: 0.0001 ATTR: gbar_Ih in ['somatic']
# 0.83% of range. Val: 0.00107774008019 Low: 0 High: 0.13 ATTR: gbar_KM in ['somatic']
# ('GEN', 198, 'Parents', 5, 'Elite', 13, 'DIV', 6, 'RND', 6, 'TOT NEW', 25)
# ('STARTED GEN', '198', 'size', 25)
# ('DONE with', 1, 'of', 25, 'of GEN', '198', 'with Fitness', '18.98')
# ('DONE with', 2, 'of', 25, 'of GEN', '198', 'with Fitness', '38.55')
# ('DONE with', 3, 'of', 25, 'of GEN', '198', 'with Fitness', '20.58')
# ('DONE with', 4, 'of', 25, 'of GEN', '198', 'with Fitness', '77.15')
# ('DONE with', 5, 'of', 25, 'of GEN', '198', 'with Fitness', '21.68')
# ('DONE with', 6, 'of', 25, 'of GEN', '198', 'with Fitness', '14.58')
# ('DONE with', 7, 'of', 25, 'of GEN', '198', 'with Fitness', '8.33')
# ('DONE with', 8, 'of', 25, 'of GEN', '198', 'with Fitness', '6.58')
# ('DONE with', 9, 'of', 25, 'of GEN', '198', 'with Fitness', '9.54')
# ('DONE with', 10, 'of', 25, 'of GEN', '198', 'with Fitness', '7.86')
# ('DONE with', 11, 'of', 25, 'of GEN', '198', 'with Fitness', '9.57')
# ('DONE with', 12, 'of', 25, 'of GEN', '198', 'with Fitness', '3.72')
# ('DONE with', 13, 'of', 25, 'of GEN', '198', 'with Fitness', '31.71')
# ('DONE with', 14, 'of', 25, 'of GEN', '198', 'with Fitness', '3.60')
# ('DONE with', 15, 'of', 25, 'of GEN', '198', 'with Fitness', '9.87')
# ('DONE with', 16, 'of', 25, 'of GEN', '198', 'with Fitness', '7.15')
# ('DONE with', 17, 'of', 25, 'of GEN', '198', 'with Fitness', '3.60')
# ('DONE with', 18, 'of', 25, 'of GEN', '198', 'with Fitness', '4.24')
# ('DONE with', 19, 'of', 25, 'of GEN', '198', 'with Fitness', '9.82')
# ('DONE with', 20, 'of', 25, 'of GEN', '198', 'with Fitness', '6.94')
# ('DONE with', 21, 'of', 25, 'of GEN', '198', 'with Fitness', '16.42')
# ('DONE with', 22, 'of', 25, 'of GEN', '198', 'with Fitness', '6.30')
# ('DONE with', 23, 'of', 25, 'of GEN', '198', 'with Fitness', '45.94')
# ('DONE with', 24, 'of', 25, 'of GEN', '198', 'with Fitness', '8.07')
# ('DONE with', 25, 'of', 25, 'of GEN', '198', 'with Fitness', '6.64')
# ('Generation', 198, 'out of', 200, 'COMPLETE')
# ('Best fitness:', 3.599211212583726)
# ('Best individual', [0.6612176297384526, 58.094003958059446, 3.3943923884236686, 37.26904050043951, -49.50647388390325, -86.25711959382369, 9.692038669317667e-05, 8.307611212489611, 0.09335591754413584, 0.14722737230872723, 0.04182067505119284, -57.7385836483234, 6.56570790637639e-07, 0.001077740080191274])
# 19.35% of range. Val: 0.661217629738 Low: 0.1 High: 3.0 ATTR: diam in ['apical']
# 46.17% of range. Val: 58.0940039581 Low: 5.0 High: 120.0 ATTR: Ra in ['all']
# 33.28% of range. Val: 3.39439238842 Low: 0.1 High: 10.0 ATTR: cm in ['all']
# 68.17% of range. Val: 37.2690405004 Low: 10.0 High: 50.0 ATTR: ena in ['all']
# 72.13% of range. Val: -49.5064738839 Low: -100.0 High: -30.0 ATTR: ek in ['all']
# 27.49% of range. Val: -86.2571195938 Low: -100.0 High: -50.0 ATTR: e_pas in ['all']
# 4.85% of range. Val: 9.69203866932e-05 Low: 0 High: 0.002 ATTR: g_pas in ['all']
# 83.08% of range. Val: 8.30761121249 Low: 0 High: 10 ATTR: sh_Na in ['all']
# 93.36% of range. Val: 0.0933559175441 Low: 0 High: 0.1 ATTR: gbar_Na in ['all']
# 36.81% of range. Val: 0.147227372309 Low: 0 High: 0.4 ATTR: gbar_Kd in ['all']
# 10.46% of range. Val: 0.0418206750512 Low: 0 High: 0.4 ATTR: gbar_KA in ['somatic']
# 4.52% of range. Val: -57.7385836483 Low: -60.0 High: -10.0 ATTR: eh in ['somatic']
# 0.66% of range. Val: 6.56570790638e-07 Low: 0 High: 0.0001 ATTR: gbar_Ih in ['somatic']
# 0.83% of range. Val: 0.00107774008019 Low: 0 High: 0.13 ATTR: gbar_KM in ['somatic']
# ('GEN', 199, 'Parents', 5, 'Elite', 13, 'DIV', 6, 'RND', 6, 'TOT NEW', 25)
# ('STARTED GEN', '199', 'size', 25)
# ('DONE with', 1, 'of', 25, 'of GEN', '199', 'with Fitness', '20.38')
# ('DONE with', 2, 'of', 25, 'of GEN', '199', 'with Fitness', '16.68')
# ('DONE with', 3, 'of', 25, 'of GEN', '199', 'with Fitness', '155.65')
# ('DONE with', 4, 'of', 25, 'of GEN', '199', 'with Fitness', '39.76')
# ('DONE with', 5, 'of', 25, 'of GEN', '199', 'with Fitness', '62.79')
# ('DONE with', 6, 'of', 25, 'of GEN', '199', 'with Fitness', '65.19')
# ('DONE with', 7, 'of', 25, 'of GEN', '199', 'with Fitness', '15.01')
# ('DONE with', 8, 'of', 25, 'of GEN', '199', 'with Fitness', '9.52')
# ('DONE with', 9, 'of', 25, 'of GEN', '199', 'with Fitness', '4.17')
# ('DONE with', 10, 'of', 25, 'of GEN', '199', 'with Fitness', '3.84')
# ('DONE with', 11, 'of', 25, 'of GEN', '199', 'with Fitness', '7.16')
# ('DONE with', 12, 'of', 25, 'of GEN', '199', 'with Fitness', '4.81')
# ('DONE with', 13, 'of', 25, 'of GEN', '199', 'with Fitness', '12.08')
# ('DONE with', 14, 'of', 25, 'of GEN', '199', 'with Fitness', '16.59')
# ('DONE with', 15, 'of', 25, 'of GEN', '199', 'with Fitness', '9.87')
# ('DONE with', 16, 'of', 25, 'of GEN', '199', 'with Fitness', '3.92')
# ('DONE with', 17, 'of', 25, 'of GEN', '199', 'with Fitness', '3.91')
# ('DONE with', 18, 'of', 25, 'of GEN', '199', 'with Fitness', '32.78')
# ('DONE with', 19, 'of', 25, 'of GEN', '199', 'with Fitness', '9.42')
# ('DONE with', 20, 'of', 25, 'of GEN', '199', 'with Fitness', '3.60')
# ('DONE with', 21, 'of', 25, 'of GEN', '199', 'with Fitness', '4.82')
# ('DONE with', 22, 'of', 25, 'of GEN', '199', 'with Fitness', '3.60')
# ('DONE with', 23, 'of', 25, 'of GEN', '199', 'with Fitness', '3.60')
# ('DONE with', 24, 'of', 25, 'of GEN', '199', 'with Fitness', '3.60')
# ('DONE with', 25, 'of', 25, 'of GEN', '199', 'with Fitness', '3.60')
# ('Generation', 199, 'out of', 200, 'COMPLETE')
# ('Best fitness:', 3.599211212583726)
# ('Best individual', [0.6612176297384526, 58.094003958059446, 3.3943923884236686, 37.26904050043951, -49.50647388390325, -86.25711959382369, 9.692038669317667e-05, 8.307611212489611, 0.09335591754413584, 0.14722737230872723, 0.04182067505119284, -57.7385836483234, 6.56570790637639e-07, 0.001077740080191274])
# 19.35% of range. Val: 0.661217629738 Low: 0.1 High: 3.0 ATTR: diam in ['apical']
# 46.17% of range. Val: 58.0940039581 Low: 5.0 High: 120.0 ATTR: Ra in ['all']
# 33.28% of range. Val: 3.39439238842 Low: 0.1 High: 10.0 ATTR: cm in ['all']
# 68.17% of range. Val: 37.2690405004 Low: 10.0 High: 50.0 ATTR: ena in ['all']
# 72.13% of range. Val: -49.5064738839 Low: -100.0 High: -30.0 ATTR: ek in ['all']
# 27.49% of range. Val: -86.2571195938 Low: -100.0 High: -50.0 ATTR: e_pas in ['all']
# 4.85% of range. Val: 9.69203866932e-05 Low: 0 High: 0.002 ATTR: g_pas in ['all']
# 83.08% of range. Val: 8.30761121249 Low: 0 High: 10 ATTR: sh_Na in ['all']
# 93.36% of range. Val: 0.0933559175441 Low: 0 High: 0.1 ATTR: gbar_Na in ['all']
# 36.81% of range. Val: 0.147227372309 Low: 0 High: 0.4 ATTR: gbar_Kd in ['all']
# 10.46% of range. Val: 0.0418206750512 Low: 0 High: 0.4 ATTR: gbar_KA in ['somatic']
# 4.52% of range. Val: -57.7385836483 Low: -60.0 High: -10.0 ATTR: eh in ['somatic']
# 0.66% of range. Val: 6.56570790638e-07 Low: 0 High: 0.0001 ATTR: gbar_Ih in ['somatic']
# 0.83% of range. Val: 0.00107774008019 Low: 0 High: 0.13 ATTR: gbar_KM in ['somatic']
# ('GEN', 200, 'Parents', 5, 'Elite', 13, 'DIV', 6, 'RND', 6, 'TOT NEW', 25)
# ('STARTED GEN', '200', 'size', 25)
# ('DONE with', 1, 'of', 25, 'of GEN', '200', 'with Fitness', '31.63')
# ('DONE with', 2, 'of', 25, 'of GEN', '200', 'with Fitness', '53.53')
# ('DONE with', 3, 'of', 25, 'of GEN', '200', 'with Fitness', '21.19')
# ('DONE with', 4, 'of', 25, 'of GEN', '200', 'with Fitness', '69.91')
# ('DONE with', 5, 'of', 25, 'of GEN', '200', 'with Fitness', '114.95')
# ('DONE with', 6, 'of', 25, 'of GEN', '200', 'with Fitness', '40.80')
# ('DONE with', 7, 'of', 25, 'of GEN', '200', 'with Fitness', '22.65')
# ('DONE with', 8, 'of', 25, 'of GEN', '200', 'with Fitness', '15.01')
# ('DONE with', 9, 'of', 25, 'of GEN', '200', 'with Fitness', '15.17')
# ('DONE with', 10, 'of', 25, 'of GEN', '200', 'with Fitness', '14.56')
# ('DONE with', 11, 'of', 25, 'of GEN', '200', 'with Fitness', '31.51')
# ('DONE with', 12, 'of', 25, 'of GEN', '200', 'with Fitness', '84.13')
# ('DONE with', 13, 'of', 25, 'of GEN', '200', 'with Fitness', '4.03')
# ('DONE with', 14, 'of', 25, 'of GEN', '200', 'with Fitness', '4.24')
# ('DONE with', 15, 'of', 25, 'of GEN', '200', 'with Fitness', '16.19')
# ('DONE with', 16, 'of', 25, 'of GEN', '200', 'with Fitness', '3.60')
# ('DONE with', 17, 'of', 25, 'of GEN', '200', 'with Fitness', '3.90')
# ('DONE with', 18, 'of', 25, 'of GEN', '200', 'with Fitness', '9.97')
# ('DONE with', 19, 'of', 25, 'of GEN', '200', 'with Fitness', '3.60')
# ('DONE with', 20, 'of', 25, 'of GEN', '200', 'with Fitness', '8.07')
# ('DONE with', 21, 'of', 25, 'of GEN', '200', 'with Fitness', '16.36')
# ('DONE with', 22, 'of', 25, 'of GEN', '200', 'with Fitness', '3.60')
# ('DONE with', 23, 'of', 25, 'of GEN', '200', 'with Fitness', '4.39')
# ('DONE with', 24, 'of', 25, 'of GEN', '200', 'with Fitness', '3.60')
# ('DONE with', 25, 'of', 25, 'of GEN', '200', 'with Fitness', '19.77')
# ('Generation', 200, 'out of', 200, 'COMPLETE')
# ('Best fitness:', 3.599211212583726)
# ('Best individual', [0.6612176297384526, 58.094003958059446, 3.3943923884236686, 37.26904050043951, -49.50647388390325, -86.25711959382369, 9.692038669317667e-05, 8.307611212489611, 0.09335591754413584, 0.14722737230872723, 0.04182067505119284, -57.7385836483234, 6.56570790637639e-07, 0.001077740080191274])
# 19.35% of range. Val: 0.661217629738 Low: 0.1 High: 3.0 ATTR: diam in ['apical']
# 46.17% of range. Val: 58.0940039581 Low: 5.0 High: 120.0 ATTR: Ra in ['all']
# 33.28% of range. Val: 3.39439238842 Low: 0.1 High: 10.0 ATTR: cm in ['all']
# 68.17% of range. Val: 37.2690405004 Low: 10.0 High: 50.0 ATTR: ena in ['all']
# 72.13% of range. Val: -49.5064738839 Low: -100.0 High: -30.0 ATTR: ek in ['all']
# 27.49% of range. Val: -86.2571195938 Low: -100.0 High: -50.0 ATTR: e_pas in ['all']
# 4.85% of range. Val: 9.69203866932e-05 Low: 0 High: 0.002 ATTR: g_pas in ['all']
# 83.08% of range. Val: 8.30761121249 Low: 0 High: 10 ATTR: sh_Na in ['all']
# 93.36% of range. Val: 0.0933559175441 Low: 0 High: 0.1 ATTR: gbar_Na in ['all']
# 36.81% of range. Val: 0.147227372309 Low: 0 High: 0.4 ATTR: gbar_Kd in ['all']
# 10.46% of range. Val: 0.0418206750512 Low: 0 High: 0.4 ATTR: gbar_KA in ['somatic']
# 4.52% of range. Val: -57.7385836483 Low: -60.0 High: -10.0 ATTR: eh in ['somatic']
# 0.66% of range. Val: 6.56570790638e-07 Low: 0 High: 0.0001 ATTR: gbar_Ih in ['somatic']
# 0.83% of range. Val: 0.00107774008019 Low: 0 High: 0.13 ATTR: gbar_KM in ['somatic']
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-4-a70bc2619298> in <module>()
#       2 #fitter.top = [[0.518568993696911, 22.331096575385537, 3.9991551066170175, 44.54836939907614, -55.16528090080958, -89.29463560245307, 0.00018368809366833735, 2.922232364299777, 0.07465156310126753, 0.19498287109045842, 0.03935002363776688, -49.39660394446575, 2.548528534052994e-06, 0.006660630409332343]]
#       3 fitter.fit(25, 200)
# ----> 4 raise
#
# TypeError: exceptions must be old-style classes or derived from BaseException, not NoneType

# %%
fitter.best = []

# %%
df, score = fitter.get_best_score()
print(score["model_score"]) 
df.transpose()

# %%
raise

# %%
from prev_ob_models.Birgiolas2020.isolated_cells import GC2
gc = GC2()
gc.param_values

# %%
from scipy.optimize import minimize
def evaluate(ind):
    print(ind)
    score = float(fitter.evaluate(ind)[0])
    print("score", score)
    return score

min_res = minimize(evaluate, gc.param_values, method='Powell', 
                   options={"disp":False, "maxfev":45, "maxiter":100})#,"xtol":0.1,"ftol":0.1})
min_res

# %%
raise

# %%
fitter.clear_cache()

# %%
fitter.fit(20, 7)

# %%
fitter.parameter_report(fitter.best)

# %%
raise

# %%
#fitter.clear_cache()
#fitter.best = []
df, score = fitter.get_best_score()
print(score["model_score"]) 
df.transpose()

# %%
score

# %%
fitter.clear_cache()
df = fitter.get_previous_model_scores()
df

# %%
df.to_csv("ephyz/"+fitter.cell_type+"_model_zscores.csv")

# %%
raise

# %%
np.linspace(0,100,0.1)

# %%
score["model_score"]

# %%
raise

# %%
fitter.top = None

# %%
cpus = multiprocessing.cpu_count()
fitter.fit(int(cpus*1.5), 48)

# %%
fitter.clear_cache()
fitter.best = []
df, score = fitter.get_best_score()
df

# %%
score["model_score"]

# %%
fitter.pretty_pop()

# %%
from prev_ob_models.Birgiolas2020.isolated_cells import MC1
mc = MC1()

# %%
fitter.print_params(fitter.best, mc.cell)
