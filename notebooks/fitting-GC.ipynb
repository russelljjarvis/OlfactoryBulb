# %%
import os; os.chdir("..");
import multiprocessing
from prev_ob_models.Birgiolas2020.fitting import *
# Out:
# /home/justas/anaconda2/envs/p27/lib/python2.7/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Could not load NEURONBackend

# %%
import sys
cell_id = sys.argv[1] if len(sys.argv) > 1 and sys.argv[1].isdigit() else 1

# %%
fitter = CellFitter(cell_type="mc", fitting_model_class="prev_ob_models.Birgiolas2020.isolated_cells.MC1")
# Out:
# ('Starting mc FITTER for model:', 'prev_ob_models.Birgiolas2020.isolated_cells.MC1')

# %%
fitter.clear_cache()
fitter.best = [4.483822127802881, 8.66219433612183, 0.8924323616844085, 22.781408934638648, -71.36528075596314, -68.12595932359295, 3.6318149288201166e-05, 1.5349502819878742, 9.731038623592067, 0.045200023063995017, 0.037639185681536326, 0.000539438090733542, 0.008199477373572574, 0.0018205696406990688, 0.00043444216625588845, -32.66490045884105, 3.9928550864601285e-07, 0.005060526438354798]
df, score = fitter.get_best_score()
print(score)
df
raise
# Out:
# [[Model]]
#     Model(ifr_func)
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 121
#     # data points      = 32
#     # variables        = 3
#     chi-square         = 1692.47875
#     reduced chi-square = 58.3613363
#     Akaike info crit   = 132.982834
#     Bayesian info crit = 137.380041
# [[Variables]]
#     start:   18.5203460 +/- 3.01989321 (16.31%) (init = 25)
#     finish:  8665.38814 +/- 1.0859e+08 (1253152.43%) (init = 25.64103)
#     tau:     7250953.76 +/- 9.1061e+10 (1255853.65%) (init = 10)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(finish, tau)   =  1.000
#     C(start, tau)    =  0.346
#     C(start, finish) =  0.346
# ...

# %%
fitter.clear_cache()
fitter.fit(30, 45)

# %%
fitter.parameter_report(fitter.best)

# %%
raise

# %%
score

# %%
fitter.clear_cache()
df = fitter.get_previous_model_scores()
df

# %%
df.to_csv("ephyz/"+fitter.cell_type+"_model_zscores.csv")

# %%
raise

# %%
np.linspace(0,100,0.1)

# %%
score["model_score"]

# %%
raise

# %%
fitter.top = None

# %%
cpus = multiprocessing.cpu_count()
fitter.fit(int(cpus*1.5), 48)

# %%
fitter.clear_cache()
fitter.best = []
df, score = fitter.get_best_score()
df

# %%
score["model_score"]

# %%
fitter.pretty_pop()

# %%
from prev_ob_models.Birgiolas2020.isolated_cells import MC1
mc = MC1()

# %%
fitter.print_params(fitter.best, mc.cell)
