# %%
import os; os.chdir("..");
import multiprocessing
from prev_ob_models.Birgiolas2020.fitting import *
# Out:
# /home/justas/anaconda2/envs/p27/lib/python2.7/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Could not load NEURONBackend

# %%
import sys
cell_id = sys.argv[1] if len(sys.argv) > 1 and sys.argv[1].isdigit() else 4
print(cell_id)
# Out:
# 4

# %%
fitter = CellFitter(cell_type="gc", fitting_model_class="prev_ob_models.Birgiolas2020.isolated_cells.GC"+str(cell_id))
# Out:
# ('Starting gc FITTER for model:', 'prev_ob_models.Birgiolas2020.isolated_cells.GC4')

# %%
fitter.clear_cache()
#fitter.top = [[0.518568993696911, 22.331096575385537, 3.9991551066170175, 44.54836939907614, -55.16528090080958, -89.29463560245307, 0.00018368809366833735, 2.922232364299777, 0.07465156310126753, 0.19498287109045842, 0.03935002363776688, -49.39660394446575, 2.548528534052994e-06, 0.006660630409332343]]
fitter.fit(25, 200)
raise
# Out:
# ('STARTED GEN', 'ZERO', 'size', 25)
# ('DONE with', 1, 'of', 25, 'of GEN', 'ZERO', 'with Fitness', '16.69')
# ('DONE with', 2, 'of', 25, 'of GEN', 'ZERO', 'with Fitness', '62.84')
# ('DONE with', 3, 'of', 25, 'of GEN', 'ZERO', 'with Fitness', '21.36')
# ('DONE with', 4, 'of', 25, 'of GEN', 'ZERO', 'with Fitness', '32.26')
# ('DONE with', 5, 'of', 25, 'of GEN', 'ZERO', 'with Fitness', '10.76')
# ('DONE with', 6, 'of', 25, 'of GEN', 'ZERO', 'with Fitness', '182.89')
# ('DONE with', 7, 'of', 25, 'of GEN', 'ZERO', 'with Fitness', '21.30')
# ('DONE with', 8, 'of', 25, 'of GEN', 'ZERO', 'with Fitness', '181.76')
# ('DONE with', 9, 'of', 25, 'of GEN', 'ZERO', 'with Fitness', '24.76')
# ('DONE with', 10, 'of', 25, 'of GEN', 'ZERO', 'with Fitness', '18.03')
# ('DONE with', 11, 'of', 25, 'of GEN', 'ZERO', 'with Fitness', '46.69')
# ('DONE with', 12, 'of', 25, 'of GEN', 'ZERO', 'with Fitness', '13.72')
# ('DONE with', 13, 'of', 25, 'of GEN', 'ZERO', 'with Fitness', '43.26')
# ('DONE with', 14, 'of', 25, 'of GEN', 'ZERO', 'with Fitness', '15.90')
# ('DONE with', 15, 'of', 25, 'of GEN', 'ZERO', 'with Fitness', '13.62')
# ('DONE with', 16, 'of', 25, 'of GEN', 'ZERO', 'with Fitness', '155.96')
# ('DONE with', 17, 'of', 25, 'of GEN', 'ZERO', 'with Fitness', '106.45')
# ('DONE with', 18, 'of', 25, 'of GEN', 'ZERO', 'with Fitness', '16.84')
# ('DONE with', 19, 'of', 25, 'of GEN', 'ZERO', 'with Fitness', '17.51')
# ('DONE with', 20, 'of', 25, 'of GEN', 'ZERO', 'with Fitness', '12.60')
# ('DONE with', 21, 'of', 25, 'of GEN', 'ZERO', 'with Fitness', '24.98')
# ('DONE with', 22, 'of', 25, 'of GEN', 'ZERO', 'with Fitness', '62.03')
# ('DONE with', 23, 'of', 25, 'of GEN', 'ZERO', 'with Fitness', '15.00')
# ('DONE with', 24, 'of', 25, 'of GEN', 'ZERO', 'with Fitness', '18.75')
# ('DONE with', 25, 'of', 25, 'of GEN', 'ZERO', 'with Fitness', '42.50')
# ('GEN', 1, 'Parents', 5, 'Elite', 13, 'DIV', 6, 'RND', 6, 'TOT NEW', 25)
# ('STARTED GEN', '1', 'size', 25)
# ('DONE with', 1, 'of', 25, 'of GEN', '1', 'with Fitness', '37.32')
# ('DONE with', 2, 'of', 25, 'of GEN', '1', 'with Fitness', '31.68')
# ('DONE with', 3, 'of', 25, 'of GEN', '1', 'with Fitness', '49.87')
# ('DONE with', 4, 'of', 25, 'of GEN', '1', 'with Fitness', '10.34')
# ('DONE with', 5, 'of', 25, 'of GEN', '1', 'with Fitness', '14.36')
# ('DONE with', 6, 'of', 25, 'of GEN', '1', 'with Fitness', '13.50')
# ('DONE with', 7, 'of', 25, 'of GEN', '1', 'with Fitness', '21.78')
# ('DONE with', 8, 'of', 25, 'of GEN', '1', 'with Fitness', '15.11')
# ('DONE with', 9, 'of', 25, 'of GEN', '1', 'with Fitness', '17.28')
# ('DONE with', 10, 'of', 25, 'of GEN', '1', 'with Fitness', '49.75')
# ('DONE with', 11, 'of', 25, 'of GEN', '1', 'with Fitness', '111.16')
# ('DONE with', 12, 'of', 25, 'of GEN', '1', 'with Fitness', '14.68')
# ('DONE with', 13, 'of', 25, 'of GEN', '1', 'with Fitness', '10.80')
# ('DONE with', 14, 'of', 25, 'of GEN', '1', 'with Fitness', '14.83')
# ('DONE with', 15, 'of', 25, 'of GEN', '1', 'with Fitness', '9.30')
# ('DONE with', 16, 'of', 25, 'of GEN', '1', 'with Fitness', '16.07')
# ('DONE with', 17, 'of', 25, 'of GEN', '1', 'with Fitness', '7.50')
# ('DONE with', 18, 'of', 25, 'of GEN', '1', 'with Fitness', '11.15')
# ('DONE with', 19, 'of', 25, 'of GEN', '1', 'with Fitness', '12.55')
# ('DONE with', 20, 'of', 25, 'of GEN', '1', 'with Fitness', '12.41')
# ('DONE with', 21, 'of', 25, 'of GEN', '1', 'with Fitness', '57.51')
# ('DONE with', 22, 'of', 25, 'of GEN', '1', 'with Fitness', '17.46')
# ('DONE with', 23, 'of', 25, 'of GEN', '1', 'with Fitness', '13.52')
# ('DONE with', 24, 'of', 25, 'of GEN', '1', 'with Fitness', '15.00')
# ('DONE with', 25, 'of', 25, 'of GEN', '1', 'with Fitness', '18.64')
# ('Generation', 1, 'out of', 200, 'COMPLETE')
# ('Best fitness:', 7.4969501362637585)
# ('Best individual', [0.4335140212478267, 38.64829654340649, 1.6511237492454793, 37.24029237221385, -40.74842921653776, -62.717917643131706, 0.0019249752362564823, 2.4170107638055383, 0.06365606941762758, 0.3415813792506557, 0.35399523853287757, -33.204551081459535, 9.308812413121528e-05, 0.04996987314422066])
# 11.50% of range. Val: 0.433514021248 Low: 0.1 High: 3.0 ATTR: diam in ['apical']
# 29.26% of range. Val: 38.6482965434 Low: 5.0 High: 120.0 ATTR: Ra in ['all']
# 15.67% of range. Val: 1.65112374925 Low: 0.1 High: 10.0 ATTR: cm in ['all']
# 68.10% of range. Val: 37.2402923722 Low: 10.0 High: 50.0 ATTR: ena in ['all']
# 84.65% of range. Val: -40.7484292165 Low: -100.0 High: -30.0 ATTR: ek in ['all']
# 74.56% of range. Val: -62.7179176431 Low: -100.0 High: -50.0 ATTR: e_pas in ['all']
# 96.25% of range. Val: 0.00192497523626 Low: 0 High: 0.002 ATTR: g_pas in ['all']
# 24.17% of range. Val: 2.41701076381 Low: 0 High: 10 ATTR: sh_Na in ['all']
# 63.66% of range. Val: 0.0636560694176 Low: 0 High: 0.1 ATTR: gbar_Na in ['all']
# 85.40% of range. Val: 0.341581379251 Low: 0 High: 0.4 ATTR: gbar_Kd in ['all']
# 88.50% of range. Val: 0.353995238533 Low: 0 High: 0.4 ATTR: gbar_KA in ['somatic']
# 53.59% of range. Val: -33.2045510815 Low: -60.0 High: -10.0 ATTR: eh in ['somatic']
# 93.09% of range. Val: 9.30881241312e-05 Low: 0 High: 0.0001 ATTR: gbar_Ih in ['somatic']
# 38.44% of range. Val: 0.0499698731442 Low: 0 High: 0.13 ATTR: gbar_KM in ['somatic']
# ('GEN', 2, 'Parents', 5, 'Elite', 13, 'DIV', 6, 'RND', 6, 'TOT NEW', 25)
# ('STARTED GEN', '2', 'size', 25)
# ('DONE with', 1, 'of', 25, 'of GEN', '2', 'with Fitness', '99.67')
# ('DONE with', 2, 'of', 25, 'of GEN', '2', 'with Fitness', '93.61')
# ('DONE with', 3, 'of', 25, 'of GEN', '2', 'with Fitness', '17.18')
# ('DONE with', 4, 'of', 25, 'of GEN', '2', 'with Fitness', '67.58')
# ('DONE with', 5, 'of', 25, 'of GEN', '2', 'with Fitness', '25.13')
# ('DONE with', 6, 'of', 25, 'of GEN', '2', 'with Fitness', '96.57')
# ('DONE with', 7, 'of', 25, 'of GEN', '2', 'with Fitness', '13.20')
# ('DONE with', 8, 'of', 25, 'of GEN', '2', 'with Fitness', '27.50')
# ('DONE with', 9, 'of', 25, 'of GEN', '2', 'with Fitness', '15.48')
# ('DONE with', 10, 'of', 25, 'of GEN', '2', 'with Fitness', '13.48')
# ('DONE with', 11, 'of', 25, 'of GEN', '2', 'with Fitness', '31.33')
# ('DONE with', 12, 'of', 25, 'of GEN', '2', 'with Fitness', '8.29')
# ('DONE with', 13, 'of', 25, 'of GEN', '2', 'with Fitness', '16.59')
# ('DONE with', 14, 'of', 25, 'of GEN', '2', 'with Fitness', '20.52')
# ('DONE with', 15, 'of', 25, 'of GEN', '2', 'with Fitness', '13.50')
# ('DONE with', 16, 'of', 25, 'of GEN', '2', 'with Fitness', '18.76')
# ('DONE with', 17, 'of', 25, 'of GEN', '2', 'with Fitness', '21.34')
# ('DONE with', 18, 'of', 25, 'of GEN', '2', 'with Fitness', '22.84')
# ('DONE with', 19, 'of', 25, 'of GEN', '2', 'with Fitness', '18.30')
# ('DONE with', 20, 'of', 25, 'of GEN', '2', 'with Fitness', '7.64')
# ('DONE with', 21, 'of', 25, 'of GEN', '2', 'with Fitness', '10.10')
# ('DONE with', 22, 'of', 25, 'of GEN', '2', 'with Fitness', '43.04')
# ('DONE with', 23, 'of', 25, 'of GEN', '2', 'with Fitness', '48.15')
# ('DONE with', 24, 'of', 25, 'of GEN', '2', 'with Fitness', '17.15')
# ('DONE with', 25, 'of', 25, 'of GEN', '2', 'with Fitness', '10.80')
# ('Generation', 2, 'out of', 200, 'COMPLETE')
# ('Best fitness:', 7.4969501362637585)
# ('Best individual', [0.4335140212478267, 38.64829654340649, 1.6511237492454793, 37.24029237221385, -40.74842921653776, -62.717917643131706, 0.0019249752362564823, 2.4170107638055383, 0.06365606941762758, 0.3415813792506557, 0.35399523853287757, -33.204551081459535, 9.308812413121528e-05, 0.04996987314422066])
# 11.50% of range. Val: 0.433514021248 Low: 0.1 High: 3.0 ATTR: diam in ['apical']
# 29.26% of range. Val: 38.6482965434 Low: 5.0 High: 120.0 ATTR: Ra in ['all']
# 15.67% of range. Val: 1.65112374925 Low: 0.1 High: 10.0 ATTR: cm in ['all']
# 68.10% of range. Val: 37.2402923722 Low: 10.0 High: 50.0 ATTR: ena in ['all']
# 84.65% of range. Val: -40.7484292165 Low: -100.0 High: -30.0 ATTR: ek in ['all']
# 74.56% of range. Val: -62.7179176431 Low: -100.0 High: -50.0 ATTR: e_pas in ['all']
# 96.25% of range. Val: 0.00192497523626 Low: 0 High: 0.002 ATTR: g_pas in ['all']
# 24.17% of range. Val: 2.41701076381 Low: 0 High: 10 ATTR: sh_Na in ['all']
# 63.66% of range. Val: 0.0636560694176 Low: 0 High: 0.1 ATTR: gbar_Na in ['all']
# 85.40% of range. Val: 0.341581379251 Low: 0 High: 0.4 ATTR: gbar_Kd in ['all']
# 88.50% of range. Val: 0.353995238533 Low: 0 High: 0.4 ATTR: gbar_KA in ['somatic']
# 53.59% of range. Val: -33.2045510815 Low: -60.0 High: -10.0 ATTR: eh in ['somatic']
# 93.09% of range. Val: 9.30881241312e-05 Low: 0 High: 0.0001 ATTR: gbar_Ih in ['somatic']
# 38.44% of range. Val: 0.0499698731442 Low: 0 High: 0.13 ATTR: gbar_KM in ['somatic']
# ('GEN', 3, 'Parents', 5, 'Elite', 13, 'DIV', 6, 'RND', 6, 'TOT NEW', 25)
# ('STARTED GEN', '3', 'size', 24)
# ('DONE with', 1, 'of', 24, 'of GEN', '3', 'with Fitness', '10.44')
# ('DONE with', 2, 'of', 24, 'of GEN', '3', 'with Fitness', '47.46')
# ('DONE with', 3, 'of', 24, 'of GEN', '3', 'with Fitness', '24.67')
# ('DONE with', 4, 'of', 24, 'of GEN', '3', 'with Fitness', '20.00')
# ('DONE with', 5, 'of', 24, 'of GEN', '3', 'with Fitness', '31.03')
# ('DONE with', 6, 'of', 24, 'of GEN', '3', 'with Fitness', '62.30')
# ('DONE with', 7, 'of', 24, 'of GEN', '3', 'with Fitness', '71.83')
# ('DONE with', 8, 'of', 24, 'of GEN', '3', 'with Fitness', '21.25')
# ('DONE with', 9, 'of', 24, 'of GEN', '3', 'with Fitness', '21.81')
# ('DONE with', 10, 'of', 24, 'of GEN', '3', 'with Fitness', '49.74')
# ('DONE with', 11, 'of', 24, 'of GEN', '3', 'with Fitness', '17.17')
# ('DONE with', 12, 'of', 24, 'of GEN', '3', 'with Fitness', '9.18')
# ('DONE with', 13, 'of', 24, 'of GEN', '3', 'with Fitness', '12.92')
# ('DONE with', 14, 'of', 24, 'of GEN', '3', 'with Fitness', '15.93')
# ('DONE with', 15, 'of', 24, 'of GEN', '3', 'with Fitness', '7.64')
# ('DONE with', 16, 'of', 24, 'of GEN', '3', 'with Fitness', '9.84')
# ('DONE with', 17, 'of', 24, 'of GEN', '3', 'with Fitness', '10.21')
# ('DONE with', 18, 'of', 24, 'of GEN', '3', 'with Fitness', '15.10')
# ('DONE with', 19, 'of', 24, 'of GEN', '3', 'with Fitness', '9.47')
# ('DONE with', 20, 'of', 24, 'of GEN', '3', 'with Fitness', '7.49')
# ('DONE with', 21, 'of', 24, 'of GEN', '3', 'with Fitness', '16.94')
# ('DONE with', 22, 'of', 24, 'of GEN', '3', 'with Fitness', '13.33')
# ('DONE with', 23, 'of', 24, 'of GEN', '3', 'with Fitness', '14.59')
# ('DONE with', 24, 'of', 24, 'of GEN', '3', 'with Fitness', '14.65')
# ('Generation', 3, 'out of', 200, 'COMPLETE')
# ('Best fitness:', 7.489812623663538)
# ('Best individual', [0.4335140212478267, 32.08696276610501, 1.6511237492454793, 38.202148759987395, -40.74842921653776, -62.717917643131706, 0.0019249752362564823, 2.4170107638055383, 0.06365606941762758, 0.3709232464037927, 0.3527133605887902, -41.8744622751733, 9.288734740515726e-05, 0.04996987314422066])
# 11.50% of range. Val: 0.433514021248 Low: 0.1 High: 3.0 ATTR: diam in ['apical']
# 23.55% of range. Val: 32.0869627661 Low: 5.0 High: 120.0 ATTR: Ra in ['all']
# 15.67% of range. Val: 1.65112374925 Low: 0.1 High: 10.0 ATTR: cm in ['all']
# 70.51% of range. Val: 38.20214876 Low: 10.0 High: 50.0 ATTR: ena in ['all']
# 84.65% of range. Val: -40.7484292165 Low: -100.0 High: -30.0 ATTR: ek in ['all']
# 74.56% of range. Val: -62.7179176431 Low: -100.0 High: -50.0 ATTR: e_pas in ['all']
# 96.25% of range. Val: 0.00192497523626 Low: 0 High: 0.002 ATTR: g_pas in ['all']
# 24.17% of range. Val: 2.41701076381 Low: 0 High: 10 ATTR: sh_Na in ['all']
# 63.66% of range. Val: 0.0636560694176 Low: 0 High: 0.1 ATTR: gbar_Na in ['all']
# 92.73% of range. Val: 0.370923246404 Low: 0 High: 0.4 ATTR: gbar_Kd in ['all']
# 88.18% of range. Val: 0.352713360589 Low: 0 High: 0.4 ATTR: gbar_KA in ['somatic']
# 36.25% of range. Val: -41.8744622752 Low: -60.0 High: -10.0 ATTR: eh in ['somatic']
# 92.89% of range. Val: 9.28873474052e-05 Low: 0 High: 0.0001 ATTR: gbar_Ih in ['somatic']
# 38.44% of range. Val: 0.0499698731442 Low: 0 High: 0.13 ATTR: gbar_KM in ['somatic']
# ('GEN', 4, 'Parents', 5, 'Elite', 13, 'DIV', 6, 'RND', 6, 'TOT NEW', 25)
# ('STARTED GEN', '4', 'size', 25)
# ('DONE with', 1, 'of', 25, 'of GEN', '4', 'with Fitness', '44.15')
# ('DONE with', 2, 'of', 25, 'of GEN', '4', 'with Fitness', '120.07')
# ('DONE with', 3, 'of', 25, 'of GEN', '4', 'with Fitness', '39.18')
# ('DONE with', 4, 'of', 25, 'of GEN', '4', 'with Fitness', '33.55')
# ('DONE with', 5, 'of', 25, 'of GEN', '4', 'with Fitness', '33.26')
# ('DONE with', 6, 'of', 25, 'of GEN', '4', 'with Fitness', '73.86')
# ('DONE with', 7, 'of', 25, 'of GEN', '4', 'with Fitness', '24.55')
# ('DONE with', 8, 'of', 25, 'of GEN', '4', 'with Fitness', '12.95')
# ('DONE with', 9, 'of', 25, 'of GEN', '4', 'with Fitness', '43.28')
# ('DONE with', 10, 'of', 25, 'of GEN', '4', 'with Fitness', '13.06')
# ('DONE with', 11, 'of', 25, 'of GEN', '4', 'with Fitness', '9.21')
# ('DONE with', 12, 'of', 25, 'of GEN', '4', 'with Fitness', '15.51')
# ('DONE with', 13, 'of', 25, 'of GEN', '4', 'with Fitness', '15.53')
# ('DONE with', 14, 'of', 25, 'of GEN', '4', 'with Fitness', '7.66')
# ('DONE with', 15, 'of', 25, 'of GEN', '4', 'with Fitness', '7.50')
# ('DONE with', 16, 'of', 25, 'of GEN', '4', 'with Fitness', '12.99')
# ('DONE with', 17, 'of', 25, 'of GEN', '4', 'with Fitness', '7.63')
# ('DONE with', 18, 'of', 25, 'of GEN', '4', 'with Fitness', '7.64')
# ('DONE with', 19, 'of', 25, 'of GEN', '4', 'with Fitness', '8.46')
# ('DONE with', 20, 'of', 25, 'of GEN', '4', 'with Fitness', '8.12')
# ('DONE with', 21, 'of', 25, 'of GEN', '4', 'with Fitness', '8.63')
# ('DONE with', 22, 'of', 25, 'of GEN', '4', 'with Fitness', '14.87')
# ('DONE with', 23, 'of', 25, 'of GEN', '4', 'with Fitness', '7.65')
# ('DONE with', 24, 'of', 25, 'of GEN', '4', 'with Fitness', '15.44')
# ('DONE with', 25, 'of', 25, 'of GEN', '4', 'with Fitness', '7.64')
# ('Generation', 4, 'out of', 200, 'COMPLETE')
# ('Best fitness:', 7.489812623663538)
# ('Best individual', [0.4335140212478267, 32.08696276610501, 1.6511237492454793, 38.202148759987395, -40.74842921653776, -62.717917643131706, 0.0019249752362564823, 2.4170107638055383, 0.06365606941762758, 0.3709232464037927, 0.3527133605887902, -41.8744622751733, 9.288734740515726e-05, 0.04996987314422066])
# 11.50% of range. Val: 0.433514021248 Low: 0.1 High: 3.0 ATTR: diam in ['apical']
# 23.55% of range. Val: 32.0869627661 Low: 5.0 High: 120.0 ATTR: Ra in ['all']
# 15.67% of range. Val: 1.65112374925 Low: 0.1 High: 10.0 ATTR: cm in ['all']
# 70.51% of range. Val: 38.20214876 Low: 10.0 High: 50.0 ATTR: ena in ['all']
# 84.65% of range. Val: -40.7484292165 Low: -100.0 High: -30.0 ATTR: ek in ['all']
# 74.56% of range. Val: -62.7179176431 Low: -100.0 High: -50.0 ATTR: e_pas in ['all']
# 96.25% of range. Val: 0.00192497523626 Low: 0 High: 0.002 ATTR: g_pas in ['all']
# 24.17% of range. Val: 2.41701076381 Low: 0 High: 10 ATTR: sh_Na in ['all']
# 63.66% of range. Val: 0.0636560694176 Low: 0 High: 0.1 ATTR: gbar_Na in ['all']
# 92.73% of range. Val: 0.370923246404 Low: 0 High: 0.4 ATTR: gbar_Kd in ['all']
# 88.18% of range. Val: 0.352713360589 Low: 0 High: 0.4 ATTR: gbar_KA in ['somatic']
# 36.25% of range. Val: -41.8744622752 Low: -60.0 High: -10.0 ATTR: eh in ['somatic']
# 92.89% of range. Val: 9.28873474052e-05 Low: 0 High: 0.0001 ATTR: gbar_Ih in ['somatic']
# 38.44% of range. Val: 0.0499698731442 Low: 0 High: 0.13 ATTR: gbar_KM in ['somatic']
# ('GEN', 5, 'Parents', 5, 'Elite', 13, 'DIV', 6, 'RND', 6, 'TOT NEW', 25)
# ('STARTED GEN', '5', 'size', 25)
# ('DONE with', 1, 'of', 25, 'of GEN', '5', 'with Fitness', '22.02')
# ('DONE with', 2, 'of', 25, 'of GEN', '5', 'with Fitness', '31.65')
# ('DONE with', 3, 'of', 25, 'of GEN', '5', 'with Fitness', '16.61')
# ('DONE with', 4, 'of', 25, 'of GEN', '5', 'with Fitness', '18.24')
# ('DONE with', 5, 'of', 25, 'of GEN', '5', 'with Fitness', '12.46')
# ('DONE with', 6, 'of', 25, 'of GEN', '5', 'with Fitness', '48.57')
# ('DONE with', 7, 'of', 25, 'of GEN', '5', 'with Fitness', '44.15')
# ('DONE with', 8, 'of', 25, 'of GEN', '5', 'with Fitness', '44.15')
# ('DONE with', 9, 'of', 25, 'of GEN', '5', 'with Fitness', '66.32')
# ('DONE with', 10, 'of', 25, 'of GEN', '5', 'with Fitness', '16.19')
# ('DONE with', 11, 'of', 25, 'of GEN', '5', 'with Fitness', '54.96')
# ('DONE with', 12, 'of', 25, 'of GEN', '5', 'with Fitness', '13.56')
# ('DONE with', 13, 'of', 25, 'of GEN', '5', 'with Fitness', '15.46')
# ('DONE with', 14, 'of', 25, 'of GEN', '5', 'with Fitness', '8.04')
# ('DONE with', 15, 'of', 25, 'of GEN', '5', 'with Fitness', '15.28')
# ('DONE with', 16, 'of', 25, 'of GEN', '5', 'with Fitness', '7.46')
# ('DONE with', 17, 'of', 25, 'of GEN', '5', 'with Fitness', '20.64')
# ('DONE with', 18, 'of', 25, 'of GEN', '5', 'with Fitness', '23.84')
# ('DONE with', 19, 'of', 25, 'of GEN', '5', 'with Fitness', '14.69')
# ('DONE with', 20, 'of', 25, 'of GEN', '5', 'with Fitness', '14.11')
# ('DONE with', 21, 'of', 25, 'of GEN', '5', 'with Fitness', '7.48')
# ('DONE with', 22, 'of', 25, 'of GEN', '5', 'with Fitness', '7.50')
# ('DONE with', 23, 'of', 25, 'of GEN', '5', 'with Fitness', '7.50')
# ('DONE with', 24, 'of', 25, 'of GEN', '5', 'with Fitness', '7.49')
# ('DONE with', 25, 'of', 25, 'of GEN', '5', 'with Fitness', '7.49')
# ('Generation', 5, 'out of', 200, 'COMPLETE')
# ('Best fitness:', 7.459183647021675)
# ('Best individual', [0.4335140212478267, 32.08696276610501, 1.6511237492454793, 27.432335707263036, -40.74842921653776, -62.717917643131706, 0.0019249752362564823, 2.4170107638055383, 0.07582202125058907, 0.2895604437163665, 0.3543566015112563, -46.7193296001189, 9.288734740515726e-05, 0.04996987314422066])
# 11.50% of range. Val: 0.433514021248 Low: 0.1 High: 3.0 ATTR: diam in ['apical']
# 23.55% of range. Val: 32.0869627661 Low: 5.0 High: 120.0 ATTR: Ra in ['all']
# 15.67% of range. Val: 1.65112374925 Low: 0.1 High: 10.0 ATTR: cm in ['all']
# 43.58% of range. Val: 27.4323357073 Low: 10.0 High: 50.0 ATTR: ena in ['all']
# 84.65% of range. Val: -40.7484292165 Low: -100.0 High: -30.0 ATTR: ek in ['all']
# 74.56% of range. Val: -62.7179176431 Low: -100.0 High: -50.0 ATTR: e_pas in ['all']
# 96.25% of range. Val: 0.00192497523626 Low: 0 High: 0.002 ATTR: g_pas in ['all']
# 24.17% of range. Val: 2.41701076381 Low: 0 High: 10 ATTR: sh_Na in ['all']
# 75.82% of range. Val: 0.0758220212506 Low: 0 High: 0.1 ATTR: gbar_Na in ['all']
# 72.39% of range. Val: 0.289560443716 Low: 0 High: 0.4 ATTR: gbar_Kd in ['all']
# 88.59% of range. Val: 0.354356601511 Low: 0 High: 0.4 ATTR: gbar_KA in ['somatic']
# 26.56% of range. Val: -46.7193296001 Low: -60.0 High: -10.0 ATTR: eh in ['somatic']
# 92.89% of range. Val: 9.28873474052e-05 Low: 0 High: 0.0001 ATTR: gbar_Ih in ['somatic']
# 38.44% of range. Val: 0.0499698731442 Low: 0 High: 0.13 ATTR: gbar_KM in ['somatic']
# ('GEN', 6, 'Parents', 5, 'Elite', 13, 'DIV', 6, 'RND', 6, 'TOT NEW', 25)
# ('STARTED GEN', '6', 'size', 25)
# ('DONE with', 1, 'of', 25, 'of GEN', '6', 'with Fitness', '8.69')
# ('DONE with', 2, 'of', 25, 'of GEN', '6', 'with Fitness', '60.05')
# ('DONE with', 3, 'of', 25, 'of GEN', '6', 'with Fitness', '52.58')
# ('DONE with', 4, 'of', 25, 'of GEN', '6', 'with Fitness', '150.89')
# ('DONE with', 5, 'of', 25, 'of GEN', '6', 'with Fitness', '9.41')
# ('DONE with', 6, 'of', 25, 'of GEN', '6', 'with Fitness', '36.07')
# ('DONE with', 7, 'of', 25, 'of GEN', '6', 'with Fitness', '53.12')
# ('DONE with', 8, 'of', 25, 'of GEN', '6', 'with Fitness', '90.61')
# ('DONE with', 9, 'of', 25, 'of GEN', '6', 'with Fitness', '7.94')
# ('DONE with', 10, 'of', 25, 'of GEN', '6', 'with Fitness', '17.41')
# ('DONE with', 11, 'of', 25, 'of GEN', '6', 'with Fitness', '8.46')
# ('DONE with', 12, 'of', 25, 'of GEN', '6', 'with Fitness', '67.96')
# ('DONE with', 13, 'of', 25, 'of GEN', '6', 'with Fitness', '7.70')
# ('DONE with', 14, 'of', 25, 'of GEN', '6', 'with Fitness', '15.46')
# ('DONE with', 15, 'of', 25, 'of GEN', '6', 'with Fitness', '21.93')
# ('DONE with', 16, 'of', 25, 'of GEN', '6', 'with Fitness', '7.40')
# ('DONE with', 17, 'of', 25, 'of GEN', '6', 'with Fitness', '13.73')
# ('DONE with', 18, 'of', 25, 'of GEN', '6', 'with Fitness', '13.31')
# ('DONE with', 19, 'of', 25, 'of GEN', '6', 'with Fitness', '7.45')
# ('DONE with', 20, 'of', 25, 'of GEN', '6', 'with Fitness', '7.46')
# ('DONE with', 21, 'of', 25, 'of GEN', '6', 'with Fitness', '7.49')
# ('DONE with', 22, 'of', 25, 'of GEN', '6', 'with Fitness', '7.49')
# ('DONE with', 23, 'of', 25, 'of GEN', '6', 'with Fitness', '7.48')
# ('DONE with', 24, 'of', 25, 'of GEN', '6', 'with Fitness', '7.48')
# ('DONE with', 25, 'of', 25, 'of GEN', '6', 'with Fitness', '7.55')
# ('Generation', 6, 'out of', 200, 'COMPLETE')
# ('Best fitness:', 7.404685241243402)
# ('Best individual', [0.4335140212478267, 32.08696276610501, 1.6511237492454793, 38.202148759987395, -40.74842921653776, -62.717917643131706, 0.0019249752362564823, 0.31434048387346536, 0.06365606941762758, 0.3474244647543619, 0.35161698797683694, -41.90796339643212, 9.288734740515726e-05, 0.04996987314422066])
# 11.50% of range. Val: 0.433514021248 Low: 0.1 High: 3.0 ATTR: diam in ['apical']
# 23.55% of range. Val: 32.0869627661 Low: 5.0 High: 120.0 ATTR: Ra in ['all']
# 15.67% of range. Val: 1.65112374925 Low: 0.1 High: 10.0 ATTR: cm in ['all']
# 70.51% of range. Val: 38.20214876 Low: 10.0 High: 50.0 ATTR: ena in ['all']
# 84.65% of range. Val: -40.7484292165 Low: -100.0 High: -30.0 ATTR: ek in ['all']
# 74.56% of range. Val: -62.7179176431 Low: -100.0 High: -50.0 ATTR: e_pas in ['all']
# 96.25% of range. Val: 0.00192497523626 Low: 0 High: 0.002 ATTR: g_pas in ['all']
# 3.14% of range. Val: 0.314340483873 Low: 0 High: 10 ATTR: sh_Na in ['all']
# 63.66% of range. Val: 0.0636560694176 Low: 0 High: 0.1 ATTR: gbar_Na in ['all']
# 86.86% of range. Val: 0.347424464754 Low: 0 High: 0.4 ATTR: gbar_Kd in ['all']
# 87.90% of range. Val: 0.351616987977 Low: 0 High: 0.4 ATTR: gbar_KA in ['somatic']
# 36.18% of range. Val: -41.9079633964 Low: -60.0 High: -10.0 ATTR: eh in ['somatic']
# 92.89% of range. Val: 9.28873474052e-05 Low: 0 High: 0.0001 ATTR: gbar_Ih in ['somatic']
# 38.44% of range. Val: 0.0499698731442 Low: 0 High: 0.13 ATTR: gbar_KM in ['somatic']
# ('GEN', 7, 'Parents', 5, 'Elite', 13, 'DIV', 6, 'RND', 6, 'TOT NEW', 25)
# ('STARTED GEN', '7', 'size', 25)
# ('DONE with', 1, 'of', 25, 'of GEN', '7', 'with Fitness', '25.24')
# ('DONE with', 2, 'of', 25, 'of GEN', '7', 'with Fitness', '27.61')
# ('DONE with', 3, 'of', 25, 'of GEN', '7', 'with Fitness', '95.28')
# ('DONE with', 4, 'of', 25, 'of GEN', '7', 'with Fitness', '21.00')
# ('DONE with', 5, 'of', 25, 'of GEN', '7', 'with Fitness', '59.11')
# ('DONE with', 6, 'of', 25, 'of GEN', '7', 'with Fitness', '31.06')
# ('DONE with', 7, 'of', 25, 'of GEN', '7', 'with Fitness', '16.14')
# ('DONE with', 8, 'of', 25, 'of GEN', '7', 'with Fitness', '7.49')
# ('DONE with', 9, 'of', 25, 'of GEN', '7', 'with Fitness', '20.52')
# ('DONE with', 10, 'of', 25, 'of GEN', '7', 'with Fitness', '24.26')
# ('DONE with', 11, 'of', 25, 'of GEN', '7', 'with Fitness', '41.40')
# ('DONE with', 12, 'of', 25, 'of GEN', '7', 'with Fitness', '15.22')
# ('DONE with', 13, 'of', 25, 'of GEN', '7', 'with Fitness', '7.45')
# ('DONE with', 14, 'of', 25, 'of GEN', '7', 'with Fitness', '7.45')
# ('DONE with', 15, 'of', 25, 'of GEN', '7', 'with Fitness', '7.40')
# ('DONE with', 16, 'of', 25, 'of GEN', '7', 'with Fitness', '10.91')
# ('DONE with', 17, 'of', 25, 'of GEN', '7', 'with Fitness', '25.96')
# ('DONE with', 18, 'of', 25, 'of GEN', '7', 'with Fitness', '13.22')
# ('DONE with', 19, 'of', 25, 'of GEN', '7', 'with Fitness', '13.21')
# ('DONE with', 20, 'of', 25, 'of GEN', '7', 'with Fitness', '13.58')
# ('DONE with', 21, 'of', 25, 'of GEN', '7', 'with Fitness', '10.04')
# ('DONE with', 22, 'of', 25, 'of GEN', '7', 'with Fitness', '28.85')
# ('DONE with', 23, 'of', 25, 'of GEN', '7', 'with Fitness', '12.95')
# ('DONE with', 1, 'of', 25, 'of GEN', '7', 'with Fitness', '25.24')
# ('DONE with', 2, 'of', 25, 'of GEN', '7', 'with Fitness', '27.61')
# ('DONE with', 3, 'of', 25, 'of GEN', '7', 'with Fitness', '95.28')
# ('DONE with', 24, 'of', 25, 'of GEN', '7', 'with Fitness', '16.31')
# ('DONE with', 25, 'of', 25, 'of GEN', '7', 'with Fitness', '15.04')
# ('Generation', 7, 'out of', 200, 'COMPLETE')
# ('Best fitness:', 7.402750198378205)
# ('Best individual', [0.4335140212478267, 32.08696276610501, 1.6511237492454793, 34.6951438255939, -40.74842921653776, -62.717917643131706, 0.0019249752362564823, 2.4170107638055383, 0.06613574027136246, 0.2895604437163665, 0.34897484430371384, -46.7193296001189, 9.288734740515726e-05, 0.04996987314422066])
# 11.50% of range. Val: 0.433514021248 Low: 0.1 High: 3.0 ATTR: diam in ['apical']
# 23.55% of range. Val: 32.0869627661 Low: 5.0 High: 120.0 ATTR: Ra in ['all']
# 15.67% of range. Val: 1.65112374925 Low: 0.1 High: 10.0 ATTR: cm in ['all']
# 61.74% of range. Val: 34.6951438256 Low: 10.0 High: 50.0 ATTR: ena in ['all']
# 84.65% of range. Val: -40.7484292165 Low: -100.0 High: -30.0 ATTR: ek in ['all']
# 74.56% of range. Val: -62.7179176431 Low: -100.0 High: -50.0 ATTR: e_pas in ['all']
# 96.25% of range. Val: 0.00192497523626 Low: 0 High: 0.002 ATTR: g_pas in ['all']
# 24.17% of range. Val: 2.41701076381 Low: 0 High: 10 ATTR: sh_Na in ['all']
# 66.14% of range. Val: 0.0661357402714 Low: 0 High: 0.1 ATTR: gbar_Na in ['all']
# 72.39% of range. Val: 0.289560443716 Low: 0 High: 0.4 ATTR: gbar_Kd in ['all']
# 87.24% of range. Val: 0.348974844304 Low: 0 High: 0.4 ATTR: gbar_KA in ['somatic']
# 26.56% of range. Val: -46.7193296001 Low: -60.0 High: -10.0 ATTR: eh in ['somatic']
# 92.89% of range. Val: 9.28873474052e-05 Low: 0 High: 0.0001 ATTR: gbar_Ih in ['somatic']
# 38.44% of range. Val: 0.0499698731442 Low: 0 High: 0.13 ATTR: gbar_KM in ['somatic']
# ('GEN', 8, 'Parents', 5, 'Elite', 13, 'DIV', 6, 'RND', 6, 'TOT NEW', 25)
# ('STARTED GEN', '8', 'size', 25)
# ('DONE with', 1, 'of', 25, 'of GEN', '8', 'with Fitness', '22.70')
# ('DONE with', 2, 'of', 25, 'of GEN', '8', 'with Fitness', '59.85')
# ('DONE with', 3, 'of', 25, 'of GEN', '8', 'with Fitness', '175.31')
# ('DONE with', 4, 'of', 25, 'of GEN', '8', 'with Fitness', '7.24')
# ('DONE with', 5, 'of', 25, 'of GEN', '8', 'with Fitness', '127.36')
# ('DONE with', 6, 'of', 25, 'of GEN', '8', 'with Fitness', '10.62')
# ('DONE with', 7, 'of', 25, 'of GEN', '8', 'with Fitness', '19.19')
# ('DONE with', 8, 'of', 25, 'of GEN', '8', 'with Fitness', '18.85')
# ('DONE with', 9, 'of', 25, 'of GEN', '8', 'with Fitness', '7.81')
# ('DONE with', 10, 'of', 25, 'of GEN', '8', 'with Fitness', '27.72')
# ('DONE with', 11, 'of', 25, 'of GEN', '8', 'with Fitness', '16.57')
# ('DONE with', 12, 'of', 25, 'of GEN', '8', 'with Fitness', '52.75')
# ('DONE with', 13, 'of', 25, 'of GEN', '8', 'with Fitness', '17.27')
# ('DONE with', 14, 'of', 25, 'of GEN', '8', 'with Fitness', '7.52')
# ('DONE with', 15, 'of', 25, 'of GEN', '8', 'with Fitness', '7.43')
# ('DONE with', 16, 'of', 25, 'of GEN', '8', 'with Fitness', '7.45')
# ('DONE with', 17, 'of', 25, 'of GEN', '8', 'with Fitness', '7.40')
# ('DONE with', 18, 'of', 25, 'of GEN', '8', 'with Fitness', '15.36')
# ('DONE with', 19, 'of', 25, 'of GEN', '8', 'with Fitness', '7.43')
# ('DONE with', 20, 'of', 25, 'of GEN', '8', 'with Fitness', '14.91')
# ('DONE with', 21, 'of', 25, 'of GEN', '8', 'with Fitness', '7.93')
# ('DONE with', 22, 'of', 25, 'of GEN', '8', 'with Fitness', '7.46')
# ('DONE with', 23, 'of', 25, 'of GEN', '8', 'with Fitness', '7.45')
# ('DONE with', 24, 'of', 25, 'of GEN', '8', 'with Fitness', '17.24')
# ('DONE with', 25, 'of', 25, 'of GEN', '8', 'with Fitness', '7.40')
# ('Generation', 8, 'out of', 200, 'COMPLETE')
# ('Best fitness:', 7.243266971467126)
# ('Best individual', [0.13082854707540428, 109.90039857748263, 5.093708395677482, 16.367537781219283, -83.11277893103615, -78.02896923231582, 0.0018051166136933174, 4.895868059108724, 0.045758894255596955, 0.12170580190636673, 0.0708222703601905, -14.231433477823472, 7.360746721147024e-05, 0.05216205230532399])
# 1.06% of range. Val: 0.130828547075 Low: 0.1 High: 3.0 ATTR: diam in ['apical']
# 91.22% of range. Val: 109.900398577 Low: 5.0 High: 120.0 ATTR: Ra in ['all']
# 50.44% of range. Val: 5.09370839568 Low: 0.1 High: 10.0 ATTR: cm in ['all']
# 15.92% of range. Val: 16.3675377812 Low: 10.0 High: 50.0 ATTR: ena in ['all']
# 24.12% of range. Val: -83.112778931 Low: -100.0 High: -30.0 ATTR: ek in ['all']
# 43.94% of range. Val: -78.0289692323 Low: -100.0 High: -50.0 ATTR: e_pas in ['all']
# 90.26% of range. Val: 0.00180511661369 Low: 0 High: 0.002 ATTR: g_pas in ['all']
# 48.96% of range. Val: 4.89586805911 Low: 0 High: 10 ATTR: sh_Na in ['all']
# 45.76% of range. Val: 0.0457588942556 Low: 0 High: 0.1 ATTR: gbar_Na in ['all']
# 30.43% of range. Val: 0.121705801906 Low: 0 High: 0.4 ATTR: gbar_Kd in ['all']
# 17.71% of range. Val: 0.0708222703602 Low: 0 High: 0.4 ATTR: gbar_KA in ['somatic']
# 91.54% of range. Val: -14.2314334778 Low: -60.0 High: -10.0 ATTR: eh in ['somatic']
# 73.61% of range. Val: 7.36074672115e-05 Low: 0 High: 0.0001 ATTR: gbar_Ih in ['somatic']
# 40.12% of range. Val: 0.0521620523053 Low: 0 High: 0.13 ATTR: gbar_KM in ['somatic']
# ('GEN', 9, 'Parents', 5, 'Elite', 13, 'DIV', 6, 'RND', 6, 'TOT NEW', 25)
# ('STARTED GEN', '9', 'size', 25)
# ('DONE with', 1, 'of', 25, 'of GEN', '9', 'with Fitness', '7.21')
# ('DONE with', 2, 'of', 25, 'of GEN', '9', 'with Fitness', '84.32')
# ('DONE with', 3, 'of', 25, 'of GEN', '9', 'with Fitness', '10.96')
# ('DONE with', 4, 'of', 25, 'of GEN', '9', 'with Fitness', '45.73')
# ('DONE with', 5, 'of', 25, 'of GEN', '9', 'with Fitness', '55.99')
# ('DONE with', 6, 'of', 25, 'of GEN', '9', 'with Fitness', '15.27')
# ('DONE with', 7, 'of', 25, 'of GEN', '9', 'with Fitness', '12.97')
# ('DONE with', 8, 'of', 25, 'of GEN', '9', 'with Fitness', '15.65')
# ('DONE with', 9, 'of', 25, 'of GEN', '9', 'with Fitness', '148.36')
# ('DONE with', 10, 'of', 25, 'of GEN', '9', 'with Fitness', '15.05')
# ('DONE with', 11, 'of', 25, 'of GEN', '9', 'with Fitness', '7.46')
# ('DONE with', 12, 'of', 25, 'of GEN', '9', 'with Fitness', '7.42')
# ('DONE with', 13, 'of', 25, 'of GEN', '9', 'with Fitness', '14.74')
# ('DONE with', 14, 'of', 25, 'of GEN', '9', 'with Fitness', '7.70')
# ('DONE with', 15, 'of', 25, 'of GEN', '9', 'with Fitness', '15.04')
# ('DONE with', 16, 'of', 25, 'of GEN', '9', 'with Fitness', '8.08')
# ('DONE with', 17, 'of', 25, 'of GEN', '9', 'with Fitness', '7.40')
# ('DONE with', 18, 'of', 25, 'of GEN', '9', 'with Fitness', '11.71')
# ('DONE with', 19, 'of', 25, 'of GEN', '9', 'with Fitness', '8.76')
# ('DONE with', 20, 'of', 25, 'of GEN', '9', 'with Fitness', '17.65')
# ('DONE with', 21, 'of', 25, 'of GEN', '9', 'with Fitness', '11.52')
# ('DONE with', 22, 'of', 25, 'of GEN', '9', 'with Fitness', '7.34')
# ('DONE with', 23, 'of', 25, 'of GEN', '9', 'with Fitness', '7.40')
# ('DONE with', 24, 'of', 25, 'of GEN', '9', 'with Fitness', '16.57')
# ('DONE with', 25, 'of', 25, 'of GEN', '9', 'with Fitness', '7.40')
# ('Generation', 9, 'out of', 200, 'COMPLETE')
# ('Best fitness:', 7.206204333103041)
# ('Best individual', [0.5080700119140835, 26.750285857654738, 5.302337189781626, 48.419076504979856, -51.40932521056985, -88.71190906695047, 0.0006604474861551105, 1.504775964510523, 0.08040525866113094, 0.3372804698997551, 0.2014219279139908, -21.132754202852915, 3.697399211139712e-05, 0.011737806709267093])
# 14.07% of range. Val: 0.508070011914 Low: 0.1 High: 3.0 ATTR: diam in ['apical']
# 18.91% of range. Val: 26.7502858577 Low: 5.0 High: 120.0 ATTR: Ra in ['all']
# 52.55% of range. Val: 5.30233718978 Low: 0.1 High: 10.0 ATTR: cm in ['all']
# 96.05% of range. Val: 48.419076505 Low: 10.0 High: 50.0 ATTR: ena in ['all']
# 69.42% of range. Val: -51.4093252106 Low: -100.0 High: -30.0 ATTR: ek in ['all']
# 22.58% of range. Val: -88.711909067 Low: -100.0 High: -50.0 ATTR: e_pas in ['all']
# 33.02% of range. Val: 0.000660447486155 Low: 0 High: 0.002 ATTR: g_pas in ['all']
# 15.05% of range. Val: 1.50477596451 Low: 0 High: 10 ATTR: sh_Na in ['all']
# 80.41% of range. Val: 0.0804052586611 Low: 0 High: 0.1 ATTR: gbar_Na in ['all']
# 84.32% of range. Val: 0.3372804699 Low: 0 High: 0.4 ATTR: gbar_Kd in ['all']
# 50.36% of range. Val: 0.201421927914 Low: 0 High: 0.4 ATTR: gbar_KA in ['somatic']
# 77.73% of range. Val: -21.1327542029 Low: -60.0 High: -10.0 ATTR: eh in ['somatic']
# 36.97% of range. Val: 3.69739921114e-05 Low: 0 High: 0.0001 ATTR: gbar_Ih in ['somatic']
# 9.03% of range. Val: 0.0117378067093 Low: 0 High: 0.13 ATTR: gbar_KM in ['somatic']
# ('GEN', 10, 'Parents', 5, 'Elite', 13, 'DIV', 6, 'RND', 6, 'TOT NEW', 25)
# ('STARTED GEN', '10', 'size', 24)
# ('DONE with', 1, 'of', 24, 'of GEN', '10', 'with Fitness', '17.71')
# ('DONE with', 2, 'of', 24, 'of GEN', '10', 'with Fitness', '54.34')
# ('DONE with', 3, 'of', 24, 'of GEN', '10', 'with Fitness', '24.79')
# ('DONE with', 4, 'of', 24, 'of GEN', '10', 'with Fitness', '87.36')
# ('DONE with', 5, 'of', 24, 'of GEN', '10', 'with Fitness', '38.68')
# ('DONE with', 6, 'of', 24, 'of GEN', '10', 'with Fitness', '33.43')
# ('DONE with', 7, 'of', 24, 'of GEN', '10', 'with Fitness', '13.57')
# ('DONE with', 8, 'of', 24, 'of GEN', '10', 'with Fitness', '104.58')
# ('DONE with', 9, 'of', 24, 'of GEN', '10', 'with Fitness', '17.57')
# ('DONE with', 10, 'of', 24, 'of GEN', '10', 'with Fitness', '16.12')
# ('DONE with', 11, 'of', 24, 'of GEN', '10', 'with Fitness', '130.78')
# ('DONE with', 12, 'of', 24, 'of GEN', '10', 'with Fitness', '13.45')
# ('DONE with', 13, 'of', 24, 'of GEN', '10', 'with Fitness', '7.33')
# ('DONE with', 14, 'of', 24, 'of GEN', '10', 'with Fitness', '7.40')
# ('DONE with', 15, 'of', 24, 'of GEN', '10', 'with Fitness', '7.12')
# ('DONE with', 16, 'of', 24, 'of GEN', '10', 'with Fitness', '16.56')
# ('DONE with', 17, 'of', 24, 'of GEN', '10', 'with Fitness', '13.04')
# ('DONE with', 18, 'of', 24, 'of GEN', '10', 'with Fitness', '8.00')
# ('DONE with', 19, 'of', 24, 'of GEN', '10', 'with Fitness', '7.21')
# ('DONE with', 20, 'of', 24, 'of GEN', '10', 'with Fitness', '7.14')
# ('DONE with', 21, 'of', 24, 'of GEN', '10', 'with Fitness', '7.97')
# ('DONE with', 1, 'of', 24, 'of GEN', '10', 'with Fitness', '17.71')
# ('DONE with', 2, 'of', 24, 'of GEN', '10', 'with Fitness', '54.34')
# ('DONE with', 22, 'of', 24, 'of GEN', '10', 'with Fitness', '16.59')
# ('DONE with', 23, 'of', 24, 'of GEN', '10', 'with Fitness', '9.14')
# ('DONE with', 24, 'of', 24, 'of GEN', '10', 'with Fitness', '7.21')
# ('Generation', 10, 'out of', 200, 'COMPLETE')
# ('Best fitness:', 7.120318361155911)
# ('Best individual', [0.12430568498169774, 109.90039857748263, 5.093708395677482, 16.72689315165628, -49.95204096232243, -88.62761397443391, 0.0018051166136933174, 2.316016061492511, 0.05257728949738781, 0.12170580190636673, 0.0708222703601905, -14.231433477823472, 9.18558003324358e-05, 0.05216205230532399])
# 0.84% of range. Val: 0.124305684982 Low: 0.1 High: 3.0 ATTR: diam in ['apical']
# 91.22% of range. Val: 109.900398577 Low: 5.0 High: 120.0 ATTR: Ra in ['all']
# 50.44% of range. Val: 5.09370839568 Low: 0.1 High: 10.0 ATTR: cm in ['all']
# 16.82% of range. Val: 16.7268931517 Low: 10.0 High: 50.0 ATTR: ena in ['all']
# 71.50% of range. Val: -49.9520409623 Low: -100.0 High: -30.0 ATTR: ek in ['all']
# 22.74% of range. Val: -88.6276139744 Low: -100.0 High: -50.0 ATTR: e_pas in ['all']
# 90.26% of range. Val: 0.00180511661369 Low: 0 High: 0.002 ATTR: g_pas in ['all']
# 23.16% of range. Val: 2.31601606149 Low: 0 High: 10 ATTR: sh_Na in ['all']
# 52.58% of range. Val: 0.0525772894974 Low: 0 High: 0.1 ATTR: gbar_Na in ['all']
# 30.43% of range. Val: 0.121705801906 Low: 0 High: 0.4 ATTR: gbar_Kd in ['all']
# 17.71% of range. Val: 0.0708222703602 Low: 0 High: 0.4 ATTR: gbar_KA in ['somatic']
# 91.54% of range. Val: -14.2314334778 Low: -60.0 High: -10.0 ATTR: eh in ['somatic']
# 91.86% of range. Val: 9.18558003324e-05 Low: 0 High: 0.0001 ATTR: gbar_Ih in ['somatic']
# 40.12% of range. Val: 0.0521620523053 Low: 0 High: 0.13 ATTR: gbar_KM in ['somatic']
# ('GEN', 11, 'Parents', 5, 'Elite', 13, 'DIV', 6, 'RND', 6, 'TOT NEW', 25)
# ('STARTED GEN', '11', 'size', 25)
# ('DONE with', 1, 'of', 25, 'of GEN', '11', 'with Fitness', '20.35')
# ('DONE with', 2, 'of', 25, 'of GEN', '11', 'with Fitness', '40.00')
# ('DONE with', 3, 'of', 25, 'of GEN', '11', 'with Fitness', '7.17')
# ('DONE with', 4, 'of', 25, 'of GEN', '11', 'with Fitness', '45.69')
# ('DONE with', 5, 'of', 25, 'of GEN', '11', 'with Fitness', '23.72')
# ('DONE with', 6, 'of', 25, 'of GEN', '11', 'with Fitness', '16.42')
# ('DONE with', 7, 'of', 25, 'of GEN', '11', 'with Fitness', '28.02')
# ('DONE with', 8, 'of', 25, 'of GEN', '11', 'with Fitness', '21.24')
# ('DONE with', 9, 'of', 25, 'of GEN', '11', 'with Fitness', '9.48')
# ('DONE with', 10, 'of', 25, 'of GEN', '11', 'with Fitness', '31.46')
# ('DONE with', 11, 'of', 25, 'of GEN', '11', 'with Fitness', '12.18')
# ('DONE with', 12, 'of', 25, 'of GEN', '11', 'with Fitness', '15.52')
# ('DONE with', 13, 'of', 25, 'of GEN', '11', 'with Fitness', '12.65')
# ('DONE with', 14, 'of', 25, 'of GEN', '11', 'with Fitness', '7.21')
# ('DONE with', 15, 'of', 25, 'of GEN', '11', 'with Fitness', '9.58')
# ('DONE with', 16, 'of', 25, 'of GEN', '11', 'with Fitness', '11.34')
# ('DONE with', 17, 'of', 25, 'of GEN', '11', 'with Fitness', '26.90')
# ('DONE with', 18, 'of', 25, 'of GEN', '11', 'with Fitness', '7.12')
# ('DONE with', 19, 'of', 25, 'of GEN', '11', 'with Fitness', '7.21')
# ('DONE with', 20, 'of', 25, 'of GEN', '11', 'with Fitness', '7.21')
# ('DONE with', 21, 'of', 25, 'of GEN', '11', 'with Fitness', '12.61')
# ('DONE with', 22, 'of', 25, 'of GEN', '11', 'with Fitness', '6.74')
# ('DONE with', 23, 'of', 25, 'of GEN', '11', 'with Fitness', '7.14')
# ('DONE with', 24, 'of', 25, 'of GEN', '11', 'with Fitness', '10.97')
# ('DONE with', 25, 'of', 25, 'of GEN', '11', 'with Fitness', '35.98')
# ('Generation', 11, 'out of', 200, 'COMPLETE')
# ('Best fitness:', 6.736642921437372)
# ('Best individual', [0.5080700119140835, 91.5531827023072, 5.302337189781626, 48.419076504979856, -46.54699223765959, -88.72831394870667, 0.0014117318100816043, 1.5578423235956464, 0.08255911336096099, 0.3372804698997551, 0.2014219279139908, -21.132754202852915, 3.697399211139712e-05, 0.04343846721672243])
# 14.07% of range. Val: 0.508070011914 Low: 0.1 High: 3.0 ATTR: diam in ['apical']
# 75.26% of range. Val: 91.5531827023 Low: 5.0 High: 120.0 ATTR: Ra in ['all']
# 52.55% of range. Val: 5.30233718978 Low: 0.1 High: 10.0 ATTR: cm in ['all']
# 96.05% of range. Val: 48.419076505 Low: 10.0 High: 50.0 ATTR: ena in ['all']
# 76.36% of range. Val: -46.5469922377 Low: -100.0 High: -30.0 ATTR: ek in ['all']
# 22.54% of range. Val: -88.7283139487 Low: -100.0 High: -50.0 ATTR: e_pas in ['all']
# 70.59% of range. Val: 0.00141173181008 Low: 0 High: 0.002 ATTR: g_pas in ['all']
# 15.58% of range. Val: 1.5578423236 Low: 0 High: 10 ATTR: sh_Na in ['all']
# 82.56% of range. Val: 0.082559113361 Low: 0 High: 0.1 ATTR: gbar_Na in ['all']
# 84.32% of range. Val: 0.3372804699 Low: 0 High: 0.4 ATTR: gbar_Kd in ['all']
# 50.36% of range. Val: 0.201421927914 Low: 0 High: 0.4 ATTR: gbar_KA in ['somatic']
# 77.73% of range. Val: -21.1327542029 Low: -60.0 High: -10.0 ATTR: eh in ['somatic']
# 36.97% of range. Val: 3.69739921114e-05 Low: 0 High: 0.0001 ATTR: gbar_Ih in ['somatic']
# 33.41% of range. Val: 0.0434384672167 Low: 0 High: 0.13 ATTR: gbar_KM in ['somatic']
# ('GEN', 12, 'Parents', 5, 'Elite', 13, 'DIV', 6, 'RND', 6, 'TOT NEW', 25)
# ('STARTED GEN', '12', 'size', 25)
# ('DONE with', 1, 'of', 25, 'of GEN', '12', 'with Fitness', '105.44')
# ('DONE with', 2, 'of', 25, 'of GEN', '12', 'with Fitness', '10.23')
# ('DONE with', 3, 'of', 25, 'of GEN', '12', 'with Fitness', '33.55')
# ('DONE with', 4, 'of', 25, 'of GEN', '12', 'with Fitness', '25.91')
# ('DONE with', 5, 'of', 25, 'of GEN', '12', 'with Fitness', '11.26')
# ('DONE with', 6, 'of', 25, 'of GEN', '12', 'with Fitness', '26.27')
# ('DONE with', 7, 'of', 25, 'of GEN', '12', 'with Fitness', '43.39')
# ('DONE with', 8, 'of', 25, 'of GEN', '12', 'with Fitness', '6.92')
# ('DONE with', 9, 'of', 25, 'of GEN', '12', 'with Fitness', '36.88')
# ('DONE with', 10, 'of', 25, 'of GEN', '12', 'with Fitness', '13.10')
# ('DONE with', 11, 'of', 25, 'of GEN', '12', 'with Fitness', '8.88')
# ('DONE with', 12, 'of', 25, 'of GEN', '12', 'with Fitness', '11.22')
# ('DONE with', 13, 'of', 25, 'of GEN', '12', 'with Fitness', '7.14')
# ('DONE with', 14, 'of', 25, 'of GEN', '12', 'with Fitness', '8.73')
# ('DONE with', 15, 'of', 25, 'of GEN', '12', 'with Fitness', '7.65')
# ('DONE with', 16, 'of', 25, 'of GEN', '12', 'with Fitness', '13.07')
# ('DONE with', 17, 'of', 25, 'of GEN', '12', 'with Fitness', '7.12')
# ('DONE with', 18, 'of', 25, 'of GEN', '12', 'with Fitness', '7.06')
# ('DONE with', 19, 'of', 25, 'of GEN', '12', 'with Fitness', '14.87')
# ('DONE with', 20, 'of', 25, 'of GEN', '12', 'with Fitness', '14.05')
# ('DONE with', 21, 'of', 25, 'of GEN', '12', 'with Fitness', '14.11')
# ('DONE with', 22, 'of', 25, 'of GEN', '12', 'with Fitness', '7.00')
# ('DONE with', 23, 'of', 25, 'of GEN', '12', 'with Fitness', '7.14')
# ('DONE with', 24, 'of', 25, 'of GEN', '12', 'with Fitness', '7.14')
# ('DONE with', 25, 'of', 25, 'of GEN', '12', 'with Fitness', '6.98')
# ('Generation', 12, 'out of', 200, 'COMPLETE')
# ('Best fitness:', 6.736642921437372)
# ('Best individual', [0.5080700119140835, 91.5531827023072, 5.302337189781626, 48.419076504979856, -46.54699223765959, -88.72831394870667, 0.0014117318100816043, 1.5578423235956464, 0.08255911336096099, 0.3372804698997551, 0.2014219279139908, -21.132754202852915, 3.697399211139712e-05, 0.04343846721672243])
# 14.07% of range. Val: 0.508070011914 Low: 0.1 High: 3.0 ATTR: diam in ['apical']
# 75.26% of range. Val: 91.5531827023 Low: 5.0 High: 120.0 ATTR: Ra in ['all']
# 52.55% of range. Val: 5.30233718978 Low: 0.1 High: 10.0 ATTR: cm in ['all']
# 96.05% of range. Val: 48.419076505 Low: 10.0 High: 50.0 ATTR: ena in ['all']
# 76.36% of range. Val: -46.5469922377 Low: -100.0 High: -30.0 ATTR: ek in ['all']
# 22.54% of range. Val: -88.7283139487 Low: -100.0 High: -50.0 ATTR: e_pas in ['all']
# 70.59% of range. Val: 0.00141173181008 Low: 0 High: 0.002 ATTR: g_pas in ['all']
# 15.58% of range. Val: 1.5578423236 Low: 0 High: 10 ATTR: sh_Na in ['all']
# 82.56% of range. Val: 0.082559113361 Low: 0 High: 0.1 ATTR: gbar_Na in ['all']
# 84.32% of range. Val: 0.3372804699 Low: 0 High: 0.4 ATTR: gbar_Kd in ['all']
# 50.36% of range. Val: 0.201421927914 Low: 0 High: 0.4 ATTR: gbar_KA in ['somatic']
# 77.73% of range. Val: -21.1327542029 Low: -60.0 High: -10.0 ATTR: eh in ['somatic']
# 36.97% of range. Val: 3.69739921114e-05 Low: 0 High: 0.0001 ATTR: gbar_Ih in ['somatic']
# 33.41% of range. Val: 0.0434384672167 Low: 0 High: 0.13 ATTR: gbar_KM in ['somatic']
# ('GEN', 13, 'Parents', 5, 'Elite', 13, 'DIV', 6, 'RND', 6, 'TOT NEW', 25)
# ('STARTED GEN', '13', 'size', 25)
# ('DONE with', 1, 'of', 25, 'of GEN', '13', 'with Fitness', '63.39')
# ('DONE with', 2, 'of', 25, 'of GEN', '13', 'with Fitness', '40.98')
# ('DONE with', 3, 'of', 25, 'of GEN', '13', 'with Fitness', '38.38')
# ('DONE with', 4, 'of', 25, 'of GEN', '13', 'with Fitness', '123.45')
# ('DONE with', 5, 'of', 25, 'of GEN', '13', 'with Fitness', '19.20')
# ('DONE with', 6, 'of', 25, 'of GEN', '13', 'with Fitness', '39.62')
# ('DONE with', 7, 'of', 25, 'of GEN', '13', 'with Fitness', '15.04')
# ('DONE with', 8, 'of', 25, 'of GEN', '13', 'with Fitness', '22.98')
# ('DONE with', 9, 'of', 25, 'of GEN', '13', 'with Fitness', '14.98')
# ('DONE with', 10, 'of', 25, 'of GEN', '13', 'with Fitness', '73.38')
# ('DONE with', 11, 'of', 25, 'of GEN', '13', 'with Fitness', '36.54')
# ('DONE with', 12, 'of', 25, 'of GEN', '13', 'with Fitness', '13.77')
# ('DONE with', 13, 'of', 25, 'of GEN', '13', 'with Fitness', '7.32')
# ('DONE with', 14, 'of', 25, 'of GEN', '13', 'with Fitness', '15.20')
# ('DONE with', 15, 'of', 25, 'of GEN', '13', 'with Fitness', '7.00')
# ('DONE with', 16, 'of', 25, 'of GEN', '13', 'with Fitness', '9.44')
# ('DONE with', 17, 'of', 25, 'of GEN', '13', 'with Fitness', '9.74')
# ('DONE with', 18, 'of', 25, 'of GEN', '13', 'with Fitness', '6.72')
# ('DONE with', 19, 'of', 25, 'of GEN', '13', 'with Fitness', '6.68')
# ('DONE with', 20, 'of', 25, 'of GEN', '13', 'with Fitness', '8.81')
# ('DONE with', 21, 'of', 25, 'of GEN', '13', 'with Fitness', '14.91')
# ('DONE with', 22, 'of', 25, 'of GEN', '13', 'with Fitness', '6.76')
# ('DONE with', 23, 'of', 25, 'of GEN', '13', 'with Fitness', '6.04')
# ('DONE with', 24, 'of', 25, 'of GEN', '13', 'with Fitness', '8.65')
# ('DONE with', 25, 'of', 25, 'of GEN', '13', 'with Fitness', '12.36')
# ('Generation', 13, 'out of', 200, 'COMPLETE')
# ('Best fitness:', 6.040272072679819)
# ('Best individual', [0.16439877692169141, 14.7001785531141, 5.302337189781626, 48.419076504979856, -54.59563883264137, -86.0558800368305, 0.0006564090603781941, 4.2381764214277275, 0.09139595472869716, 0.2205437175074938, 0.2090042649313935, -21.132754202852915, 3.697399211139712e-05, 0.004511866253600477])
# 2.22% of range. Val: 0.164398776922 Low: 0.1 High: 3.0 ATTR: diam in ['apical']
# 8.43% of range. Val: 14.7001785531 Low: 5.0 High: 120.0 ATTR: Ra in ['all']
# 52.55% of range. Val: 5.30233718978 Low: 0.1 High: 10.0 ATTR: cm in ['all']
# 96.05% of range. Val: 48.419076505 Low: 10.0 High: 50.0 ATTR: ena in ['all']
# 64.86% of range. Val: -54.5956388326 Low: -100.0 High: -30.0 ATTR: ek in ['all']
# 27.89% of range. Val: -86.0558800368 Low: -100.0 High: -50.0 ATTR: e_pas in ['all']
# 32.82% of range. Val: 0.000656409060378 Low: 0 High: 0.002 ATTR: g_pas in ['all']
# 42.38% of range. Val: 4.23817642143 Low: 0 High: 10 ATTR: sh_Na in ['all']
# 91.40% of range. Val: 0.0913959547287 Low: 0 High: 0.1 ATTR: gbar_Na in ['all']
# 55.14% of range. Val: 0.220543717507 Low: 0 High: 0.4 ATTR: gbar_Kd in ['all']
# 52.25% of range. Val: 0.209004264931 Low: 0 High: 0.4 ATTR: gbar_KA in ['somatic']
# 77.73% of range. Val: -21.1327542029 Low: -60.0 High: -10.0 ATTR: eh in ['somatic']
# 36.97% of range. Val: 3.69739921114e-05 Low: 0 High: 0.0001 ATTR: gbar_Ih in ['somatic']
# 3.47% of range. Val: 0.0045118662536 Low: 0 High: 0.13 ATTR: gbar_KM in ['somatic']
# ('GEN', 14, 'Parents', 5, 'Elite', 13, 'DIV', 6, 'RND', 6, 'TOT NEW', 25)
# ('STARTED GEN', '14', 'size', 25)
# ('DONE with', 1, 'of', 25, 'of GEN', '14', 'with Fitness', '37.15')
# ('DONE with', 2, 'of', 25, 'of GEN', '14', 'with Fitness', '17.17')
# ('DONE with', 3, 'of', 25, 'of GEN', '14', 'with Fitness', '10.91')
# ('DONE with', 4, 'of', 25, 'of GEN', '14', 'with Fitness', '7.48')
# ('DONE with', 5, 'of', 25, 'of GEN', '14', 'with Fitness', '16.20')
# ('DONE with', 6, 'of', 25, 'of GEN', '14', 'with Fitness', '15.80')
# ('DONE with', 7, 'of', 25, 'of GEN', '14', 'with Fitness', '15.84')
# ('DONE with', 8, 'of', 25, 'of GEN', '14', 'with Fitness', '131.02')
# ('DONE with', 9, 'of', 25, 'of GEN', '14', 'with Fitness', '31.22')
# ('DONE with', 10, 'of', 25, 'of GEN', '14', 'with Fitness', '14.95')
# ('DONE with', 11, 'of', 25, 'of GEN', '14', 'with Fitness', '14.37')
# ('DONE with', 12, 'of', 25, 'of GEN', '14', 'with Fitness', '6.07')
# ('DONE with', 13, 'of', 25, 'of GEN', '14', 'with Fitness', '7.18')
# ('DONE with', 14, 'of', 25, 'of GEN', '14', 'with Fitness', '7.48')
# ('DONE with', 15, 'of', 25, 'of GEN', '14', 'with Fitness', '6.72')
# ('DONE with', 16, 'of', 25, 'of GEN', '14', 'with Fitness', '63.36')
# ('DONE with', 17, 'of', 25, 'of GEN', '14', 'with Fitness', '6.53')
# ('DONE with', 18, 'of', 25, 'of GEN', '14', 'with Fitness', '12.43')
# ('DONE with', 19, 'of', 25, 'of GEN', '14', 'with Fitness', '6.26')
# ('DONE with', 20, 'of', 25, 'of GEN', '14', 'with Fitness', '85.18')
# ('DONE with', 21, 'of', 25, 'of GEN', '14', 'with Fitness', '9.68')
# ('DONE with', 22, 'of', 25, 'of GEN', '14', 'with Fitness', '9.89')
# ('DONE with', 23, 'of', 25, 'of GEN', '14', 'with Fitness', '6.74')
# ('DONE with', 24, 'of', 25, 'of GEN', '14', 'with Fitness', '14.68')
# ('DONE with', 25, 'of', 25, 'of GEN', '14', 'with Fitness', '6.68')
# ('Generation', 14, 'out of', 200, 'COMPLETE')
# ('Best fitness:', 6.040272072679819)
# ('Best individual', [0.16439877692169141, 14.7001785531141, 5.302337189781626, 48.419076504979856, -54.59563883264137, -86.0558800368305, 0.0006564090603781941, 4.2381764214277275, 0.09139595472869716, 0.2205437175074938, 0.2090042649313935, -21.132754202852915, 3.697399211139712e-05, 0.004511866253600477])
# 2.22% of range. Val: 0.164398776922 Low: 0.1 High: 3.0 ATTR: diam in ['apical']
# 8.43% of range. Val: 14.7001785531 Low: 5.0 High: 120.0 ATTR: Ra in ['all']
# 52.55% of range. Val: 5.30233718978 Low: 0.1 High: 10.0 ATTR: cm in ['all']
# 96.05% of range. Val: 48.419076505 Low: 10.0 High: 50.0 ATTR: ena in ['all']
# 64.86% of range. Val: -54.5956388326 Low: -100.0 High: -30.0 ATTR: ek in ['all']
# 27.89% of range. Val: -86.0558800368 Low: -100.0 High: -50.0 ATTR: e_pas in ['all']
# 32.82% of range. Val: 0.000656409060378 Low: 0 High: 0.002 ATTR: g_pas in ['all']
# ...
# ('DONE with', 17, 'of', 25, 'of GEN', '55', 'with Fitness', '14.75')
# ('DONE with', 18, 'of', 25, 'of GEN', '55', 'with Fitness', '4.00')
# ('DONE with', 19, 'of', 25, 'of GEN', '55', 'with Fitness', '14.12')
# ('DONE with', 20, 'of', 25, 'of GEN', '55', 'with Fitness', '4.01')
# ('DONE with', 21, 'of', 25, 'of GEN', '55', 'with Fitness', '20.82')
# ('DONE with', 22, 'of', 25, 'of GEN', '55', 'with Fitness', '16.30')
# ('DONE with', 23, 'of', 25, 'of GEN', '55', 'with Fitness', '7.53')
# ('DONE with', 24, 'of', 25, 'of GEN', '55', 'with Fitness', '9.39')
# ('DONE with', 25, 'of', 25, 'of GEN', '55', 'with Fitness', '33.01')
# ('Generation', 55, 'out of', 200, 'COMPLETE')
# ('Best fitness:', 4.001985424210276)
# ('Best individual', [0.39560570044908316, 14.7001785531141, 5.603476105466056, 46.39200778061111, -59.13731541119851, -88.95055139135725, 0.00019849201601866652, 2.0573566940370247, 0.09017983310353604, 0.3722082289291057, 0.09497518063921444, -33.1825270925653, 1.4655822138088778e-05, 0.10855432376524068])
# 10.19% of range. Val: 0.395605700449 Low: 0.1 High: 3.0 ATTR: diam in ['apical']
# 8.43% of range. Val: 14.7001785531 Low: 5.0 High: 120.0 ATTR: Ra in ['all']
# 55.59% of range. Val: 5.60347610547 Low: 0.1 High: 10.0 ATTR: cm in ['all']
# 90.98% of range. Val: 46.3920077806 Low: 10.0 High: 50.0 ATTR: ena in ['all']
# 58.38% of range. Val: -59.1373154112 Low: -100.0 High: -30.0 ATTR: ek in ['all']
# 22.10% of range. Val: -88.9505513914 Low: -100.0 High: -50.0 ATTR: e_pas in ['all']
# 9.92% of range. Val: 0.000198492016019 Low: 0 High: 0.002 ATTR: g_pas in ['all']
# 20.57% of range. Val: 2.05735669404 Low: 0 High: 10 ATTR: sh_Na in ['all']
# 90.18% of range. Val: 0.0901798331035 Low: 0 High: 0.1 ATTR: gbar_Na in ['all']
# 93.05% of range. Val: 0.372208228929 Low: 0 High: 0.4 ATTR: gbar_Kd in ['all']
# 23.74% of range. Val: 0.0949751806392 Low: 0 High: 0.4 ATTR: gbar_KA in ['somatic']
# 53.63% of range. Val: -33.1825270926 Low: -60.0 High: -10.0 ATTR: eh in ['somatic']
# 14.66% of range. Val: 1.46558221381e-05 Low: 0 High: 0.0001 ATTR: gbar_Ih in ['somatic']
# 83.50% of range. Val: 0.108554323765 Low: 0 High: 0.13 ATTR: gbar_KM in ['somatic']
# ('GEN', 56, 'Parents', 5, 'Elite', 13, 'DIV', 6, 'RND', 6, 'TOT NEW', 25)
# ('STARTED GEN', '56', 'size', 25)
# ('DONE with', 1, 'of', 25, 'of GEN', '56', 'with Fitness', '20.23')
# ('DONE with', 2, 'of', 25, 'of GEN', '56', 'with Fitness', '18.86')
# ('DONE with', 3, 'of', 25, 'of GEN', '56', 'with Fitness', '11.72')
# ('DONE with', 4, 'of', 25, 'of GEN', '56', 'with Fitness', '33.41')
# ('DONE with', 5, 'of', 25, 'of GEN', '56', 'with Fitness', '69.85')
# ('DONE with', 6, 'of', 25, 'of GEN', '56', 'with Fitness', '38.25')
# ('DONE with', 7, 'of', 25, 'of GEN', '56', 'with Fitness', '16.29')
# ('DONE with', 8, 'of', 25, 'of GEN', '56', 'with Fitness', '9.20')
# ('DONE with', 9, 'of', 25, 'of GEN', '56', 'with Fitness', '40.81')
# ('DONE with', 10, 'of', 25, 'of GEN', '56', 'with Fitness', '52.75')
# ('DONE with', 11, 'of', 25, 'of GEN', '56', 'with Fitness', '9.08')
# ('DONE with', 12, 'of', 25, 'of GEN', '56', 'with Fitness', '55.30')
# ('DONE with', 13, 'of', 25, 'of GEN', '56', 'with Fitness', '4.41')
# ('DONE with', 14, 'of', 25, 'of GEN', '56', 'with Fitness', '26.59')
# ('DONE with', 15, 'of', 25, 'of GEN', '56', 'with Fitness', '6.23')
# ('DONE with', 16, 'of', 25, 'of GEN', '56', 'with Fitness', '4.97')
# ('DONE with', 17, 'of', 25, 'of GEN', '56', 'with Fitness', '4.07')
# ('DONE with', 18, 'of', 25, 'of GEN', '56', 'with Fitness', '26.80')
# ('DONE with', 19, 'of', 25, 'of GEN', '56', 'with Fitness', '10.17')
# ('DONE with', 20, 'of', 25, 'of GEN', '56', 'with Fitness', '4.06')
# ('DONE with', 21, 'of', 25, 'of GEN', '56', 'with Fitness', '4.12')
# ('DONE with', 22, 'of', 25, 'of GEN', '56', 'with Fitness', '5.23')
# ('DONE with', 23, 'of', 25, 'of GEN', '56', 'with Fitness', '4.02')
# ('DONE with', 24, 'of', 25, 'of GEN', '56', 'with Fitness', '5.76')
# ('DONE with', 25, 'of', 25, 'of GEN', '56', 'with Fitness', '15.29')
# ('Generation', 56, 'out of', 200, 'COMPLETE')
# ('Best fitness:', 4.001985424210276)
# ('Best individual', [0.39560570044908316, 14.7001785531141, 5.603476105466056, 46.39200778061111, -59.13731541119851, -88.95055139135725, 0.00019849201601866652, 2.0573566940370247, 0.09017983310353604, 0.3722082289291057, 0.09497518063921444, -33.1825270925653, 1.4655822138088778e-05, 0.10855432376524068])
# 10.19% of range. Val: 0.395605700449 Low: 0.1 High: 3.0 ATTR: diam in ['apical']
# 8.43% of range. Val: 14.7001785531 Low: 5.0 High: 120.0 ATTR: Ra in ['all']
# 55.59% of range. Val: 5.60347610547 Low: 0.1 High: 10.0 ATTR: cm in ['all']
# 90.98% of range. Val: 46.3920077806 Low: 10.0 High: 50.0 ATTR: ena in ['all']
# 58.38% of range. Val: -59.1373154112 Low: -100.0 High: -30.0 ATTR: ek in ['all']
# 22.10% of range. Val: -88.9505513914 Low: -100.0 High: -50.0 ATTR: e_pas in ['all']
# 9.92% of range. Val: 0.000198492016019 Low: 0 High: 0.002 ATTR: g_pas in ['all']
# 20.57% of range. Val: 2.05735669404 Low: 0 High: 10 ATTR: sh_Na in ['all']
# 90.18% of range. Val: 0.0901798331035 Low: 0 High: 0.1 ATTR: gbar_Na in ['all']
# 93.05% of range. Val: 0.372208228929 Low: 0 High: 0.4 ATTR: gbar_Kd in ['all']
# 23.74% of range. Val: 0.0949751806392 Low: 0 High: 0.4 ATTR: gbar_KA in ['somatic']
# 53.63% of range. Val: -33.1825270926 Low: -60.0 High: -10.0 ATTR: eh in ['somatic']
# 14.66% of range. Val: 1.46558221381e-05 Low: 0 High: 0.0001 ATTR: gbar_Ih in ['somatic']
# 83.50% of range. Val: 0.108554323765 Low: 0 High: 0.13 ATTR: gbar_KM in ['somatic']
# ('GEN', 57, 'Parents', 5, 'Elite', 13, 'DIV', 6, 'RND', 6, 'TOT NEW', 25)
# ('STARTED GEN', '57', 'size', 25)
# ('DONE with', 1, 'of', 25, 'of GEN', '57', 'with Fitness', '12.10')
# ('DONE with', 2, 'of', 25, 'of GEN', '57', 'with Fitness', '23.89')
# ('DONE with', 3, 'of', 25, 'of GEN', '57', 'with Fitness', '16.23')
# ('DONE with', 4, 'of', 25, 'of GEN', '57', 'with Fitness', '13.36')
# ('DONE with', 5, 'of', 25, 'of GEN', '57', 'with Fitness', '64.96')
# ('DONE with', 6, 'of', 25, 'of GEN', '57', 'with Fitness', '164.86')
# ('DONE with', 7, 'of', 25, 'of GEN', '57', 'with Fitness', '26.83')
# ('DONE with', 8, 'of', 25, 'of GEN', '57', 'with Fitness', '15.35')
# ('DONE with', 9, 'of', 25, 'of GEN', '57', 'with Fitness', '4.24')
# ('DONE with', 10, 'of', 25, 'of GEN', '57', 'with Fitness', '6.37')
# ('DONE with', 11, 'of', 25, 'of GEN', '57', 'with Fitness', '7.52')
# ('DONE with', 12, 'of', 25, 'of GEN', '57', 'with Fitness', '8.54')
# ('DONE with', 13, 'of', 25, 'of GEN', '57', 'with Fitness', '5.11')
# ('DONE with', 14, 'of', 25, 'of GEN', '57', 'with Fitness', '24.36')
# ('DONE with', 15, 'of', 25, 'of GEN', '57', 'with Fitness', '4.10')
# ('DONE with', 16, 'of', 25, 'of GEN', '57', 'with Fitness', '4.14')
# ('DONE with', 17, 'of', 25, 'of GEN', '57', 'with Fitness', '4.79')
# ('DONE with', 18, 'of', 25, 'of GEN', '57', 'with Fitness', '28.09')
# ('DONE with', 19, 'of', 25, 'of GEN', '57', 'with Fitness', '14.10')
# ('DONE with', 20, 'of', 25, 'of GEN', '57', 'with Fitness', '11.58')
# ('DONE with', 21, 'of', 25, 'of GEN', '57', 'with Fitness', '4.37')
# ('DONE with', 22, 'of', 25, 'of GEN', '57', 'with Fitness', '4.51')
# ('DONE with', 23, 'of', 25, 'of GEN', '57', 'with Fitness', '4.06')
# ('DONE with', 24, 'of', 25, 'of GEN', '57', 'with Fitness', '4.06')
# ('DONE with', 25, 'of', 25, 'of GEN', '57', 'with Fitness', '12.16')
# ('Generation', 57, 'out of', 200, 'COMPLETE')
# ('Best fitness:', 4.001985424210276)
# ('Best individual', [0.39560570044908316, 14.7001785531141, 5.603476105466056, 46.39200778061111, -59.13731541119851, -88.95055139135725, 0.00019849201601866652, 2.0573566940370247, 0.09017983310353604, 0.3722082289291057, 0.09497518063921444, -33.1825270925653, 1.4655822138088778e-05, 0.10855432376524068])
# 10.19% of range. Val: 0.395605700449 Low: 0.1 High: 3.0 ATTR: diam in ['apical']
# 8.43% of range. Val: 14.7001785531 Low: 5.0 High: 120.0 ATTR: Ra in ['all']
# 55.59% of range. Val: 5.60347610547 Low: 0.1 High: 10.0 ATTR: cm in ['all']
# 90.98% of range. Val: 46.3920077806 Low: 10.0 High: 50.0 ATTR: ena in ['all']
# 58.38% of range. Val: -59.1373154112 Low: -100.0 High: -30.0 ATTR: ek in ['all']
# 22.10% of range. Val: -88.9505513914 Low: -100.0 High: -50.0 ATTR: e_pas in ['all']
# 9.92% of range. Val: 0.000198492016019 Low: 0 High: 0.002 ATTR: g_pas in ['all']
# 20.57% of range. Val: 2.05735669404 Low: 0 High: 10 ATTR: sh_Na in ['all']
# 90.18% of range. Val: 0.0901798331035 Low: 0 High: 0.1 ATTR: gbar_Na in ['all']
# 93.05% of range. Val: 0.372208228929 Low: 0 High: 0.4 ATTR: gbar_Kd in ['all']
# 23.74% of range. Val: 0.0949751806392 Low: 0 High: 0.4 ATTR: gbar_KA in ['somatic']
# 53.63% of range. Val: -33.1825270926 Low: -60.0 High: -10.0 ATTR: eh in ['somatic']
# 14.66% of range. Val: 1.46558221381e-05 Low: 0 High: 0.0001 ATTR: gbar_Ih in ['somatic']
# 83.50% of range. Val: 0.108554323765 Low: 0 High: 0.13 ATTR: gbar_KM in ['somatic']
# ('GEN', 58, 'Parents', 5, 'Elite', 13, 'DIV', 6, 'RND', 6, 'TOT NEW', 25)
# ('STARTED GEN', '58', 'size', 25)
# ('DONE with', 1, 'of', 25, 'of GEN', '58', 'with Fitness', '144.97')
# ('DONE with', 2, 'of', 25, 'of GEN', '58', 'with Fitness', '46.11')
# ('DONE with', 3, 'of', 25, 'of GEN', '58', 'with Fitness', '11.97')
# ('DONE with', 4, 'of', 25, 'of GEN', '58', 'with Fitness', '6.66')
# ('DONE with', 5, 'of', 25, 'of GEN', '58', 'with Fitness', '16.21')
# ('DONE with', 6, 'of', 25, 'of GEN', '58', 'with Fitness', '9.87')
# ('DONE with', 7, 'of', 25, 'of GEN', '58', 'with Fitness', '9.41')
# ('DONE with', 8, 'of', 25, 'of GEN', '58', 'with Fitness', '6.24')
# ('DONE with', 9, 'of', 25, 'of GEN', '58', 'with Fitness', '29.35')
# ('DONE with', 10, 'of', 25, 'of GEN', '58', 'with Fitness', '4.55')
# ('DONE with', 11, 'of', 25, 'of GEN', '58', 'with Fitness', '30.84')
# ('DONE with', 12, 'of', 25, 'of GEN', '58', 'with Fitness', '27.21')
# ('DONE with', 13, 'of', 25, 'of GEN', '58', 'with Fitness', '4.12')
# ('DONE with', 14, 'of', 25, 'of GEN', '58', 'with Fitness', '4.07')
# ('DONE with', 15, 'of', 25, 'of GEN', '58', 'with Fitness', '10.62')
# ('DONE with', 2, 'of', 25, 'of GEN', '58', 'with Fitness', '46.11')
# ('DONE with', 16, 'of', 25, 'of GEN', '58', 'with Fitness', '4.11')
# ('DONE with', 17, 'of', 25, 'of GEN', '58', 'with Fitness', '12.42')
# ('DONE with', 18, 'of', 25, 'of GEN', '58', 'with Fitness', '5.93')
# ('DONE with', 19, 'of', 25, 'of GEN', '58', 'with Fitness', '11.47')
# ('DONE with', 20, 'of', 25, 'of GEN', '58', 'with Fitness', '50.26')
# ('DONE with', 21, 'of', 25, 'of GEN', '58', 'with Fitness', '31.74')
# ('DONE with', 22, 'of', 25, 'of GEN', '58', 'with Fitness', '5.35')
# ('DONE with', 23, 'of', 25, 'of GEN', '58', 'with Fitness', '5.59')
# ('DONE with', 24, 'of', 25, 'of GEN', '58', 'with Fitness', '4.15')
# ('DONE with', 25, 'of', 25, 'of GEN', '58', 'with Fitness', '26.44')
# ('Generation', 58, 'out of', 200, 'COMPLETE')
# ('Best fitness:', 4.001985424210276)
# ('Best individual', [0.39560570044908316, 14.7001785531141, 5.603476105466056, 46.39200778061111, -59.13731541119851, -88.95055139135725, 0.00019849201601866652, 2.0573566940370247, 0.09017983310353604, 0.3722082289291057, 0.09497518063921444, -33.1825270925653, 1.4655822138088778e-05, 0.10855432376524068])
# 10.19% of range. Val: 0.395605700449 Low: 0.1 High: 3.0 ATTR: diam in ['apical']
# 8.43% of range. Val: 14.7001785531 Low: 5.0 High: 120.0 ATTR: Ra in ['all']
# 55.59% of range. Val: 5.60347610547 Low: 0.1 High: 10.0 ATTR: cm in ['all']
# 90.98% of range. Val: 46.3920077806 Low: 10.0 High: 50.0 ATTR: ena in ['all']
# 58.38% of range. Val: -59.1373154112 Low: -100.0 High: -30.0 ATTR: ek in ['all']
# 22.10% of range. Val: -88.9505513914 Low: -100.0 High: -50.0 ATTR: e_pas in ['all']
# 9.92% of range. Val: 0.000198492016019 Low: 0 High: 0.002 ATTR: g_pas in ['all']
# 20.57% of range. Val: 2.05735669404 Low: 0 High: 10 ATTR: sh_Na in ['all']
# 90.18% of range. Val: 0.0901798331035 Low: 0 High: 0.1 ATTR: gbar_Na in ['all']
# 93.05% of range. Val: 0.372208228929 Low: 0 High: 0.4 ATTR: gbar_Kd in ['all']
# 23.74% of range. Val: 0.0949751806392 Low: 0 High: 0.4 ATTR: gbar_KA in ['somatic']
# 53.63% of range. Val: -33.1825270926 Low: -60.0 High: -10.0 ATTR: eh in ['somatic']
# 14.66% of range. Val: 1.46558221381e-05 Low: 0 High: 0.0001 ATTR: gbar_Ih in ['somatic']
# 83.50% of range. Val: 0.108554323765 Low: 0 High: 0.13 ATTR: gbar_KM in ['somatic']
# ('GEN', 59, 'Parents', 5, 'Elite', 13, 'DIV', 6, 'RND', 6, 'TOT NEW', 25)
# ('STARTED GEN', '59', 'size', 25)
# ('DONE with', 1, 'of', 25, 'of GEN', '59', 'with Fitness', '557.29')
# ('DONE with', 2, 'of', 25, 'of GEN', '59', 'with Fitness', '30.15')
# ('DONE with', 3, 'of', 25, 'of GEN', '59', 'with Fitness', '18.78')
# ('DONE with', 4, 'of', 25, 'of GEN', '59', 'with Fitness', '263.83')
# ('DONE with', 5, 'of', 25, 'of GEN', '59', 'with Fitness', '54.21')
# ('DONE with', 6, 'of', 25, 'of GEN', '59', 'with Fitness', '18.81')
# ('DONE with', 7, 'of', 25, 'of GEN', '59', 'with Fitness', '38.94')
# ('DONE with', 8, 'of', 25, 'of GEN', '59', 'with Fitness', '10.20')
# ('DONE with', 9, 'of', 25, 'of GEN', '59', 'with Fitness', '5.07')
# ('DONE with', 10, 'of', 25, 'of GEN', '59', 'with Fitness', '35.46')
# ('DONE with', 11, 'of', 25, 'of GEN', '59', 'with Fitness', '35.78')
# ('DONE with', 12, 'of', 25, 'of GEN', '59', 'with Fitness', '111.55')
# ('DONE with', 13, 'of', 25, 'of GEN', '59', 'with Fitness', '4.10')
# ('DONE with', 14, 'of', 25, 'of GEN', '59', 'with Fitness', '14.90')
# ('DONE with', 15, 'of', 25, 'of GEN', '59', 'with Fitness', '4.15')
# ('DONE with', 16, 'of', 25, 'of GEN', '59', 'with Fitness', '7.36')
# ('DONE with', 17, 'of', 25, 'of GEN', '59', 'with Fitness', '5.26')
# ('DONE with', 18, 'of', 25, 'of GEN', '59', 'with Fitness', '20.29')
# ('DONE with', 19, 'of', 25, 'of GEN', '59', 'with Fitness', '10.38')
# ('DONE with', 20, 'of', 25, 'of GEN', '59', 'with Fitness', '4.25')
# ('DONE with', 21, 'of', 25, 'of GEN', '59', 'with Fitness', '4.24')
# ('DONE with', 22, 'of', 25, 'of GEN', '59', 'with Fitness', '12.66')
# ('DONE with', 23, 'of', 25, 'of GEN', '59', 'with Fitness', '25.61')
# ('DONE with', 24, 'of', 25, 'of GEN', '59', 'with Fitness', '5.25')
# ('DONE with', 25, 'of', 25, 'of GEN', '59', 'with Fitness', '34.26')
# ('Generation', 59, 'out of', 200, 'COMPLETE')
# ('Best fitness:', 4.001985424210276)
# ('Best individual', [0.39560570044908316, 14.7001785531141, 5.603476105466056, 46.39200778061111, -59.13731541119851, -88.95055139135725, 0.00019849201601866652, 2.0573566940370247, 0.09017983310353604, 0.3722082289291057, 0.09497518063921444, -33.1825270925653, 1.4655822138088778e-05, 0.10855432376524068])
# 10.19% of range. Val: 0.395605700449 Low: 0.1 High: 3.0 ATTR: diam in ['apical']
# 8.43% of range. Val: 14.7001785531 Low: 5.0 High: 120.0 ATTR: Ra in ['all']
# 55.59% of range. Val: 5.60347610547 Low: 0.1 High: 10.0 ATTR: cm in ['all']
# 90.98% of range. Val: 46.3920077806 Low: 10.0 High: 50.0 ATTR: ena in ['all']
# 58.38% of range. Val: -59.1373154112 Low: -100.0 High: -30.0 ATTR: ek in ['all']
# 22.10% of range. Val: -88.9505513914 Low: -100.0 High: -50.0 ATTR: e_pas in ['all']
# 9.92% of range. Val: 0.000198492016019 Low: 0 High: 0.002 ATTR: g_pas in ['all']
# 20.57% of range. Val: 2.05735669404 Low: 0 High: 10 ATTR: sh_Na in ['all']
# 90.18% of range. Val: 0.0901798331035 Low: 0 High: 0.1 ATTR: gbar_Na in ['all']
# 93.05% of range. Val: 0.372208228929 Low: 0 High: 0.4 ATTR: gbar_Kd in ['all']
# 23.74% of range. Val: 0.0949751806392 Low: 0 High: 0.4 ATTR: gbar_KA in ['somatic']
# 53.63% of range. Val: -33.1825270926 Low: -60.0 High: -10.0 ATTR: eh in ['somatic']
# 14.66% of range. Val: 1.46558221381e-05 Low: 0 High: 0.0001 ATTR: gbar_Ih in ['somatic']
# 83.50% of range. Val: 0.108554323765 Low: 0 High: 0.13 ATTR: gbar_KM in ['somatic']
# ('GEN', 60, 'Parents', 5, 'Elite', 13, 'DIV', 6, 'RND', 6, 'TOT NEW', 25)
# ('STARTED GEN', '60', 'size', 25)
# ('DONE with', 1, 'of', 25, 'of GEN', '60', 'with Fitness', '14.86')
# ('DONE with', 2, 'of', 25, 'of GEN', '60', 'with Fitness', '9.27')
# ('DONE with', 3, 'of', 25, 'of GEN', '60', 'with Fitness', '35.05')
# ('DONE with', 4, 'of', 25, 'of GEN', '60', 'with Fitness', '75.93')

# %%
fitter.best = []

# %%
df, score = fitter.get_best_score()
print(score["model_score"]) 
df.transpose()

# %%
raise

# %%
from prev_ob_models.Birgiolas2020.isolated_cells import GC2
gc = GC2()
gc.param_values

# %%
from scipy.optimize import minimize
def evaluate(ind):
    print(ind)
    score = float(fitter.evaluate(ind)[0])
    print("score", score)
    return score

min_res = minimize(evaluate, gc.param_values, method='Powell', 
                   options={"disp":False, "maxfev":45, "maxiter":100})#,"xtol":0.1,"ftol":0.1})
min_res

# %%
raise

# %%
fitter.clear_cache()

# %%
fitter.fit(20, 7)

# %%
fitter.parameter_report(fitter.best)

# %%
raise

# %%
#fitter.clear_cache()
#fitter.best = []
df, score = fitter.get_best_score()
print(score["model_score"]) 
df.transpose()

# %%
score

# %%
fitter.clear_cache()
df = fitter.get_previous_model_scores()
df

# %%
df.to_csv("ephyz/"+fitter.cell_type+"_model_zscores.csv")

# %%
raise

# %%
np.linspace(0,100,0.1)

# %%
score["model_score"]

# %%
raise

# %%
fitter.top = None

# %%
cpus = multiprocessing.cpu_count()
fitter.fit(int(cpus*1.5), 48)

# %%
fitter.clear_cache()
fitter.best = []
df, score = fitter.get_best_score()
df

# %%
score["model_score"]

# %%
fitter.pretty_pop()

# %%
from prev_ob_models.Birgiolas2020.isolated_cells import MC1
mc = MC1()

# %%
fitter.print_params(fitter.best, mc.cell)
