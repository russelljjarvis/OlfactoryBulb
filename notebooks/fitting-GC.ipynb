# %%
import os; os.chdir("..");
import multiprocessing
from prev_ob_models.Birgiolas2020.fitting import *
# Out:
# /home/justas/anaconda2/envs/p27/lib/python2.7/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Could not load NEURONBackend

# %%
import sys
cell_id = sys.argv[1] if len(sys.argv) > 1 and sys.argv[1].isdigit() else 5
print(cell_id)
# Out:
# 5

# %%
fitter = CellFitter(cell_type="mc", fitting_model_class="prev_ob_models.Birgiolas2020.isolated_cells.MC"+str(cell_id))
# Out:
# ('Starting mc FITTER for model:', 'prev_ob_models.Birgiolas2020.isolated_cells.MC5')

# %%
fitter.clear_cache()

# %%
fitter.fit(20, 7)
# Out:
# ('STARTED GEN', 'ZERO', 'size', 4)
# ('DONE with', 1, 'of', 4, 'of GEN', 'ZERO', 'with Fitness', '3.50')
# ('DONE with', 2, 'of', 4, 'of GEN', 'ZERO', 'with Fitness', '3.53')
# ('DONE with', 3, 'of', 4, 'of GEN', 'ZERO', 'with Fitness', '3.59')
# ('DONE with', 4, 'of', 4, 'of GEN', 'ZERO', 'with Fitness', '3.59')
# ('GEN', 1, 'Parents', 4, 'Elite', 10, 'DIV', 5, 'RND', 5, 'TOT NEW', 20)
# ('STARTED GEN', '1', 'size', 20)
# Traceback (most recent call last):
#   File "prev_ob_models/Birgiolas2020/fitting.py", line 195, in get_workitem_score
#     raise Exception(prediction)
# Exception: Traceback (most recent call last):
#   File "/home/justas/Repositories/neuronunit_justasb/neuronunit/tests/olfactory_bulb/__init__.py", line 30, in generate_prediction
#     result = self.generate_prediction_nocache(model)
#   File "/home/justas/Repositories/neuronunit_justasb/neuronunit/tests/olfactory_bulb/tests.py", line 1027, in generate_prediction_nocache
#     freq_targetHz, crossings, voltage = self.get_dependent_prediction(TargetFreqTestHelper, model)
# ValueError: too many values to unpack
#
#
# Traceback (most recent call last):
#   File "prev_ob_models/Birgiolas2020/fitting.py", line 195, in get_workitem_score
#     raise Exception(prediction)
# Exception: Traceback (most recent call last):
#   File "/home/justas/Repositories/neuronunit_justasb/neuronunit/tests/olfactory_bulb/__init__.py", line 30, in generate_prediction
#     result = self.generate_prediction_nocache(model)
#   File "/home/justas/Repositories/neuronunit_justasb/neuronunit/tests/olfactory_bulb/tests.py", line 385, in generate_prediction_nocache
#     return ap["threshold_v"]
# TypeError: string indices must be integers, not str
#
#
# Traceback (most recent call last):
#   File "prev_ob_models/Birgiolas2020/fitting.py", line 195, in get_workitem_score
#     raise Exception(prediction)
# Exception: Traceback (most recent call last):
#   File "/home/justas/Repositories/neuronunit_justasb/neuronunit/tests/olfactory_bulb/__init__.py", line 30, in generate_prediction
#     result = self.generate_prediction_nocache(model)
#   File "/home/justas/Repositories/neuronunit_justasb/neuronunit/tests/olfactory_bulb/tests.py", line 385, in generate_prediction_nocache
#     return ap["threshold_v"]
# TypeError: string indices must be integers, not str
#
#
# Traceback (most recent call last):
#   File "prev_ob_models/Birgiolas2020/fitting.py", line 195, in get_workitem_score
#     raise Exception(prediction)
# Exception: Traceback (most recent call last):
#   File "/home/justas/Repositories/neuronunit_justasb/neuronunit/tests/olfactory_bulb/__init__.py", line 30, in generate_prediction
#     result = self.generate_prediction_nocache(model)
#   File "/home/justas/Repositories/neuronunit_justasb/neuronunit/tests/olfactory_bulb/tests.py", line 1072, in generate_prediction_nocache
#     freq_targetHz, crossings, voltage = self.get_dependent_prediction(TargetFreqTestHelper, model)
# ValueError: too many values to unpack
#
#
# Traceback (most recent call last):
#   File "prev_ob_models/Birgiolas2020/fitting.py", line 195, in get_workitem_score
#     raise Exception(prediction)
# Exception: Traceback (most recent call last):
#   File "/home/justas/Repositories/neuronunit_justasb/neuronunit/tests/olfactory_bulb/__init__.py", line 30, in generate_prediction
#     result = self.generate_prediction_nocache(model)
#   File "/home/justas/Repositories/neuronunit_justasb/neuronunit/tests/olfactory_bulb/tests.py", line 1027, in generate_prediction_nocache
#     freq_targetHz, crossings, voltage = self.get_dependent_prediction(TargetFreqTestHelper, model)
# ValueError: too many values to unpack
#
#
# Traceback (most recent call last):
#   File "prev_ob_models/Birgiolas2020/fitting.py", line 195, in get_workitem_score
#     raise Exception(prediction)
# Exception: Traceback (most recent call last):
#   File "/home/justas/Repositories/neuronunit_justasb/neuronunit/tests/olfactory_bulb/__init__.py", line 30, in generate_prediction
#     result = self.generate_prediction_nocache(model)
#   File "/home/justas/Repositories/neuronunit_justasb/neuronunit/tests/olfactory_bulb/tests.py", line 415, in generate_prediction_nocache
#     return ap["amplitude"]
# TypeError: string indices must be integers, not str
#
#
# Traceback (most recent call last):
#   File "prev_ob_models/Birgiolas2020/fitting.py", line 195, in get_workitem_score
#     raise Exception(prediction)
# Exception: Traceback (most recent call last):
#   File "/home/justas/Repositories/neuronunit_justasb/neuronunit/tests/olfactory_bulb/__init__.py", line 30, in generate_prediction
#     result = self.generate_prediction_nocache(model)
#   File "/home/justas/Repositories/neuronunit_justasb/neuronunit/tests/olfactory_bulb/tests.py", line 415, in generate_prediction_nocache
#     return ap["amplitude"]
# TypeError: string indices must be integers, not str
#
#
# Traceback (most recent call last):
#   File "prev_ob_models/Birgiolas2020/fitting.py", line 195, in get_workitem_score
#     raise Exception(prediction)
# Exception: Traceback (most recent call last):
#   File "/home/justas/Repositories/neuronunit_justasb/neuronunit/tests/olfactory_bulb/__init__.py", line 30, in generate_prediction
#     result = self.generate_prediction_nocache(model)
#   File "/home/justas/Repositories/neuronunit_justasb/neuronunit/tests/olfactory_bulb/tests.py", line 442, in generate_prediction_nocache
#     return ap["half_width"]
# TypeError: string indices must be integers, not str
#
#
# Traceback (most recent call last):
#   File "prev_ob_models/Birgiolas2020/fitting.py", line 195, in get_workitem_score
#     raise Exception(prediction)
# Exception: Traceback (most recent call last):
#   File "/home/justas/Repositories/neuronunit_justasb/neuronunit/tests/olfactory_bulb/__init__.py", line 30, in generate_prediction
#     result = self.generate_prediction_nocache(model)
#   File "/home/justas/Repositories/neuronunit_justasb/neuronunit/tests/olfactory_bulb/tests.py", line 442, in generate_prediction_nocache
#     return ap["half_width"]
# TypeError: string indices must be integers, not str
#
#
# Traceback (most recent call last):
#   File "prev_ob_models/Birgiolas2020/fitting.py", line 195, in get_workitem_score
#     raise Exception(prediction)
# Exception: Traceback (most recent call last):
#   File "/home/justas/Repositories/neuronunit_justasb/neuronunit/tests/olfactory_bulb/__init__.py", line 30, in generate_prediction
#     result = self.generate_prediction_nocache(model)
#   File "/home/justas/Repositories/neuronunit_justasb/neuronunit/tests/olfactory_bulb/tests.py", line 270, in generate_prediction_nocache
#     raise Exception("Rheobase was not found between 0 and " + str(upper_bound))
# Exception: Rheobase was not found between 0 and 0.594376252591392 nA
#
#
# Traceback (most recent call last):
#   File "prev_ob_models/Birgiolas2020/fitting.py", line 195, in get_workitem_score
#     raise Exception(prediction)
# Exception: Traceback (most recent call last):
#   File "/home/justas/Repositories/neuronunit_justasb/neuronunit/tests/olfactory_bulb/__init__.py", line 30, in generate_prediction
#     result = self.generate_prediction_nocache(model)
#   File "/home/justas/Repositories/neuronunit_justasb/neuronunit/tests/olfactory_bulb/tests.py", line 400, in generate_prediction_nocache
#     return ap["peak_v"]
# TypeError: string indices must be integers, not str
#
#
# Traceback (most recent call last):
#   File "prev_ob_models/Birgiolas2020/fitting.py", line 195, in get_workitem_score
#     raise Exception(prediction)
# Exception: Traceback (most recent call last):
#   File "/home/justas/Repositories/neuronunit_justasb/neuronunit/tests/olfactory_bulb/__init__.py", line 30, in generate_prediction
#     result = self.generate_prediction_nocache(model)
#   File "/home/justas/Repositories/neuronunit_justasb/neuronunit/tests/olfactory_bulb/tests.py", line 625, in generate_prediction_nocache
#     _, _, voltage = self.get_dependent_prediction(TargetFreqTestHelper, model)
# ValueError: too many values to unpack
#
#
# Traceback (most recent call last):
#   File "prev_ob_models/Birgiolas2020/fitting.py", line 195, in get_workitem_score
#     raise Exception(prediction)
# Exception: Traceback (most recent call last):
#   File "/home/justas/Repositories/neuronunit_justasb/neuronunit/tests/olfactory_bulb/__init__.py", line 30, in generate_prediction
#     result = self.generate_prediction_nocache(model)
#   File "/home/justas/Repositories/neuronunit_justasb/neuronunit/tests/olfactory_bulb/tests.py", line 625, in generate_prediction_nocache
#     _, _, voltage = self.get_dependent_prediction(TargetFreqTestHelper, model)
# ValueError: too many values to unpack
# Traceback (most recent call last):
#   File "prev_ob_models/Birgiolas2020/fitting.py", line 195, in get_workitem_score
#     raise Exception(prediction)
# Exception: Traceback (most recent call last):
#   File "/home/justas/Repositories/neuronunit_justasb/neuronunit/tests/olfactory_bulb/__init__.py", line 30, in generate_prediction
#     result = self.generate_prediction_nocache(model)
#   File "/home/justas/Repositories/neuronunit_justasb/neuronunit/tests/olfactory_bulb/tests.py", line 954, in generate_prediction_nocache
#     freq_targetHz, crossings, voltage = self.get_dependent_prediction(TargetFreqTestHelper, model)
# ValueError: too many values to unpack
#
#
# Traceback (most recent call last):
#   File "prev_ob_models/Birgiolas2020/fitting.py", line 195, in get_workitem_score
#     raise Exception(prediction)
# Exception: Traceback (most recent call last):
#   File "/home/justas/Repositories/neuronunit_justasb/neuronunit/tests/olfactory_bulb/__init__.py", line 30, in generate_prediction
#     result = self.generate_prediction_nocache(model)
#   File "/home/justas/Repositories/neuronunit_justasb/neuronunit/tests/olfactory_bulb/tests.py", line 954, in generate_prediction_nocache
#     freq_targetHz, crossings, voltage = self.get_dependent_prediction(TargetFreqTestHelper, model)
# ValueError: too many values to unpack
#
#
# Traceback (most recent call last):
#   File "prev_ob_models/Birgiolas2020/fitting.py", line 195, in get_workitem_score
#     raise Exception(prediction)
# Exception: Traceback (most recent call last):
#   File "/home/justas/Repositories/neuronunit_justasb/neuronunit/tests/olfactory_bulb/__init__.py", line 30, in generate_prediction
#     result = self.generate_prediction_nocache(model)
#   File "/home/justas/Repositories/neuronunit_justasb/neuronunit/tests/olfactory_bulb/tests.py", line 385, in generate_prediction_nocache
#     return ap["threshold_v"]
# TypeError: string indices must be integers, not str
#
#
# Traceback (most recent call last):
#   File "prev_ob_models/Birgiolas2020/fitting.py", line 195, in get_workitem_score
#     raise Exception(prediction)
# Exception: Traceback (most recent call last):
#   File "/home/justas/Repositories/neuronunit_justasb/neuronunit/tests/olfactory_bulb/__init__.py", line 30, in generate_prediction
#     result = self.generate_prediction_nocache(model)
#   File "/home/justas/Repositories/neuronunit_justasb/neuronunit/tests/olfactory_bulb/tests.py", line 385, in generate_prediction_nocache
#     return ap["threshold_v"]
# TypeError: string indices must be integers, not str
#
#
# Traceback (most recent call last):
#   File "prev_ob_models/Birgiolas2020/fitting.py", line 195, in get_workitem_score
#     raise Exception(prediction)
# Exception: Traceback (most recent call last):
#   File "/home/justas/Repositories/neuronunit_justasb/neuronunit/tests/olfactory_bulb/__init__.py", line 30, in generate_prediction
#     result = self.generate_prediction_nocache(model)
#   File "/home/justas/Repositories/neuronunit_justasb/neuronunit/tests/olfactory_bulb/tests.py", line 1072, in generate_prediction_nocache
#     freq_targetHz, crossings, voltage = self.get_dependent_prediction(TargetFreqTestHelper, model)
# ValueError: too many values to unpack
#
#
# Traceback (most recent call last):
#   File "prev_ob_models/Birgiolas2020/fitting.py", line 195, in get_workitem_score
#     raise Exception(prediction)
# Exception: Traceback (most recent call last):
#   File "/home/justas/Repositories/neuronunit_justasb/neuronunit/tests/olfactory_bulb/__init__.py", line 30, in generate_prediction
#     result = self.generate_prediction_nocache(model)
#   File "/home/justas/Repositories/neuronunit_justasb/neuronunit/tests/olfactory_bulb/tests.py", line 415, in generate_prediction_nocache
#     return ap["amplitude"]
# TypeError: string indices must be integers, not str
#
#
# Traceback (most recent call last):
#   File "prev_ob_models/Birgiolas2020/fitting.py", line 195, in get_workitem_score
#     raise Exception(prediction)
# Exception: Traceback (most recent call last):
#   File "/home/justas/Repositories/neuronunit_justasb/neuronunit/tests/olfactory_bulb/__init__.py", line 30, in generate_prediction
#     result = self.generate_prediction_nocache(model)
#   File "/home/justas/Repositories/neuronunit_justasb/neuronunit/tests/olfactory_bulb/tests.py", line 415, in generate_prediction_nocache
#     return ap["amplitude"]
# TypeError: string indices must be integers, not str
#
#
# Traceback (most recent call last):
#   File "prev_ob_models/Birgiolas2020/fitting.py", line 195, in get_workitem_score
#     raise Exception(prediction)
# Exception: Traceback (most recent call last):
#   File "/home/justas/Repositories/neuronunit_justasb/neuronunit/tests/olfactory_bulb/__init__.py", line 30, in generate_prediction
#     result = self.generate_prediction_nocache(model)
#   File "/home/justas/Repositories/neuronunit_justasb/neuronunit/tests/olfactory_bulb/tests.py", line 442, in generate_prediction_nocache
#     return ap["half_width"]
# TypeError: string indices must be integers, not str
#
#
# Traceback (most recent call last):
#   File "prev_ob_models/Birgiolas2020/fitting.py", line 195, in get_workitem_score
#     raise Exception(prediction)
# Exception: Traceback (most recent call last):
#   File "/home/justas/Repositories/neuronunit_justasb/neuronunit/tests/olfactory_bulb/__init__.py", line 30, in generate_prediction
#     result = self.generate_prediction_nocache(model)
#   File "/home/justas/Repositories/neuronunit_justasb/neuronunit/tests/olfactory_bulb/tests.py", line 442, in generate_prediction_nocache
#     return ap["half_width"]
# TypeError: string indices must be integers, not str
#
#
# Traceback (most recent call last):
#   File "prev_ob_models/Birgiolas2020/fitting.py", line 195, in get_workitem_score
#     raise Exception(prediction)
# Exception: Traceback (most recent call last):
#   File "/home/justas/Repositories/neuronunit_justasb/neuronunit/tests/olfactory_bulb/__init__.py", line 30, in generate_prediction
#     result = self.generate_prediction_nocache(model)
#   File "/home/justas/Repositories/neuronunit_justasb/neuronunit/tests/olfactory_bulb/tests.py", line 270, in generate_prediction_nocache
#     raise Exception("Rheobase was not found between 0 and " + str(upper_bound))
# Exception: Rheobase was not found between 0 and 1.3635091092124088 nA
#
#
# Traceback (most recent call last):
#   File "prev_ob_models/Birgiolas2020/fitting.py", line 195, in get_workitem_score
#     raise Exception(prediction)
# Exception: Traceback (most recent call last):
#   File "/home/justas/Repositories/neuronunit_justasb/neuronunit/tests/olfactory_bulb/__init__.py", line 30, in generate_prediction
#     result = self.generate_prediction_nocache(model)
#   File "/home/justas/Repositories/neuronunit_justasb/neuronunit/tests/olfactory_bulb/tests.py", line 400, in generate_prediction_nocache
#     return ap["peak_v"]
# TypeError: string indices must be integers, not str
#
#
# Traceback (most recent call last):
#   File "prev_ob_models/Birgiolas2020/fitting.py", line 195, in get_workitem_score
#     raise Exception(prediction)
# Exception: Traceback (most recent call last):
#   File "/home/justas/Repositories/neuronunit_justasb/neuronunit/tests/olfactory_bulb/__init__.py", line 30, in generate_prediction
#     result = self.generate_prediction_nocache(model)
#   File "/home/justas/Repositories/neuronunit_justasb/neuronunit/tests/olfactory_bulb/tests.py", line 625, in generate_prediction_nocache
#     _, _, voltage = self.get_dependent_prediction(TargetFreqTestHelper, model)
# ValueError: too many values to unpack
#
#
# Traceback (most recent call last):
#   File "prev_ob_models/Birgiolas2020/fitting.py", line 195, in get_workitem_score
#     raise Exception(prediction)
# Exception: Traceback (most recent call last):
#   File "/home/justas/Repositories/neuronunit_justasb/neuronunit/tests/olfactory_bulb/__init__.py", line 30, in generate_prediction
#     result = self.generate_prediction_nocache(model)
#   File "/home/justas/Repositories/neuronunit_justasb/neuronunit/tests/olfactory_bulb/tests.py", line 626, in generate_prediction_nocache
#     aps = self.get_aps(voltage)
#   File "/home/justas/Repositories/neuronunit_justasb/neuronunit/tests/olfactory_bulb/__init__.py", line 115, in get_aps
#     return get_APs(voltage, self.ss_delay, self.threshold_method)
#   File "/home/justas/Repositories/neuronunit_justasb/neuronunit/tests/olfactory_bulb/utilities.py", line 87, in get_APs
#     ss_delay_point = int(ss_delay * voltage.sampling_rate)+1
# AttributeError: 'NoneType' object has no attribute 'sampling_rate'
# Traceback (most recent call last):
#   File "prev_ob_models/Birgiolas2020/fitting.py", line 195, in get_workitem_score
#     raise Exception(prediction)
# Exception: Traceback (most recent call last):
#   File "/home/justas/Repositories/neuronunit_justasb/neuronunit/tests/olfactory_bulb/__init__.py", line 30, in generate_prediction
#     result = self.generate_prediction_nocache(model)
#   File "/home/justas/Repositories/neuronunit_justasb/neuronunit/tests/olfactory_bulb/tests.py", line 954, in generate_prediction_nocache
#     freq_targetHz, crossings, voltage = self.get_dependent_prediction(TargetFreqTestHelper, model)
# ValueError: too many values to unpack
#
#
# Traceback (most recent call last):
#   File "prev_ob_models/Birgiolas2020/fitting.py", line 195, in get_workitem_score
#     raise Exception(prediction)
# Exception: Traceback (most recent call last):
#   File "/home/justas/Repositories/neuronunit_justasb/neuronunit/tests/olfactory_bulb/__init__.py", line 30, in generate_prediction
#     result = self.generate_prediction_nocache(model)
#   File "/home/justas/Repositories/neuronunit_justasb/neuronunit/tests/olfactory_bulb/tests.py", line 625, in generate_prediction_nocache
#     _, _, voltage = self.get_dependent_prediction(TargetFreqTestHelper, model)
# ValueError: too many values to unpack
#
#
# Traceback (most recent call last):
#   File "prev_ob_models/Birgiolas2020/fitting.py", line 195, in get_workitem_score
#     raise Exception(prediction)
# Exception: Traceback (most recent call last):
#   File "/home/justas/Repositories/neuronunit_justasb/neuronunit/tests/olfactory_bulb/__init__.py", line 30, in generate_prediction
#     result = self.generate_prediction_nocache(model)
#   File "/home/justas/Repositories/neuronunit_justasb/neuronunit/tests/olfactory_bulb/tests.py", line 625, in generate_prediction_nocache
#     _, _, voltage = self.get_dependent_prediction(TargetFreqTestHelper, model)
# ValueError: too many values to unpack
#
#
# Traceback (most recent call last):
#   File "prev_ob_models/Birgiolas2020/fitting.py", line 195, in get_workitem_score
#     raise Exception(prediction)
# Exception: Traceback (most recent call last):
#   File "/home/justas/Repositories/neuronunit_justasb/neuronunit/tests/olfactory_bulb/__init__.py", line 30, in generate_prediction
#     result = self.generate_prediction_nocache(model)
#   File "/home/justas/Repositories/neuronunit_justasb/neuronunit/tests/olfactory_bulb/tests.py", line 954, in generate_prediction_nocache
#     freq_targetHz, crossings, voltage = self.get_dependent_prediction(TargetFreqTestHelper, model)
# ValueError: too many values to unpack
#
#
# Traceback (most recent call last):
#   File "prev_ob_models/Birgiolas2020/fitting.py", line 195, in get_workitem_score
#     raise Exception(prediction)
# Exception: Traceback (most recent call last):
#   File "/home/justas/Repositories/neuronunit_justasb/neuronunit/tests/olfactory_bulb/__init__.py", line 30, in generate_prediction
#     result = self.generate_prediction_nocache(model)
#   File "/home/justas/Repositories/neuronunit_justasb/neuronunit/tests/olfactory_bulb/tests.py", line 954, in generate_prediction_nocache
#     freq_targetHz, crossings, voltage = self.get_dependent_prediction(TargetFreqTestHelper, model)
# ValueError: too many values to unpack
#
#
# Traceback (most recent call last):
#   File "prev_ob_models/Birgiolas2020/fitting.py", line 195, in get_workitem_score
#     raise Exception(prediction)
# Exception: Traceback (most recent call last):
#   File "/home/justas/Repositories/neuronunit_justasb/neuronunit/tests/olfactory_bulb/__init__.py", line 30, in generate_prediction
#     result = self.generate_prediction_nocache(model)
#   File "/home/justas/Repositories/neuronunit_justasb/neuronunit/tests/olfactory_bulb/tests.py", line 1027, in generate_prediction_nocache
#     freq_targetHz, crossings, voltage = self.get_dependent_prediction(TargetFreqTestHelper, model)
# ValueError: too many values to unpack
#
#
# ('DONE with', 1, 'of', 20, 'of GEN', '1', 'with Fitness', '10.03')
# ('DONE with', 2, 'of', 20, 'of GEN', '1', 'with Fitness', '27.78')
# ('DONE with', 3, 'of', 20, 'of GEN', '1', 'with Fitness', '19.34')
# ('DONE with', 4, 'of', 20, 'of GEN', '1', 'with Fitness', '18.53')
# ('DONE with', 5, 'of', 20, 'of GEN', '1', 'with Fitness', '24.72')
# Traceback (most recent call last):
#   File "prev_ob_models/Birgiolas2020/fitting.py", line 195, in get_workitem_score
#     raise Exception(prediction)
# Exception: Traceback (most recent call last):
#   File "/home/justas/Repositories/neuronunit_justasb/neuronunit/tests/olfactory_bulb/__init__.py", line 30, in generate_prediction
#     result = self.generate_prediction_nocache(model)
#   File "/home/justas/Repositories/neuronunit_justasb/neuronunit/tests/olfactory_bulb/tests.py", line 385, in generate_prediction_nocache
#     return ap["threshold_v"]
# TypeError: string indices must be integers, not str
#
#
# Traceback (most recent call last):
#   File "prev_ob_models/Birgiolas2020/fitting.py", line 195, in get_workitem_score
#     raise Exception(prediction)
# Exception: Traceback (most recent call last):
#   File "/home/justas/Repositories/neuronunit_justasb/neuronunit/tests/olfactory_bulb/__init__.py", line 30, in generate_prediction
#     result = self.generate_prediction_nocache(model)
#   File "/home/justas/Repositories/neuronunit_justasb/neuronunit/tests/olfactory_bulb/tests.py", line 385, in generate_prediction_nocache
#     return ap["threshold_v"]
# TypeError: string indices must be integers, not str
#
#
# Traceback (most recent call last):
#   File "prev_ob_models/Birgiolas2020/fitting.py", line 195, in get_workitem_score
#     raise Exception(prediction)
# Exception: Traceback (most recent call last):
#   File "/home/justas/Repositories/neuronunit_justasb/neuronunit/tests/olfactory_bulb/__init__.py", line 30, in generate_prediction
#     result = self.generate_prediction_nocache(model)
#   File "/home/justas/Repositories/neuronunit_justasb/neuronunit/tests/olfactory_bulb/tests.py", line 1072, in generate_prediction_nocache
#     freq_targetHz, crossings, voltage = self.get_dependent_prediction(TargetFreqTestHelper, model)
# ValueError: too many values to unpack
#
#
# Simulation timed out
# ('DONE with', 6, 'of', 20, 'of GEN', '1', 'with Fitness', '90.00')
# ('DONE with', 7, 'of', 20, 'of GEN', '1', 'with Fitness', '13.71')
# ('DONE with', 8, 'of', 20, 'of GEN', '1', 'with Fitness', '3.53')
# ('DONE with', 9, 'of', 20, 'of GEN', '1', 'with Fitness', '2836.44')
# ('DONE with', 10, 'of', 20, 'of GEN', '1', 'with Fitness', '3.53')
# ('DONE with', 11, 'of', 20, 'of GEN', '1', 'with Fitness', '3.59')
# ('DONE with', 12, 'of', 20, 'of GEN', '1', 'with Fitness', '5.18')
# ('DONE with', 13, 'of', 20, 'of GEN', '1', 'with Fitness', '4.67')
# ('DONE with', 14, 'of', 20, 'of GEN', '1', 'with Fitness', '3.98')
# ('DONE with', 15, 'of', 20, 'of GEN', '1', 'with Fitness', '8.71')
# ('DONE with', 16, 'of', 20, 'of GEN', '1', 'with Fitness', '4.30')
# ('DONE with', 17, 'of', 20, 'of GEN', '1', 'with Fitness', '3.60')
# ('DONE with', 18, 'of', 20, 'of GEN', '1', 'with Fitness', '3.52')
# ('DONE with', 19, 'of', 20, 'of GEN', '1', 'with Fitness', '7.44')
# Simulation timed out
# ('DONE with', 20, 'of', 20, 'of GEN', '1', 'with Fitness', '90.00')
# ('Generation', 1, 'out of', 7, 'COMPLETE')
# ('Best fitness:', 3.50314119705441)
# ('Best individual', [1.2471592703753913, 85.91729392565932, 0.9576321104748539, 32.45265517788054, -63.438841110533915, -75.05751351034053, 3.657331273597089e-05, 2.7626423490513514, 9.666857483589407, 0.06150916169169841, 0.03759175148995797, 0.0004759847063037054, 0.0042226776511213, 0.00776370232830789, 9.599737738463663e-06, -16.369883529143777, 1.9500130790130927e-06, 0.01027446638931233])
# diam in ['apical', 'basal', 'axonal'] at 23.41% of range. Val: 1.24715927038 Low: 0.1 High: 5.0
# Ra in ['all'] at 56.99% of range. Val: 85.9172939257 Low: 1.0 High: 150.0
# cm in ['all'] at 45.14% of range. Val: 0.957632110475 Low: 0.1 High: 2.0
# ena in ['all'] at 20.75% of range. Val: 32.4526551779 Low: 20.0 High: 80.0
# ek in ['all'] at 73.12% of range. Val: -63.4388411105 Low: -100.0 High: -50.0
# e_pas in ['all'] at 37.36% of range. Val: -75.0575135103 Low: -90.0 High: -50.0
# g_pas in ['all'] at 91.43% of range. Val: 3.6573312736e-05 Low: 0 High: 4e-05
# sh_Na in ['all'] at 27.63% of range. Val: 2.76264234905 Low: 0 High: 10
# tau_CaPool in ['all'] at 2.90% of range. Val: 9.66685748359 Low: 1 High: 300
# gbar_Na in ['all'] at 61.51% of range. Val: 0.0615091616917 Low: 0 High: 0.1
# gbar_Kd in ['all'] at 37.59% of range. Val: 0.03759175149 Low: 0 High: 0.1
# gbar_Kslow in ['all'] at 47.60% of range. Val: 0.000475984706304 Low: 0 High: 0.001
# gbar_KA in ['all'] at 21.11% of range. Val: 0.00422267765112 Low: 0 High: 0.02
# gbar_KCa in ['all'] at 48.52% of range. Val: 0.00776370232831 Low: 0 High: 0.016
# gbar_LCa in ['all'] at 1.92% of range. Val: 9.59973773846e-06 Low: 0 High: 0.0005
# eh in ['apical'] at 78.77% of range. Val: -16.3698835291 Low: -40.0 High: -10.0
# gbar_Ih in ['apical'] at 65.00% of range. Val: 1.95001307901e-06 Low: 0 High: 3e-06
# gbar_CaT in ['apical'] at 51.37% of range. Val: 0.0102744663893 Low: 0 High: 0.02
# ('GEN', 2, 'Parents', 4, 'Elite', 10, 'DIV', 5, 'RND', 5, 'TOT NEW', 20)
# ('STARTED GEN', '2', 'size', 20)
# Traceback (most recent call last):
#   File "prev_ob_models/Birgiolas2020/fitting.py", line 195, in get_workitem_score
#     raise Exception(prediction)
# Exception: Traceback (most recent call last):
#   File "/home/justas/Repositories/neuronunit_justasb/neuronunit/tests/olfactory_bulb/__init__.py", line 30, in generate_prediction
#     result = self.generate_prediction_nocache(model)
#   File "/home/justas/Repositories/neuronunit_justasb/neuronunit/tests/olfactory_bulb/tests.py", line 1027, in generate_prediction_nocache
#     freq_targetHz, crossings, voltage = self.get_dependent_prediction(TargetFreqTestHelper, model)
# ValueError: too many values to unpack
#
#
# Traceback (most recent call last):
#   File "prev_ob_models/Birgiolas2020/fitting.py", line 195, in get_workitem_score
#     raise Exception(prediction)
# Exception: Traceback (most recent call last):
#   File "/home/justas/Repositories/neuronunit_justasb/neuronunit/tests/olfactory_bulb/__init__.py", line 30, in generate_prediction
#     result = self.generate_prediction_nocache(model)
#   File "/home/justas/Repositories/neuronunit_justasb/neuronunit/tests/olfactory_bulb/tests.py", line 385, in generate_prediction_nocache
#     return ap["threshold_v"]
# TypeError: string indices must be integers, not str
#
#
# Traceback (most recent call last):
#   File "prev_ob_models/Birgiolas2020/fitting.py", line 195, in get_workitem_score
#     raise Exception(prediction)
# Exception: Traceback (most recent call last):
#   File "/home/justas/Repositories/neuronunit_justasb/neuronunit/tests/olfactory_bulb/__init__.py", line 30, in generate_prediction
#     result = self.generate_prediction_nocache(model)
#   File "/home/justas/Repositories/neuronunit_justasb/neuronunit/tests/olfactory_bulb/tests.py", line 385, in generate_prediction_nocache
#     return ap["threshold_v"]
# TypeError: string indices must be integers, not str
#
#
# Traceback (most recent call last):
#   File "prev_ob_models/Birgiolas2020/fitting.py", line 195, in get_workitem_score
#     raise Exception(prediction)
# Exception: Traceback (most recent call last):
#   File "/home/justas/Repositories/neuronunit_justasb/neuronunit/tests/olfactory_bulb/__init__.py", line 30, in generate_prediction
#     result = self.generate_prediction_nocache(model)
#   File "/home/justas/Repositories/neuronunit_justasb/neuronunit/tests/olfactory_bulb/tests.py", line 1072, in generate_prediction_nocache
#     freq_targetHz, crossings, voltage = self.get_dependent_prediction(TargetFreqTestHelper, model)
# ValueError: too many values to unpack
#
#
# Traceback (most recent call last):
#   File "prev_ob_models/Birgiolas2020/fitting.py", line 195, in get_workitem_score
#     raise Exception(prediction)
# Exception: Traceback (most recent call last):
#   File "/home/justas/Repositories/neuronunit_justasb/neuronunit/tests/olfactory_bulb/__init__.py", line 30, in generate_prediction
#     result = self.generate_prediction_nocache(model)
#   File "/home/justas/Repositories/neuronunit_justasb/neuronunit/tests/olfactory_bulb/tests.py", line 1027, in generate_prediction_nocache
#     freq_targetHz, crossings, voltage = self.get_dependent_prediction(TargetFreqTestHelper, model)
# ValueError: too many values to unpack
#
#
# Traceback (most recent call last):
#   File "prev_ob_models/Birgiolas2020/fitting.py", line 195, in get_workitem_score
#     raise Exception(prediction)
# Exception: Traceback (most recent call last):
#   File "/home/justas/Repositories/neuronunit_justasb/neuronunit/tests/olfactory_bulb/__init__.py", line 30, in generate_prediction
#     result = self.generate_prediction_nocache(model)
#   File "/home/justas/Repositories/neuronunit_justasb/neuronunit/tests/olfactory_bulb/tests.py", line 385, in generate_prediction_nocache
#     return ap["threshold_v"]
# TypeError: string indices must be integers, not str
#
#
# Traceback (most recent call last):
#   File "prev_ob_models/Birgiolas2020/fitting.py", line 195, in get_workitem_score
#     raise Exception(prediction)
# Exception: Traceback (most recent call last):
#   File "/home/justas/Repositories/neuronunit_justasb/neuronunit/tests/olfactory_bulb/__init__.py", line 30, in generate_prediction
#     result = self.generate_prediction_nocache(model)
#   File "/home/justas/Repositories/neuronunit_justasb/neuronunit/tests/olfactory_bulb/tests.py", line 385, in generate_prediction_nocache
#     return ap["threshold_v"]
# TypeError: string indices must be integers, not str
#
#
# Traceback (most recent call last):
#   File "prev_ob_models/Birgiolas2020/fitting.py", line 195, in get_workitem_score
#     raise Exception(prediction)
# Exception: Traceback (most recent call last):
#   File "/home/justas/Repositories/neuronunit_justasb/neuronunit/tests/olfactory_bulb/__init__.py", line 30, in generate_prediction
#     result = self.generate_prediction_nocache(model)
#   File "/home/justas/Repositories/neuronunit_justasb/neuronunit/tests/olfactory_bulb/tests.py", line 1072, in generate_prediction_nocache
#     freq_targetHz, crossings, voltage = self.get_dependent_prediction(TargetFreqTestHelper, model)
# ValueError: too many values to unpack
#
#
# Traceback (most recent call last):
#   File "prev_ob_models/Birgiolas2020/fitting.py", line 195, in get_workitem_score
#     raise Exception(prediction)
# Exception: Traceback (most recent call last):
#   File "/home/justas/Repositories/neuronunit_justasb/neuronunit/tests/olfactory_bulb/__init__.py", line 30, in generate_prediction
#     result = self.generate_prediction_nocache(model)
#   File "/home/justas/Repositories/neuronunit_justasb/neuronunit/tests/olfactory_bulb/tests.py", line 415, in generate_prediction_nocache
#     return ap["amplitude"]
# TypeError: string indices must be integers, not str
#
#
# Traceback (most recent call last):
#   File "prev_ob_models/Birgiolas2020/fitting.py", line 195, in get_workitem_score
#     raise Exception(prediction)
# Exception: Traceback (most recent call last):
#   File "/home/justas/Repositories/neuronunit_justasb/neuronunit/tests/olfactory_bulb/__init__.py", line 30, in generate_prediction
#     result = self.generate_prediction_nocache(model)
#   File "/home/justas/Repositories/neuronunit_justasb/neuronunit/tests/olfactory_bulb/tests.py", line 415, in generate_prediction_nocache
#     return ap["amplitude"]
# TypeError: string indices must be integers, not str
#
#
# Traceback (most recent call last):
#   File "prev_ob_models/Birgiolas2020/fitting.py", line 195, in get_workitem_score
#     raise Exception(prediction)
# Exception: Traceback (most recent call last):
#   File "/home/justas/Repositories/neuronunit_justasb/neuronunit/tests/olfactory_bulb/__init__.py", line 30, in generate_prediction
#     result = self.generate_prediction_nocache(model)
#   File "/home/justas/Repositories/neuronunit_justasb/neuronunit/tests/olfactory_bulb/tests.py", line 442, in generate_prediction_nocache
#     return ap["half_width"]
# TypeError: string indices must be integers, not str
#
#
# Traceback (most recent call last):
#   File "prev_ob_models/Birgiolas2020/fitting.py", line 195, in get_workitem_score
#     raise Exception(prediction)
# Exception: Traceback (most recent call last):
#   File "/home/justas/Repositories/neuronunit_justasb/neuronunit/tests/olfactory_bulb/__init__.py", line 30, in generate_prediction
#     result = self.generate_prediction_nocache(model)
#   File "/home/justas/Repositories/neuronunit_justasb/neuronunit/tests/olfactory_bulb/tests.py", line 442, in generate_prediction_nocache
#     return ap["half_width"]
# TypeError: string indices must be integers, not str
#
#
# Traceback (most recent call last):
#   File "prev_ob_models/Birgiolas2020/fitting.py", line 195, in get_workitem_score
#     raise Exception(prediction)
# Exception: Traceback (most recent call last):
#   File "/home/justas/Repositories/neuronunit_justasb/neuronunit/tests/olfactory_bulb/__init__.py", line 30, in generate_prediction
#     result = self.generate_prediction_nocache(model)
#   File "/home/justas/Repositories/neuronunit_justasb/neuronunit/tests/olfactory_bulb/tests.py", line 1027, in generate_prediction_nocache
#     freq_targetHz, crossings, voltage = self.get_dependent_prediction(TargetFreqTestHelper, model)
# ValueError: too many values to unpack
#
#
# Traceback (most recent call last):
#   File "prev_ob_models/Birgiolas2020/fitting.py", line 195, in get_workitem_score
#     raise Exception(prediction)
# Exception: Traceback (most recent call last):
#   File "/home/justas/Repositories/neuronunit_justasb/neuronunit/tests/olfactory_bulb/__init__.py", line 30, in generate_prediction
#     result = self.generate_prediction_nocache(model)
#   File "/home/justas/Repositories/neuronunit_justasb/neuronunit/tests/olfactory_bulb/tests.py", line 1027, in generate_prediction_nocache
#     freq_targetHz, crossings, voltage = self.get_dependent_prediction(TargetFreqTestHelper, model)
# ValueError: too many values to unpack
# Traceback (most recent call last):
#   File "prev_ob_models/Birgiolas2020/fitting.py", line 195, in get_workitem_score
#     raise Exception(prediction)
# Exception: Traceback (most recent call last):
#   File "/home/justas/Repositories/neuronunit_justasb/neuronunit/tests/olfactory_bulb/__init__.py", line 30, in generate_prediction
#     result = self.generate_prediction_nocache(model)
#   File "/home/justas/Repositories/neuronunit_justasb/neuronunit/tests/olfactory_bulb/tests.py", line 267, in generate_prediction_nocache
#     raise Exception("Negative rheobase: Model produces spikes without stimulation")
# Exception: Negative rheobase: Model produces spikes without stimulation
#
#
# Traceback (most recent call last):
#   File "prev_ob_models/Birgiolas2020/fitting.py", line 195, in get_workitem_score
#     raise Exception(prediction)
# Exception: Traceback (most recent call last):
#   File "/home/justas/Repositories/neuronunit_justasb/neuronunit/tests/olfactory_bulb/__init__.py", line 30, in generate_prediction
#     result = self.generate_prediction_nocache(model)
#   File "/home/justas/Repositories/neuronunit_justasb/neuronunit/tests/olfactory_bulb/tests.py", line 400, in generate_prediction_nocache
#     return ap["peak_v"]
# TypeError: string indices must be integers, not str
#
#
# Traceback (most recent call last):
#   File "prev_ob_models/Birgiolas2020/fitting.py", line 195, in get_workitem_score
#     raise Exception(prediction)
# Exception: Traceback (most recent call last):
#   File "/home/justas/Repositories/neuronunit_justasb/neuronunit/tests/olfactory_bulb/__init__.py", line 30, in generate_prediction
#     result = self.generate_prediction_nocache(model)
#   File "/home/justas/Repositories/neuronunit_justasb/neuronunit/tests/olfactory_bulb/tests.py", line 385, in generate_prediction_nocache
#     return ap["threshold_v"]
# TypeError: string indices must be integers, not str
#
#
# Traceback (most recent call last):
#   File "prev_ob_models/Birgiolas2020/fitting.py", line 195, in get_workitem_score
#     raise Exception(prediction)
# Exception: Traceback (most recent call last):
#   File "/home/justas/Repositories/neuronunit_justasb/neuronunit/tests/olfactory_bulb/__init__.py", line 30, in generate_prediction
#     result = self.generate_prediction_nocache(model)
#   File "/home/justas/Repositories/neuronunit_justasb/neuronunit/tests/olfactory_bulb/tests.py", line 385, in generate_prediction_nocache
#     return ap["threshold_v"]
# TypeError: string indices must be integers, not str
#
#
# Traceback (most recent call last):
#   File "prev_ob_models/Birgiolas2020/fitting.py", line 195, in get_workitem_score
#     raise Exception(prediction)
# Exception: Traceback (most recent call last):
#   File "/home/justas/Repositories/neuronunit_justasb/neuronunit/tests/olfactory_bulb/__init__.py", line 30, in generate_prediction
#     result = self.generate_prediction_nocache(model)
#   File "/home/justas/Repositories/neuronunit_justasb/neuronunit/tests/olfactory_bulb/tests.py", line 1072, in generate_prediction_nocache
#     freq_targetHz, crossings, voltage = self.get_dependent_prediction(TargetFreqTestHelper, model)
# ValueError: too many values to unpack
#
#
# Traceback (most recent call last):
#   File "prev_ob_models/Birgiolas2020/fitting.py", line 195, in get_workitem_score
#     raise Exception(prediction)
# Exception: Traceback (most recent call last):
#   File "/home/justas/Repositories/neuronunit_justasb/neuronunit/tests/olfactory_bulb/__init__.py", line 30, in generate_prediction
#     result = self.generate_prediction_nocache(model)
#   File "/home/justas/Repositories/neuronunit_justasb/neuronunit/tests/olfactory_bulb/tests.py", line 625, in generate_prediction_nocache
#     _, _, voltage = self.get_dependent_prediction(TargetFreqTestHelper, model)
# ValueError: too many values to unpack
#
#
# Traceback (most recent call last):
#   File "prev_ob_models/Birgiolas2020/fitting.py", line 195, in get_workitem_score
#     raise Exception(prediction)
# Exception: Traceback (most recent call last):
#   File "/home/justas/Repositories/neuronunit_justasb/neuronunit/tests/olfactory_bulb/__init__.py", line 30, in generate_prediction
#     result = self.generate_prediction_nocache(model)
#   File "/home/justas/Repositories/neuronunit_justasb/neuronunit/tests/olfactory_bulb/tests.py", line 625, in generate_prediction_nocache
#     _, _, voltage = self.get_dependent_prediction(TargetFreqTestHelper, model)
# ValueError: too many values to unpack
#
#
# Traceback (most recent call last):
#   File "prev_ob_models/Birgiolas2020/fitting.py", line 195, in get_workitem_score
#     raise Exception(prediction)
# Exception: Traceback (most recent call last):
#   File "/home/justas/Repositories/neuronunit_justasb/neuronunit/tests/olfactory_bulb/__init__.py", line 30, in generate_prediction
#     result = self.generate_prediction_nocache(model)
#   File "/home/justas/Repositories/neuronunit_justasb/neuronunit/tests/olfactory_bulb/tests.py", line 954, in generate_prediction_nocache
#     freq_targetHz, crossings, voltage = self.get_dependent_prediction(TargetFreqTestHelper, model)
# ValueError: too many values to unpack
#
#
# Traceback (most recent call last):
#   File "prev_ob_models/Birgiolas2020/fitting.py", line 195, in get_workitem_score
#     raise Exception(prediction)
# Exception: Traceback (most recent call last):
#   File "/home/justas/Repositories/neuronunit_justasb/neuronunit/tests/olfactory_bulb/__init__.py", line 30, in generate_prediction
#     result = self.generate_prediction_nocache(model)
#   File "/home/justas/Repositories/neuronunit_justasb/neuronunit/tests/olfactory_bulb/tests.py", line 954, in generate_prediction_nocache
#     freq_targetHz, crossings, voltage = self.get_dependent_prediction(TargetFreqTestHelper, model)
# ValueError: too many values to unpack
#
#
# ('DONE with', 1, 'of', 20, 'of GEN', '2', 'with Fitness', '18.95')
# ('DONE with', 2, 'of', 20, 'of GEN', '2', 'with Fitness', '27.66')
# ('DONE with', 3, 'of', 20, 'of GEN', '2', 'with Fitness', '568.45')
# Traceback (most recent call last):
#   File "prev_ob_models/Birgiolas2020/fitting.py", line 195, in get_workitem_score
#     raise Exception(prediction)
# Exception: Traceback (most recent call last):
#   File "/home/justas/Repositories/neuronunit_justasb/neuronunit/tests/olfactory_bulb/__init__.py", line 30, in generate_prediction
#     result = self.generate_prediction_nocache(model)
#   File "/home/justas/Repositories/neuronunit_justasb/neuronunit/tests/olfactory_bulb/tests.py", line 415, in generate_prediction_nocache
#     return ap["amplitude"]
# TypeError: string indices must be integers, not str
#
#
# Traceback (most recent call last):
#   File "prev_ob_models/Birgiolas2020/fitting.py", line 195, in get_workitem_score
#     raise Exception(prediction)
# Exception: Traceback (most recent call last):
#   File "/home/justas/Repositories/neuronunit_justasb/neuronunit/tests/olfactory_bulb/__init__.py", line 30, in generate_prediction
#     result = self.generate_prediction_nocache(model)
#   File "/home/justas/Repositories/neuronunit_justasb/neuronunit/tests/olfactory_bulb/tests.py", line 415, in generate_prediction_nocache
#     return ap["amplitude"]
# TypeError: string indices must be integers, not str
#
#
# Traceback (most recent call last):
#   File "prev_ob_models/Birgiolas2020/fitting.py", line 195, in get_workitem_score
#     raise Exception(prediction)
# Exception: Traceback (most recent call last):
#   File "/home/justas/Repositories/neuronunit_justasb/neuronunit/tests/olfactory_bulb/__init__.py", line 30, in generate_prediction
#     result = self.generate_prediction_nocache(model)
#   File "/home/justas/Repositories/neuronunit_justasb/neuronunit/tests/olfactory_bulb/tests.py", line 442, in generate_prediction_nocache
#     return ap["half_width"]
# TypeError: string indices must be integers, not str
#
#
# Traceback (most recent call last):
#   File "prev_ob_models/Birgiolas2020/fitting.py", line 195, in get_workitem_score
#     raise Exception(prediction)
# Exception: Traceback (most recent call last):
#   File "/home/justas/Repositories/neuronunit_justasb/neuronunit/tests/olfactory_bulb/__init__.py", line 30, in generate_prediction
#     result = self.generate_prediction_nocache(model)
#   File "/home/justas/Repositories/neuronunit_justasb/neuronunit/tests/olfactory_bulb/tests.py", line 442, in generate_prediction_nocache
#     return ap["half_width"]
# TypeError: string indices must be integers, not str
# Traceback (most recent call last):
#   File "prev_ob_models/Birgiolas2020/fitting.py", line 195, in get_workitem_score
#     raise Exception(prediction)
# Exception: Traceback (most recent call last):
#   File "/home/justas/Repositories/neuronunit_justasb/neuronunit/tests/olfactory_bulb/__init__.py", line 30, in generate_prediction
#     result = self.generate_prediction_nocache(model)
#   File "/home/justas/Repositories/neuronunit_justasb/neuronunit/tests/olfactory_bulb/tests.py", line 385, in generate_prediction_nocache
#     return ap["threshold_v"]
# TypeError: string indices must be integers, not str
#
#
# Traceback (most recent call last):
#   File "prev_ob_models/Birgiolas2020/fitting.py", line 195, in get_workitem_score
#     raise Exception(prediction)
# Exception: Traceback (most recent call last):
#   File "/home/justas/Repositories/neuronunit_justasb/neuronunit/tests/olfactory_bulb/__init__.py", line 30, in generate_prediction
#     result = self.generate_prediction_nocache(model)
#   File "/home/justas/Repositories/neuronunit_justasb/neuronunit/tests/olfactory_bulb/tests.py", line 385, in generate_prediction_nocache
#     return ap["threshold_v"]
# TypeError: string indices must be integers, not str
#
#
# Traceback (most recent call last):
#   File "prev_ob_models/Birgiolas2020/fitting.py", line 195, in get_workitem_score
#     raise Exception(prediction)
# Exception: Traceback (most recent call last):
#   File "/home/justas/Repositories/neuronunit_justasb/neuronunit/tests/olfactory_bulb/__init__.py", line 30, in generate_prediction
#     result = self.generate_prediction_nocache(model)
#   File "/home/justas/Repositories/neuronunit_justasb/neuronunit/tests/olfactory_bulb/tests.py", line 1072, in generate_prediction_nocache
#     freq_targetHz, crossings, voltage = self.get_dependent_prediction(TargetFreqTestHelper, model)
# ValueError: too many values to unpack
#
#
# Simulation timed out
# ('DONE with', 4, 'of', 20, 'of GEN', '2', 'with Fitness', '90.00')
# ('DONE with', 5, 'of', 20, 'of GEN', '2', 'with Fitness', '13.08')
# Simulation timed out
# ('DONE with', 6, 'of', 20, 'of GEN', '2', 'with Fitness', '90.00')
# ('DONE with', 7, 'of', 20, 'of GEN', '2', 'with Fitness', '6.56')
# ('DONE with', 8, 'of', 20, 'of GEN', '2', 'with Fitness', '17.93')
# ('DONE with', 9, 'of', 20, 'of GEN', '2', 'with Fitness', '11157.76')
# Simulation timed out
# ('DONE with', 10, 'of', 20, 'of GEN', '2', 'with Fitness', '90.00')
# ('DONE with', 11, 'of', 20, 'of GEN', '2', 'with Fitness', '4.10')
# ('DONE with', 12, 'of', 20, 'of GEN', '2', 'with Fitness', '4.26')
# ('DONE with', 13, 'of', 20, 'of GEN', '2', 'with Fitness', '3.71')
# ('DONE with', 14, 'of', 20, 'of GEN', '2', 'with Fitness', '3.68')
# ('DONE with', 15, 'of', 20, 'of GEN', '2', 'with Fitness', '4.10')
# ('DONE with', 16, 'of', 20, 'of GEN', '2', 'with Fitness', '3.53')
# Simulation timed out
# ('DONE with', 17, 'of', 20, 'of GEN', '2', 'with Fitness', '90.00')
# Simulation timed out
# ('DONE with', 18, 'of', 20, 'of GEN', '2', 'with Fitness', '90.00')
# Simulation timed out
# ('DONE with', 19, 'of', 20, 'of GEN', '2', 'with Fitness', '90.00')
# Simulation timed out
# ('DONE with', 20, 'of', 20, 'of GEN', '2', 'with Fitness', '90.00')
# ('Generation', 2, 'out of', 7, 'COMPLETE')
# ('Best fitness:', 3.50314119705441)
# ('Best individual', [1.2471592703753913, 85.91729392565932, 0.9576321104748539, 32.45265517788054, -63.438841110533915, -75.05751351034053, 3.657331273597089e-05, 2.7626423490513514, 9.666857483589407, 0.06150916169169841, 0.03759175148995797, 0.0004759847063037054, 0.0042226776511213, 0.00776370232830789, 9.599737738463663e-06, -16.369883529143777, 1.9500130790130927e-06, 0.01027446638931233])
# diam in ['apical', 'basal', 'axonal'] at 23.41% of range. Val: 1.24715927038 Low: 0.1 High: 5.0
# Ra in ['all'] at 56.99% of range. Val: 85.9172939257 Low: 1.0 High: 150.0
# cm in ['all'] at 45.14% of range. Val: 0.957632110475 Low: 0.1 High: 2.0
# ena in ['all'] at 20.75% of range. Val: 32.4526551779 Low: 20.0 High: 80.0
# ek in ['all'] at 73.12% of range. Val: -63.4388411105 Low: -100.0 High: -50.0
# e_pas in ['all'] at 37.36% of range. Val: -75.0575135103 Low: -90.0 High: -50.0
# g_pas in ['all'] at 91.43% of range. Val: 3.6573312736e-05 Low: 0 High: 4e-05
# sh_Na in ['all'] at 27.63% of range. Val: 2.76264234905 Low: 0 High: 10
# tau_CaPool in ['all'] at 2.90% of range. Val: 9.66685748359 Low: 1 High: 300
# gbar_Na in ['all'] at 61.51% of range. Val: 0.0615091616917 Low: 0 High: 0.1
# gbar_Kd in ['all'] at 37.59% of range. Val: 0.03759175149 Low: 0 High: 0.1
# gbar_Kslow in ['all'] at 47.60% of range. Val: 0.000475984706304 Low: 0 High: 0.001
# gbar_KA in ['all'] at 21.11% of range. Val: 0.00422267765112 Low: 0 High: 0.02
# gbar_KCa in ['all'] at 48.52% of range. Val: 0.00776370232831 Low: 0 High: 0.016
# gbar_LCa in ['all'] at 1.92% of range. Val: 9.59973773846e-06 Low: 0 High: 0.0005
# eh in ['apical'] at 78.77% of range. Val: -16.3698835291 Low: -40.0 High: -10.0
# ...
#   File "prev_ob_models/Birgiolas2020/fitting.py", line 195, in get_workitem_score
#     raise Exception(prediction)
# Exception: Traceback (most recent call last):
#   File "/home/justas/Repositories/neuronunit_justasb/neuronunit/tests/olfactory_bulb/__init__.py", line 30, in generate_prediction
#     result = self.generate_prediction_nocache(model)
#   File "/home/justas/Repositories/neuronunit_justasb/neuronunit/tests/olfactory_bulb/tests.py", line 270, in generate_prediction_nocache
#     raise Exception("Rheobase was not found between 0 and " + str(upper_bound))
# Exception: Rheobase was not found between 0 and 1.3234251394357068 nA
#
#
# Traceback (most recent call last):
#   File "prev_ob_models/Birgiolas2020/fitting.py", line 195, in get_workitem_score
#     raise Exception(prediction)
# Exception: Traceback (most recent call last):
#   File "/home/justas/Repositories/neuronunit_justasb/neuronunit/tests/olfactory_bulb/__init__.py", line 30, in generate_prediction
#     result = self.generate_prediction_nocache(model)
#   File "/home/justas/Repositories/neuronunit_justasb/neuronunit/tests/olfactory_bulb/tests.py", line 370, in generate_prediction_nocache
#     return self.get_first_ap(model)
#   File "/home/justas/Repositories/neuronunit_justasb/neuronunit/tests/olfactory_bulb/tests.py", line 365, in get_first_ap
#     raise Exception("The voltage trace does not contain any detectable action potentials using method: " + self.threshold_method)
# Exception: The voltage trace does not contain any detectable action potentials using method: d3v/dt3
# Traceback (most recent call last):
#   File "prev_ob_models/Birgiolas2020/fitting.py", line 195, in get_workitem_score
#     raise Exception(prediction)
# Exception: Traceback (most recent call last):
#   File "/home/justas/Repositories/neuronunit_justasb/neuronunit/tests/olfactory_bulb/__init__.py", line 30, in generate_prediction
#     result = self.generate_prediction_nocache(model)
#   File "/home/justas/Repositories/neuronunit_justasb/neuronunit/tests/olfactory_bulb/tests.py", line 626, in generate_prediction_nocache
#     aps = self.get_aps(voltage)
#   File "/home/justas/Repositories/neuronunit_justasb/neuronunit/tests/olfactory_bulb/__init__.py", line 115, in get_aps
#     return get_APs(voltage, self.ss_delay, self.threshold_method)
#   File "/home/justas/Repositories/neuronunit_justasb/neuronunit/tests/olfactory_bulb/utilities.py", line 87, in get_APs
#     ss_delay_point = int(ss_delay * voltage.sampling_rate)+1
# AttributeError: 'NoneType' object has no attribute 'sampling_rate'
#
#
# Traceback (most recent call last):
#   File "prev_ob_models/Birgiolas2020/fitting.py", line 195, in get_workitem_score
#     raise Exception(prediction)
# Exception: Traceback (most recent call last):
#   File "/home/justas/Repositories/neuronunit_justasb/neuronunit/tests/olfactory_bulb/__init__.py", line 30, in generate_prediction
#     result = self.generate_prediction_nocache(model)
#   File "/home/justas/Repositories/neuronunit_justasb/neuronunit/tests/olfactory_bulb/tests.py", line 626, in generate_prediction_nocache
#     aps = self.get_aps(voltage)
#   File "/home/justas/Repositories/neuronunit_justasb/neuronunit/tests/olfactory_bulb/__init__.py", line 115, in get_aps
#     return get_APs(voltage, self.ss_delay, self.threshold_method)
#   File "/home/justas/Repositories/neuronunit_justasb/neuronunit/tests/olfactory_bulb/utilities.py", line 87, in get_APs
#     ss_delay_point = int(ss_delay * voltage.sampling_rate)+1
# AttributeError: 'NoneType' object has no attribute 'sampling_rate'
#
#
# ('DONE with', 1, 'of', 20, 'of GEN', '7', 'with Fitness', '10.22')
# ('DONE with', 2, 'of', 20, 'of GEN', '7', 'with Fitness', '17.60')
# Traceback (most recent call last):
#   File "prev_ob_models/Birgiolas2020/fitting.py", line 195, in get_workitem_score
#     raise Exception(prediction)
# Exception: Traceback (most recent call last):
#   File "/home/justas/Repositories/neuronunit_justasb/neuronunit/tests/olfactory_bulb/__init__.py", line 30, in generate_prediction
#     result = self.generate_prediction_nocache(model)
#   File "/home/justas/Repositories/neuronunit_justasb/neuronunit/tests/olfactory_bulb/tests.py", line 1027, in generate_prediction_nocache
#     freq_targetHz, crossings, voltage = self.get_dependent_prediction(TargetFreqTestHelper, model)
# ValueError: too many values to unpack
#
#
# Traceback (most recent call last):
#   File "prev_ob_models/Birgiolas2020/fitting.py", line 195, in get_workitem_score
#     raise Exception(prediction)
# Exception: Traceback (most recent call last):
#   File "/home/justas/Repositories/neuronunit_justasb/neuronunit/tests/olfactory_bulb/__init__.py", line 30, in generate_prediction
#     result = self.generate_prediction_nocache(model)
#   File "/home/justas/Repositories/neuronunit_justasb/neuronunit/tests/olfactory_bulb/tests.py", line 626, in generate_prediction_nocache
#     aps = self.get_aps(voltage)
#   File "/home/justas/Repositories/neuronunit_justasb/neuronunit/tests/olfactory_bulb/__init__.py", line 115, in get_aps
#     return get_APs(voltage, self.ss_delay, self.threshold_method)
#   File "/home/justas/Repositories/neuronunit_justasb/neuronunit/tests/olfactory_bulb/utilities.py", line 87, in get_APs
#     ss_delay_point = int(ss_delay * voltage.sampling_rate)+1
# AttributeError: 'NoneType' object has no attribute 'sampling_rate'
#
#
# Traceback (most recent call last):
#   File "prev_ob_models/Birgiolas2020/fitting.py", line 195, in get_workitem_score
#     raise Exception(prediction)
# Exception: Traceback (most recent call last):
#   File "/home/justas/Repositories/neuronunit_justasb/neuronunit/tests/olfactory_bulb/__init__.py", line 30, in generate_prediction
#     result = self.generate_prediction_nocache(model)
#   File "/home/justas/Repositories/neuronunit_justasb/neuronunit/tests/olfactory_bulb/tests.py", line 625, in generate_prediction_nocache
#     _, _, voltage = self.get_dependent_prediction(TargetFreqTestHelper, model)
# ValueError: too many values to unpack
#
#
# Traceback (most recent call last):
#   File "prev_ob_models/Birgiolas2020/fitting.py", line 195, in get_workitem_score
#     raise Exception(prediction)
# Exception: Traceback (most recent call last):
#   File "/home/justas/Repositories/neuronunit_justasb/neuronunit/tests/olfactory_bulb/__init__.py", line 30, in generate_prediction
#     result = self.generate_prediction_nocache(model)
#   File "/home/justas/Repositories/neuronunit_justasb/neuronunit/tests/olfactory_bulb/tests.py", line 954, in generate_prediction_nocache
#     freq_targetHz, crossings, voltage = self.get_dependent_prediction(TargetFreqTestHelper, model)
# ValueError: too many values to unpack
#
#
# Traceback (most recent call last):
#   File "prev_ob_models/Birgiolas2020/fitting.py", line 195, in get_workitem_score
#     raise Exception(prediction)
# Exception: Traceback (most recent call last):
#   File "/home/justas/Repositories/neuronunit_justasb/neuronunit/tests/olfactory_bulb/__init__.py", line 30, in generate_prediction
#     result = self.generate_prediction_nocache(model)
#   File "/home/justas/Repositories/neuronunit_justasb/neuronunit/tests/olfactory_bulb/tests.py", line 626, in generate_prediction_nocache
#     aps = self.get_aps(voltage)
#   File "/home/justas/Repositories/neuronunit_justasb/neuronunit/tests/olfactory_bulb/__init__.py", line 115, in get_aps
#     return get_APs(voltage, self.ss_delay, self.threshold_method)
#   File "/home/justas/Repositories/neuronunit_justasb/neuronunit/tests/olfactory_bulb/utilities.py", line 87, in get_APs
#     ss_delay_point = int(ss_delay * voltage.sampling_rate)+1
# AttributeError: 'NoneType' object has no attribute 'sampling_rate'
#
#
# Traceback (most recent call last):
#   File "prev_ob_models/Birgiolas2020/fitting.py", line 195, in get_workitem_score
#     raise Exception(prediction)
# Exception: Traceback (most recent call last):
#   File "/home/justas/Repositories/neuronunit_justasb/neuronunit/tests/olfactory_bulb/__init__.py", line 30, in generate_prediction
#     result = self.generate_prediction_nocache(model)
#   File "/home/justas/Repositories/neuronunit_justasb/neuronunit/tests/olfactory_bulb/tests.py", line 626, in generate_prediction_nocache
#     aps = self.get_aps(voltage)
#   File "/home/justas/Repositories/neuronunit_justasb/neuronunit/tests/olfactory_bulb/__init__.py", line 115, in get_aps
#     return get_APs(voltage, self.ss_delay, self.threshold_method)
#   File "/home/justas/Repositories/neuronunit_justasb/neuronunit/tests/olfactory_bulb/utilities.py", line 87, in get_APs
#     ss_delay_point = int(ss_delay * voltage.sampling_rate)+1
# AttributeError: 'NoneType' object has no attribute 'sampling_rate'
#
#
# ('DONE with', 3, 'of', 20, 'of GEN', '7', 'with Fitness', '10.23')
# ('DONE with', 4, 'of', 20, 'of GEN', '7', 'with Fitness', '17.38')
# Traceback (most recent call last):
#   File "prev_ob_models/Birgiolas2020/fitting.py", line 195, in get_workitem_score
#     raise Exception(prediction)
# Exception: Traceback (most recent call last):
#   File "/home/justas/Repositories/neuronunit_justasb/neuronunit/tests/olfactory_bulb/__init__.py", line 30, in generate_prediction
#     result = self.generate_prediction_nocache(model)
#   File "/home/justas/Repositories/neuronunit_justasb/neuronunit/tests/olfactory_bulb/tests.py", line 385, in generate_prediction_nocache
#     return ap["threshold_v"]
# TypeError: string indices must be integers, not str
#
#
# Traceback (most recent call last):
#   File "prev_ob_models/Birgiolas2020/fitting.py", line 195, in get_workitem_score
#     raise Exception(prediction)
# Exception: Traceback (most recent call last):
#   File "/home/justas/Repositories/neuronunit_justasb/neuronunit/tests/olfactory_bulb/__init__.py", line 30, in generate_prediction
#     result = self.generate_prediction_nocache(model)
#   File "/home/justas/Repositories/neuronunit_justasb/neuronunit/tests/olfactory_bulb/tests.py", line 385, in generate_prediction_nocache
#     return ap["threshold_v"]
# TypeError: string indices must be integers, not str
# Traceback (most recent call last):
#   File "prev_ob_models/Birgiolas2020/fitting.py", line 195, in get_workitem_score
#     raise Exception(prediction)
# Exception: Traceback (most recent call last):
#   File "/home/justas/Repositories/neuronunit_justasb/neuronunit/tests/olfactory_bulb/__init__.py", line 30, in generate_prediction
#     result = self.generate_prediction_nocache(model)
#   File "/home/justas/Repositories/neuronunit_justasb/neuronunit/tests/olfactory_bulb/tests.py", line 1072, in generate_prediction_nocache
#     freq_targetHz, crossings, voltage = self.get_dependent_prediction(TargetFreqTestHelper, model)
# ValueError: too many values to unpack
#
#
# ('DONE with', 5, 'of', 20, 'of GEN', '7', 'with Fitness', '17.40')
# Traceback (most recent call last):
#   File "prev_ob_models/Birgiolas2020/fitting.py", line 195, in get_workitem_score
#     raise Exception(prediction)
# Exception: Traceback (most recent call last):
#   File "/home/justas/Repositories/neuronunit_justasb/neuronunit/tests/olfactory_bulb/__init__.py", line 30, in generate_prediction
#     result = self.generate_prediction_nocache(model)
#   File "/home/justas/Repositories/neuronunit_justasb/neuronunit/tests/olfactory_bulb/tests.py", line 415, in generate_prediction_nocache
#     return ap["amplitude"]
# TypeError: string indices must be integers, not str
#
#
# Traceback (most recent call last):
#   File "prev_ob_models/Birgiolas2020/fitting.py", line 195, in get_workitem_score
#     raise Exception(prediction)
# Exception: Traceback (most recent call last):
#   File "/home/justas/Repositories/neuronunit_justasb/neuronunit/tests/olfactory_bulb/__init__.py", line 30, in generate_prediction
#     result = self.generate_prediction_nocache(model)
#   File "/home/justas/Repositories/neuronunit_justasb/neuronunit/tests/olfactory_bulb/tests.py", line 415, in generate_prediction_nocache
#     return ap["amplitude"]
# TypeError: string indices must be integers, not str
#
#
# Traceback (most recent call last):
#   File "prev_ob_models/Birgiolas2020/fitting.py", line 195, in get_workitem_score
#     raise Exception(prediction)
# Exception: Traceback (most recent call last):
#   File "/home/justas/Repositories/neuronunit_justasb/neuronunit/tests/olfactory_bulb/__init__.py", line 30, in generate_prediction
#     result = self.generate_prediction_nocache(model)
#   File "/home/justas/Repositories/neuronunit_justasb/neuronunit/tests/olfactory_bulb/tests.py", line 442, in generate_prediction_nocache
#     return ap["half_width"]
# TypeError: string indices must be integers, not str
#
#
# Traceback (most recent call last):
#   File "prev_ob_models/Birgiolas2020/fitting.py", line 195, in get_workitem_score
#     raise Exception(prediction)
# Exception: Traceback (most recent call last):
#   File "/home/justas/Repositories/neuronunit_justasb/neuronunit/tests/olfactory_bulb/__init__.py", line 30, in generate_prediction
#     result = self.generate_prediction_nocache(model)
#   File "/home/justas/Repositories/neuronunit_justasb/neuronunit/tests/olfactory_bulb/tests.py", line 442, in generate_prediction_nocache
#     return ap["half_width"]
# TypeError: string indices must be integers, not str
#
#
# Simulation timed out
# ('DONE with', 6, 'of', 20, 'of GEN', '7', 'with Fitness', '90.00')
# Simulation timed out
# ('DONE with', 7, 'of', 20, 'of GEN', '7', 'with Fitness', '90.00')
# ('DONE with', 8, 'of', 20, 'of GEN', '7', 'with Fitness', '16.91')
# ('DONE with', 9, 'of', 20, 'of GEN', '7', 'with Fitness', '19.27')
# ('DONE with', 10, 'of', 20, 'of GEN', '7', 'with Fitness', '3.91')
# ('DONE with', 11, 'of', 20, 'of GEN', '7', 'with Fitness', '3.32')
# ('DONE with', 12, 'of', 20, 'of GEN', '7', 'with Fitness', '4.03')
# ('DONE with', 13, 'of', 20, 'of GEN', '7', 'with Fitness', '3.98')
# ('DONE with', 14, 'of', 20, 'of GEN', '7', 'with Fitness', '3.81')
# ('DONE with', 15, 'of', 20, 'of GEN', '7', 'with Fitness', '6.48')
# ('DONE with', 16, 'of', 20, 'of GEN', '7', 'with Fitness', '3.65')
# ('DONE with', 17, 'of', 20, 'of GEN', '7', 'with Fitness', '3.52')
# Simulation timed out
# ('DONE with', 18, 'of', 20, 'of GEN', '7', 'with Fitness', '90.00')
# Simulation timed out
# ('DONE with', 19, 'of', 20, 'of GEN', '7', 'with Fitness', '90.00')
# Simulation timed out
# ('DONE with', 20, 'of', 20, 'of GEN', '7', 'with Fitness', '90.00')
# ('Generation', 7, 'out of', 7, 'COMPLETE')
# ('Best fitness:', 3.3152560659679104)
# ('Best individual', [1.2471592703753913, 89.54731666051053, 0.9576321104748539, 23.163661456098886, -63.438841110533915, -75.05751351034053, 3.657331273597089e-05, 2.6570771987427655, 9.666857483589407, 0.06150916169169841, 0.03759175148995797, 0.0004759847063037054, 0.0042226776511213, 0.00776370232830789, 9.599737738463663e-06, -16.369883529143777, 1.9500130790130927e-06, 0.01027446638931233])
# diam in ['apical', 'basal', 'axonal'] at 23.41% of range. Val: 1.24715927038 Low: 0.1 High: 5.0
# Ra in ['all'] at 59.43% of range. Val: 89.5473166605 Low: 1.0 High: 150.0
# cm in ['all'] at 45.14% of range. Val: 0.957632110475 Low: 0.1 High: 2.0
# ena in ['all'] at 5.27% of range. Val: 23.1636614561 Low: 20.0 High: 80.0
# ek in ['all'] at 73.12% of range. Val: -63.4388411105 Low: -100.0 High: -50.0
# e_pas in ['all'] at 37.36% of range. Val: -75.0575135103 Low: -90.0 High: -50.0
# g_pas in ['all'] at 91.43% of range. Val: 3.6573312736e-05 Low: 0 High: 4e-05
# sh_Na in ['all'] at 26.57% of range. Val: 2.65707719874 Low: 0 High: 10
# tau_CaPool in ['all'] at 2.90% of range. Val: 9.66685748359 Low: 1 High: 300
# gbar_Na in ['all'] at 61.51% of range. Val: 0.0615091616917 Low: 0 High: 0.1
# gbar_Kd in ['all'] at 37.59% of range. Val: 0.03759175149 Low: 0 High: 0.1
# gbar_Kslow in ['all'] at 47.60% of range. Val: 0.000475984706304 Low: 0 High: 0.001
# gbar_KA in ['all'] at 21.11% of range. Val: 0.00422267765112 Low: 0 High: 0.02
# gbar_KCa in ['all'] at 48.52% of range. Val: 0.00776370232831 Low: 0 High: 0.016
# gbar_LCa in ['all'] at 1.92% of range. Val: 9.59973773846e-06 Low: 0 High: 0.0005
# eh in ['apical'] at 78.77% of range. Val: -16.3698835291 Low: -40.0 High: -10.0
# gbar_Ih in ['apical'] at 65.00% of range. Val: 1.95001307901e-06 Low: 0 High: 3e-06
# gbar_CaT in ['apical'] at 51.37% of range. Val: 0.0102744663893 Low: 0 High: 0.02

# %%
fitter.parameter_report(fitter.best)
# Out:
# diam in ['apical', 'basal', 'axonal'] at 23.41% of range. Val: 1.24715927038 Low: 0.1 High: 5.0
# Ra in ['all'] at 59.43% of range. Val: 89.5473166605 Low: 1.0 High: 150.0
# cm in ['all'] at 45.14% of range. Val: 0.957632110475 Low: 0.1 High: 2.0
# ena in ['all'] at 5.27% of range. Val: 23.1636614561 Low: 20.0 High: 80.0
# ek in ['all'] at 73.12% of range. Val: -63.4388411105 Low: -100.0 High: -50.0
# e_pas in ['all'] at 37.36% of range. Val: -75.0575135103 Low: -90.0 High: -50.0
# g_pas in ['all'] at 91.43% of range. Val: 3.6573312736e-05 Low: 0 High: 4e-05
# sh_Na in ['all'] at 26.57% of range. Val: 2.65707719874 Low: 0 High: 10
# tau_CaPool in ['all'] at 2.90% of range. Val: 9.66685748359 Low: 1 High: 300
# gbar_Na in ['all'] at 61.51% of range. Val: 0.0615091616917 Low: 0 High: 0.1
# gbar_Kd in ['all'] at 37.59% of range. Val: 0.03759175149 Low: 0 High: 0.1
# gbar_Kslow in ['all'] at 47.60% of range. Val: 0.000475984706304 Low: 0 High: 0.001
# gbar_KA in ['all'] at 21.11% of range. Val: 0.00422267765112 Low: 0 High: 0.02
# gbar_KCa in ['all'] at 48.52% of range. Val: 0.00776370232831 Low: 0 High: 0.016
# gbar_LCa in ['all'] at 1.92% of range. Val: 9.59973773846e-06 Low: 0 High: 0.0005
# eh in ['apical'] at 78.77% of range. Val: -16.3698835291 Low: -40.0 High: -10.0
# gbar_Ih in ['apical'] at 65.00% of range. Val: 1.95001307901e-06 Low: 0 High: 3e-06
# gbar_CaT in ['apical'] at 51.37% of range. Val: 0.0102744663893 Low: 0 High: 0.02

# %%
df, score = fitter.get_best_score()
print(score["model_score"]) 
df.transpose()
# Out:
# 3.31525606597
#                                      prev_ob_models.Birgiolas2020.isolated_cells.MC5
# AfterHyperpolarizationAmplitudeTest                            [-0.0842979900939449]
# AfterHyperpolarizationTimeTest                                   0.34810481314048597
# CellCapacitanceTest                                            -0.016566774158164266
# FISlopeTest                                                      0.05263157894736842
# ISICVTest                                                         0.1548043535286971
# InputResistanceTest                                               0.2821214479896947
# MembraneTimeConstantTest                                        -0.22822171156143767
# ReboundSpikingTest                                                               0.0
# RestingVoltageTest                                              -0.06479666859830868
# RheobaseTest                                                      0.3729925294302069
# SagVoltageTest                                                    0.8033096866012128
# SpikeAccommodationTest                                          -0.05572027859771893
# SpikeAccommodationTimeConstantTest                                 3.000667836088192
# SpikeAmplitudeTest                                            [-0.21737347557677872]
# SpikeHalfWidthTest                                                0.3706896551722807
# SpikePeakTest                                                     0.4241340313707585
# SpikeThresholdTest                                              [0.7373334768638938]
# model                                prev_ob_models.Birgiolas2020.isolated_cells.MC5

# %%
raise
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-8-9c9a2cba73bf> in <module>()
# ----> 1 raise
#
# TypeError: exceptions must be old-style classes or derived from BaseException, not NoneType

# %%
#fitter.clear_cache()
#fitter.best = []
df, score = fitter.get_best_score()
print(score["model_score"]) 
df.transpose()

# %%
raise

# %%
from scipy.optimize import minimize
def evaluate(ind):
    print(ind)
    return ind[0]**2+ind[1]**2+1

min_res = minimize(evaluate, [1.0,2.3], method='Nelder-Mead', options={"disp":False, "maxfev":50, "maxiter":500,"xatol":0.1,"fatol":0.1})
min_res

# %%
score

# %%
fitter.clear_cache()
df = fitter.get_previous_model_scores()
df

# %%
df.to_csv("ephyz/"+fitter.cell_type+"_model_zscores.csv")

# %%
raise

# %%
np.linspace(0,100,0.1)

# %%
score["model_score"]

# %%
raise

# %%
fitter.top = None

# %%
cpus = multiprocessing.cpu_count()
fitter.fit(int(cpus*1.5), 48)

# %%
fitter.clear_cache()
fitter.best = []
df, score = fitter.get_best_score()
df

# %%
score["model_score"]

# %%
fitter.pretty_pop()

# %%
from prev_ob_models.Birgiolas2020.isolated_cells import MC1
mc = MC1()

# %%
fitter.print_params(fitter.best, mc.cell)
