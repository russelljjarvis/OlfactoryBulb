# %%
import os; os.chdir('..')
import multiprocessing
from prev_ob_models.Birgiolas2020.fitting import *
# Out:
# /home/justas/anaconda2/envs/p27/lib/python2.7/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Could not load NEURONBackend

# %%
import sys
cell_id = sys.argv[1] if len(sys.argv) > 1 and sys.argv[1].isdigit() else 2
print(cell_id)
# Out:
# 2

# %%
fitter = CellFitter(cell_type="tc", fitting_model_class="prev_ob_models.Birgiolas2020.isolated_cells.TC"+str(cell_id))
# Out:
# ('Starting tc FITTER for model:', 'prev_ob_models.Birgiolas2020.isolated_cells.TC2')

# %%
import prev_ob_models.Birgiolas2020.fitting

# %%
prev_ob_models.Birgiolas2020.fitting.SHOW_ERRORS = False

# %%
#fitter.clear_cache()
fitter.fit(int(multiprocessing.cpu_count()*1.5), 50)
# Out:
# ('STARTED GEN', 'ZERO', 'size', 24)
# ('DONE with', 1, 'of', 24, 'of GEN', 'ZERO', 'with Fitness', '13.89')
# NEURON: variable step integrator error
#  near line 0
#  ^
#         fadvance()
#       advance()
#     step()
#   continuerun(3100)
# and others
# NEURON: variable step integrator error
#  near line 0
#  ^
#         fadvance()
#       advance()
#     step()
#   continuerun(3100)
# and others
# ('DONE with', 2, 'of', 24, 'of GEN', 'ZERO', 'with Fitness', '15.59')
# ('DONE with', 3, 'of', 24, 'of GEN', 'ZERO', 'with Fitness', '97.46')
# ('DONE with', 4, 'of', 24, 'of GEN', 'ZERO', 'with Fitness', '25.76')
# ('DONE with', 5, 'of', 24, 'of GEN', 'ZERO', 'with Fitness', '19.00')
# ('DONE with', 6, 'of', 24, 'of GEN', 'ZERO', 'with Fitness', '17.14')
# ('DONE with', 7, 'of', 24, 'of GEN', 'ZERO', 'with Fitness', '32.71')
# ('DONE with', 8, 'of', 24, 'of GEN', 'ZERO', 'with Fitness', '22.56')
# ('DONE with', 9, 'of', 24, 'of GEN', 'ZERO', 'with Fitness', '26.60')
# ('DONE with', 10, 'of', 24, 'of GEN', 'ZERO', 'with Fitness', '90.00')
# ('DONE with', 11, 'of', 24, 'of GEN', 'ZERO', 'with Fitness', '19.33')
# ('DONE with', 12, 'of', 24, 'of GEN', 'ZERO', 'with Fitness', '53.08')
# ('DONE with', 13, 'of', 24, 'of GEN', 'ZERO', 'with Fitness', '15.82')
# ('DONE with', 14, 'of', 24, 'of GEN', 'ZERO', 'with Fitness', '18.86')
# ('DONE with', 15, 'of', 24, 'of GEN', 'ZERO', 'with Fitness', '47.20')
# ('DONE with', 16, 'of', 24, 'of GEN', 'ZERO', 'with Fitness', '11.31')
# ('DONE with', 17, 'of', 24, 'of GEN', 'ZERO', 'with Fitness', '77.62')
# ('DONE with', 18, 'of', 24, 'of GEN', 'ZERO', 'with Fitness', '22.61')
# ('DONE with', 19, 'of', 24, 'of GEN', 'ZERO', 'with Fitness', '90.00')
# ('DONE with', 20, 'of', 24, 'of GEN', 'ZERO', 'with Fitness', '15.07')
# ('DONE with', 21, 'of', 24, 'of GEN', 'ZERO', 'with Fitness', '19.04')
# ('DONE with', 22, 'of', 24, 'of GEN', 'ZERO', 'with Fitness', '28.24')
# ('DONE with', 23, 'of', 24, 'of GEN', 'ZERO', 'with Fitness', '18.64')
# ('DONE with', 24, 'of', 24, 'of GEN', 'ZERO', 'with Fitness', '18.50')
# ('GEN', 1, 'Parents', 4, 'Elite', 12, 'DIV', 6, 'RND', 6, 'TOT NEW', 24)
# ('STARTED GEN', '1', 'size', 24)
# NEURON: variable step integrator error
#  near line 0
#  ^
#         fadvance()
#       advance()
#     step()
#   continuerun(3100)
# and others
# ('DONE with', 1, 'of', 24, 'of GEN', '1', 'with Fitness', '8.22')
# ('DONE with', 2, 'of', 24, 'of GEN', '1', 'with Fitness', '13.26')
# ('DONE with', 3, 'of', 24, 'of GEN', '1', 'with Fitness', '20.81')
# ('DONE with', 4, 'of', 24, 'of GEN', '1', 'with Fitness', '20.80')
# ('DONE with', 5, 'of', 24, 'of GEN', '1', 'with Fitness', '51.92')
# ('DONE with', 6, 'of', 24, 'of GEN', '1', 'with Fitness', '21.10')
# ('DONE with', 7, 'of', 24, 'of GEN', '1', 'with Fitness', '7.92')
# ('DONE with', 8, 'of', 24, 'of GEN', '1', 'with Fitness', '32.44')
# ('DONE with', 9, 'of', 24, 'of GEN', '1', 'with Fitness', '8.50')
# ('DONE with', 10, 'of', 24, 'of GEN', '1', 'with Fitness', '57.83')
# ('DONE with', 11, 'of', 24, 'of GEN', '1', 'with Fitness', '12.42')
# ('DONE with', 12, 'of', 24, 'of GEN', '1', 'with Fitness', '16.11')
# ('DONE with', 13, 'of', 24, 'of GEN', '1', 'with Fitness', '14.64')
# ('DONE with', 14, 'of', 24, 'of GEN', '1', 'with Fitness', '19.92')
# ('DONE with', 15, 'of', 24, 'of GEN', '1', 'with Fitness', '15.59')
# ('DONE with', 16, 'of', 24, 'of GEN', '1', 'with Fitness', '17.64')
# ('DONE with', 17, 'of', 24, 'of GEN', '1', 'with Fitness', '15.57')
# ('DONE with', 18, 'of', 24, 'of GEN', '1', 'with Fitness', '7.69')
# ('DONE with', 19, 'of', 24, 'of GEN', '1', 'with Fitness', '9.74')
# ('DONE with', 20, 'of', 24, 'of GEN', '1', 'with Fitness', '10.51')
# ('DONE with', 21, 'of', 24, 'of GEN', '1', 'with Fitness', '15.59')
# ('DONE with', 22, 'of', 24, 'of GEN', '1', 'with Fitness', '16918.49')
# ('DONE with', 23, 'of', 24, 'of GEN', '1', 'with Fitness', '12.18')
# ('DONE with', 24, 'of', 24, 'of GEN', '1', 'with Fitness', '13.28')
#                                      prev_ob_models.Birgiolas2020.isolated_cells.TC2
# AfterHyperpolarizationAmplitudeTest                             [0.3886318585587443]
# AfterHyperpolarizationTimeTest                                   -0.9514925373134282
# CellCapacitanceTest                                                -1.12951211100694
# FISlopeTest                                                       -2.680555555555555
# ISICVTest                                                        -1.1205764519298227
# InputResistanceTest                                              -1.5883270680780752
# MembraneTimeConstantTest                                         -1.9534883720930234
# ReboundSpikingTest                                                               0.0
# RestingVoltageTest                                                2.0536686384068865
# RheobaseTest                                                      0.4105412950466783
# SagVoltageTest                                                    1.1219273870859632
# SpikeAccommodationTest                                           0.10997133448627132
# SpikeAccommodationTimeConstantTest                               -0.8523201004066602
# SpikeAmplitudeTest                                                [5.77432502663352]
# SpikeHalfWidthTest                                                1.2999999999988987
# SpikeThresholdTest                                             [-0.7456366463328908]
# model                                prev_ob_models.Birgiolas2020.isolated_cells.TC2
# 79.69% of range. Val: 1.61415870377 Low: 0.1 High: 2.0 ATTR: diam in ['apical', 'basal', 'axonal']
# 87.75% of range. Val: 10.6077685477 Low: 3.5 High: 11.6 ATTR: L in ['somatic']
# 89.49% of range. Val: 134.33948575 Low: 1.0 High: 150.0 ATTR: Ra in ['all']
# 15.88% of range. Val: 0.877956667995 Low: 0.1 High: 5.0 ATTR: cm in ['all']
# 57.69% of range. Val: 54.6127917817 Low: 20.0 High: 80.0 ATTR: ena in ['all']
# 44.86% of range. Val: -77.5712074717 Low: -100.0 High: -50.0 ATTR: ek in ['all']
# 91.86% of range. Val: -53.2544344463 Low: -90.0 High: -50.0 ATTR: e_pas in ['all']
# 66.15% of range. Val: 0.000264597112008 Low: 0 High: 0.0004 ATTR: g_pas in ['all']
# 48.83% of range. Val: 4.8827065042 Low: 0 High: 10 ATTR: sh_Na in ['all']
# 10.36% of range. Val: 31.9655130225 Low: 1 High: 300 ATTR: tau_CaPool in ['all']
# 80.64% of range. Val: 0.0806412230688 Low: 0 High: 0.1 ATTR: gbar_Na in ['all']
# 20.24% of range. Val: 0.040483995753 Low: 0 High: 0.2 ATTR: gbar_Kd in ['all']
# 69.49% of range. Val: 0.00138978855251 Low: 0 High: 0.002 ATTR: gbar_Kslow in ['all']
# 16.36% of range. Val: 0.00327129211069 Low: 0 High: 0.02 ATTR: gbar_KA in ['all']
# 32.63% of range. Val: 0.00522081849029 Low: 0 High: 0.016 ATTR: gbar_KCa in ['all']
# 77.79% of range. Val: 0.000777898626461 Low: 0 High: 0.001 ATTR: gbar_LCa in ['all']
# 53.40% of range. Val: -23.9794005523 Low: -40.0 High: -10.0 ATTR: eh in ['apical']
# 74.31% of range. Val: 4.45874370321e-05 Low: 0 High: 6e-05 ATTR: gbar_Ih in ['apical']
# 79.12% of range. Val: 0.0158232892766 Low: 0 High: 0.02 ATTR: gbar_CaT in ['apical']
# ('Best individual', [1.6141587037715928, 10.607768547693361, 134.33948574957364, 0.877956667994785, 54.612791781724944, -77.57120747174648, -53.2544344463116, 0.00026459711200801044, 4.882706504204019, 31.965513022510866, 0.08064122306879148, 0.040483995753045586, 0.0013897885525116273, 0.003271292110691629, 0.005220818490293454, 0.0007778986264609879, -23.9794005523483, 4.458743703208395e-05, 0.015823289276634084])
# ('Best fitness:', 7.686631681551081)
# ('Generation', 1, 'out of', 50, 'COMPLETE')
# ('GEN', 2, 'Parents', 4, 'Elite', 12, 'DIV', 6, 'RND', 6, 'TOT NEW', 24)
# ('STARTED GEN', '2', 'size', 24)
# ('DONE with', 1, 'of', 24, 'of GEN', '2', 'with Fitness', '18.15')
# ('DONE with', 2, 'of', 24, 'of GEN', '2', 'with Fitness', '33.36')
# ('DONE with', 3, 'of', 24, 'of GEN', '2', 'with Fitness', '18.66')
# ('DONE with', 4, 'of', 24, 'of GEN', '2', 'with Fitness', '116.72')
# ('DONE with', 5, 'of', 24, 'of GEN', '2', 'with Fitness', '30.46')
# ('DONE with', 6, 'of', 24, 'of GEN', '2', 'with Fitness', '39.57')
# ('DONE with', 7, 'of', 24, 'of GEN', '2', 'with Fitness', '16.58')
# ('DONE with', 8, 'of', 24, 'of GEN', '2', 'with Fitness', '18.07')
# ('DONE with', 9, 'of', 24, 'of GEN', '2', 'with Fitness', '19.65')
# ('DONE with', 10, 'of', 24, 'of GEN', '2', 'with Fitness', '18.49')
# ('DONE with', 11, 'of', 24, 'of GEN', '2', 'with Fitness', '23.71')
# ('DONE with', 12, 'of', 24, 'of GEN', '2', 'with Fitness', '22.55')
# ('DONE with', 13, 'of', 24, 'of GEN', '2', 'with Fitness', '9.14')
# ('DONE with', 14, 'of', 24, 'of GEN', '2', 'with Fitness', '9.43')
# ('DONE with', 15, 'of', 24, 'of GEN', '2', 'with Fitness', '6.86')
# ('DONE with', 16, 'of', 24, 'of GEN', '2', 'with Fitness', '9.57')
# ('DONE with', 17, 'of', 24, 'of GEN', '2', 'with Fitness', '10.90')
# ('DONE with', 18, 'of', 24, 'of GEN', '2', 'with Fitness', '18.05')
# ('DONE with', 13, 'of', 24, 'of GEN', '2', 'with Fitness', '9.14')
# ('DONE with', 14, 'of', 24, 'of GEN', '2', 'with Fitness', '9.43')
# ('DONE with', 15, 'of', 24, 'of GEN', '2', 'with Fitness', '6.86')
# ('DONE with', 16, 'of', 24, 'of GEN', '2', 'with Fitness', '9.57')
# ('DONE with', 17, 'of', 24, 'of GEN', '2', 'with Fitness', '10.90')
# ('DONE with', 19, 'of', 24, 'of GEN', '2', 'with Fitness', '90.00')
# ('DONE with', 20, 'of', 24, 'of GEN', '2', 'with Fitness', '11.94')
# ('DONE with', 21, 'of', 24, 'of GEN', '2', 'with Fitness', '7.77')
# ('DONE with', 22, 'of', 24, 'of GEN', '2', 'with Fitness', '8.38')
# ('DONE with', 23, 'of', 24, 'of GEN', '2', 'with Fitness', '8.22')
# ('DONE with', 24, 'of', 24, 'of GEN', '2', 'with Fitness', '7.81')
#                                      prev_ob_models.Birgiolas2020.isolated_cells.TC2
# AfterHyperpolarizationAmplitudeTest                            [0.20475959871454022]
# AfterHyperpolarizationTimeTest                                   -1.0199004975124377
# CellCapacitanceTest                                              -1.4681033390714122
# FISlopeTest                                                      -1.9166666666666667
# ISICVTest                                                          -1.86046511627907
# InputResistanceTest                                              0.08361900827572401
# MembraneTimeConstantTest                                         -1.8372093023255816
# ReboundSpikingTest                                                              -1.0
# RestingVoltageTest                                              0.014879413392350216
# RheobaseTest                                                     0.16508185470855155
# SagVoltageTest                                                    0.8518240923248677
# SpikeAccommodationTest                                             1.057591623036649
# SpikeAccommodationTimeConstantTest                                2.1310240963855422
# SpikeAmplitudeTest                                                 [3.7176439443167]
# SpikeHalfWidthTest                                               -1.1999999999997157
# SpikeThresholdTest                                                [3.25843071892726]
# model                                prev_ob_models.Birgiolas2020.isolated_cells.TC2
# 28.39% of range. Val: 0.639354343276 Low: 0.1 High: 2.0 ATTR: diam in ['apical', 'basal', 'axonal']
# 89.51% of range. Val: 10.7503998463 Low: 3.5 High: 11.6 ATTR: L in ['somatic']
# 89.49% of range. Val: 134.33948575 Low: 1.0 High: 150.0 ATTR: Ra in ['all']
# 11.06% of range. Val: 0.641733397693 Low: 0.1 High: 5.0 ATTR: cm in ['all']
# 57.69% of range. Val: 54.6127917817 Low: 20.0 High: 80.0 ATTR: ena in ['all']
# 70.63% of range. Val: -64.6867497251 Low: -100.0 High: -50.0 ATTR: ek in ['all']
# 51.04% of range. Val: -69.5821638003 Low: -90.0 High: -50.0 ATTR: e_pas in ['all']
# 67.73% of range. Val: 0.000270935036589 Low: 0 High: 0.0004 ATTR: g_pas in ['all']
# 48.83% of range. Val: 4.8827065042 Low: 0 High: 10 ATTR: sh_Na in ['all']
# 10.36% of range. Val: 31.9655130225 Low: 1 High: 300 ATTR: tau_CaPool in ['all']
# 80.64% of range. Val: 0.0806412230688 Low: 0 High: 0.1 ATTR: gbar_Na in ['all']
# 28.32% of range. Val: 0.0566420309475 Low: 0 High: 0.2 ATTR: gbar_Kd in ['all']
# 53.67% of range. Val: 0.00107341825297 Low: 0 High: 0.002 ATTR: gbar_Kslow in ['all']
# 16.36% of range. Val: 0.00327129211069 Low: 0 High: 0.02 ATTR: gbar_KA in ['all']
# 32.63% of range. Val: 0.00522081849029 Low: 0 High: 0.016 ATTR: gbar_KCa in ['all']
# 77.79% of range. Val: 0.000777898626461 Low: 0 High: 0.001 ATTR: gbar_LCa in ['all']
# 30.81% of range. Val: -30.7557974544 Low: -40.0 High: -10.0 ATTR: eh in ['apical']
# 28.35% of range. Val: 1.70078436355e-05 Low: 0 High: 6e-05 ATTR: gbar_Ih in ['apical']
# 79.12% of range. Val: 0.0158232892766 Low: 0 High: 0.02 ATTR: gbar_CaT in ['apical']
# ('Best individual', [0.6393543432763806, 10.750399846292778, 134.33948574957364, 0.6417333976932493, 54.612791781724944, -64.68674972508471, -69.5821638002925, 0.0002709350365889211, 4.882706504204019, 31.965513022510866, 0.08064122306879148, 0.05664203094750875, 0.0010734182529668057, 0.003271292110691629, 0.005220818490293454, 0.0007778986264609879, -30.755797454360117, 1.7007843635549316e-05, 0.015823289276634084])
# ('Best fitness:', 6.858994921896462)
# ('Generation', 2, 'out of', 50, 'COMPLETE')
# ('GEN', 3, 'Parents', 4, 'Elite', 12, 'DIV', 6, 'RND', 6, 'TOT NEW', 24)
# ('STARTED GEN', '3', 'size', 24)
# ('DONE with', 1, 'of', 24, 'of GEN', '3', 'with Fitness', '9.21')
# ('DONE with', 2, 'of', 24, 'of GEN', '3', 'with Fitness', '16.34')
# ('DONE with', 3, 'of', 24, 'of GEN', '3', 'with Fitness', '13.69')
# ('DONE with', 4, 'of', 24, 'of GEN', '3', 'with Fitness', '11.45')
# ('DONE with', 5, 'of', 24, 'of GEN', '3', 'with Fitness', '16.94')
# ('DONE with', 6, 'of', 24, 'of GEN', '3', 'with Fitness', '90.00')
# ('DONE with', 7, 'of', 24, 'of GEN', '3', 'with Fitness', '8.64')
# ('DONE with', 8, 'of', 24, 'of GEN', '3', 'with Fitness', '7.61')
# ('DONE with', 9, 'of', 24, 'of GEN', '3', 'with Fitness', '18.22')
# ('DONE with', 10, 'of', 24, 'of GEN', '3', 'with Fitness', '95.50')
# ('DONE with', 11, 'of', 24, 'of GEN', '3', 'with Fitness', '6.23')
# ('DONE with', 12, 'of', 24, 'of GEN', '3', 'with Fitness', '12.56')
# ('DONE with', 13, 'of', 24, 'of GEN', '3', 'with Fitness', '10.67')
# ('DONE with', 14, 'of', 24, 'of GEN', '3', 'with Fitness', '27.25')
# ('DONE with', 15, 'of', 24, 'of GEN', '3', 'with Fitness', '12.42')
# ('DONE with', 16, 'of', 24, 'of GEN', '3', 'with Fitness', '18.24')
# ('DONE with', 17, 'of', 24, 'of GEN', '3', 'with Fitness', '8.35')
# ('DONE with', 18, 'of', 24, 'of GEN', '3', 'with Fitness', '6.88')
# ('DONE with', 19, 'of', 24, 'of GEN', '3', 'with Fitness', '10.67')
# ('DONE with', 20, 'of', 24, 'of GEN', '3', 'with Fitness', '6.80')
# ('DONE with', 21, 'of', 24, 'of GEN', '3', 'with Fitness', '5.04')
# ('DONE with', 22, 'of', 24, 'of GEN', '3', 'with Fitness', '11.98')
# ('DONE with', 23, 'of', 24, 'of GEN', '3', 'with Fitness', '12.94')
# ('DONE with', 24, 'of', 24, 'of GEN', '3', 'with Fitness', '9.82')
#                                      prev_ob_models.Birgiolas2020.isolated_cells.TC2
# AfterHyperpolarizationAmplitudeTest                           [-0.21082939463084385]
# AfterHyperpolarizationTimeTest                                   -0.9622937941869562
# CellCapacitanceTest                                              -1.4721757543859675
# FISlopeTest                                                       -2.263888888888889
# ISICVTest                                                       -0.10667552658525448
# InputResistanceTest                                              0.11859043110447356
# MembraneTimeConstantTest                                         -1.8372093023255816
# ReboundSpikingTest                                                              -1.0
# RestingVoltageTest                                              0.013303004109220782
# RheobaseTest                                                      0.3601343426223456
# SagVoltageTest                                                    0.8465810380012856
# SpikeAccommodationTest                                            0.7890992079473756
# SpikeAccommodationTimeConstantTest                               -0.7496234335171049
# SpikeAmplitudeTest                                              [2.0796779627615467]
# SpikeHalfWidthTest                                               -1.1999999999997157
# SpikeThresholdTest                                               [2.219749764957679]
# model                                prev_ob_models.Birgiolas2020.isolated_cells.TC2
# 28.95% of range. Val: 0.65008402166 Low: 0.1 High: 2.0 ATTR: diam in ['apical', 'basal', 'axonal']
# 77.34% of range. Val: 9.7647450433 Low: 3.5 High: 11.6 ATTR: L in ['somatic']
# 96.77% of range. Val: 145.180351248 Low: 1.0 High: 150.0 ATTR: Ra in ['all']
# 11.06% of range. Val: 0.641733397693 Low: 0.1 High: 5.0 ATTR: cm in ['all']
# 57.69% of range. Val: 54.6127917817 Low: 20.0 High: 80.0 ATTR: ena in ['all']
# 67.50% of range. Val: -66.2505901358 Low: -100.0 High: -50.0 ATTR: ek in ['all']
# 51.04% of range. Val: -69.5821638003 Low: -90.0 High: -50.0 ATTR: e_pas in ['all']
# 67.73% of range. Val: 0.000270935036589 Low: 0 High: 0.0004 ATTR: g_pas in ['all']
# 16.36% of range. Val: 1.63632117894 Low: 0 High: 10 ATTR: sh_Na in ['all']
# 15.69% of range. Val: 47.9129693927 Low: 1 High: 300 ATTR: tau_CaPool in ['all']
# 80.64% of range. Val: 0.0806412230688 Low: 0 High: 0.1 ATTR: gbar_Na in ['all']
# 75.34% of range. Val: 0.150672696579 Low: 0 High: 0.2 ATTR: gbar_Kd in ['all']
# 73.50% of range. Val: 0.00146999040954 Low: 0 High: 0.002 ATTR: gbar_Kslow in ['all']
# 33.81% of range. Val: 0.00676267430155 Low: 0 High: 0.02 ATTR: gbar_KA in ['all']
# 29.55% of range. Val: 0.00472733745505 Low: 0 High: 0.016 ATTR: gbar_KCa in ['all']
# 49.82% of range. Val: 0.000498237152922 Low: 0 High: 0.001 ATTR: gbar_LCa in ['all']
# 25.94% of range. Val: -32.217803271 Low: -40.0 High: -10.0 ATTR: eh in ['apical']
# 28.27% of range. Val: 1.69629430095e-05 Low: 0 High: 6e-05 ATTR: gbar_Ih in ['apical']
# 69.51% of range. Val: 0.0139014640956 Low: 0 High: 0.02 ATTR: gbar_CaT in ['apical']
# ('Best individual', [0.6500840216599895, 9.764745043302765, 145.18035124845895, 0.6417333976932493, 54.612791781724944, -66.25059013579343, -69.5821638002925, 0.0002709350365889211, 1.6363211789390302, 47.9129693926854, 0.08064122306879148, 0.15067269657887095, 0.0014699904095443425, 0.006762674301550519, 0.004727337455046674, 0.000498237152921818, -32.21780327100569, 1.6962943009482955e-05, 0.013901464095629508])
# ('Best fitness:', 5.038578130814773)
# ('Generation', 3, 'out of', 50, 'COMPLETE')
# ('GEN', 4, 'Parents', 4, 'Elite', 12, 'DIV', 6, 'RND', 6, 'TOT NEW', 24)
# ('STARTED GEN', '4', 'size', 24)
# ('DONE with', 1, 'of', 24, 'of GEN', '4', 'with Fitness', '70.45')
# ('DONE with', 2, 'of', 24, 'of GEN', '4', 'with Fitness', '1414.95')
# ('DONE with', 3, 'of', 24, 'of GEN', '4', 'with Fitness', '11.47')
# ('DONE with', 4, 'of', 24, 'of GEN', '4', 'with Fitness', '13223.42')
# ('DONE with', 5, 'of', 24, 'of GEN', '4', 'with Fitness', '18.26')
# ('DONE with', 6, 'of', 24, 'of GEN', '4', 'with Fitness', '27.77')
# ('DONE with', 7, 'of', 24, 'of GEN', '4', 'with Fitness', '19.21')
# ('DONE with', 8, 'of', 24, 'of GEN', '4', 'with Fitness', '12.44')
# ('DONE with', 9, 'of', 24, 'of GEN', '4', 'with Fitness', '7850.12')
# ('DONE with', 10, 'of', 24, 'of GEN', '4', 'with Fitness', '7.82')
# ('DONE with', 11, 'of', 24, 'of GEN', '4', 'with Fitness', '63.77')
# ('DONE with', 12, 'of', 24, 'of GEN', '4', 'with Fitness', '10.67')
# ('DONE with', 13, 'of', 24, 'of GEN', '4', 'with Fitness', '9.56')
# ('DONE with', 14, 'of', 24, 'of GEN', '4', 'with Fitness', '5.59')
# ('DONE with', 15, 'of', 24, 'of GEN', '4', 'with Fitness', '11.28')
# ('DONE with', 16, 'of', 24, 'of GEN', '4', 'with Fitness', '6.39')
# ('DONE with', 17, 'of', 24, 'of GEN', '4', 'with Fitness', '90.00')
# ('DONE with', 18, 'of', 24, 'of GEN', '4', 'with Fitness', '7.71')
# ('DONE with', 19, 'of', 24, 'of GEN', '4', 'with Fitness', '8.02')
# ('DONE with', 20, 'of', 24, 'of GEN', '4', 'with Fitness', '8.01')
# ('DONE with', 21, 'of', 24, 'of GEN', '4', 'with Fitness', '5.66')
# ('DONE with', 22, 'of', 24, 'of GEN', '4', 'with Fitness', '8.97')
# ('DONE with', 23, 'of', 24, 'of GEN', '4', 'with Fitness', '4.99')
# ('DONE with', 24, 'of', 24, 'of GEN', '4', 'with Fitness', '5.04')
#                                      prev_ob_models.Birgiolas2020.isolated_cells.TC2
# AfterHyperpolarizationAmplitudeTest                            [-0.6892788705737956]
# AfterHyperpolarizationTimeTest                                   -0.9609845509295587
# CellCapacitanceTest                                               -1.479634241754916
# FISlopeTest                                                       -2.263888888888889
# ISICVTest                                                          0.802907963258709
# InputResistanceTest                                              0.18270158250200114
# MembraneTimeConstantTest                                         -1.8372093023255816
# ReboundSpikingTest                                                              -1.0
# RestingVoltageTest                                               -0.0141248586918364
# RheobaseTest                                                      1.0903499615651175
# SagVoltageTest                                                    0.7265041915929589
# SpikeAccommodationTest                                           -0.9682498363533982
# SpikeAccommodationTimeConstantTest                               -0.8263947098340184
# SpikeAmplitudeTest                                              [1.7846755739998705]
# SpikeHalfWidthTest                                               -1.1999999999997157
# SpikeThresholdTest                                              [1.7917247121055624]
# model                                prev_ob_models.Birgiolas2020.isolated_cells.TC2
# 28.95% of range. Val: 0.65008402166 Low: 0.1 High: 2.0 ATTR: diam in ['apical', 'basal', 'axonal']
# 77.34% of range. Val: 9.7647450433 Low: 3.5 High: 11.6 ATTR: L in ['somatic']
# 96.77% of range. Val: 145.180351248 Low: 1.0 High: 150.0 ATTR: Ra in ['all']
# 11.06% of range. Val: 0.641733397693 Low: 0.1 High: 5.0 ATTR: cm in ['all']
# 57.69% of range. Val: 54.6127917817 Low: 20.0 High: 80.0 ATTR: ena in ['all']
# 67.50% of range. Val: -66.2505901358 Low: -100.0 High: -50.0 ATTR: ek in ['all']
# 51.04% of range. Val: -69.5821638003 Low: -90.0 High: -50.0 ATTR: e_pas in ['all']
# 67.73% of range. Val: 0.000270935036589 Low: 0 High: 0.0004 ATTR: g_pas in ['all']
# 16.36% of range. Val: 1.63632117894 Low: 0 High: 10 ATTR: sh_Na in ['all']
# 15.69% of range. Val: 47.9129693927 Low: 1 High: 300 ATTR: tau_CaPool in ['all']
# 80.64% of range. Val: 0.0806412230688 Low: 0 High: 0.1 ATTR: gbar_Na in ['all']
# 75.34% of range. Val: 0.150672696579 Low: 0 High: 0.2 ATTR: gbar_Kd in ['all']
# 73.50% of range. Val: 0.00146999040954 Low: 0 High: 0.002 ATTR: gbar_Kslow in ['all']
# 33.81% of range. Val: 0.00676267430155 Low: 0 High: 0.02 ATTR: gbar_KA in ['all']
# 29.55% of range. Val: 0.00472733745505 Low: 0 High: 0.016 ATTR: gbar_KCa in ['all']
# 49.82% of range. Val: 0.000498237152922 Low: 0 High: 0.001 ATTR: gbar_LCa in ['all']
# 25.94% of range. Val: -32.217803271 Low: -40.0 High: -10.0 ATTR: eh in ['apical']
# 1.30% of range. Val: 7.78764864797e-07 Low: 0 High: 6e-05 ATTR: gbar_Ih in ['apical']
# 69.51% of range. Val: 0.0139014640956 Low: 0 High: 0.02 ATTR: gbar_CaT in ['apical']
# ('Best individual', [0.6500840216599895, 9.764745043302765, 145.18035124845895, 0.6417333976932493, 54.612791781724944, -66.25059013579343, -69.5821638002925, 0.0002709350365889211, 1.6363211789390302, 47.9129693926854, 0.08064122306879148, 0.15067269657887095, 0.0014699904095443425, 0.006762674301550519, 0.004727337455046674, 0.000498237152921818, -32.21780327100569, 7.787648647971102e-07, 0.013901464095629508])
# ('Best fitness:', 4.993910025879397)
# ('Generation', 4, 'out of', 50, 'COMPLETE')
# ('GEN', 5, 'Parents', 4, 'Elite', 12, 'DIV', 6, 'RND', 6, 'TOT NEW', 24)
# ('STARTED GEN', '5', 'size', 24)
# NEURON: variable step integrator error
#  near line 0
#  ^
#         fadvance()
#       advance()
#     step()
#   continuerun(3100)
# and others
# ('DONE with', 1, 'of', 24, 'of GEN', '5', 'with Fitness', '24.27')
# ('DONE with', 2, 'of', 24, 'of GEN', '5', 'with Fitness', '18.32')
# ('DONE with', 3, 'of', 24, 'of GEN', '5', 'with Fitness', '20.29')
# ('DONE with', 4, 'of', 24, 'of GEN', '5', 'with Fitness', '11.88')
# ('DONE with', 5, 'of', 24, 'of GEN', '5', 'with Fitness', '13.36')
# ('DONE with', 6, 'of', 24, 'of GEN', '5', 'with Fitness', '9.80')
# ('DONE with', 7, 'of', 24, 'of GEN', '5', 'with Fitness', '28.00')
# ('DONE with', 8, 'of', 24, 'of GEN', '5', 'with Fitness', '90.00')
# ('DONE with', 9, 'of', 24, 'of GEN', '5', 'with Fitness', '12.02')
# ('DONE with', 10, 'of', 24, 'of GEN', '5', 'with Fitness', '9.47')
# ('DONE with', 11, 'of', 24, 'of GEN', '5', 'with Fitness', '10.54')
# ('DONE with', 12, 'of', 24, 'of GEN', '5', 'with Fitness', '6.55')
# ('DONE with', 13, 'of', 24, 'of GEN', '5', 'with Fitness', '5.17')
# ('DONE with', 14, 'of', 24, 'of GEN', '5', 'with Fitness', '6.21')
# ('DONE with', 15, 'of', 24, 'of GEN', '5', 'with Fitness', '4.85')
# ('DONE with', 16, 'of', 24, 'of GEN', '5', 'with Fitness', '6685.19')
# ('DONE with', 17, 'of', 24, 'of GEN', '5', 'with Fitness', '6.91')
# ('DONE with', 18, 'of', 24, 'of GEN', '5', 'with Fitness', '6.52')
# ('DONE with', 19, 'of', 24, 'of GEN', '5', 'with Fitness', '4.99')
# ('DONE with', 20, 'of', 24, 'of GEN', '5', 'with Fitness', '5.04')
# ('DONE with', 21, 'of', 24, 'of GEN', '5', 'with Fitness', '5.59')
# ('DONE with', 22, 'of', 24, 'of GEN', '5', 'with Fitness', '11.13')
# ('DONE with', 23, 'of', 24, 'of GEN', '5', 'with Fitness', '6.72')
# ('DONE with', 24, 'of', 24, 'of GEN', '5', 'with Fitness', '6.61')
#                                      prev_ob_models.Birgiolas2020.isolated_cells.TC2
# AfterHyperpolarizationAmplitudeTest                            [-0.6702812017580143]
# AfterHyperpolarizationTimeTest                                   -0.9626865671641731
# CellCapacitanceTest                                              -1.4719469739001307
# FISlopeTest                                                       -2.263888888888889
# ISICVTest                                                       -0.13862081009449267
# InputResistanceTest                                              0.11599510104051124
# MembraneTimeConstantTest                                         -1.8372093023255816
# ReboundSpikingTest                                                              -1.0
# RestingVoltageTest                                             -0.009721442529257005
# RheobaseTest                                                      0.6796711851548346
# SagVoltageTest                                                    0.8489188099504862
# SpikeAccommodationTest                                            0.8492785423639366
# SpikeAccommodationTimeConstantTest                               -0.8793279979802532
# SpikeAmplitudeTest                                              [1.8041423357850694]
# SpikeHalfWidthTest                                               -1.1999999999997157
# SpikeThresholdTest                                              [1.7522762322509067]
# model                                prev_ob_models.Birgiolas2020.isolated_cells.TC2
# 28.95% of range. Val: 0.65008402166 Low: 0.1 High: 2.0 ATTR: diam in ['apical', 'basal', 'axonal']
# 77.34% of range. Val: 9.7647450433 Low: 3.5 High: 11.6 ATTR: L in ['somatic']
# 96.77% of range. Val: 145.180351248 Low: 1.0 High: 150.0 ATTR: Ra in ['all']
# 11.06% of range. Val: 0.641733397693 Low: 0.1 High: 5.0 ATTR: cm in ['all']
# 57.69% of range. Val: 54.6127917817 Low: 20.0 High: 80.0 ATTR: ena in ['all']
# 67.50% of range. Val: -66.2505901358 Low: -100.0 High: -50.0 ATTR: ek in ['all']
# 51.04% of range. Val: -69.5821638003 Low: -90.0 High: -50.0 ATTR: e_pas in ['all']
# 67.73% of range. Val: 0.000270935036589 Low: 0 High: 0.0004 ATTR: g_pas in ['all']
# 16.36% of range. Val: 1.63632117894 Low: 0 High: 10 ATTR: sh_Na in ['all']
# 15.69% of range. Val: 47.9129693927 Low: 1 High: 300 ATTR: tau_CaPool in ['all']
# 80.64% of range. Val: 0.0806412230688 Low: 0 High: 0.1 ATTR: gbar_Na in ['all']
# 75.34% of range. Val: 0.150672696579 Low: 0 High: 0.2 ATTR: gbar_Kd in ['all']
# 73.50% of range. Val: 0.00146999040954 Low: 0 High: 0.002 ATTR: gbar_Kslow in ['all']
# 33.81% of range. Val: 0.00676267430155 Low: 0 High: 0.02 ATTR: gbar_KA in ['all']
# 21.11% of range. Val: 0.00337735376027 Low: 0 High: 0.016 ATTR: gbar_KCa in ['all']
# 49.82% of range. Val: 0.000498237152922 Low: 0 High: 0.001 ATTR: gbar_LCa in ['all']
# 25.94% of range. Val: -32.217803271 Low: -40.0 High: -10.0 ATTR: eh in ['apical']
# 28.27% of range. Val: 1.69629430095e-05 Low: 0 High: 6e-05 ATTR: gbar_Ih in ['apical']
# 69.51% of range. Val: 0.0139014640956 Low: 0 High: 0.02 ATTR: gbar_CaT in ['apical']
# ('Best individual', [0.6500840216599895, 9.764745043302765, 145.18035124845895, 0.6417333976932493, 54.612791781724944, -66.25059013579343, -69.5821638002925, 0.0002709350365889211, 1.6363211789390302, 47.9129693926854, 0.08064122306879148, 0.15067269657887095, 0.0014699904095443425, 0.006762674301550519, 0.0033773537602658577, 0.000498237152921818, -32.21780327100569, 1.6962943009482955e-05, 0.013901464095629508])
# ('Best fitness:', 4.849585098639062)
# ('Generation', 5, 'out of', 50, 'COMPLETE')
# ('GEN', 6, 'Parents', 4, 'Elite', 12, 'DIV', 6, 'RND', 6, 'TOT NEW', 24)
# ('STARTED GEN', '6', 'size', 24)
# ('DONE with', 1, 'of', 24, 'of GEN', '6', 'with Fitness', '21.65')
# ('DONE with', 2, 'of', 24, 'of GEN', '6', 'with Fitness', '18.24')
# ('DONE with', 3, 'of', 24, 'of GEN', '6', 'with Fitness', '16.48')
# ('DONE with', 4, 'of', 24, 'of GEN', '6', 'with Fitness', '9.72')
# ('DONE with', 5, 'of', 24, 'of GEN', '6', 'with Fitness', '19.75')
# ('DONE with', 6, 'of', 24, 'of GEN', '6', 'with Fitness', '8.33')
# ('DONE with', 7, 'of', 24, 'of GEN', '6', 'with Fitness', '8.18')
# ('DONE with', 8, 'of', 24, 'of GEN', '6', 'with Fitness', '8.38')
# ('DONE with', 9, 'of', 24, 'of GEN', '6', 'with Fitness', '13.09')
# ('DONE with', 10, 'of', 24, 'of GEN', '6', 'with Fitness', '90.00')
# ('DONE with', 11, 'of', 24, 'of GEN', '6', 'with Fitness', '7.23')
# ('DONE with', 12, 'of', 24, 'of GEN', '6', 'with Fitness', '6.74')
# ('DONE with', 13, 'of', 24, 'of GEN', '6', 'with Fitness', '5.54')
# ('DONE with', 14, 'of', 24, 'of GEN', '6', 'with Fitness', '4.99')
# ('DONE with', 15, 'of', 24, 'of GEN', '6', 'with Fitness', '6.28')
# ('DONE with', 16, 'of', 24, 'of GEN', '6', 'with Fitness', '5.04')
# ('DONE with', 17, 'of', 24, 'of GEN', '6', 'with Fitness', '7.27')
# ('DONE with', 18, 'of', 24, 'of GEN', '6', 'with Fitness', '8.64')
# ('DONE with', 19, 'of', 24, 'of GEN', '6', 'with Fitness', '4.67')
# ('DONE with', 20, 'of', 24, 'of GEN', '6', 'with Fitness', '6.07')
# ('DONE with', 21, 'of', 24, 'of GEN', '6', 'with Fitness', '5.90')
# ('DONE with', 22, 'of', 24, 'of GEN', '6', 'with Fitness', '5.53')
# ('DONE with', 23, 'of', 24, 'of GEN', '6', 'with Fitness', '5.60')
# ('DONE with', 24, 'of', 24, 'of GEN', '6', 'with Fitness', '6.96')
#                                      prev_ob_models.Birgiolas2020.isolated_cells.TC2
# AfterHyperpolarizationAmplitudeTest                            [-1.5735653704157186]
# AfterHyperpolarizationTimeTest                                   -0.9950248756218899
# CellCapacitanceTest                                              -1.5586074571477977
# FISlopeTest                                                      -2.1944444444444446
# ISICVTest                                                        -0.5639964723928568
# InputResistanceTest                                              0.18379124740006844
# MembraneTimeConstantTest                                         -1.9534883720930234
# ReboundSpikingTest                                                              -1.0
# RestingVoltageTest                                             -0.011150565767426531
# RheobaseTest                                                       1.345658182269996
# SagVoltageTest                                                    0.7266072737038299
# SpikeAccommodationTest                                          -0.17466834173874887
# SpikeAccommodationTimeConstantTest                               -0.7964620052652013
# SpikeAmplitudeTest                                             [0.12976143769616175]
# SpikeHalfWidthTest                                                1.2999999999988987
# SpikeThresholdTest                                              [1.1025121664174609]
# model                                prev_ob_models.Birgiolas2020.isolated_cells.TC2
# 28.95% of range. Val: 0.65008402166 Low: 0.1 High: 2.0 ATTR: diam in ['apical', 'basal', 'axonal']
# 77.34% of range. Val: 9.7647450433 Low: 3.5 High: 11.6 ATTR: L in ['somatic']
# 96.77% of range. Val: 145.180351248 Low: 1.0 High: 150.0 ATTR: Ra in ['all']
# 4.95% of range. Val: 0.342319631599 Low: 0.1 High: 5.0 ATTR: cm in ['all']
# 13.72% of range. Val: 28.2314485361 Low: 20.0 High: 80.0 ATTR: ena in ['all']
# 67.50% of range. Val: -66.2505901358 Low: -100.0 High: -50.0 ATTR: ek in ['all']
# 51.04% of range. Val: -69.5821638003 Low: -90.0 High: -50.0 ATTR: e_pas in ['all']
# 67.73% of range. Val: 0.000270935036589 Low: 0 High: 0.0004 ATTR: g_pas in ['all']
# 5.36% of range. Val: 0.536196886339 Low: 0 High: 10 ATTR: sh_Na in ['all']
# 15.69% of range. Val: 47.9129693927 Low: 1 High: 300 ATTR: tau_CaPool in ['all']
# 80.64% of range. Val: 0.0806412230688 Low: 0 High: 0.1 ATTR: gbar_Na in ['all']
# 75.34% of range. Val: 0.150672696579 Low: 0 High: 0.2 ATTR: gbar_Kd in ['all']
# 73.50% of range. Val: 0.00146999040954 Low: 0 High: 0.002 ATTR: gbar_Kslow in ['all']
# 33.81% of range. Val: 0.00676267430155 Low: 0 High: 0.02 ATTR: gbar_KA in ['all']
# 29.55% of range. Val: 0.00472733745505 Low: 0 High: 0.016 ATTR: gbar_KCa in ['all']
# 49.82% of range. Val: 0.000498237152922 Low: 0 High: 0.001 ATTR: gbar_LCa in ['all']
# 25.94% of range. Val: -32.217803271 Low: -40.0 High: -10.0 ATTR: eh in ['apical']
# 1.30% of range. Val: 7.78764864797e-07 Low: 0 High: 6e-05 ATTR: gbar_Ih in ['apical']
# 69.51% of range. Val: 0.0139014640956 Low: 0 High: 0.02 ATTR: gbar_CaT in ['apical']
# ('Best individual', [0.6500840216599895, 9.764745043302765, 145.18035124845895, 0.3423196315991928, 28.231448536057798, -66.25059013579343, -69.5821638002925, 0.0002709350365889211, 0.5361968863393589, 47.9129693926854, 0.08064122306879148, 0.15067269657887095, 0.0014699904095443425, 0.006762674301550519, 0.004727337455046674, 0.000498237152921818, -32.21780327100569, 7.787648647971102e-07, 0.013901464095629508])
# ('Best fitness:', 4.669595746825921)
# ('Generation', 6, 'out of', 50, 'COMPLETE')
# ('GEN', 7, 'Parents', 4, 'Elite', 12, 'DIV', 6, 'RND', 6, 'TOT NEW', 24)
# ('STARTED GEN', '7', 'size', 24)
# ('DONE with', 1, 'of', 24, 'of GEN', '7', 'with Fitness', '6.98')
# ('DONE with', 2, 'of', 24, 'of GEN', '7', 'with Fitness', '90.00')
# ('DONE with', 3, 'of', 24, 'of GEN', '7', 'with Fitness', '3788.11')
# ('DONE with', 4, 'of', 24, 'of GEN', '7', 'with Fitness', '15.08')
# ('DONE with', 5, 'of', 24, 'of GEN', '7', 'with Fitness', '15.53')
# ('DONE with', 6, 'of', 24, 'of GEN', '7', 'with Fitness', '20.11')
# ('DONE with', 7, 'of', 24, 'of GEN', '7', 'with Fitness', '24.40')
# ('DONE with', 8, 'of', 24, 'of GEN', '7', 'with Fitness', '18.23')
# ('DONE with', 9, 'of', 24, 'of GEN', '7', 'with Fitness', '13.38')
# ('DONE with', 10, 'of', 24, 'of GEN', '7', 'with Fitness', '90.00')
# ('DONE with', 11, 'of', 24, 'of GEN', '7', 'with Fitness', '6.25')
# ('DONE with', 12, 'of', 24, 'of GEN', '7', 'with Fitness', '90.00')
# ('DONE with', 13, 'of', 24, 'of GEN', '7', 'with Fitness', '6.66')
# ('DONE with', 14, 'of', 24, 'of GEN', '7', 'with Fitness', '5.48')
# ('DONE with', 15, 'of', 24, 'of GEN', '7', 'with Fitness', '4.96')
# ('DONE with', 16, 'of', 24, 'of GEN', '7', 'with Fitness', '4.99')
# ('DONE with', 17, 'of', 24, 'of GEN', '7', 'with Fitness', '6.48')
# ('DONE with', 18, 'of', 24, 'of GEN', '7', 'with Fitness', '6.43')
# ('DONE with', 19, 'of', 24, 'of GEN', '7', 'with Fitness', '6.19')
# ('DONE with', 20, 'of', 24, 'of GEN', '7', 'with Fitness', '8.68')
# ('DONE with', 21, 'of', 24, 'of GEN', '7', 'with Fitness', '5.33')
# ('DONE with', 22, 'of', 24, 'of GEN', '7', 'with Fitness', '4.67')
# ('DONE with', 23, 'of', 24, 'of GEN', '7', 'with Fitness', '4.90')
# ('DONE with', 24, 'of', 24, 'of GEN', '7', 'with Fitness', '6.34')
#                                      prev_ob_models.Birgiolas2020.isolated_cells.TC2
# AfterHyperpolarizationAmplitudeTest                            [-1.5821345743731967]
# AfterHyperpolarizationTimeTest                                   -1.0042643923240924
# CellCapacitanceTest                                              -1.5586403201186025
# FISlopeTest                                                      -2.0555555555555554
# ISICVTest                                                        -0.4282466719124563
# InputResistanceTest                                              0.18418939520788766
# MembraneTimeConstantTest                                         -1.9534883720930234
# ReboundSpikingTest                                                              -1.0
# RestingVoltageTest                                             -0.010370378496799169
# RheobaseTest                                                       1.344807593017947
# SagVoltageTest                                                    0.7260699807944422
# SpikeAccommodationTest                                            0.8795099191509065
# SpikeAccommodationTimeConstantTest                               -0.7502814659038334
# SpikeAmplitudeTest                                             [0.17648188288497255]
# SpikeHalfWidthTest                                                1.2999999999988987
# SpikeThresholdTest                                              [1.0913413743496196]
# model                                prev_ob_models.Birgiolas2020.isolated_cells.TC2
# 28.95% of range. Val: 0.65008402166 Low: 0.1 High: 2.0 ATTR: diam in ['apical', 'basal', 'axonal']
# 77.34% of range. Val: 9.7647450433 Low: 3.5 High: 11.6 ATTR: L in ['somatic']
# 96.77% of range. Val: 145.180351248 Low: 1.0 High: 150.0 ATTR: Ra in ['all']
# 4.95% of range. Val: 0.342319631599 Low: 0.1 High: 5.0 ATTR: cm in ['all']
# 13.72% of range. Val: 28.2314485361 Low: 20.0 High: 80.0 ATTR: ena in ['all']
# 67.50% of range. Val: -66.2505901358 Low: -100.0 High: -50.0 ATTR: ek in ['all']
# 51.04% of range. Val: -69.5821638003 Low: -90.0 High: -50.0 ATTR: e_pas in ['all']
# 67.73% of range. Val: 0.000270935036589 Low: 0 High: 0.0004 ATTR: g_pas in ['all']
# 5.36% of range. Val: 0.536196886339 Low: 0 High: 10 ATTR: sh_Na in ['all']
# 15.69% of range. Val: 47.9129693927 Low: 1 High: 300 ATTR: tau_CaPool in ['all']
# 80.64% of range. Val: 0.0806412230688 Low: 0 High: 0.1 ATTR: gbar_Na in ['all']
# 75.34% of range. Val: 0.150672696579 Low: 0 High: 0.2 ATTR: gbar_Kd in ['all']
# 86.03% of range. Val: 0.00172054830615 Low: 0 High: 0.002 ATTR: gbar_Kslow in ['all']
# 33.81% of range. Val: 0.00676267430155 Low: 0 High: 0.02 ATTR: gbar_KA in ['all']
# 29.55% of range. Val: 0.00472733745505 Low: 0 High: 0.016 ATTR: gbar_KCa in ['all']
# 49.82% of range. Val: 0.000498237152922 Low: 0 High: 0.001 ATTR: gbar_LCa in ['all']
# 0.24% of range. Val: -39.9276154204 Low: -40.0 High: -10.0 ATTR: eh in ['apical']
# 1.30% of range. Val: 7.78764864797e-07 Low: 0 High: 6e-05 ATTR: gbar_Ih in ['apical']
# 69.51% of range. Val: 0.0139014640956 Low: 0 High: 0.02 ATTR: gbar_CaT in ['apical']
# ('Best individual', [0.6500840216599895, 9.764745043302765, 145.18035124845895, 0.3423196315991928, 28.231448536057798, -66.25059013579343, -69.5821638002925, 0.0002709350365889211, 0.5361968863393589, 47.9129693926854, 0.08064122306879148, 0.15067269657887095, 0.0017205483061463367, 0.006762674301550519, 0.004727337455046674, 0.000498237152921818, -39.92761542041398, 7.787648647971102e-07, 0.013901464095629508])
# ('Best fitness:', 4.667357634263749)
# ('Generation', 7, 'out of', 50, 'COMPLETE')
# ('GEN', 8, 'Parents', 4, 'Elite', 12, 'DIV', 6, 'RND', 6, 'TOT NEW', 24)
# ('STARTED GEN', '8', 'size', 24)
# ('DONE with', 1, 'of', 24, 'of GEN', '8', 'with Fitness', '45.17')
# ('DONE with', 2, 'of', 24, 'of GEN', '8', 'with Fitness', '21.06')
# ('DONE with', 3, 'of', 24, 'of GEN', '8', 'with Fitness', '63.96')
# ('DONE with', 4, 'of', 24, 'of GEN', '8', 'with Fitness', '37.50')
# ('DONE with', 5, 'of', 24, 'of GEN', '8', 'with Fitness', '10.82')
# ('DONE with', 6, 'of', 24, 'of GEN', '8', 'with Fitness', '21.23')
# ('DONE with', 7, 'of', 24, 'of GEN', '8', 'with Fitness', '9.91')
# ('DONE with', 8, 'of', 24, 'of GEN', '8', 'with Fitness', '14.12')
# ('DONE with', 9, 'of', 24, 'of GEN', '8', 'with Fitness', '11.13')
# ('DONE with', 10, 'of', 24, 'of GEN', '8', 'with Fitness', '19.54')
# ('DONE with', 11, 'of', 24, 'of GEN', '8', 'with Fitness', '6.41')
# ('DONE with', 12, 'of', 24, 'of GEN', '8', 'with Fitness', '12.26')
# ('DONE with', 13, 'of', 24, 'of GEN', '8', 'with Fitness', '5.46')
# ('DONE with', 14, 'of', 24, 'of GEN', '8', 'with Fitness', '4.88')
# ('DONE with', 15, 'of', 24, 'of GEN', '8', 'with Fitness', '5.48')
# ('DONE with', 16, 'of', 24, 'of GEN', '8', 'with Fitness', '5.70')
# ('DONE with', 17, 'of', 24, 'of GEN', '8', 'with Fitness', '13.61')
# ('DONE with', 18, 'of', 24, 'of GEN', '8', 'with Fitness', '4.67')
# ('DONE with', 19, 'of', 24, 'of GEN', '8', 'with Fitness', '6.38')
# ('DONE with', 20, 'of', 24, 'of GEN', '8', 'with Fitness', '5.27')
# ('DONE with', 21, 'of', 24, 'of GEN', '8', 'with Fitness', '9.36')
# ('DONE with', 22, 'of', 24, 'of GEN', '8', 'with Fitness', '12019.18')
# ('DONE with', 23, 'of', 24, 'of GEN', '8', 'with Fitness', '90.00')
# ('DONE with', 24, 'of', 24, 'of GEN', '8', 'with Fitness', '7.98')
#                                      prev_ob_models.Birgiolas2020.isolated_cells.TC2
# AfterHyperpolarizationAmplitudeTest                            [-1.5821345743731967]
# AfterHyperpolarizationTimeTest                                   -1.0042643923240924
# CellCapacitanceTest                                              -1.5586403201186025
# FISlopeTest                                                      -2.0555555555555554
# ISICVTest                                                        -0.4282466719124563
# InputResistanceTest                                              0.18418939520788766
# MembraneTimeConstantTest                                         -1.9534883720930234
# ReboundSpikingTest                                                              -1.0
# RestingVoltageTest                                             -0.010370378496799169
# RheobaseTest                                                       1.344807593017947
# SagVoltageTest                                                    0.7260699807944422
# SpikeAccommodationTest                                            0.8795099191509065
# SpikeAccommodationTimeConstantTest                               -0.7502814659038334
# SpikeAmplitudeTest                                             [0.17648188288497255]
# SpikeHalfWidthTest                                                1.2999999999988987
# SpikeThresholdTest                                              [1.0913413743496196]
# model                                prev_ob_models.Birgiolas2020.isolated_cells.TC2
# 28.95% of range. Val: 0.65008402166 Low: 0.1 High: 2.0 ATTR: diam in ['apical', 'basal', 'axonal']
# 77.34% of range. Val: 9.7647450433 Low: 3.5 High: 11.6 ATTR: L in ['somatic']
# 96.77% of range. Val: 145.180351248 Low: 1.0 High: 150.0 ATTR: Ra in ['all']
# 4.95% of range. Val: 0.342319631599 Low: 0.1 High: 5.0 ATTR: cm in ['all']
# 13.72% of range. Val: 28.2314485361 Low: 20.0 High: 80.0 ATTR: ena in ['all']
# 67.50% of range. Val: -66.2505901358 Low: -100.0 High: -50.0 ATTR: ek in ['all']
# 51.04% of range. Val: -69.5821638003 Low: -90.0 High: -50.0 ATTR: e_pas in ['all']
# 67.73% of range. Val: 0.000270935036589 Low: 0 High: 0.0004 ATTR: g_pas in ['all']
# 5.36% of range. Val: 0.536196886339 Low: 0 High: 10 ATTR: sh_Na in ['all']
# 15.69% of range. Val: 47.9129693927 Low: 1 High: 300 ATTR: tau_CaPool in ['all']
# 80.64% of range. Val: 0.0806412230688 Low: 0 High: 0.1 ATTR: gbar_Na in ['all']
# 75.34% of range. Val: 0.150672696579 Low: 0 High: 0.2 ATTR: gbar_Kd in ['all']
# 86.03% of range. Val: 0.00172054830615 Low: 0 High: 0.002 ATTR: gbar_Kslow in ['all']
# 33.81% of range. Val: 0.00676267430155 Low: 0 High: 0.02 ATTR: gbar_KA in ['all']
# 29.55% of range. Val: 0.00472733745505 Low: 0 High: 0.016 ATTR: gbar_KCa in ['all']
# 49.82% of range. Val: 0.000498237152922 Low: 0 High: 0.001 ATTR: gbar_LCa in ['all']
# 0.24% of range. Val: -39.9276154204 Low: -40.0 High: -10.0 ATTR: eh in ['apical']
# 1.30% of range. Val: 7.78764864797e-07 Low: 0 High: 6e-05 ATTR: gbar_Ih in ['apical']
# 69.51% of range. Val: 0.0139014640956 Low: 0 High: 0.02 ATTR: gbar_CaT in ['apical']
# ('Best individual', [0.6500840216599895, 9.764745043302765, 145.18035124845895, 0.3423196315991928, 28.231448536057798, -66.25059013579343, -69.5821638002925, 0.0002709350365889211, 0.5361968863393589, 47.9129693926854, 0.08064122306879148, 0.15067269657887095, 0.0017205483061463367, 0.006762674301550519, 0.004727337455046674, 0.000498237152921818, -39.92761542041398, 7.787648647971102e-07, 0.013901464095629508])
# ('Best fitness:', 4.667357634263749)
# ('Generation', 8, 'out of', 50, 'COMPLETE')
# ('GEN', 9, 'Parents', 4, 'Elite', 12, 'DIV', 6, 'RND', 6, 'TOT NEW', 24)
# ('STARTED GEN', '9', 'size', 24)
# ('DONE with', 1, 'of', 24, 'of GEN', '9', 'with Fitness', '32.46')
# ('DONE with', 2, 'of', 24, 'of GEN', '9', 'with Fitness', '9.72')
# ('DONE with', 3, 'of', 24, 'of GEN', '9', 'with Fitness', '25.03')
# ('DONE with', 4, 'of', 24, 'of GEN', '9', 'with Fitness', '18.97')
# ('DONE with', 5, 'of', 24, 'of GEN', '9', 'with Fitness', '14.61')
# ('DONE with', 6, 'of', 24, 'of GEN', '9', 'with Fitness', '78.69')
# ('DONE with', 7, 'of', 24, 'of GEN', '9', 'with Fitness', '20.03')
# ('DONE with', 8, 'of', 24, 'of GEN', '9', 'with Fitness', '6.38')
# ('DONE with', 9, 'of', 24, 'of GEN', '9', 'with Fitness', '12.62')
# ('DONE with', 10, 'of', 24, 'of GEN', '9', 'with Fitness', '7.74')
# ('DONE with', 11, 'of', 24, 'of GEN', '9', 'with Fitness', '5.94')
# ('DONE with', 12, 'of', 24, 'of GEN', '9', 'with Fitness', '10.45')
# ('DONE with', 13, 'of', 24, 'of GEN', '9', 'with Fitness', '5.62')
# ('DONE with', 14, 'of', 24, 'of GEN', '9', 'with Fitness', '4.97')
# ('DONE with', 15, 'of', 24, 'of GEN', '9', 'with Fitness', '4.85')
# ('DONE with', 16, 'of', 24, 'of GEN', '9', 'with Fitness', '4.85')
# ('DONE with', 17, 'of', 24, 'of GEN', '9', 'with Fitness', '6.98')
# ('DONE with', 18, 'of', 24, 'of GEN', '9', 'with Fitness', '13117.22')
# ('DONE with', 19, 'of', 24, 'of GEN', '9', 'with Fitness', '5.20')
# ('DONE with', 20, 'of', 24, 'of GEN', '9', 'with Fitness', '18.50')
# ('DONE with', 21, 'of', 24, 'of GEN', '9', 'with Fitness', '4.81')
# ('DONE with', 22, 'of', 24, 'of GEN', '9', 'with Fitness', '4.67')
# ('DONE with', 23, 'of', 24, 'of GEN', '9', 'with Fitness', '6.80')
# ('DONE with', 24, 'of', 24, 'of GEN', '9', 'with Fitness', '8.53')
#                                      prev_ob_models.Birgiolas2020.isolated_cells.TC2
# AfterHyperpolarizationAmplitudeTest                            [-1.5821345743731967]
# AfterHyperpolarizationTimeTest                                   -1.0042643923240924
# CellCapacitanceTest                                              -1.5586403201186025
# FISlopeTest                                                      -2.0555555555555554
# ISICVTest                                                        -0.4282466719124563
# InputResistanceTest                                              0.18418939520788766
# MembraneTimeConstantTest                                         -1.9534883720930234
# ReboundSpikingTest                                                              -1.0
# RestingVoltageTest                                             -0.010370378496799169
# RheobaseTest                                                       1.344807593017947
# SagVoltageTest                                                    0.7260699807944422
# SpikeAccommodationTest                                            0.8795099191509065
# SpikeAccommodationTimeConstantTest                               -0.7502814659038334
# ...
# ('DONE with', 2, 'of', 24, 'of GEN', '12', 'with Fitness', '17.24')
# ('DONE with', 3, 'of', 24, 'of GEN', '12', 'with Fitness', '8.85')
# ('DONE with', 4, 'of', 24, 'of GEN', '12', 'with Fitness', '11.30')
# ('DONE with', 5, 'of', 24, 'of GEN', '12', 'with Fitness', '26.06')
# ('DONE with', 6, 'of', 24, 'of GEN', '12', 'with Fitness', '90.00')
# ('DONE with', 7, 'of', 24, 'of GEN', '12', 'with Fitness', '6.91')
# ('DONE with', 8, 'of', 24, 'of GEN', '12', 'with Fitness', '9.53')
# ('DONE with', 9, 'of', 24, 'of GEN', '12', 'with Fitness', '15.41')
# ('DONE with', 10, 'of', 24, 'of GEN', '12', 'with Fitness', '7.36')
# ('DONE with', 11, 'of', 24, 'of GEN', '12', 'with Fitness', '7406.24')
# ('DONE with', 12, 'of', 24, 'of GEN', '12', 'with Fitness', '50.68')
# ('DONE with', 13, 'of', 24, 'of GEN', '12', 'with Fitness', '5.79')
# ('DONE with', 14, 'of', 24, 'of GEN', '12', 'with Fitness', '4.46')
# ('DONE with', 15, 'of', 24, 'of GEN', '12', 'with Fitness', '5.04')
# ('DONE with', 16, 'of', 24, 'of GEN', '12', 'with Fitness', '5.50')
# ('DONE with', 17, 'of', 24, 'of GEN', '12', 'with Fitness', '7.70')
# ('DONE with', 18, 'of', 24, 'of GEN', '12', 'with Fitness', '4.82')
# ('DONE with', 19, 'of', 24, 'of GEN', '12', 'with Fitness', '4.66')
# ('DONE with', 20, 'of', 24, 'of GEN', '12', 'with Fitness', '7.53')
# ('DONE with', 21, 'of', 24, 'of GEN', '12', 'with Fitness', '90.00')
# ('DONE with', 22, 'of', 24, 'of GEN', '12', 'with Fitness', '12.90')
# ('DONE with', 23, 'of', 24, 'of GEN', '12', 'with Fitness', '4.49')
# ('DONE with', 24, 'of', 24, 'of GEN', '12', 'with Fitness', '24.63')
#                                      prev_ob_models.Birgiolas2020.isolated_cells.TC2
# AfterHyperpolarizationAmplitudeTest                            [-1.0830240067022483]
# AfterHyperpolarizationTimeTest                                   -0.9581403328186623
# CellCapacitanceTest                                              -1.5585355134565362
# FISlopeTest                                                      -1.9861111111111112
# ISICVTest                                                        0.09546278897113691
# InputResistanceTest                                              0.18285177780006723
# MembraneTimeConstantTest                                         -1.9534883720930234
# ReboundSpikingTest                                                              -1.0
# RestingVoltageTest                                             -0.010444947741692875
# RheobaseTest                                                      0.6454567846927376
# SagVoltageTest                                                    0.7281620146868647
# SpikeAccommodationTest                                            0.6212914485165796
# SpikeAccommodationTimeConstantTest                               -0.8809212255890315
# SpikeAmplitudeTest                                            [-0.22359505563352658]
# SpikeHalfWidthTest                                               0.04999999999959148
# SpikeThresholdTest                                              [1.4925635729437416]
# model                                prev_ob_models.Birgiolas2020.isolated_cells.TC2
# 28.95% of range. Val: 0.65008402166 Low: 0.1 High: 2.0 ATTR: diam in ['apical', 'basal', 'axonal']
# 77.34% of range. Val: 9.7647450433 Low: 3.5 High: 11.6 ATTR: L in ['somatic']
# 96.77% of range. Val: 145.180351248 Low: 1.0 High: 150.0 ATTR: Ra in ['all']
# 7.63% of range. Val: 0.474002345938 Low: 0.1 High: 5.0 ATTR: cm in ['all']
# 13.72% of range. Val: 28.2314485361 Low: 20.0 High: 80.0 ATTR: ena in ['all']
# 67.50% of range. Val: -66.2505901358 Low: -100.0 High: -50.0 ATTR: ek in ['all']
# 51.04% of range. Val: -69.5821638003 Low: -90.0 High: -50.0 ATTR: e_pas in ['all']
# 67.73% of range. Val: 0.000270935036589 Low: 0 High: 0.0004 ATTR: g_pas in ['all']
# 5.36% of range. Val: 0.536196886339 Low: 0 High: 10 ATTR: sh_Na in ['all']
# 15.69% of range. Val: 47.9129693927 Low: 1 High: 300 ATTR: tau_CaPool in ['all']
# 80.64% of range. Val: 0.0806412230688 Low: 0 High: 0.1 ATTR: gbar_Na in ['all']
# 75.34% of range. Val: 0.150672696579 Low: 0 High: 0.2 ATTR: gbar_Kd in ['all']
# 73.50% of range. Val: 0.00146999040954 Low: 0 High: 0.002 ATTR: gbar_Kslow in ['all']
# 33.81% of range. Val: 0.00676267430155 Low: 0 High: 0.02 ATTR: gbar_KA in ['all']
# 29.55% of range. Val: 0.00472733745505 Low: 0 High: 0.016 ATTR: gbar_KCa in ['all']
# 49.82% of range. Val: 0.000498237152922 Low: 0 High: 0.001 ATTR: gbar_LCa in ['all']
# 96.57% of range. Val: -11.0304715857 Low: -40.0 High: -10.0 ATTR: eh in ['apical']
# 1.30% of range. Val: 7.78764864797e-07 Low: 0 High: 6e-05 ATTR: gbar_Ih in ['apical']
# 69.51% of range. Val: 0.0139014640956 Low: 0 High: 0.02 ATTR: gbar_CaT in ['apical']
# ('Best individual', [0.6500840216599895, 9.764745043302765, 145.18035124845895, 0.4740023459383019, 28.231448536057798, -66.25059013579343, -69.5821638002925, 0.0002709350365889211, 0.5361968863393589, 47.9129693926854, 0.08064122306879148, 0.15067269657887095, 0.0014699904095443425, 0.006762674301550519, 0.004727337455046674, 0.000498237152921818, -11.030471585656382, 7.787648647971102e-07, 0.013901464095629508])
# ('Best fitness:', 4.208624293141929)
# ('Generation', 12, 'out of', 50, 'COMPLETE')
# ('GEN', 13, 'Parents', 4, 'Elite', 12, 'DIV', 6, 'RND', 6, 'TOT NEW', 24)
# ('STARTED GEN', '13', 'size', 24)
# ('DONE with', 1, 'of', 24, 'of GEN', '13', 'with Fitness', '12.59')
# ('DONE with', 2, 'of', 24, 'of GEN', '13', 'with Fitness', '14.12')
# ('DONE with', 3, 'of', 24, 'of GEN', '13', 'with Fitness', '10.09')
# ('DONE with', 4, 'of', 24, 'of GEN', '13', 'with Fitness', '12769.26')
# ('DONE with', 5, 'of', 24, 'of GEN', '13', 'with Fitness', '14.68')
# ('DONE with', 6, 'of', 24, 'of GEN', '13', 'with Fitness', '18.99')
# ('DONE with', 7, 'of', 24, 'of GEN', '13', 'with Fitness', '15.27')
# ('DONE with', 8, 'of', 24, 'of GEN', '13', 'with Fitness', '7.29')
# ('DONE with', 9, 'of', 24, 'of GEN', '13', 'with Fitness', '9.04')
# ('DONE with', 10, 'of', 24, 'of GEN', '13', 'with Fitness', '5.45')
# ('DONE with', 11, 'of', 24, 'of GEN', '13', 'with Fitness', '8.97')
# ('DONE with', 12, 'of', 24, 'of GEN', '13', 'with Fitness', '14.41')
# ('DONE with', 13, 'of', 24, 'of GEN', '13', 'with Fitness', '4.46')
# ('DONE with', 14, 'of', 24, 'of GEN', '13', 'with Fitness', '7307.38')
# ('DONE with', 15, 'of', 24, 'of GEN', '13', 'with Fitness', '5.23')
# ('DONE with', 16, 'of', 24, 'of GEN', '13', 'with Fitness', '4.46')
# ('DONE with', 17, 'of', 24, 'of GEN', '13', 'with Fitness', '6.23')
# ('DONE with', 18, 'of', 24, 'of GEN', '13', 'with Fitness', '4.60')
# ('DONE with', 19, 'of', 24, 'of GEN', '13', 'with Fitness', '4.54')
# ('DONE with', 20, 'of', 24, 'of GEN', '13', 'with Fitness', '5.11')
# ('DONE with', 21, 'of', 24, 'of GEN', '13', 'with Fitness', '18.12')
# ('DONE with', 22, 'of', 24, 'of GEN', '13', 'with Fitness', '4.34')
# ('DONE with', 23, 'of', 24, 'of GEN', '13', 'with Fitness', '4.58')
# ('DONE with', 24, 'of', 24, 'of GEN', '13', 'with Fitness', '5.63')
#                                      prev_ob_models.Birgiolas2020.isolated_cells.TC2
# AfterHyperpolarizationAmplitudeTest                            [-1.0830240067022483]
# AfterHyperpolarizationTimeTest                                   -0.9581403328186623
# CellCapacitanceTest                                              -1.5585355134565362
# FISlopeTest                                                      -1.9861111111111112
# ISICVTest                                                        0.09546278897113691
# InputResistanceTest                                              0.18285177780006723
# MembraneTimeConstantTest                                         -1.9534883720930234
# ReboundSpikingTest                                                              -1.0
# RestingVoltageTest                                             -0.010444947741692875
# RheobaseTest                                                      0.6454567846927376
# SagVoltageTest                                                    0.7281620146868647
# SpikeAccommodationTest                                            0.6212914485165796
# SpikeAccommodationTimeConstantTest                               -0.8809212255890315
# SpikeAmplitudeTest                                            [-0.22359505563352658]
# SpikeHalfWidthTest                                               0.04999999999959148
# SpikeThresholdTest                                              [1.4925635729437416]
# model                                prev_ob_models.Birgiolas2020.isolated_cells.TC2
# 28.95% of range. Val: 0.65008402166 Low: 0.1 High: 2.0 ATTR: diam in ['apical', 'basal', 'axonal']
# 77.34% of range. Val: 9.7647450433 Low: 3.5 High: 11.6 ATTR: L in ['somatic']
# 96.77% of range. Val: 145.180351248 Low: 1.0 High: 150.0 ATTR: Ra in ['all']
# 7.63% of range. Val: 0.474002345938 Low: 0.1 High: 5.0 ATTR: cm in ['all']
# 13.72% of range. Val: 28.2314485361 Low: 20.0 High: 80.0 ATTR: ena in ['all']
# 67.50% of range. Val: -66.2505901358 Low: -100.0 High: -50.0 ATTR: ek in ['all']
# 51.04% of range. Val: -69.5821638003 Low: -90.0 High: -50.0 ATTR: e_pas in ['all']
# 67.73% of range. Val: 0.000270935036589 Low: 0 High: 0.0004 ATTR: g_pas in ['all']
# 5.36% of range. Val: 0.536196886339 Low: 0 High: 10 ATTR: sh_Na in ['all']
# 15.69% of range. Val: 47.9129693927 Low: 1 High: 300 ATTR: tau_CaPool in ['all']
# 80.64% of range. Val: 0.0806412230688 Low: 0 High: 0.1 ATTR: gbar_Na in ['all']
# 75.34% of range. Val: 0.150672696579 Low: 0 High: 0.2 ATTR: gbar_Kd in ['all']
# 73.50% of range. Val: 0.00146999040954 Low: 0 High: 0.002 ATTR: gbar_Kslow in ['all']
# 33.81% of range. Val: 0.00676267430155 Low: 0 High: 0.02 ATTR: gbar_KA in ['all']
# 29.55% of range. Val: 0.00472733745505 Low: 0 High: 0.016 ATTR: gbar_KCa in ['all']
# 49.82% of range. Val: 0.000498237152922 Low: 0 High: 0.001 ATTR: gbar_LCa in ['all']
# 96.57% of range. Val: -11.0304715857 Low: -40.0 High: -10.0 ATTR: eh in ['apical']
# 1.30% of range. Val: 7.78764864797e-07 Low: 0 High: 6e-05 ATTR: gbar_Ih in ['apical']
# 69.51% of range. Val: 0.0139014640956 Low: 0 High: 0.02 ATTR: gbar_CaT in ['apical']
# ('Best individual', [0.6500840216599895, 9.764745043302765, 145.18035124845895, 0.4740023459383019, 28.231448536057798, -66.25059013579343, -69.5821638002925, 0.0002709350365889211, 0.5361968863393589, 47.9129693926854, 0.08064122306879148, 0.15067269657887095, 0.0014699904095443425, 0.006762674301550519, 0.004727337455046674, 0.000498237152921818, -11.030471585656382, 7.787648647971102e-07, 0.013901464095629508])
# ('Best fitness:', 4.208624293141929)
# ('Generation', 13, 'out of', 50, 'COMPLETE')
# ('GEN', 14, 'Parents', 4, 'Elite', 12, 'DIV', 6, 'RND', 6, 'TOT NEW', 24)
# ('STARTED GEN', '14', 'size', 24)
# ('DONE with', 1, 'of', 24, 'of GEN', '14', 'with Fitness', '18.68')
# ('DONE with', 2, 'of', 24, 'of GEN', '14', 'with Fitness', '12.36')
# ('DONE with', 3, 'of', 24, 'of GEN', '14', 'with Fitness', '20.10')
# ('DONE with', 4, 'of', 24, 'of GEN', '14', 'with Fitness', '10.33')
# ('DONE with', 5, 'of', 24, 'of GEN', '14', 'with Fitness', '9.77')
# ('DONE with', 6, 'of', 24, 'of GEN', '14', 'with Fitness', '18.17')
# ('DONE with', 7, 'of', 24, 'of GEN', '14', 'with Fitness', '9.22')
# ('DONE with', 8, 'of', 24, 'of GEN', '14', 'with Fitness', '90.00')
# ('DONE with', 9, 'of', 24, 'of GEN', '14', 'with Fitness', '4.89')
# ('DONE with', 10, 'of', 24, 'of GEN', '14', 'with Fitness', '5.20')
# ('DONE with', 11, 'of', 24, 'of GEN', '14', 'with Fitness', '10.78')
# ('DONE with', 12, 'of', 24, 'of GEN', '14', 'with Fitness', '13.64')
# ('DONE with', 13, 'of', 24, 'of GEN', '14', 'with Fitness', '4.90')
# ('DONE with', 14, 'of', 24, 'of GEN', '14', 'with Fitness', '4.65')
# ('DONE with', 15, 'of', 24, 'of GEN', '14', 'with Fitness', '4.77')
# ('DONE with', 16, 'of', 24, 'of GEN', '14', 'with Fitness', '4.20')
# ('DONE with', 17, 'of', 24, 'of GEN', '14', 'with Fitness', '5.11')
# ('DONE with', 18, 'of', 24, 'of GEN', '14', 'with Fitness', '10.58')
# ('DONE with', 19, 'of', 24, 'of GEN', '14', 'with Fitness', '4.44')
# ('DONE with', 20, 'of', 24, 'of GEN', '14', 'with Fitness', '4.67')
# ('DONE with', 21, 'of', 24, 'of GEN', '14', 'with Fitness', '5.38')
# ('DONE with', 22, 'of', 24, 'of GEN', '14', 'with Fitness', '5.75')
# ('DONE with', 23, 'of', 24, 'of GEN', '14', 'with Fitness', '6.69')
# ('DONE with', 24, 'of', 24, 'of GEN', '14', 'with Fitness', '90.00')
#                                      prev_ob_models.Birgiolas2020.isolated_cells.TC2
# AfterHyperpolarizationAmplitudeTest                            [-1.2899838380392212]
# AfterHyperpolarizationTimeTest                                   -0.9467369037167049
# CellCapacitanceTest                                              -1.5572233957129733
# FISlopeTest                                                      -1.5694444444444444
# ISICVTest                                                        0.12566153382293357
# InputResistanceTest                                              0.15895140881303482
# MembraneTimeConstantTest                                         -1.9534883720930234
# ReboundSpikingTest                                                              -1.0
# RestingVoltageTest                                               -0.0769105346990362
# RheobaseTest                                                    -0.06775140311884008
# SagVoltageTest                                                    0.7242815182880111
# SpikeAccommodationTest                                            1.1042547433061753
# SpikeAccommodationTimeConstantTest                                0.8705086517408782
# SpikeAmplitudeTest                                             [0.11299087330732245]
# SpikeHalfWidthTest                                                1.2999999999988987
# SpikeThresholdTest                                                 [1.0632063915857]
# model                                prev_ob_models.Birgiolas2020.isolated_cells.TC2
# 28.95% of range. Val: 0.65008402166 Low: 0.1 High: 2.0 ATTR: diam in ['apical', 'basal', 'axonal']
# 77.36% of range. Val: 9.76625382023 Low: 3.5 High: 11.6 ATTR: L in ['somatic']
# 96.77% of range. Val: 145.180351248 Low: 1.0 High: 150.0 ATTR: Ra in ['all']
# 6.86% of range. Val: 0.436054525314 Low: 0.1 High: 5.0 ATTR: cm in ['all']
# 13.72% of range. Val: 28.2314485361 Low: 20.0 High: 80.0 ATTR: ena in ['all']
# 67.50% of range. Val: -66.2505901358 Low: -100.0 High: -50.0 ATTR: ek in ['all']
# 51.04% of range. Val: -69.5821638003 Low: -90.0 High: -50.0 ATTR: e_pas in ['all']
# 67.73% of range. Val: 0.000270935036589 Low: 0 High: 0.0004 ATTR: g_pas in ['all']
# 5.36% of range. Val: 0.536196886339 Low: 0 High: 10 ATTR: sh_Na in ['all']
# 3.02% of range. Val: 10.0354432702 Low: 1 High: 300 ATTR: tau_CaPool in ['all']
# 89.23% of range. Val: 0.0892333943417 Low: 0 High: 0.1 ATTR: gbar_Na in ['all']
# 75.34% of range. Val: 0.150672696579 Low: 0 High: 0.2 ATTR: gbar_Kd in ['all']
# 73.50% of range. Val: 0.00146999040954 Low: 0 High: 0.002 ATTR: gbar_Kslow in ['all']
# 36.93% of range. Val: 0.00738536373097 Low: 0 High: 0.02 ATTR: gbar_KA in ['all']
# 30.01% of range. Val: 0.00480190131898 Low: 0 High: 0.016 ATTR: gbar_KCa in ['all']
# 49.82% of range. Val: 0.000498237152922 Low: 0 High: 0.001 ATTR: gbar_LCa in ['all']
# 81.64% of range. Val: -15.5077861428 Low: -40.0 High: -10.0 ATTR: eh in ['apical']
# 0.42% of range. Val: 2.49105400483e-07 Low: 0 High: 6e-05 ATTR: gbar_Ih in ['apical']
# 69.51% of range. Val: 0.0139014640956 Low: 0 High: 0.02 ATTR: gbar_CaT in ['apical']
# ('Best individual', [0.6500840216599895, 9.766253820226583, 145.18035124845895, 0.4360545253143458, 28.231448536057798, -66.25059013579343, -69.5821638002925, 0.0002709350365889211, 0.5361968863393589, 10.035443270197067, 0.08923339434172924, 0.15067269657887095, 0.0014699904095443425, 0.007385363730973165, 0.004801901318984596, 0.000498237152921818, -15.507786142826568, 2.491054004831983e-07, 0.013901464095629508])
# ('Best fitness:', 4.201317727463162)
# ('Generation', 14, 'out of', 50, 'COMPLETE')
# ('GEN', 15, 'Parents', 4, 'Elite', 12, 'DIV', 6, 'RND', 6, 'TOT NEW', 24)
# ('STARTED GEN', '15', 'size', 24)
