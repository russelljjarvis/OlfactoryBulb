# %%
import os; os.chdir('..')
import multiprocessing
from prev_ob_models.Birgiolas2020.fitting import *
# Out:
# /home/justas/anaconda2/envs/p27/lib/python2.7/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Could not load NEURONBackend

# %%
types = ['gc', 'mc', 'tc']

for type in types:
    for i in range(1,6):
        fitter = CellFitter(cell_type=type, fitting_model_class="prev_ob_models.Birgiolas2020.isolated_cells."+type.upper()+str(i))
        fitter.clear_cache()
        fitter.best = []
        df, score = fitter.get_best_score()
        print(fitter.fitting_model_class, "SCORE", score["model_score"])
        print(df.transpose())
        fitter.parameter_report(fitter.import_model_class(fitter.fitting_model_class)().param_values)
# Out:
# ('Starting gc FITTER for model:', 'prev_ob_models.Birgiolas2020.isolated_cells.GC1')
# ('prev_ob_models.Birgiolas2020.isolated_cells.GC1', 'SCORE', 3.6390524430328814)
#                               prev_ob_models.Birgiolas2020.isolated_cells.GC1
# AfterDepolarizationDepthTest                           0.00043013247737633264
# AfterDepolarizationTimeTest                               -1.6363636363636358
# CellCapacitanceTest                                       -0.5127547518703688
# FISlopeTest                                               -2.0303030303030303
# InputResistanceTest                                        0.5080314499843865
# MembraneTimeConstantTest                                   0.8863636363636364
# ReboundSpikingTest                                                        0.0
# RestingVoltageTest                                         0.6852657588439125
# RheobaseTest                                               0.7669810509158402
# SagVoltageTest                                             1.9589599290643576
# SpikeAccommodationTest                                    -0.4082465809348843
# SpikeAmplitudeTest                                      [0.23312790043313628]
# SpikeHalfWidthTest                                     -5.796532844358712e-13
# SpikeThresholdTest                                      [0.14087328369491195]
# model                         prev_ob_models.Birgiolas2020.isolated_cells.GC1
# 35.99% of range. Val: 1.14369979806 Low: 0.1 High: 3.0 ATTR: diam in ['apical']
# 29.25% of range. Val: 38.6358851212 Low: 5.0 High: 120.0 ATTR: Ra in ['all']
# 12.37% of range. Val: 1.32462442442 Low: 0.1 High: 10.0 ATTR: cm in ['all']
# 29.11% of range. Val: 21.644563059 Low: 10.0 High: 50.0 ATTR: ena in ['all']
# 30.77% of range. Val: -78.4595897679 Low: -100.0 High: -30.0 ATTR: ek in ['all']
# 31.65% of range. Val: -84.1769716277 Low: -100.0 High: -50.0 ATTR: e_pas in ['all']
# 1.76% of range. Val: 3.52324610199e-05 Low: 0 High: 0.002 ATTR: g_pas in ['all']
# 48.07% of range. Val: 4.80689728702 Low: 0 High: 10 ATTR: sh_Na in ['all']
# 64.31% of range. Val: 0.0643060955999 Low: 0 High: 0.1 ATTR: gbar_Na in ['all']
# 36.91% of range. Val: 0.147633496964 Low: 0 High: 0.4 ATTR: gbar_Kd in ['all']
# 1.37% of range. Val: 0.00548325621865 Low: 0 High: 0.4 ATTR: gbar_KA in ['somatic']
# 86.56% of range. Val: -16.7180860768 Low: -60.0 High: -10.0 ATTR: eh in ['somatic']
# 1.16% of range. Val: 1.15538746694e-06 Low: 0 High: 0.0001 ATTR: gbar_Ih in ['somatic']
# 54.10% of range. Val: 0.0703331611112 Low: 0 High: 0.13 ATTR: gbar_KM in ['somatic']
# ('Starting gc FITTER for model:', 'prev_ob_models.Birgiolas2020.isolated_cells.GC2')
# /home/justas/anaconda2/envs/p27/lib/python2.7/site-packages/deap/creator.py:141: RuntimeWarning: A class named 'FitnessMin' has already been created and it will be overwritten. Consider deleting previous creation of that class or rename it.
#   RuntimeWarning)
# /home/justas/anaconda2/envs/p27/lib/python2.7/site-packages/deap/creator.py:141: RuntimeWarning: A class named 'Individual' has already been created and it will be overwritten. Consider deleting previous creation of that class or rename it.
#   RuntimeWarning)
# ('prev_ob_models.Birgiolas2020.isolated_cells.GC2', 'SCORE', 3.4361565124298883)
#                               prev_ob_models.Birgiolas2020.isolated_cells.GC2
# AfterDepolarizationDepthTest                            0.0004070521279402328
# AfterDepolarizationTimeTest                               0.24431818181817921
# CellCapacitanceTest                                       -0.5955105537678627
# FISlopeTest                                               -1.2121212121212122
# InputResistanceTest                                       -0.4083645276383939
# MembraneTimeConstantTest                                 -0.25000000000000006
# ReboundSpikingTest                                                        0.0
# RestingVoltageTest                                       -0.07256013635619041
# RheobaseTest                                                0.653052918191078
# SagVoltageTest                                              2.955764764199244
# SpikeAccommodationTest                                     0.4625346901017586
# SpikeAmplitudeTest                                       [0.4248449299586614]
# SpikeHalfWidthTest                                     -5.796532844358712e-13
# SpikeThresholdTest                                      [0.36280547902793686]
# model                         prev_ob_models.Birgiolas2020.isolated_cells.GC2
# 14.43% of range. Val: 0.518568993697 Low: 0.1 High: 3.0 ATTR: diam in ['apical']
# 15.07% of range. Val: 22.3310965754 Low: 5.0 High: 120.0 ATTR: Ra in ['all']
# 39.39% of range. Val: 3.99915510662 Low: 0.1 High: 10.0 ATTR: cm in ['all']
# 86.37% of range. Val: 44.5483693991 Low: 10.0 High: 50.0 ATTR: ena in ['all']
# 64.05% of range. Val: -55.1652809008 Low: -100.0 High: -30.0 ATTR: ek in ['all']
# 21.41% of range. Val: -89.2946356025 Low: -100.0 High: -50.0 ATTR: e_pas in ['all']
# 9.18% of range. Val: 0.000183688093668 Low: 0 High: 0.002 ATTR: g_pas in ['all']
# 27.76% of range. Val: 2.77600360135 Low: 0 High: 10 ATTR: sh_Na in ['all']
# 74.65% of range. Val: 0.0746515631013 Low: 0 High: 0.1 ATTR: gbar_Na in ['all']
# 53.03% of range. Val: 0.212110960208 Low: 0 High: 0.4 ATTR: gbar_Kd in ['all']
# 12.35% of range. Val: 0.049412958656 Low: 0 High: 0.4 ATTR: gbar_KA in ['somatic']
# 13.12% of range. Val: -53.4411385168 Low: -60.0 High: -10.0 ATTR: eh in ['somatic']
# 2.55% of range. Val: 2.54852853405e-06 Low: 0 High: 0.0001 ATTR: gbar_Ih in ['somatic']
# 5.12% of range. Val: 0.00666063040933 Low: 0 High: 0.13 ATTR: gbar_KM in ['somatic']
# ('Starting gc FITTER for model:', 'prev_ob_models.Birgiolas2020.isolated_cells.GC3')
# ('prev_ob_models.Birgiolas2020.isolated_cells.GC3', 'SCORE', 3.836260810677486)
#                               prev_ob_models.Birgiolas2020.isolated_cells.GC3
# AfterDepolarizationDepthTest                          -0.00019683616716292818
# AfterDepolarizationTimeTest                               -1.4829545454545394
# CellCapacitanceTest                                       -0.7228242789744563
# FISlopeTest                                               -0.9090909090909091
# InputResistanceTest                                       0.06245339678341265
# MembraneTimeConstantTest                                   0.2045454545454545
# ReboundSpikingTest                                                        0.0
# RestingVoltageTest                                        -1.1510861149849596
# RheobaseTest                                               0.6940911537903199
# SagVoltageTest                                              2.951278455420285
# SpikeAccommodationTest                                                    0.0
# SpikeAmplitudeTest                                       [0.1838607645680419]
# SpikeHalfWidthTest                                         0.6578947368423297
# SpikeThresholdTest                                      [0.37369203239831833]
# model                         prev_ob_models.Birgiolas2020.isolated_cells.GC3
# 28.51% of range. Val: 0.926901441192 Low: 0.1 High: 3.0 ATTR: diam in ['apical']
# 56.89% of range. Val: 70.4217157366 Low: 5.0 High: 120.0 ATTR: Ra in ['all']
# 18.90% of range. Val: 1.97134227462 Low: 0.1 High: 10.0 ATTR: cm in ['all']
# 92.77% of range. Val: 47.107745396 Low: 10.0 High: 50.0 ATTR: ena in ['all']
# 56.30% of range. Val: -60.5888373035 Low: -100.0 High: -30.0 ATTR: ek in ['all']
# 8.44% of range. Val: -95.7809271486 Low: -100.0 High: -50.0 ATTR: e_pas in ['all']
# 3.03% of range. Val: 6.06121468541e-05 Low: 0 High: 0.002 ATTR: g_pas in ['all']
# 16.25% of range. Val: 1.62519397568 Low: 0 High: 10 ATTR: sh_Na in ['all']
# 28.14% of range. Val: 0.0281390285658 Low: 0 High: 0.1 ATTR: gbar_Na in ['all']
# 20.43% of range. Val: 0.0817222051988 Low: 0 High: 0.4 ATTR: gbar_Kd in ['all']
# 4.90% of range. Val: 0.0196047217167 Low: 0 High: 0.4 ATTR: gbar_KA in ['somatic']
# 34.55% of range. Val: -42.7246497632 Low: -60.0 High: -10.0 ATTR: eh in ['somatic']
# 0.41% of range. Val: 4.05643859646e-07 Low: 0 High: 0.0001 ATTR: gbar_Ih in ['somatic']
# 2.69% of range. Val: 0.00349892285241 Low: 0 High: 0.13 ATTR: gbar_KM in ['somatic']
# ('Starting gc FITTER for model:', 'prev_ob_models.Birgiolas2020.isolated_cells.GC4')
# ('prev_ob_models.Birgiolas2020.isolated_cells.GC4', 'SCORE', 3.728146575661205)
#                               prev_ob_models.Birgiolas2020.isolated_cells.GC4
# AfterDepolarizationDepthTest                            0.0014140678883904911
# AfterDepolarizationTimeTest                                -1.619318181818181
# CellCapacitanceTest                                       -0.4973512919680828
# FISlopeTest                                               -1.2727272727272727
# InputResistanceTest                                      -0.10612162781643891
# MembraneTimeConstantTest                                  0.12878787878787873
# ReboundSpikingTest                                                        0.0
# RestingVoltageTest                                       0.014903259755228777
# RheobaseTest                                               0.2057432948959927
# SagVoltageTest                                              3.005202726655848
# SpikeAccommodationTest                                                    0.0
# SpikeAmplitudeTest                                       [0.5090316354974522]
# SpikeHalfWidthTest                                     -5.796532844358712e-13
# SpikeThresholdTest                                       [0.2212088047462693]
# model                         prev_ob_models.Birgiolas2020.isolated_cells.GC4
# 10.19% of range. Val: 0.395605700449 Low: 0.1 High: 3.0 ATTR: diam in ['apical']
# 8.43% of range. Val: 14.7001785531 Low: 5.0 High: 120.0 ATTR: Ra in ['all']
# 55.59% of range. Val: 5.60347610547 Low: 0.1 High: 10.0 ATTR: cm in ['all']
# 97.13% of range. Val: 48.8534100183 Low: 10.0 High: 50.0 ATTR: ena in ['all']
# 58.38% of range. Val: -59.1373154112 Low: -100.0 High: -30.0 ATTR: ek in ['all']
# 22.10% of range. Val: -88.9505513914 Low: -100.0 High: -50.0 ATTR: e_pas in ['all']
# 9.92% of range. Val: 0.000198492016019 Low: 0 High: 0.002 ATTR: g_pas in ['all']
# 3.32% of range. Val: 0.332377877394 Low: 0 High: 10 ATTR: sh_Na in ['all']
# 90.18% of range. Val: 0.0901798331035 Low: 0 High: 0.1 ATTR: gbar_Na in ['all']
# 93.05% of range. Val: 0.372208228929 Low: 0 High: 0.4 ATTR: gbar_Kd in ['all']
# 5.17% of range. Val: 0.0206758667844 Low: 0 High: 0.4 ATTR: gbar_KA in ['somatic']
# 60.56% of range. Val: -29.7189125918 Low: -60.0 High: -10.0 ATTR: eh in ['somatic']
# 22.67% of range. Val: 2.26746196472e-05 Low: 0 High: 0.0001 ATTR: gbar_Ih in ['somatic']
# 1.70% of range. Val: 0.00220582010316 Low: 0 High: 0.13 ATTR: gbar_KM in ['somatic']
# ('Starting gc FITTER for model:', 'prev_ob_models.Birgiolas2020.isolated_cells.GC5')
# ('prev_ob_models.Birgiolas2020.isolated_cells.GC5', 'SCORE', 3.599211212583726)
#                               prev_ob_models.Birgiolas2020.isolated_cells.GC5
# AfterDepolarizationDepthTest                            0.0020537912204048325
# AfterDepolarizationTimeTest                              -0.03409090909090877
# CellCapacitanceTest                                       -0.8512863055783685
# FISlopeTest                                               -1.0606060606060606
# InputResistanceTest                                         0.566894084878331
# MembraneTimeConstantTest                                   0.5833333333333333
# ReboundSpikingTest                                                        0.0
# RestingVoltageTest                                         0.5790186364959371
# RheobaseTest                                             -0.17043696493882743
# SagVoltageTest                                              2.954054642971292
# SpikeAccommodationTest                                                    0.0
# SpikeAmplitudeTest                                       [0.2653459916251961]
# SpikeHalfWidthTest                                         0.6578947368423297
# SpikeThresholdTest                                       [0.9208422880255813]
# model                         prev_ob_models.Birgiolas2020.isolated_cells.GC5
# 19.35% of range. Val: 0.661217629738 Low: 0.1 High: 3.0 ATTR: diam in ['apical']
# 46.17% of range. Val: 58.0940039581 Low: 5.0 High: 120.0 ATTR: Ra in ['all']
# 33.28% of range. Val: 3.39439238842 Low: 0.1 High: 10.0 ATTR: cm in ['all']
# 68.17% of range. Val: 37.2690405004 Low: 10.0 High: 50.0 ATTR: ena in ['all']
# 72.13% of range. Val: -49.5064738839 Low: -100.0 High: -30.0 ATTR: ek in ['all']
# 27.49% of range. Val: -86.2571195938 Low: -100.0 High: -50.0 ATTR: e_pas in ['all']
# 4.85% of range. Val: 9.69203866932e-05 Low: 0 High: 0.002 ATTR: g_pas in ['all']
# 83.08% of range. Val: 8.30761121249 Low: 0 High: 10 ATTR: sh_Na in ['all']
# 93.36% of range. Val: 0.0933559175441 Low: 0 High: 0.1 ATTR: gbar_Na in ['all']
# 36.81% of range. Val: 0.147227372309 Low: 0 High: 0.4 ATTR: gbar_Kd in ['all']
# 10.46% of range. Val: 0.0418206750512 Low: 0 High: 0.4 ATTR: gbar_KA in ['somatic']
# 4.52% of range. Val: -57.7385836483 Low: -60.0 High: -10.0 ATTR: eh in ['somatic']
# 0.66% of range. Val: 6.56570790638e-07 Low: 0 High: 0.0001 ATTR: gbar_Ih in ['somatic']
# 0.83% of range. Val: 0.00107774008019 Low: 0 High: 0.13 ATTR: gbar_KM in ['somatic']
# ('Starting mc FITTER for model:', 'prev_ob_models.Birgiolas2020.isolated_cells.MC1')
# ('prev_ob_models.Birgiolas2020.isolated_cells.MC1', 'SCORE', 3.626551514692352)
#                                      prev_ob_models.Birgiolas2020.isolated_cells.MC1
# AfterHyperpolarizationAmplitudeTest                           [0.037655246338952585]
# AfterHyperpolarizationTimeTest                                  -0.03721240731472401
# CellCapacitanceTest                                              -0.4909672193133616
# FISlopeTest                                                      0.05263157894736842
# ISICVTest                                                       -0.27044983246982846
# InputResistanceTest                                            -0.013407326266424907
# MembraneTimeConstantTest                                         -0.8555895287038536
# ReboundSpikingTest                                                               0.0
# RestingVoltageTest                                              -0.10211620747423211
# RheobaseTest                                                      0.9477803807952717
# SagVoltageTest                                                    0.7674879518251413
# SpikeAccommodationTest                                          -0.02969868312388958
# SpikeAccommodationTimeConstantTest                                2.9380271449804685
# SpikeAmplitudeTest                                              [0.4202434026709759]
# SpikeHalfWidthTest                                               -0.7715517241383497
# SpikePeakTest                                                     0.9607488876861585
# SpikeThresholdTest                                              [0.5237598266995493]
# model                                prev_ob_models.Birgiolas2020.isolated_cells.MC1
# 63.75% of range. Val: 3.22389443491 Low: 0.1 High: 5.0 ATTR: diam in ['apical', 'basal', 'axonal']
# 1.22% of range. Val: 2.81865928031 Low: 1.0 High: 150.0 ATTR: Ra in ['all']
# 12.24% of range. Val: 0.332610430032 Low: 0.1 High: 2.0 ATTR: cm in ['all']
# 11.67% of range. Val: 27.0037817822 Low: 20.0 High: 80.0 ATTR: ena in ['all']
# 70.13% of range. Val: -64.9373291407 Low: -100.0 High: -50.0 ATTR: ek in ['all']
# 41.87% of range. Val: -73.2520477592 Low: -90.0 High: -50.0 ATTR: e_pas in ['all']
# 53.40% of range. Val: 2.13613162311e-05 Low: 0 High: 4e-05 ATTR: g_pas in ['all']
# 37.65% of range. Val: 3.76535811521 Low: 0 High: 10 ATTR: sh_Na in ['all']
# 1.11% of range. Val: 4.30802485594 Low: 1 High: 300 ATTR: tau_CaPool in ['all']
# 31.87% of range. Val: 0.0318695262923 Low: 0 High: 0.1 ATTR: gbar_Na in ['all']
# 23.80% of range. Val: 0.0237952012855 Low: 0 High: 0.1 ATTR: gbar_Kd in ['all']
# 71.86% of range. Val: 0.000718575007398 Low: 0 High: 0.001 ATTR: gbar_Kslow in ['all']
# 12.63% of range. Val: 0.00252611784602 Low: 0 High: 0.02 ATTR: gbar_KA in ['all']
# 5.91% of range. Val: 0.000945516354456 Low: 0 High: 0.016 ATTR: gbar_KCa in ['all']
# 33.73% of range. Val: 0.000168633619029 Low: 0 High: 0.0005 ATTR: gbar_LCa in ['all']
# 13.00% of range. Val: -36.0996242685 Low: -40.0 High: -10.0 ATTR: eh in ['apical']
# 12.19% of range. Val: 3.65564860782e-07 Low: 0 High: 3e-06 ATTR: gbar_Ih in ['apical']
# 22.14% of range. Val: 0.00442892025119 Low: 0 High: 0.02 ATTR: gbar_CaT in ['apical']
# ('Starting mc FITTER for model:', 'prev_ob_models.Birgiolas2020.isolated_cells.MC2')
# ('prev_ob_models.Birgiolas2020.isolated_cells.MC2', 'SCORE', 3.9031654995826637)
#                                      prev_ob_models.Birgiolas2020.isolated_cells.MC2
# AfterHyperpolarizationAmplitudeTest                           [-0.11171522973904219]
# AfterHyperpolarizationTimeTest                                     1.341261621401503
# CellCapacitanceTest                                             -0.29940480971963773
# FISlopeTest                                                       0.4473684210526316
# ISICVTest                                                        -1.0885545724188541
# InputResistanceTest                                             0.010617976358161918
# MembraneTimeConstantTest                                         -0.6640574726606181
# ReboundSpikingTest                                                               0.5
# RestingVoltageTest                                                1.8953705050688916
# RheobaseTest                                                      -1.309566373780451
# SagVoltageTest                                                    0.7467753533028082
# SpikeAccommodationTest                                          -0.05884204117394829
# SpikeAccommodationTimeConstantTest                                0.5361339902721673
# SpikeAmplitudeTest                                              [0.5034829595334972]
# SpikeHalfWidthTest                                                0.9956896551719343
# SpikePeakTest                                                      1.514110119450341
# SpikeThresholdTest                                               [1.250611320717072]
# model                                prev_ob_models.Birgiolas2020.isolated_cells.MC2
# 45.94% of range. Val: 2.35114594387 Low: 0.1 High: 5.0 ATTR: diam in ['apical', 'basal', 'axonal']
# 84.42% of range. Val: 126.792401569 Low: 1.0 High: 150.0 ATTR: Ra in ['all']
# 21.94% of range. Val: 0.516951613266 Low: 0.1 High: 2.0 ATTR: cm in ['all']
# 27.84% of range. Val: 36.7014644379 Low: 20.0 High: 80.0 ATTR: ena in ['all']
# 80.12% of range. Val: -59.9392586072 Low: -100.0 High: -50.0 ATTR: ek in ['all']
# 66.40% of range. Val: -63.4410286887 Low: -90.0 High: -50.0 ATTR: e_pas in ['all']
# 62.72% of range. Val: 2.50898263807e-05 Low: 0 High: 4e-05 ATTR: g_pas in ['all']
# 34.86% of range. Val: 3.48586703433 Low: 0 High: 10 ATTR: sh_Na in ['all']
# 2.18% of range. Val: 7.50732159567 Low: 1 High: 300 ATTR: tau_CaPool in ['all']
# 13.63% of range. Val: 0.0136309719234 Low: 0 High: 0.1 ATTR: gbar_Na in ['all']
# 1.15% of range. Val: 0.00114557385843 Low: 0 High: 0.1 ATTR: gbar_Kd in ['all']
# 39.00% of range. Val: 0.000389983499581 Low: 0 High: 0.001 ATTR: gbar_Kslow in ['all']
# 16.25% of range. Val: 0.00325015915466 Low: 0 High: 0.02 ATTR: gbar_KA in ['all']
# 23.61% of range. Val: 0.00377715639597 Low: 0 High: 0.016 ATTR: gbar_KCa in ['all']
# 88.67% of range. Val: 0.000443326104187 Low: 0 High: 0.0005 ATTR: gbar_LCa in ['all']
# 80.30% of range. Val: -15.910465735 Low: -40.0 High: -10.0 ATTR: eh in ['apical']
# 6.05% of range. Val: 1.81612417562e-07 Low: 0 High: 3e-06 ATTR: gbar_Ih in ['apical']
# 39.56% of range. Val: 0.00791249529004 Low: 0 High: 0.02 ATTR: gbar_CaT in ['apical']
# ('Starting mc FITTER for model:', 'prev_ob_models.Birgiolas2020.isolated_cells.MC3')
# ('prev_ob_models.Birgiolas2020.isolated_cells.MC3', 'SCORE', 4.076663038125182)
#                                      prev_ob_models.Birgiolas2020.isolated_cells.MC3
# AfterHyperpolarizationAmplitudeTest                             [1.4174607122593865]
# AfterHyperpolarizationTimeTest                                  -0.11301982122039926
# CellCapacitanceTest                                               0.8617362858734989
# FISlopeTest                                                      0.05263157894736842
# ISICVTest                                                        -0.7605683796550717
# InputResistanceTest                                              -0.6461231051514168
# MembraneTimeConstantTest                                          -0.314321307735265
# ReboundSpikingTest                                                               0.0
# RestingVoltageTest                                                1.3035978844521436
# RheobaseTest                                                      0.1899266073937012
# SagVoltageTest                                                    0.7741606465285225
# SpikeAccommodationTest                                         -0.060047844151681976
# SpikeAccommodationTimeConstantTest                                 2.966311322227177
# SpikeAmplitudeTest                                            [-0.04410789424152837]
# SpikeHalfWidthTest                                               0.26293103448360405
# SpikePeakTest                                                     0.7779214148616459
# SpikeThresholdTest                                              [0.9713411452365325]
# model                                prev_ob_models.Birgiolas2020.isolated_cells.MC3
# 49.84% of range. Val: 2.54231682834 Low: 0.1 High: 5.0 ATTR: diam in ['apical', 'basal', 'axonal']
# 14.26% of range. Val: 22.2443874217 Low: 1.0 High: 150.0 ATTR: Ra in ['all']
# 28.92% of range. Val: 0.649505943508 Low: 0.1 High: 2.0 ATTR: cm in ['all']
# 9.19% of range. Val: 25.5147986226 Low: 20.0 High: 80.0 ATTR: ena in ['all']
# 60.39% of range. Val: -69.8071292017 Low: -100.0 High: -50.0 ATTR: ek in ['all']
# 81.45% of range. Val: -57.4204078176 Low: -90.0 High: -50.0 ATTR: e_pas in ['all']
# 48.69% of range. Val: 1.94762226493e-05 Low: 0 High: 4e-05 ATTR: g_pas in ['all']
# 43.44% of range. Val: 4.34360014792 Low: 0 High: 10 ATTR: sh_Na in ['all']
# 1.89% of range. Val: 6.65941008135 Low: 1 High: 300 ATTR: tau_CaPool in ['all']
# 44.29% of range. Val: 0.0442881146904 Low: 0 High: 0.1 ATTR: gbar_Na in ['all']
# 14.23% of range. Val: 0.01422973515 Low: 0 High: 0.1 ATTR: gbar_Kd in ['all']
# 16.48% of range. Val: 0.000164829360405 Low: 0 High: 0.001 ATTR: gbar_Kslow in ['all']
# 26.91% of range. Val: 0.00538299077675 Low: 0 High: 0.02 ATTR: gbar_KA in ['all']
# 7.86% of range. Val: 0.0012568660047 Low: 0 High: 0.016 ATTR: gbar_KCa in ['all']
# 21.95% of range. Val: 0.000109745813112 Low: 0 High: 0.0005 ATTR: gbar_LCa in ['all']
# 36.77% of range. Val: -28.9700569257 Low: -40.0 High: -10.0 ATTR: eh in ['apical']
# 21.52% of range. Val: 6.45500119024e-07 Low: 0 High: 3e-06 ATTR: gbar_Ih in ['apical']
# 12.34% of range. Val: 0.00246882982798 Low: 0 High: 0.02 ATTR: gbar_CaT in ['apical']
# ('Starting mc FITTER for model:', 'prev_ob_models.Birgiolas2020.isolated_cells.MC4')
# ('prev_ob_models.Birgiolas2020.isolated_cells.MC4', 'SCORE', 3.948852753949319)
#                                      prev_ob_models.Birgiolas2020.isolated_cells.MC4
# AfterHyperpolarizationAmplitudeTest                             [0.1754496898765888]
# AfterHyperpolarizationTimeTest                                    0.5752432572486934
# CellCapacitanceTest                                              0.07352061102990999
# FISlopeTest                                                     -0.34210526315789475
# ISICVTest                                                         0.2745958290008004
# InputResistanceTest                                             0.058401847609618626
# MembraneTimeConstantTest                                        -0.34153651919722183
# ReboundSpikingTest                                                               0.0
# RestingVoltageTest                                               0.12104121690117808
# RheobaseTest                                                      0.6285695671151211
# SagVoltageTest                                                    0.7644246132531681
# SpikeAccommodationTest                                          -0.01904985469308512
# SpikeAccommodationTimeConstantTest                                 3.003827620381387
# SpikeAmplitudeTest                                             [0.01391791788345736]
# SpikeHalfWidthTest                                               -1.5043103448266801
# SpikePeakTest                                                      1.095194127865962
# SpikeThresholdTest                                              [1.1974206058992913]
# model                                prev_ob_models.Birgiolas2020.isolated_cells.MC4
# 20.17% of range. Val: 1.08828276606 Low: 0.1 High: 5.0 ATTR: diam in ['apical', 'basal', 'axonal']
# 5.35% of range. Val: 8.97791641085 Low: 1.0 High: 150.0 ATTR: Ra in ['all']
# 27.93% of range. Val: 0.630745344826 Low: 0.1 High: 2.0 ATTR: cm in ['all']
# 41.35% of range. Val: 44.8111596662 Low: 20.0 High: 80.0 ATTR: ena in ['all']
# 77.61% of range. Val: -61.193413141 Low: -100.0 High: -50.0 ATTR: ek in ['all']
# 43.07% of range. Val: -72.7720592722 Low: -90.0 High: -50.0 ATTR: e_pas in ['all']
# 75.01% of range. Val: 3.00050663591e-05 Low: 0 High: 4e-05 ATTR: g_pas in ['all']
# 12.27% of range. Val: 1.22731677605 Low: 0 High: 10 ATTR: sh_Na in ['all']
# 2.53% of range. Val: 8.57738871414 Low: 1 High: 300 ATTR: tau_CaPool in ['all']
# 9.75% of range. Val: 0.00974510358871 Low: 0 High: 0.1 ATTR: gbar_Na in ['all']
# 16.81% of range. Val: 0.0168142741058 Low: 0 High: 0.1 ATTR: gbar_Kd in ['all']
# 86.30% of range. Val: 0.000863016189101 Low: 0 High: 0.001 ATTR: gbar_Kslow in ['all']
# 14.95% of range. Val: 0.00298994424636 Low: 0 High: 0.02 ATTR: gbar_KA in ['all']
# 10.77% of range. Val: 0.0017233830355 Low: 0 High: 0.016 ATTR: gbar_KCa in ['all']
# 75.17% of range. Val: 0.000375867516456 Low: 0 High: 0.0005 ATTR: gbar_LCa in ['all']
# 66.33% of range. Val: -20.1017584557 Low: -40.0 High: -10.0 ATTR: eh in ['apical']
# 32.33% of range. Val: 9.69971109159e-07 Low: 0 High: 3e-06 ATTR: gbar_Ih in ['apical']
# 5.78% of range. Val: 0.00115590092254 Low: 0 High: 0.02 ATTR: gbar_CaT in ['apical']
# ('Starting mc FITTER for model:', 'prev_ob_models.Birgiolas2020.isolated_cells.MC5')
# ('prev_ob_models.Birgiolas2020.isolated_cells.MC5', 'SCORE', 3.3152560659679104)
#                                      prev_ob_models.Birgiolas2020.isolated_cells.MC5
# AfterHyperpolarizationAmplitudeTest                            [-0.0842979900939449]
# AfterHyperpolarizationTimeTest                                   0.34810481314048597
# CellCapacitanceTest                                            -0.016566774158164266
# FISlopeTest                                                      0.05263157894736842
# ISICVTest                                                         0.1548043535286971
# InputResistanceTest                                               0.2821214479896947
# MembraneTimeConstantTest                                        -0.22822171156143767
# ReboundSpikingTest                                                               0.0
# RestingVoltageTest                                              -0.06479666859830868
# RheobaseTest                                                      0.3729925294302069
# SagVoltageTest                                                    0.8033096866012128
# SpikeAccommodationTest                                          -0.05572027859771893
# SpikeAccommodationTimeConstantTest                                 3.000667836088192
# SpikeAmplitudeTest                                            [-0.21737347557677872]
# SpikeHalfWidthTest                                                0.3706896551722807
# SpikePeakTest                                                     0.4241340313707585
# SpikeThresholdTest                                              [0.7373334768638938]
# model                                prev_ob_models.Birgiolas2020.isolated_cells.MC5
# 23.41% of range. Val: 1.24715927038 Low: 0.1 High: 5.0 ATTR: diam in ['apical', 'basal', 'axonal']
# 59.43% of range. Val: 89.5473166605 Low: 1.0 High: 150.0 ATTR: Ra in ['all']
# 45.14% of range. Val: 0.957632110475 Low: 0.1 High: 2.0 ATTR: cm in ['all']
# 5.27% of range. Val: 23.1636614561 Low: 20.0 High: 80.0 ATTR: ena in ['all']
# 73.12% of range. Val: -63.4388411105 Low: -100.0 High: -50.0 ATTR: ek in ['all']
# 37.36% of range. Val: -75.0575135103 Low: -90.0 High: -50.0 ATTR: e_pas in ['all']
# 91.43% of range. Val: 3.6573312736e-05 Low: 0 High: 4e-05 ATTR: g_pas in ['all']
# 26.57% of range. Val: 2.65707719874 Low: 0 High: 10 ATTR: sh_Na in ['all']
# 2.90% of range. Val: 9.66685748359 Low: 1 High: 300 ATTR: tau_CaPool in ['all']
# 61.51% of range. Val: 0.0615091616917 Low: 0 High: 0.1 ATTR: gbar_Na in ['all']
# 37.59% of range. Val: 0.03759175149 Low: 0 High: 0.1 ATTR: gbar_Kd in ['all']
# 47.60% of range. Val: 0.000475984706304 Low: 0 High: 0.001 ATTR: gbar_Kslow in ['all']
# 21.11% of range. Val: 0.00422267765112 Low: 0 High: 0.02 ATTR: gbar_KA in ['all']
# 48.52% of range. Val: 0.00776370232831 Low: 0 High: 0.016 ATTR: gbar_KCa in ['all']
# 1.92% of range. Val: 9.59973773846e-06 Low: 0 High: 0.0005 ATTR: gbar_LCa in ['all']
# 78.77% of range. Val: -16.3698835291 Low: -40.0 High: -10.0 ATTR: eh in ['apical']
# 65.00% of range. Val: 1.95001307901e-06 Low: 0 High: 3e-06 ATTR: gbar_Ih in ['apical']
# 51.37% of range. Val: 0.0102744663893 Low: 0 High: 0.02 ATTR: gbar_CaT in ['apical']
# ('Starting tc FITTER for model:', 'prev_ob_models.Birgiolas2020.isolated_cells.TC1')
# ('prev_ob_models.Birgiolas2020.isolated_cells.TC1', 'SCORE', 3.4638370259424334)
#                                      prev_ob_models.Birgiolas2020.isolated_cells.TC1
# AfterHyperpolarizationAmplitudeTest                            [-0.5497892927577254]
# AfterHyperpolarizationTimeTest                                   -0.9522388059701451
# CellCapacitanceTest                                              -0.7608616264585896
# FISlopeTest                                                      -1.6388888888888888
# ISICVTest                                                    -0.00013897473442125739
# InputResistanceTest                                               0.3448765279479658
# MembraneTimeConstantTest                                         -0.6744186046511629
# ReboundSpikingTest                                                              -1.0
# RestingVoltageTest                                               -0.1729370971150049
# RheobaseTest                                                    -0.13060339527921275
# SagVoltageTest                                                    0.9483694417462797
# SpikeAccommodationTest                                             1.057591623036649
# SpikeAccommodationTimeConstantTest                                -0.876999057391418
# SpikeAmplitudeTest                                              [0.8636031254060196]
# SpikeHalfWidthTest                                               0.04999999999959148
# SpikeThresholdTest                                              [1.5388910305575954]
# model                                prev_ob_models.Birgiolas2020.isolated_cells.TC1
# 53.68% of range. Val: 2.73044418588 Low: 0.1 High: 5.0 ATTR: diam in ['apical', 'basal', 'axonal']
# 60.83% of range. Val: 91.6411082119 Low: 1.0 High: 150.0 ATTR: Ra in ['all']
# 13.26% of range. Val: 0.749738700771 Low: 0.1 High: 5.0 ATTR: cm in ['all']
# 28.06% of range. Val: 36.8359783386 Low: 20.0 High: 80.0 ATTR: ena in ['all']
# 67.47% of range. Val: -66.266842775 Low: -100.0 High: -50.0 ATTR: ek in ['all']
# 42.25% of range. Val: -73.1000477361 Low: -90.0 High: -50.0 ATTR: e_pas in ['all']
# 13.77% of range. Val: 5.50821117834e-05 Low: 0 High: 0.0004 ATTR: g_pas in ['all']
# 8.04% of range. Val: 0.803938182556 Low: 0 High: 10 ATTR: sh_Na in ['all']
# 2.24% of range. Val: 7.71104991958 Low: 1 High: 300 ATTR: tau_CaPool in ['all']
# 69.18% of range. Val: 0.0691839256782 Low: 0 High: 0.1 ATTR: gbar_Na in ['all']
# 92.62% of range. Val: 0.0926231305088 Low: 0 High: 0.1 ATTR: gbar_Kd in ['all']
# 62.23% of range. Val: 0.00124466368598 Low: 0 High: 0.002 ATTR: gbar_Kslow in ['all']
# 72.00% of range. Val: 0.0144001999144 Low: 0 High: 0.02 ATTR: gbar_KA in ['all']
# 11.06% of range. Val: 0.00177003111041 Low: 0 High: 0.016 ATTR: gbar_KCa in ['all']
# 59.29% of range. Val: 0.000592914432028 Low: 0 High: 0.001 ATTR: gbar_LCa in ['all']
# 76.09% of range. Val: -17.1739006072 Low: -40.0 High: -10.0 ATTR: eh in ['apical']
# 11.05% of range. Val: 3.31409893808e-06 Low: 0 High: 3e-05 ATTR: gbar_Ih in ['apical']
# 60.60% of range. Val: 0.0121199135142 Low: 0 High: 0.02 ATTR: gbar_CaT in ['apical']
# ('Starting tc FITTER for model:', 'prev_ob_models.Birgiolas2020.isolated_cells.TC2')
# ('prev_ob_models.Birgiolas2020.isolated_cells.TC2', 'SCORE', 3.1143285162749184)
#                                      prev_ob_models.Birgiolas2020.isolated_cells.TC2
# AfterHyperpolarizationAmplitudeTest                             [1.2970604504226946]
# AfterHyperpolarizationTimeTest                                   -0.9668325041459335
# CellCapacitanceTest                                              -0.7461969396712874
# FISlopeTest                                                      -1.1527777777777775
# ISICVTest                                                         -0.915906383321269
# InputResistanceTest                                             0.023761587053023957
# MembraneTimeConstantTest                                         -0.7906976744186048
# ReboundSpikingTest                                                              -1.0
# RestingVoltageTest                                              0.042070116037284895
# RheobaseTest                                                    -0.02956437101069732
# SagVoltageTest                                                     0.725855829135489
# SpikeAccommodationTest                                            0.5340314136125653
# SpikeAccommodationTimeConstantTest                              -0.19271760430060195
# SpikeAmplitudeTest                                              [0.9869928837555567]
# SpikeHalfWidthTest                                               0.04999999999959148
# SpikeThresholdTest                                              [0.9502934222566471]
# model                                prev_ob_models.Birgiolas2020.isolated_cells.TC2
# 75.21% of range. Val: 3.78546290058 Low: 0.1 High: 5.0 ATTR: diam in ['apical', 'basal', 'axonal']
# 59.60% of range. Val: 89.7966939676 Low: 1.0 High: 150.0 ATTR: Ra in ['all']
# 4.41% of range. Val: 0.315856598226 Low: 0.1 High: 5.0 ATTR: cm in ['all']
# 13.66% of range. Val: 28.1978532316 Low: 20.0 High: 80.0 ATTR: ena in ['all']
# 51.91% of range. Val: -74.046248165 Low: -100.0 High: -50.0 ATTR: ek in ['all']
# 84.03% of range. Val: -56.3871425833 Low: -90.0 High: -50.0 ATTR: e_pas in ['all']
# 3.35% of range. Val: 1.3397520148e-05 Low: 0 High: 0.0004 ATTR: g_pas in ['all']
# 12.66% of range. Val: 1.26631215766 Low: 0 High: 10 ATTR: sh_Na in ['all']
# 0.30% of range. Val: 1.89608644687 Low: 1 High: 300 ATTR: tau_CaPool in ['all']
# 95.76% of range. Val: 0.0957626674996 Low: 0 High: 0.1 ATTR: gbar_Na in ['all']
# 95.66% of range. Val: 0.095662328848 Low: 0 High: 0.1 ATTR: gbar_Kd in ['all']
# 38.97% of range. Val: 0.000779451515047 Low: 0 High: 0.002 ATTR: gbar_Kslow in ['all']
# 1.91% of range. Val: 0.000381165878237 Low: 0 High: 0.02 ATTR: gbar_KA in ['all']
# 69.30% of range. Val: 0.0110879983643 Low: 0 High: 0.016 ATTR: gbar_KCa in ['all']
# 58.41% of range. Val: 0.000584111472522 Low: 0 High: 0.001 ATTR: gbar_LCa in ['all']
# 92.28% of range. Val: -12.3145369766 Low: -40.0 High: -10.0 ATTR: eh in ['apical']
# 0.16% of range. Val: 4.68615741318e-08 Low: 0 High: 3e-05 ATTR: gbar_Ih in ['apical']
# 10.92% of range. Val: 0.0021843751014 Low: 0 High: 0.02 ATTR: gbar_CaT in ['apical']
# ('Starting tc FITTER for model:', 'prev_ob_models.Birgiolas2020.isolated_cells.TC3')
# ('prev_ob_models.Birgiolas2020.isolated_cells.TC3', 'SCORE', 3.4801273328587423)
#                                      prev_ob_models.Birgiolas2020.isolated_cells.TC3
# AfterHyperpolarizationAmplitudeTest                            [-0.8911288596602085]
# AfterHyperpolarizationTimeTest                                    -0.957310223078155
# CellCapacitanceTest                                              -0.7685165156780015
# FISlopeTest                                                      -0.9444444444444444
# ISICVTest                                                        -0.7034459977281298
# InputResistanceTest                                               0.1811333420076729
# MembraneTimeConstantTest                                         -0.7906976744186048
# ReboundSpikingTest                                                              -1.0
# RestingVoltageTest                                             -0.002731981652229788
# RheobaseTest                                                     -0.6635645847849254
# SagVoltageTest                                                    0.7856673802195925
# SpikeAccommodationTest                                           0.48638036957368097
# SpikeAccommodationTimeConstantTest                              -0.31831974353610176
# SpikeAmplitudeTest                                              [0.4866871236475147]
# SpikeHalfWidthTest                                               0.04999999999959148
# SpikeThresholdTest                                               [2.265046378428136]
# model                                prev_ob_models.Birgiolas2020.isolated_cells.TC3
# 24.35% of range. Val: 1.29321681222 Low: 0.1 High: 5.0 ATTR: diam in ['apical', 'basal', 'axonal']
# 51.88% of range. Val: 78.2971055194 Low: 1.0 High: 150.0 ATTR: Ra in ['all']
# 40.76% of range. Val: 2.09740659726 Low: 0.1 High: 5.0 ATTR: cm in ['all']
# 23.43% of range. Val: 34.0552252744 Low: 20.0 High: 80.0 ATTR: ena in ['all']
# 73.89% of range. Val: -63.0562278954 Low: -100.0 High: -50.0 ATTR: ek in ['all']
# 49.06% of range. Val: -70.3758399712 Low: -90.0 High: -50.0 ATTR: e_pas in ['all']
# 46.60% of range. Val: 0.000186403548414 Low: 0 High: 0.0004 ATTR: g_pas in ['all']
# 1.83% of range. Val: 0.182907957783 Low: 0 High: 10 ATTR: sh_Na in ['all']
# 1.53% of range. Val: 5.56953349106 Low: 1 High: 300 ATTR: tau_CaPool in ['all']
# 92.55% of range. Val: 0.0925484421635 Low: 0 High: 0.1 ATTR: gbar_Na in ['all']
# 97.84% of range. Val: 0.0978373848067 Low: 0 High: 0.1 ATTR: gbar_Kd in ['all']
# 98.56% of range. Val: 0.00197123971055 Low: 0 High: 0.002 ATTR: gbar_Kslow in ['all']
# 67.11% of range. Val: 0.0134214984725 Low: 0 High: 0.02 ATTR: gbar_KA in ['all']
# 7.88% of range. Val: 0.00126004467578 Low: 0 High: 0.016 ATTR: gbar_KCa in ['all']
# 64.39% of range. Val: 0.000643937167701 Low: 0 High: 0.001 ATTR: gbar_LCa in ['all']
# 27.03% of range. Val: -31.891616784 Low: -40.0 High: -10.0 ATTR: eh in ['apical']
# 18.56% of range. Val: 5.56786276812e-06 Low: 0 High: 3e-05 ATTR: gbar_Ih in ['apical']
# 71.80% of range. Val: 0.0143603248376 Low: 0 High: 0.02 ATTR: gbar_CaT in ['apical']
# ('Starting tc FITTER for model:', 'prev_ob_models.Birgiolas2020.isolated_cells.TC4')
# ('prev_ob_models.Birgiolas2020.isolated_cells.TC4', 'SCORE', 3.231291501090366)
#                                      prev_ob_models.Birgiolas2020.isolated_cells.TC4
# AfterHyperpolarizationAmplitudeTest                              [0.465999454533324]
# AfterHyperpolarizationTimeTest                                   -0.9646213377556639
# CellCapacitanceTest                                              -0.6088217711924392
# FISlopeTest                                                      -1.3611111111111112
# ISICVTest                                                        -0.5821306421550337
# InputResistanceTest                                             -0.21530062637543876
# MembraneTimeConstantTest                                         -0.7906976744186048
# ReboundSpikingTest                                                              -1.0
# RestingVoltageTest                                             -0.010683963016923164
# RheobaseTest                                                      0.5307111445070332
# SagVoltageTest                                                    0.9251274423114089
# SpikeAccommodationTest                                            0.2804932612227917
# SpikeAccommodationTimeConstantTest                               -0.8083294223352239
# SpikeAmplitudeTest                                               [1.420011967941057]
# SpikeHalfWidthTest                                               0.05000000000181193
# SpikeThresholdTest                                              [1.0822375531739215]
# model                                prev_ob_models.Birgiolas2020.isolated_cells.TC4
# 72.68% of range. Val: 3.66126800278 Low: 0.1 High: 5.0 ATTR: diam in ['apical', 'basal', 'axonal']
# 4.37% of range. Val: 7.5139906345 Low: 1.0 High: 150.0 ATTR: Ra in ['all']
# 4.72% of range. Val: 0.331416215171 Low: 0.1 High: 5.0 ATTR: cm in ['all']
# 19.25% of range. Val: 31.5502329728 Low: 20.0 High: 80.0 ATTR: ena in ['all']
# 58.41% of range. Val: -70.795059365 Low: -100.0 High: -50.0 ATTR: ek in ['all']
# 58.37% of range. Val: -66.6528731754 Low: -90.0 High: -50.0 ATTR: e_pas in ['all']
# 5.15% of range. Val: 2.05825462315e-05 Low: 0 High: 0.0004 ATTR: g_pas in ['all']
# 16.82% of range. Val: 1.68190400885 Low: 0 High: 10 ATTR: sh_Na in ['all']
# 42.08% of range. Val: 126.814400562 Low: 1 High: 300 ATTR: tau_CaPool in ['all']
# 87.19% of range. Val: 0.0871889147943 Low: 0 High: 0.1 ATTR: gbar_Na in ['all']
# 82.95% of range. Val: 0.0829534889555 Low: 0 High: 0.1 ATTR: gbar_Kd in ['all']
# 49.83% of range. Val: 0.00099664965887 Low: 0 High: 0.002 ATTR: gbar_Kslow in ['all']
# 25.86% of range. Val: 0.00517175819134 Low: 0 High: 0.02 ATTR: gbar_KA in ['all']
# 7.88% of range. Val: 0.00126041787226 Low: 0 High: 0.016 ATTR: gbar_KCa in ['all']
# 12.46% of range. Val: 0.000124589546353 Low: 0 High: 0.001 ATTR: gbar_LCa in ['all']
# 20.87% of range. Val: -33.7392080559 Low: -40.0 High: -10.0 ATTR: eh in ['apical']
# 7.09% of range. Val: 2.12846829948e-06 Low: 0 High: 3e-05 ATTR: gbar_Ih in ['apical']
# 1.47% of range. Val: 0.000293758972865 Low: 0 High: 0.02 ATTR: gbar_CaT in ['apical']
# ('Starting tc FITTER for model:', 'prev_ob_models.Birgiolas2020.isolated_cells.TC5')
# ('List', 'axonal', 'not found in cell', 'TC5', 'Skipping list...')
# ('prev_ob_models.Birgiolas2020.isolated_cells.TC5', 'SCORE', 3.3998474584334053)
#                                      prev_ob_models.Birgiolas2020.isolated_cells.TC5
# AfterHyperpolarizationAmplitudeTest                           [-0.49270274742010617]
# AfterHyperpolarizationTimeTest                                   -0.9609360604385442
# CellCapacitanceTest                                             0.020870762800494057
# FISlopeTest                                                                     -1.5
# ISICVTest                                                       -0.29917620488089386
# InputResistanceTest                                               0.3352148579877328
# MembraneTimeConstantTest                                          0.7209302325581396
# ReboundSpikingTest                                                              -1.0
# RestingVoltageTest                                                 0.704729221020315
# RheobaseTest                                                      0.6617851104228366
# SagVoltageTest                                                     0.721920985782506
# SpikeAccommodationTest                                            0.0881425413299803
# SpikeAccommodationTimeConstantTest                                0.6031041956904756
# SpikeAmplitudeTest                                               [0.355129408341288]
# SpikeHalfWidthTest                                               0.05000000000181193
# SpikeThresholdTest                                              [2.1130224436431595]
# model                                prev_ob_models.Birgiolas2020.isolated_cells.TC5
# ('List', 'axonal', 'not found in cell', 'TC5', 'Skipping list...')
# 88.71% of range. Val: 4.44693746291 Low: 0.1 High: 5.0 ATTR: diam in ['apical', 'basal', 'axonal']
# 71.93% of range. Val: 108.169431423 Low: 1.0 High: 150.0 ATTR: Ra in ['all']
# 8.39% of range. Val: 0.51096058952 Low: 0.1 High: 5.0 ATTR: cm in ['all']
# 12.33% of range. Val: 27.3983806944 Low: 20.0 High: 80.0 ATTR: ena in ['all']
# 70.36% of range. Val: -64.818622541 Low: -100.0 High: -50.0 ATTR: ek in ['all']
# 46.46% of range. Val: -71.417803497 Low: -90.0 High: -50.0 ATTR: e_pas in ['all']
# 2.74% of range. Val: 1.09769481904e-05 Low: 0 High: 0.0004 ATTR: g_pas in ['all']
# 15.20% of range. Val: 1.51980456159 Low: 0 High: 10 ATTR: sh_Na in ['all']
# 4.96% of range. Val: 15.8418551898 Low: 1 High: 300 ATTR: tau_CaPool in ['all']
# 61.17% of range. Val: 0.0611722168525 Low: 0 High: 0.1 ATTR: gbar_Na in ['all']
# 44.02% of range. Val: 0.0440199045578 Low: 0 High: 0.1 ATTR: gbar_Kd in ['all']
# 82.68% of range. Val: 0.00165354991185 Low: 0 High: 0.002 ATTR: gbar_Kslow in ['all']
# 73.38% of range. Val: 0.0146750793439 Low: 0 High: 0.02 ATTR: gbar_KA in ['all']
# 40.70% of range. Val: 0.00651221002717 Low: 0 High: 0.016 ATTR: gbar_KCa in ['all']
# 26.35% of range. Val: 0.000263465176607 Low: 0 High: 0.001 ATTR: gbar_LCa in ['all']
# 52.26% of range. Val: -24.322850064 Low: -40.0 High: -10.0 ATTR: eh in ['apical']
# 0.02% of range. Val: 4.84249245578e-09 Low: 0 High: 3e-05 ATTR: gbar_Ih in ['apical']
# 3.58% of range. Val: 0.000716447060532 Low: 0 High: 0.02 ATTR: gbar_CaT in ['apical']
