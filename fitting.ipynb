# %%
import multiprocessing
from prev_ob_models.Birgiolas2020.fitting import *
# Out:
# /home/justas/anaconda2/envs/p27/lib/python2.7/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Could not load NEURONBackend

# %%
import sys
mc_id = sys.argv[1] if sys.argv[1].isdigit() else 1

# %%
fitter = FitterMC("prev_ob_models.Birgiolas2020.isolated_cells.MC"+str(mc_id))
# Out:
# ('Starting FITTER for', 'prev_ob_models.Birgiolas2020.isolated_cells.MC1')

# %%
#fitter.top = [fitter.best]

# %%
cpus = multiprocessing.cpu_count()
fitter.fit(int(cpus*1.5), 120)
# Out:
# ('STARTED GEN', 'ZERO')
# ('DONE with', 1, 'of', 1, 'of GEN', 'ZERO', 'with Fitness', '4.22')
# ('STARTED GEN', '1')

# %%
df, score = fitter.get_best_score()
df
# Out:
#                                                 AfterHyperpolarizationAmplitudeTest  \
# prev_ob_models.Birgiolas2020.isolated_cells.MC1                [1.6092924246063611]
#
#                                                 AfterHyperpolarizationTimeTest  \
# prev_ob_models.Birgiolas2020.isolated_cells.MC1             0.7034071770954855
#
#                                                 CellCapacitanceTest  \
# prev_ob_models.Birgiolas2020.isolated_cells.MC1    1.09397820656824
#
#                                                          FISlopeTest  \
# prev_ob_models.Birgiolas2020.isolated_cells.MC1  -0.7368421052631579
#
#                                                           ISICVTest  \
# prev_ob_models.Birgiolas2020.isolated_cells.MC1  -0.779206274307834
#
#                                                  InputResistanceTest  \
# prev_ob_models.Birgiolas2020.isolated_cells.MC1  -0.3738436159029639
#
#                                                 MembraneTimeConstantTest  \
# prev_ob_models.Birgiolas2020.isolated_cells.MC1     -0.01631419905150194
#
#                                                 ReboundSpikingTest  \
# prev_ob_models.Birgiolas2020.isolated_cells.MC1                0.0
#
#                                                 RestingVoltageTest  \
# prev_ob_models.Birgiolas2020.isolated_cells.MC1  1.220523323242281
#
#                                                        RheobaseTest  \
# prev_ob_models.Birgiolas2020.isolated_cells.MC1  0.7258491740227709
#
#                                                      SagVoltageTest  \
# prev_ob_models.Birgiolas2020.isolated_cells.MC1  0.8269699259126412
#
#                                                 SpikeAccommodationTest  \
# prev_ob_models.Birgiolas2020.isolated_cells.MC1    0.11860208211462125
#
#                                                 SpikeAccommodationTimeConstantTest  \
# prev_ob_models.Birgiolas2020.isolated_cells.MC1                 2.9369165658001446
#
#                                                    SpikeAmplitudeTest  \
# prev_ob_models.Birgiolas2020.isolated_cells.MC1  [0.8568893939928983]
#
#                                                  SpikeHalfWidthTest  \
# prev_ob_models.Birgiolas2020.isolated_cells.MC1  1.2413793103456363
#
#                                                       SpikePeakTest  \
# prev_ob_models.Birgiolas2020.isolated_cells.MC1  0.6221560342533736
